# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.signal 
import pywt
from sklearn.ensemble import RandomForestClassifier as rf
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,precision_score
import statistics
from sklearn.svm import SVC
import six
import sys
sys.modules['sklearn.externals.six'] = six
from scipy.special import logsumexp
sys.modules['scipy.misc.logsumexp'] = logsumexp
from seqlearn import hmm
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

# %%
def carf(row):
    for i,elect in row.items():
        elect-=statistics.mean(row)
        row[i]= elect
    return row

# %%
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
for i in range(1):
        labels=[]
        try_label=[]
        try_data={
            "1st":[],
            "2nd":[],
            "3rd":[],
            "4th":[],
            "5th":[],
            "6th":[],
            "7th":[],
            "8th":[],
            "9th":[],
            "10th":[],
            "11th":[],
            "12th":[],
            "13th":[],
            "14th":[],
            "username":[],
            "label":[]
        }
        gamma_data1={
            "1stgamma":[],
            "2ndgamma":[],
            "3rdgamma":[],
            "4thgamma":[],
            "5thgamma":[],
            "6thgamma":[],
            "7thgamma":[],
            "8thgamma":[],
            "9thgamma":[],
            "10thgamma":[],
            "11thgamma":[],
            "12thgamma":[],
            "13thgamma":[],
            "14thgamma":[],
        "username":[],
            "label":[]}
        beta_data1={
            "1stbeta":[],
            "2ndbeta":[],
            "3rdbeta":[],
            "4thbeta":[],
            "5thbeta":[],
            "6thbeta":[],
            "7thbeta":[],
            "8thbeta":[],
            "9thbeta":[],
            "10thbeta":[],
            "11thbeta":[],
            "12thbeta":[],
            "13thbeta":[],
            "14thbeta":[],
        "username":[],
            "label":[]}
        alpha_data1={
            "1stalpha":[],
            "2ndalpha":[],
            "3rdalpha":[],
            "4thalpha":[],
            "5thalpha":[],
            "6thalpha":[],
            "7thalpha":[],
            "8thalpha":[],
            "9thalpha":[],
            "10thalpha":[],
            "11thalpha":[],
            "12thalpha":[],
            "13thalpha":[],
            "14thalpha":[],
        "username":[],
            "label":[]}
        theta_data1={
            "1sttheta":[],
            "2ndtheta":[],
            "3rdtheta":[],
            "4ththeta":[],
            "5ththeta":[],
            "6ththeta":[],
            "7ththeta":[],
            "8ththeta":[],
            "9ththeta":[],
            "10ththeta":[],
            "11ththeta":[],
            "12ththeta":[],
            "13ththeta":[],
            "14ththeta":[],
        "username":[],
            "label":[]}
        delta_data1={
            "1stdelta":[],
            "2nddelta":[],
            "3rddelta":[],
            "4thdelta":[],
            "5thdelta":[],
            "6thdelta":[],
            "7thdelta":[],
            "8thdelta":[],
            "9thdelta":[],
            "10thdelta":[],
            "11thdelta":[],
            "12thdelta":[],
            "13thdelta":[],
            "14thdelta":[],
            "username":[],
            "label":[]}


        for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :

            for i in range(42):
                try:
                    user_data = pd.read_csv("25-users/"+name+str(i+1)+".txt", sep=" ", header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
                    user_label = pd.read_csv("labels/"+name+str(i+1)+".lab",header=None,names=["label"])
                except:
                    continue
                labels.append(user_label.values.tolist()[0][0])

                user_data.apply(lambda row : carf(row), axis = 1)

                first_electrode = user_data['1st']
                second_electrode = user_data['2nd']
                third_electrode = user_data['3rd']
                fourth_electrode = user_data['4th']
                fifth_electrode = user_data['5th']
                sixth_electrode = user_data['6th']
                seventh_electrode = user_data['7th']
                eighth_electrode = user_data['8th']
                nineth_electrode = user_data['9th']
                tenth_electrode = user_data['10th']
                eleventh_electrode = user_data['11th']
                twelveth_electrode = user_data['12th']
                thirteenth_electrode = user_data['13th']
                fouteenth_electrode = user_data['14th']

                s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
                s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
                s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
                s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
                s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
                s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
                s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
                s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
                s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
                s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
                s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
                s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
                s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
                s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)
                
                
                
                try_data["label"].append(user_label.values.tolist()[0][0])
                try_data["username"].append(name)

                gamma_data1["label"].append(user_label.values.tolist()[0][0])
                gamma_data1["username"].append(name)

                beta_data1["label"].append(user_label.values.tolist()[0][0])
                beta_data1["username"].append(name)

                alpha_data1["label"].append(user_label.values.tolist()[0][0])
                alpha_data1["username"].append(name)

                theta_data1["label"].append(user_label.values.tolist()[0][0])
                theta_data1["username"].append(name)

                delta_data1["label"].append(user_label.values.tolist()[0][0])
                delta_data1["username"].append(name)

                try_data["1st"].append(s_golay_filtered_signal1[0*128:(0+1)*128])
                try_data["2nd"].append(s_golay_filtered_signal2[0*128:(0+1)*128])
                try_data["3rd"].append(s_golay_filtered_signal3[0*128:(0+1)*128])
                try_data["4th"].append(s_golay_filtered_signal4[0*128:(0+1)*128])
                try_data["5th"].append(s_golay_filtered_signal5[0*128:(0+1)*128])
                try_data["6th"].append(s_golay_filtered_signal6[0*128:(0+1)*128])
                try_data["7th"].append(s_golay_filtered_signal7[0*128:(0+1)*128])
                try_data["8th"].append(s_golay_filtered_signal8[0*128:(0+1)*128])
                try_data["9th"].append(s_golay_filtered_signal9[0*128:(0+1)*128])
                try_data["10th"].append(s_golay_filtered_signal10[0*128:(0+1)*128])
                try_data["11th"].append(s_golay_filtered_signal11[0*128:(0+1)*128])
                try_data["12th"].append(s_golay_filtered_signal12[0*128:(0+1)*128])
                try_data["13th"].append(s_golay_filtered_signal13[0*128:(0+1)*128])
                try_data["14th"].append(s_golay_filtered_signal14[0*128:(0+1)*128])

                cA1, d11 = pywt.dwt(s_golay_filtered_signal1[0*128:(0+1)*128], 'db4')
                cA12, d12 = pywt.dwt(cA1, 'db4')
                cA13, d13 = pywt.dwt(cA12, 'db4')
                a14, d14 = pywt.dwt(cA13, 'db4')
                gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
                beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
                alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
                theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
                delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
                gamma_data1['1stgamma'].append(gamma_RMS1)
                beta_data1['1stbeta'].append(beta_RMS1)
                alpha_data1['1stalpha'].append(alpha_RMS1)
                theta_data1['1sttheta'].append(theta_RMS1)
                delta_data1['1stdelta'].append(delta_RMS1)

                cA2, d21 = pywt.dwt(s_golay_filtered_signal2[0*128:(0+1)*128], 'db4')
                cA22, d22 = pywt.dwt(cA2, 'db4')
                cA23, d23 = pywt.dwt(cA22, 'db4')
                a24, d24 = pywt.dwt(cA23, 'db4')
                gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
                beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
                alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
                theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
                delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
                gamma_data1['2ndgamma'].append(gamma_RMS2)
                beta_data1['2ndbeta'].append(beta_RMS2)
                alpha_data1['2ndalpha'].append(alpha_RMS2)
                theta_data1['2ndtheta'].append(theta_RMS2)
                delta_data1['2nddelta'].append(delta_RMS2)

                cA3, d31 = pywt.dwt(s_golay_filtered_signal3[0*128:(0+1)*128], 'db4')
                cA32, d32 = pywt.dwt(cA3, 'db4')
                cA33, d33 = pywt.dwt(cA32, 'db4')
                a34, d34 = pywt.dwt(cA33, 'db4')
                gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
                beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
                alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
                theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
                delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
                gamma_data1['3rdgamma'].append(gamma_RMS3)
                beta_data1['3rdbeta'].append(beta_RMS3)
                alpha_data1['3rdalpha'].append(alpha_RMS3)
                theta_data1['3rdtheta'].append(theta_RMS3)
                delta_data1['3rddelta'].append(delta_RMS3)

                cA4, d41 = pywt.dwt(s_golay_filtered_signal4[0*128:(0+1)*128], 'db4')
                cA42, d42 = pywt.dwt(cA4, 'db4')
                cA43, d43 = pywt.dwt(cA42, 'db4')
                a44, d44 = pywt.dwt(cA43, 'db4')
                gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
                beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
                alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
                theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
                delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
                gamma_data1['4thgamma'].append(gamma_RMS4)
                beta_data1['4thbeta'].append(beta_RMS4)
                alpha_data1['4thalpha'].append(alpha_RMS4)
                theta_data1['4ththeta'].append(theta_RMS4)
                delta_data1['4thdelta'].append(delta_RMS4)

                cA5, d51 = pywt.dwt(s_golay_filtered_signal5[0*128:(0+1)*128], 'db4')
                cA52, d52 = pywt.dwt(cA5, 'db4')
                cA53, d53 = pywt.dwt(cA52, 'db4')
                a54, d54 = pywt.dwt(cA53, 'db4')
                gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
                beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
                alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
                theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
                delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
                gamma_data1['5thgamma'].append(gamma_RMS5)
                beta_data1['5thbeta'].append(beta_RMS5)
                alpha_data1['5thalpha'].append(alpha_RMS5)
                theta_data1['5ththeta'].append(theta_RMS5)
                delta_data1['5thdelta'].append(delta_RMS5)

                cA6, d61 = pywt.dwt(s_golay_filtered_signal6[0*128:(0+1)*128], 'db4')
                cA62, d62 = pywt.dwt(cA6, 'db4')
                cA63, d63 = pywt.dwt(cA62, 'db4')
                a64, d64 = pywt.dwt(cA63, 'db4')
                gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
                beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
                alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
                theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
                delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
                gamma_data1['6thgamma'].append(gamma_RMS6)
                beta_data1['6thbeta'].append(beta_RMS6)
                alpha_data1['6thalpha'].append(alpha_RMS6)
                theta_data1['6ththeta'].append(theta_RMS6)
                delta_data1['6thdelta'].append(delta_RMS6)


                cA7, d71 = pywt.dwt(s_golay_filtered_signal7[0*128:(0+1)*128], 'db4')
                cA72, d72 = pywt.dwt(cA7, 'db4')
                cA73, d73 = pywt.dwt(cA72, 'db4')
                a74, d74 = pywt.dwt(cA73, 'db4')
                gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
                beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
                alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
                theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
                delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
                gamma_data1['7thgamma'].append(gamma_RMS7)
                beta_data1['7thbeta'].append(beta_RMS7)
                alpha_data1['7thalpha'].append(alpha_RMS7)
                theta_data1['7ththeta'].append(theta_RMS7)
                delta_data1['7thdelta'].append(delta_RMS7)

                cA8, d81 = pywt.dwt(s_golay_filtered_signal8[0*128:(0+1)*128], 'db4')
                cA82, d82 = pywt.dwt(cA8, 'db4')
                cA83, d83 = pywt.dwt(cA82, 'db4')
                a84, d84 = pywt.dwt(cA83, 'db4')
                gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
                beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
                alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
                theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
                delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
                gamma_data1['8thgamma'].append(gamma_RMS8)
                beta_data1['8thbeta'].append(beta_RMS8)
                alpha_data1['8thalpha'].append(alpha_RMS8)
                theta_data1['8ththeta'].append(theta_RMS8)
                delta_data1['8thdelta'].append(delta_RMS8)

                cA9, d91 = pywt.dwt(s_golay_filtered_signal9[0*128:(0+1)*128], 'db4')
                cA92, d92 = pywt.dwt(cA9, 'db4')
                cA93, d93 = pywt.dwt(cA92, 'db4')
                a94, d94 = pywt.dwt(cA93, 'db4')
                gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
                beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
                alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
                theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
                delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
                gamma_data1['9thgamma'].append(gamma_RMS9)
                beta_data1['9thbeta'].append(beta_RMS9)
                alpha_data1['9thalpha'].append(alpha_RMS9)
                theta_data1['9ththeta'].append(theta_RMS9)
                delta_data1['9thdelta'].append(delta_RMS9)

                cA10, d101 = pywt.dwt(s_golay_filtered_signal10[0*128:(0+1)*128], 'db4')
                cA102, d102 = pywt.dwt(cA10, 'db4')
                cA103, d103 = pywt.dwt(cA102, 'db4')
                a104, d104 = pywt.dwt(cA103, 'db4')
                gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
                beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
                alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
                theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
                delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
                gamma_data1['10thgamma'].append(gamma_RMS10)
                beta_data1['10thbeta'].append(beta_RMS10)
                alpha_data1['10thalpha'].append(alpha_RMS10)
                theta_data1['10ththeta'].append(theta_RMS10)
                delta_data1['10thdelta'].append(delta_RMS10)

                cA11, d111 = pywt.dwt(s_golay_filtered_signal11[0*128:(0+1)*128], 'db4')
                cA112, d112 = pywt.dwt(cA11, 'db4')
                cA113, d113 = pywt.dwt(cA112, 'db4')
                a114, d114 = pywt.dwt(cA113, 'db4')
                gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
                beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
                alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
                theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
                delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
                gamma_data1['11thgamma'].append(gamma_RMS11)
                beta_data1['11thbeta'].append(beta_RMS11)
                alpha_data1['11thalpha'].append(alpha_RMS11)
                theta_data1['11ththeta'].append(theta_RMS11)
                delta_data1['11thdelta'].append(delta_RMS11)

                cA12, d121 = pywt.dwt(s_golay_filtered_signal12[0*128:(0+1)*128], 'db4')
                cA122, d122 = pywt.dwt(cA12, 'db4')
                cA123, d123 = pywt.dwt(cA122, 'db4')
                a124, d124 = pywt.dwt(cA123, 'db4')
                gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
                beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
                alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
                theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
                delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
                gamma_data1['12thgamma'].append(gamma_RMS12)
                beta_data1['12thbeta'].append(beta_RMS12)
                alpha_data1['12thalpha'].append(alpha_RMS12)
                theta_data1['12ththeta'].append(theta_RMS12)
                delta_data1['12thdelta'].append(delta_RMS12)

                cA13, d131 = pywt.dwt(s_golay_filtered_signal13[0*128:(0+1)*128], 'db4')
                cA132, d132 = pywt.dwt(cA13, 'db4')
                cA133, d133 = pywt.dwt(cA132, 'db4')
                a134, d134 = pywt.dwt(cA133, 'db4')
                gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
                beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
                alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
                theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
                delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
                gamma_data1['13thgamma'].append(gamma_RMS13)
                beta_data1['13thbeta'].append(beta_RMS13)
                alpha_data1['13thalpha'].append(alpha_RMS13)
                theta_data1['13ththeta'].append(theta_RMS13)
                delta_data1['13thdelta'].append(delta_RMS13)

                cA14, d141 = pywt.dwt(s_golay_filtered_signal14[0*128:(0+1)*128], 'db4')
                cA142, d142 = pywt.dwt(cA14, 'db4')
                cA143, d143 = pywt.dwt(cA142, 'db4')
                a144, d144 = pywt.dwt(cA143, 'db4')
                gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
                beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
                alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
                theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
                delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
                gamma_data1['14thgamma'].append(gamma_RMS14)
                beta_data1['14thbeta'].append(beta_RMS14)
                alpha_data1['14thalpha'].append(alpha_RMS14)
                theta_data1['14ththeta'].append(theta_RMS14)
                delta_data1['14thdelta'].append(delta_RMS14)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)

# %%
results_mk={"result_theta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (theta_data1.loc[theta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = theta_data1.loc[theta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=200)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_theta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean =0.0
for i in results_mk['result_theta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_theta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
    
print(mean/len(results_mk['result_theta']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.4361136714773169 0.5591397849462365 {'Disike': {'precision': 0.5666666666666667, 'recall': 0.8095238095238095, 'f1-score': 0.6666666666666666, 'support': 21}, 'Like': {'precision': 0.6363636363636364, 'recall': 0.35, 'f1-score': 0.45161290322580644, 'support': 20}, 'accuracy': 0.5853658536585366, 'macro avg': {'precision': 0.6015151515151516, 'recall': 0.5797619047619047, 'f1-score': 0.5591397849462365, 'support': 41}, 'weighted avg': {'precision': 0.6006651884700664, 'recall': 0.5853658536585366, 'f1-score': 0.5617623918174666, 'support': 41}} 8

# %%
results_mk={"result_gamma":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (gamma_data1.loc[gamma_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = gamma_data1.loc[gamma_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_gamma'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean =0.0
for i in results_mk['result_gamma'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_gamma'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
    
print(mean/len(results_mk['result_gamma']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.4771375940742522 0.6571428571428571 {'Disike': {'precision': 0.9117647058823529, 'recall': 0.8611111111111112, 'f1-score': 0.8857142857142858, 'support': 36}, 'Like': {'precision': 0.375, 'recall': 0.5, 'f1-score': 0.42857142857142855, 'support': 6}, 'accuracy': 0.8095238095238095, 'macro avg': {'precision': 0.6433823529411764, 'recall': 0.6805555555555556, 'f1-score': 0.6571428571428571, 'support': 42}, 'weighted avg': {'precision': 0.8350840336134453, 'recall': 0.8095238095238095, 'f1-score': 0.8204081632653063, 'support': 42}} 15

# %%
results_mk={"result_beta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (beta_data1.loc[beta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = beta_data1.loc[beta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_beta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_beta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_beta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean += i['macro avg']['f1-score']
print(mean/len(results_mk['result_beta']),maxx,j,k)
# Out:
# 0.437455448340453 0.6499999999999999 {'Disike': {'precision': 0.4, 'recall': 0.6666666666666666, 'f1-score': 0.5, 'support': 9}, 'Like': {'precision': 0.8888888888888888, 'recall': 0.7272727272727273, 'f1-score': 0.7999999999999999, 'support': 33}, 'accuracy': 0.7142857142857143, 'macro avg': {'precision': 0.6444444444444444, 'recall': 0.696969696969697, 'f1-score': 0.6499999999999999, 'support': 42}, 'weighted avg': {'precision': 0.784126984126984, 'recall': 0.7142857142857143, 'f1-score': 0.7357142857142857, 'support': 42}} 5

# %%
results_mk={"result_alpha":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (alpha_data1.loc[alpha_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = alpha_data1.loc[alpha_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=20000)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_alpha'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean = 0.0
for i in results_mk['result_alpha'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_alpha'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
print(mean/len(results_mk['result_alpha']),maxx,j,k)
# Out:
# 0.43625119691848335 0.595008508224617 {'Disike': {'precision': 0.5416666666666666, 'recall': 0.6842105263157895, 'f1-score': 0.6046511627906976, 'support': 19}, 'Like': {'precision': 0.6666666666666666, 'recall': 0.5217391304347826, 'f1-score': 0.5853658536585366, 'support': 23}, 'accuracy': 0.5952380952380952, 'macro avg': {'precision': 0.6041666666666666, 'recall': 0.602974828375286, 'f1-score': 0.595008508224617, 'support': 42}, 'weighted avg': {'precision': 0.6101190476190477, 'recall': 0.5952380952380952, 'f1-score': 0.5940901601707047, 'support': 42}} 18

# %%
results_mk={"result_delta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (delta_data1.loc[delta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = delta_data1.loc[delta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_delta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_delta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_delta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean +=i['macro avg']['f1-score'] 
print(mean/len(results_mk['result_delta']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.45187862338000295 0.611111111111111 {'Disike': {'precision': 0.6956521739130435, 'recall': 0.64, 'f1-score': 0.6666666666666666, 'support': 25}, 'Like': {'precision': 0.5263157894736842, 'recall': 0.5882352941176471, 'f1-score': 0.5555555555555555, 'support': 17}, 'accuracy': 0.6190476190476191, 'macro avg': {'precision': 0.6109839816933638, 'recall': 0.6141176470588235, 'f1-score': 0.611111111111111, 'support': 42}, 'weighted avg': {'precision': 0.6271112564018742, 'recall': 0.6190476190476191, 'f1-score': 0.6216931216931216, 'support': 42}} 4

# %%
results_mk={"result_merged":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (merged.loc[merged['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = merged.loc[merged['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_merged'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_merged'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_merged'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean += i['macro avg']['f1-score']
print(mean/len(results_mk['result_merged']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.4489344044480292 0.641025641025641 {'Disike': {'precision': 0.625, 'recall': 0.7142857142857143, 'f1-score': 0.6666666666666666, 'support': 21}, 'Like': {'precision': 0.6666666666666666, 'recall': 0.5714285714285714, 'f1-score': 0.6153846153846153, 'support': 21}, 'accuracy': 0.6428571428571429, 'macro avg': {'precision': 0.6458333333333333, 'recall': 0.6428571428571428, 'f1-score': 0.641025641025641, 'support': 42}, 'weighted avg': {'precision': 0.6458333333333334, 'recall': 0.6428571428571429, 'f1-score': 0.641025641025641, 'support': 42}} 0

# %%
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
for i in range(1):
        labels=[]
        try_label=[]
        try_data={
            "1st":[],
            "2nd":[],
            "3rd":[],
            "4th":[],
            "5th":[],
            "6th":[],
            "7th":[],
            "8th":[],
            "9th":[],
            "10th":[],
            "11th":[],
            "12th":[],
            "13th":[],
            "14th":[],
            "username":[],
            "label":[]
        }
        gamma_data1={
            "1stgamma":[],
            "2ndgamma":[],
            "3rdgamma":[],
            "4thgamma":[],
            "5thgamma":[],
            "6thgamma":[],
            "7thgamma":[],
            "8thgamma":[],
            "9thgamma":[],
            "10thgamma":[],
            "11thgamma":[],
            "12thgamma":[],
            "13thgamma":[],
            "14thgamma":[],
        "username":[],
            "label":[]}
        beta_data1={
            "1stbeta":[],
            "2ndbeta":[],
            "3rdbeta":[],
            "4thbeta":[],
            "5thbeta":[],
            "6thbeta":[],
            "7thbeta":[],
            "8thbeta":[],
            "9thbeta":[],
            "10thbeta":[],
            "11thbeta":[],
            "12thbeta":[],
            "13thbeta":[],
            "14thbeta":[],
        "username":[],
            "label":[]}
        alpha_data1={
            "1stalpha":[],
            "2ndalpha":[],
            "3rdalpha":[],
            "4thalpha":[],
            "5thalpha":[],
            "6thalpha":[],
            "7thalpha":[],
            "8thalpha":[],
            "9thalpha":[],
            "10thalpha":[],
            "11thalpha":[],
            "12thalpha":[],
            "13thalpha":[],
            "14thalpha":[],
        "username":[],
            "label":[]}
        theta_data1={
            "1sttheta":[],
            "2ndtheta":[],
            "3rdtheta":[],
            "4ththeta":[],
            "5ththeta":[],
            "6ththeta":[],
            "7ththeta":[],
            "8ththeta":[],
            "9ththeta":[],
            "10ththeta":[],
            "11ththeta":[],
            "12ththeta":[],
            "13ththeta":[],
            "14ththeta":[],
        "username":[],
            "label":[]}
        delta_data1={
            "1stdelta":[],
            "2nddelta":[],
            "3rddelta":[],
            "4thdelta":[],
            "5thdelta":[],
            "6thdelta":[],
            "7thdelta":[],
            "8thdelta":[],
            "9thdelta":[],
            "10thdelta":[],
            "11thdelta":[],
            "12thdelta":[],
            "13thdelta":[],
            "14thdelta":[],
            "username":[],
            "label":[]}


        for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :

            for i in range(42):
                try:
                    user_data = pd.read_csv("25-users/"+name+str(i+1)+".txt", sep=" ", header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
                    user_label = pd.read_csv("labels/"+name+str(i+1)+".lab",header=None,names=["label"])
                except:
                    continue
                labels.append(user_label.values.tolist()[0][0])

                user_data.apply(lambda row : carf(row), axis = 1)

                first_electrode = user_data['1st']
                second_electrode = user_data['2nd']
                third_electrode = user_data['3rd']
                fourth_electrode = user_data['4th']
                fifth_electrode = user_data['5th']
                sixth_electrode = user_data['6th']
                seventh_electrode = user_data['7th']
                eighth_electrode = user_data['8th']
                nineth_electrode = user_data['9th']
                tenth_electrode = user_data['10th']
                eleventh_electrode = user_data['11th']
                twelveth_electrode = user_data['12th']
                thirteenth_electrode = user_data['13th']
                fouteenth_electrode = user_data['14th']

                s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
                s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
                s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
                s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
                s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
                s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
                s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
                s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
                s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
                s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
                s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
                s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
                s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
                s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)
                
                
                
                try_data["label"].append(user_label.values.tolist()[0][0])
                try_data["username"].append(name)

                gamma_data1["label"].append(user_label.values.tolist()[0][0])
                gamma_data1["username"].append(name)

                beta_data1["label"].append(user_label.values.tolist()[0][0])
                beta_data1["username"].append(name)

                alpha_data1["label"].append(user_label.values.tolist()[0][0])
                alpha_data1["username"].append(name)

                theta_data1["label"].append(user_label.values.tolist()[0][0])
                theta_data1["username"].append(name)

                delta_data1["label"].append(user_label.values.tolist()[0][0])
                delta_data1["username"].append(name)

                try_data["1st"].append(s_golay_filtered_signal1[1*128:(1+1)*128])
                try_data["2nd"].append(s_golay_filtered_signal2[1*128:(1+1)*128])
                try_data["3rd"].append(s_golay_filtered_signal3[1*128:(1+1)*128])
                try_data["4th"].append(s_golay_filtered_signal4[1*128:(1+1)*128])
                try_data["5th"].append(s_golay_filtered_signal5[1*128:(1+1)*128])
                try_data["6th"].append(s_golay_filtered_signal6[1*128:(1+1)*128])
                try_data["7th"].append(s_golay_filtered_signal7[1*128:(1+1)*128])
                try_data["8th"].append(s_golay_filtered_signal8[1*128:(1+1)*128])
                try_data["9th"].append(s_golay_filtered_signal9[1*128:(1+1)*128])
                try_data["10th"].append(s_golay_filtered_signal10[1*128:(1+1)*128])
                try_data["11th"].append(s_golay_filtered_signal11[1*128:(1+1)*128])
                try_data["12th"].append(s_golay_filtered_signal12[1*128:(1+1)*128])
                try_data["13th"].append(s_golay_filtered_signal13[1*128:(1+1)*128])
                try_data["14th"].append(s_golay_filtered_signal14[1*128:(1+1)*128])

                cA1, d11 = pywt.dwt(s_golay_filtered_signal1[1*128:(1+1)*128], 'db4')
                cA12, d12 = pywt.dwt(cA1, 'db4')
                cA13, d13 = pywt.dwt(cA12, 'db4')
                a14, d14 = pywt.dwt(cA13, 'db4')
                gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
                beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
                alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
                theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
                delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
                gamma_data1['1stgamma'].append(gamma_RMS1)
                beta_data1['1stbeta'].append(beta_RMS1)
                alpha_data1['1stalpha'].append(alpha_RMS1)
                theta_data1['1sttheta'].append(theta_RMS1)
                delta_data1['1stdelta'].append(delta_RMS1)

                cA2, d21 = pywt.dwt(s_golay_filtered_signal2[1*128:(1+1)*128], 'db4')
                cA22, d22 = pywt.dwt(cA2, 'db4')
                cA23, d23 = pywt.dwt(cA22, 'db4')
                a24, d24 = pywt.dwt(cA23, 'db4')
                gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
                beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
                alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
                theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
                delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
                gamma_data1['2ndgamma'].append(gamma_RMS2)
                beta_data1['2ndbeta'].append(beta_RMS2)
                alpha_data1['2ndalpha'].append(alpha_RMS2)
                theta_data1['2ndtheta'].append(theta_RMS2)
                delta_data1['2nddelta'].append(delta_RMS2)

                cA3, d31 = pywt.dwt(s_golay_filtered_signal3[1*128:(1+1)*128], 'db4')
                cA32, d32 = pywt.dwt(cA3, 'db4')
                cA33, d33 = pywt.dwt(cA32, 'db4')
                a34, d34 = pywt.dwt(cA33, 'db4')
                gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
                beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
                alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
                theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
                delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
                gamma_data1['3rdgamma'].append(gamma_RMS3)
                beta_data1['3rdbeta'].append(beta_RMS3)
                alpha_data1['3rdalpha'].append(alpha_RMS3)
                theta_data1['3rdtheta'].append(theta_RMS3)
                delta_data1['3rddelta'].append(delta_RMS3)

                cA4, d41 = pywt.dwt(s_golay_filtered_signal4[1*128:(1+1)*128], 'db4')
                cA42, d42 = pywt.dwt(cA4, 'db4')
                cA43, d43 = pywt.dwt(cA42, 'db4')
                a44, d44 = pywt.dwt(cA43, 'db4')
                gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
                beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
                alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
                theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
                delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
                gamma_data1['4thgamma'].append(gamma_RMS4)
                beta_data1['4thbeta'].append(beta_RMS4)
                alpha_data1['4thalpha'].append(alpha_RMS4)
                theta_data1['4ththeta'].append(theta_RMS4)
                delta_data1['4thdelta'].append(delta_RMS4)

                cA5, d51 = pywt.dwt(s_golay_filtered_signal5[1*128:(1+1)*128], 'db4')
                cA52, d52 = pywt.dwt(cA5, 'db4')
                cA53, d53 = pywt.dwt(cA52, 'db4')
                a54, d54 = pywt.dwt(cA53, 'db4')
                gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
                beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
                alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
                theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
                delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
                gamma_data1['5thgamma'].append(gamma_RMS5)
                beta_data1['5thbeta'].append(beta_RMS5)
                alpha_data1['5thalpha'].append(alpha_RMS5)
                theta_data1['5ththeta'].append(theta_RMS5)
                delta_data1['5thdelta'].append(delta_RMS5)

                cA6, d61 = pywt.dwt(s_golay_filtered_signal6[1*128:(1+1)*128], 'db4')
                cA62, d62 = pywt.dwt(cA6, 'db4')
                cA63, d63 = pywt.dwt(cA62, 'db4')
                a64, d64 = pywt.dwt(cA63, 'db4')
                gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
                beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
                alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
                theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
                delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
                gamma_data1['6thgamma'].append(gamma_RMS6)
                beta_data1['6thbeta'].append(beta_RMS6)
                alpha_data1['6thalpha'].append(alpha_RMS6)
                theta_data1['6ththeta'].append(theta_RMS6)
                delta_data1['6thdelta'].append(delta_RMS6)


                cA7, d71 = pywt.dwt(s_golay_filtered_signal7[1*128:(1+1)*128], 'db4')
                cA72, d72 = pywt.dwt(cA7, 'db4')
                cA73, d73 = pywt.dwt(cA72, 'db4')
                a74, d74 = pywt.dwt(cA73, 'db4')
                gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
                beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
                alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
                theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
                delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
                gamma_data1['7thgamma'].append(gamma_RMS7)
                beta_data1['7thbeta'].append(beta_RMS7)
                alpha_data1['7thalpha'].append(alpha_RMS7)
                theta_data1['7ththeta'].append(theta_RMS7)
                delta_data1['7thdelta'].append(delta_RMS7)

                cA8, d81 = pywt.dwt(s_golay_filtered_signal8[1*128:(1+1)*128], 'db4')
                cA82, d82 = pywt.dwt(cA8, 'db4')
                cA83, d83 = pywt.dwt(cA82, 'db4')
                a84, d84 = pywt.dwt(cA83, 'db4')
                gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
                beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
                alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
                theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
                delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
                gamma_data1['8thgamma'].append(gamma_RMS8)
                beta_data1['8thbeta'].append(beta_RMS8)
                alpha_data1['8thalpha'].append(alpha_RMS8)
                theta_data1['8ththeta'].append(theta_RMS8)
                delta_data1['8thdelta'].append(delta_RMS8)

                cA9, d91 = pywt.dwt(s_golay_filtered_signal9[1*128:(1+1)*128], 'db4')
                cA92, d92 = pywt.dwt(cA9, 'db4')
                cA93, d93 = pywt.dwt(cA92, 'db4')
                a94, d94 = pywt.dwt(cA93, 'db4')
                gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
                beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
                alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
                theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
                delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
                gamma_data1['9thgamma'].append(gamma_RMS9)
                beta_data1['9thbeta'].append(beta_RMS9)
                alpha_data1['9thalpha'].append(alpha_RMS9)
                theta_data1['9ththeta'].append(theta_RMS9)
                delta_data1['9thdelta'].append(delta_RMS9)

                cA10, d101 = pywt.dwt(s_golay_filtered_signal10[1*128:(1+1)*128], 'db4')
                cA102, d102 = pywt.dwt(cA10, 'db4')
                cA103, d103 = pywt.dwt(cA102, 'db4')
                a104, d104 = pywt.dwt(cA103, 'db4')
                gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
                beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
                alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
                theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
                delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
                gamma_data1['10thgamma'].append(gamma_RMS10)
                beta_data1['10thbeta'].append(beta_RMS10)
                alpha_data1['10thalpha'].append(alpha_RMS10)
                theta_data1['10ththeta'].append(theta_RMS10)
                delta_data1['10thdelta'].append(delta_RMS10)

                cA11, d111 = pywt.dwt(s_golay_filtered_signal11[1*128:(1+1)*128], 'db4')
                cA112, d112 = pywt.dwt(cA11, 'db4')
                cA113, d113 = pywt.dwt(cA112, 'db4')
                a114, d114 = pywt.dwt(cA113, 'db4')
                gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
                beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
                alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
                theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
                delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
                gamma_data1['11thgamma'].append(gamma_RMS11)
                beta_data1['11thbeta'].append(beta_RMS11)
                alpha_data1['11thalpha'].append(alpha_RMS11)
                theta_data1['11ththeta'].append(theta_RMS11)
                delta_data1['11thdelta'].append(delta_RMS11)

                cA12, d121 = pywt.dwt(s_golay_filtered_signal12[1*128:(1+1)*128], 'db4')
                cA122, d122 = pywt.dwt(cA12, 'db4')
                cA123, d123 = pywt.dwt(cA122, 'db4')
                a124, d124 = pywt.dwt(cA123, 'db4')
                gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
                beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
                alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
                theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
                delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
                gamma_data1['12thgamma'].append(gamma_RMS12)
                beta_data1['12thbeta'].append(beta_RMS12)
                alpha_data1['12thalpha'].append(alpha_RMS12)
                theta_data1['12ththeta'].append(theta_RMS12)
                delta_data1['12thdelta'].append(delta_RMS12)

                cA13, d131 = pywt.dwt(s_golay_filtered_signal13[1*128:(1+1)*128], 'db4')
                cA132, d132 = pywt.dwt(cA13, 'db4')
                cA133, d133 = pywt.dwt(cA132, 'db4')
                a134, d134 = pywt.dwt(cA133, 'db4')
                gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
                beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
                alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
                theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
                delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
                gamma_data1['13thgamma'].append(gamma_RMS13)
                beta_data1['13thbeta'].append(beta_RMS13)
                alpha_data1['13thalpha'].append(alpha_RMS13)
                theta_data1['13ththeta'].append(theta_RMS13)
                delta_data1['13thdelta'].append(delta_RMS13)

                cA14, d141 = pywt.dwt(s_golay_filtered_signal14[1*128:(1+1)*128], 'db4')
                cA142, d142 = pywt.dwt(cA14, 'db4')
                cA143, d143 = pywt.dwt(cA142, 'db4')
                a144, d144 = pywt.dwt(cA143, 'db4')
                gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
                beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
                alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
                theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
                delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
                gamma_data1['14thgamma'].append(gamma_RMS14)
                beta_data1['14thbeta'].append(beta_RMS14)
                alpha_data1['14thalpha'].append(alpha_RMS14)
                theta_data1['14ththeta'].append(theta_RMS14)
                delta_data1['14thdelta'].append(delta_RMS14)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)

# %%
results_mk={"result_theta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (theta_data1.loc[theta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = theta_data1.loc[theta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=200)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_theta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean =0.0
for i in results_mk['result_theta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_theta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
    
print(mean/len(results_mk['result_theta']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.4633728669382723 0.7116704805491991 {'Disike': {'precision': 0.6296296296296297, 'recall': 0.8947368421052632, 'f1-score': 0.7391304347826088, 'support': 19}, 'Like': {'precision': 0.8666666666666667, 'recall': 0.5652173913043478, 'f1-score': 0.6842105263157895, 'support': 23}, 'accuracy': 0.7142857142857143, 'macro avg': {'precision': 0.7481481481481482, 'recall': 0.7299771167048055, 'f1-score': 0.7116704805491991, 'support': 42}, 'weighted avg': {'precision': 0.7594356261022929, 'recall': 0.7142857142857143, 'f1-score': 0.709055246812684, 'support': 42}} 12

# %%
results_mk={"result_gamma":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (gamma_data1.loc[gamma_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = gamma_data1.loc[gamma_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_gamma'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean =0.0
for i in results_mk['result_gamma'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_gamma'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
    
print(mean/len(results_mk['result_gamma']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.44836051604423716 0.6377228292121908 {'Disike': {'precision': 0.9166666666666666, 'recall': 0.44, 'f1-score': 0.5945945945945945, 'support': 25}, 'Like': {'precision': 0.5333333333333333, 'recall': 0.9411764705882353, 'f1-score': 0.6808510638297872, 'support': 17}, 'accuracy': 0.6428571428571429, 'macro avg': {'precision': 0.725, 'recall': 0.6905882352941176, 'f1-score': 0.6377228292121908, 'support': 42}, 'weighted avg': {'precision': 0.7615079365079365, 'recall': 0.6428571428571429, 'f1-score': 0.6295079273802677, 'support': 42}} 4

# %%
results_mk={"result_beta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (beta_data1.loc[beta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = beta_data1.loc[beta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_beta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_beta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_beta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean += i['macro avg']['f1-score']
print(mean/len(results_mk['result_beta']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.4294004976989234 0.5980392156862745 {'Disike': {'precision': 0.5925925925925926, 'recall': 0.7619047619047619, 'f1-score': 0.6666666666666666, 'support': 21}, 'Like': {'precision': 0.6428571428571429, 'recall': 0.45, 'f1-score': 0.5294117647058824, 'support': 20}, 'accuracy': 0.6097560975609756, 'macro avg': {'precision': 0.6177248677248677, 'recall': 0.6059523809523809, 'f1-score': 0.5980392156862745, 'support': 41}, 'weighted avg': {'precision': 0.6171118854045683, 'recall': 0.6097560975609756, 'f1-score': 0.5997130559540889, 'support': 41}} 20

# %%
results_mk={"result_alpha":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (alpha_data1.loc[alpha_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = alpha_data1.loc[alpha_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=20000)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_alpha'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean = 0.0
for i in results_mk['result_alpha'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_alpha'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
print(mean/len(results_mk['result_alpha']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.45807195541574736 0.6047058823529412 {'Disike': {'precision': 0.6071428571428571, 'recall': 0.7727272727272727, 'f1-score': 0.68, 'support': 22}, 'Like': {'precision': 0.6428571428571429, 'recall': 0.45, 'f1-score': 0.5294117647058824, 'support': 20}, 'accuracy': 0.6190476190476191, 'macro avg': {'precision': 0.625, 'recall': 0.6113636363636363, 'f1-score': 0.6047058823529412, 'support': 42}, 'weighted avg': {'precision': 0.6241496598639455, 'recall': 0.6190476190476191, 'f1-score': 0.6082913165266106, 'support': 42}} 7

# %%
results_mk={"result_delta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (delta_data1.loc[delta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = delta_data1.loc[delta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_delta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_delta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_delta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean +=i['macro avg']['f1-score'] 
print(mean/len(results_mk['result_delta']),maxx,j,k)
# Out:
# 0.44951311792405657 0.6095238095238096 {'Disike': {'precision': 0.8378378378378378, 'recall': 0.9393939393939394, 'f1-score': 0.8857142857142858, 'support': 33}, 'Like': {'precision': 0.5, 'recall': 0.25, 'f1-score': 0.3333333333333333, 'support': 8}, 'accuracy': 0.8048780487804879, 'macro avg': {'precision': 0.6689189189189189, 'recall': 0.5946969696969697, 'f1-score': 0.6095238095238096, 'support': 41}, 'weighted avg': {'precision': 0.7719182597231378, 'recall': 0.8048780487804879, 'f1-score': 0.777932636469222, 'support': 41}} 14

# %%
results_mk={"result_merged":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (merged.loc[merged['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = merged.loc[merged['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_merged'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_merged'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_merged'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean += i['macro avg']['f1-score']
print(mean/len(results_mk['result_merged']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.47331834856787663 0.7428571428571429 {'Disike': {'precision': 0.9411764705882353, 'recall': 0.8888888888888888, 'f1-score': 0.9142857142857143, 'support': 36}, 'Like': {'precision': 0.5, 'recall': 0.6666666666666666, 'f1-score': 0.5714285714285715, 'support': 6}, 'accuracy': 0.8571428571428571, 'macro avg': {'precision': 0.7205882352941176, 'recall': 0.7777777777777777, 'f1-score': 0.7428571428571429, 'support': 42}, 'weighted avg': {'precision': 0.8781512605042017, 'recall': 0.8571428571428571, 'f1-score': 0.8653061224489795, 'support': 42}} 15

# %%
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
for i in range(1):
        labels=[]
        try_label=[]
        try_data={
            "1st":[],
            "2nd":[],
            "3rd":[],
            "4th":[],
            "5th":[],
            "6th":[],
            "7th":[],
            "8th":[],
            "9th":[],
            "10th":[],
            "11th":[],
            "12th":[],
            "13th":[],
            "14th":[],
            "username":[],
            "label":[]
        }
        gamma_data1={
            "1stgamma":[],
            "2ndgamma":[],
            "3rdgamma":[],
            "4thgamma":[],
            "5thgamma":[],
            "6thgamma":[],
            "7thgamma":[],
            "8thgamma":[],
            "9thgamma":[],
            "10thgamma":[],
            "11thgamma":[],
            "12thgamma":[],
            "13thgamma":[],
            "14thgamma":[],
        "username":[],
            "label":[]}
        beta_data1={
            "1stbeta":[],
            "2ndbeta":[],
            "3rdbeta":[],
            "4thbeta":[],
            "5thbeta":[],
            "6thbeta":[],
            "7thbeta":[],
            "8thbeta":[],
            "9thbeta":[],
            "10thbeta":[],
            "11thbeta":[],
            "12thbeta":[],
            "13thbeta":[],
            "14thbeta":[],
        "username":[],
            "label":[]}
        alpha_data1={
            "1stalpha":[],
            "2ndalpha":[],
            "3rdalpha":[],
            "4thalpha":[],
            "5thalpha":[],
            "6thalpha":[],
            "7thalpha":[],
            "8thalpha":[],
            "9thalpha":[],
            "10thalpha":[],
            "11thalpha":[],
            "12thalpha":[],
            "13thalpha":[],
            "14thalpha":[],
        "username":[],
            "label":[]}
        theta_data1={
            "1sttheta":[],
            "2ndtheta":[],
            "3rdtheta":[],
            "4ththeta":[],
            "5ththeta":[],
            "6ththeta":[],
            "7ththeta":[],
            "8ththeta":[],
            "9ththeta":[],
            "10ththeta":[],
            "11ththeta":[],
            "12ththeta":[],
            "13ththeta":[],
            "14ththeta":[],
        "username":[],
            "label":[]}
        delta_data1={
            "1stdelta":[],
            "2nddelta":[],
            "3rddelta":[],
            "4thdelta":[],
            "5thdelta":[],
            "6thdelta":[],
            "7thdelta":[],
            "8thdelta":[],
            "9thdelta":[],
            "10thdelta":[],
            "11thdelta":[],
            "12thdelta":[],
            "13thdelta":[],
            "14thdelta":[],
            "username":[],
            "label":[]}


        for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :

            for i in range(42):
                try:
                    user_data = pd.read_csv("25-users/"+name+str(i+1)+".txt", sep=" ", header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
                    user_label = pd.read_csv("labels/"+name+str(i+1)+".lab",header=None,names=["label"])
                except:
                    continue
                labels.append(user_label.values.tolist()[0][0])

                user_data.apply(lambda row : carf(row), axis = 1)

                first_electrode = user_data['1st']
                second_electrode = user_data['2nd']
                third_electrode = user_data['3rd']
                fourth_electrode = user_data['4th']
                fifth_electrode = user_data['5th']
                sixth_electrode = user_data['6th']
                seventh_electrode = user_data['7th']
                eighth_electrode = user_data['8th']
                nineth_electrode = user_data['9th']
                tenth_electrode = user_data['10th']
                eleventh_electrode = user_data['11th']
                twelveth_electrode = user_data['12th']
                thirteenth_electrode = user_data['13th']
                fouteenth_electrode = user_data['14th']

                s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
                s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
                s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
                s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
                s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
                s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
                s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
                s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
                s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
                s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
                s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
                s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
                s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
                s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)
                
                
                
                try_data["label"].append(user_label.values.tolist()[0][0])
                try_data["username"].append(name)

                gamma_data1["label"].append(user_label.values.tolist()[0][0])
                gamma_data1["username"].append(name)

                beta_data1["label"].append(user_label.values.tolist()[0][0])
                beta_data1["username"].append(name)

                alpha_data1["label"].append(user_label.values.tolist()[0][0])
                alpha_data1["username"].append(name)

                theta_data1["label"].append(user_label.values.tolist()[0][0])
                theta_data1["username"].append(name)

                delta_data1["label"].append(user_label.values.tolist()[0][0])
                delta_data1["username"].append(name)

                try_data["1st"].append(s_golay_filtered_signal1[2*128:(2+1)*128])
                try_data["2nd"].append(s_golay_filtered_signal2[2*128:(2+1)*128])
                try_data["3rd"].append(s_golay_filtered_signal3[2*128:(2+1)*128])
                try_data["4th"].append(s_golay_filtered_signal4[2*128:(2+1)*128])
                try_data["5th"].append(s_golay_filtered_signal5[2*128:(2+1)*128])
                try_data["6th"].append(s_golay_filtered_signal6[2*128:(2+1)*128])
                try_data["7th"].append(s_golay_filtered_signal7[2*128:(2+1)*128])
                try_data["8th"].append(s_golay_filtered_signal8[2*128:(2+1)*128])
                try_data["9th"].append(s_golay_filtered_signal9[2*128:(2+1)*128])
                try_data["10th"].append(s_golay_filtered_signal10[2*128:(2+1)*128])
                try_data["11th"].append(s_golay_filtered_signal11[2*128:(2+1)*128])
                try_data["12th"].append(s_golay_filtered_signal12[2*128:(2+1)*128])
                try_data["13th"].append(s_golay_filtered_signal13[2*128:(2+1)*128])
                try_data["14th"].append(s_golay_filtered_signal14[2*128:(2+1)*128])

                cA1, d11 = pywt.dwt(s_golay_filtered_signal1[2*128:(2+1)*128], 'db4')
                cA12, d12 = pywt.dwt(cA1, 'db4')
                cA13, d13 = pywt.dwt(cA12, 'db4')
                a14, d14 = pywt.dwt(cA13, 'db4')
                gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
                beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
                alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
                theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
                delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
                gamma_data1['1stgamma'].append(gamma_RMS1)
                beta_data1['1stbeta'].append(beta_RMS1)
                alpha_data1['1stalpha'].append(alpha_RMS1)
                theta_data1['1sttheta'].append(theta_RMS1)
                delta_data1['1stdelta'].append(delta_RMS1)

                cA2, d21 = pywt.dwt(s_golay_filtered_signal2[2*128:(2+1)*128], 'db4')
                cA22, d22 = pywt.dwt(cA2, 'db4')
                cA23, d23 = pywt.dwt(cA22, 'db4')
                a24, d24 = pywt.dwt(cA23, 'db4')
                gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
                beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
                alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
                theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
                delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
                gamma_data1['2ndgamma'].append(gamma_RMS2)
                beta_data1['2ndbeta'].append(beta_RMS2)
                alpha_data1['2ndalpha'].append(alpha_RMS2)
                theta_data1['2ndtheta'].append(theta_RMS2)
                delta_data1['2nddelta'].append(delta_RMS2)

                cA3, d31 = pywt.dwt(s_golay_filtered_signal3[2*128:(2+1)*128], 'db4')
                cA32, d32 = pywt.dwt(cA3, 'db4')
                cA33, d33 = pywt.dwt(cA32, 'db4')
                a34, d34 = pywt.dwt(cA33, 'db4')
                gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
                beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
                alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
                theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
                delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
                gamma_data1['3rdgamma'].append(gamma_RMS3)
                beta_data1['3rdbeta'].append(beta_RMS3)
                alpha_data1['3rdalpha'].append(alpha_RMS3)
                theta_data1['3rdtheta'].append(theta_RMS3)
                delta_data1['3rddelta'].append(delta_RMS3)

                cA4, d41 = pywt.dwt(s_golay_filtered_signal4[2*128:(2+1)*128], 'db4')
                cA42, d42 = pywt.dwt(cA4, 'db4')
                cA43, d43 = pywt.dwt(cA42, 'db4')
                a44, d44 = pywt.dwt(cA43, 'db4')
                gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
                beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
                alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
                theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
                delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
                gamma_data1['4thgamma'].append(gamma_RMS4)
                beta_data1['4thbeta'].append(beta_RMS4)
                alpha_data1['4thalpha'].append(alpha_RMS4)
                theta_data1['4ththeta'].append(theta_RMS4)
                delta_data1['4thdelta'].append(delta_RMS4)

                cA5, d51 = pywt.dwt(s_golay_filtered_signal5[2*128:(2+1)*128], 'db4')
                cA52, d52 = pywt.dwt(cA5, 'db4')
                cA53, d53 = pywt.dwt(cA52, 'db4')
                a54, d54 = pywt.dwt(cA53, 'db4')
                gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
                beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
                alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
                theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
                delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
                gamma_data1['5thgamma'].append(gamma_RMS5)
                beta_data1['5thbeta'].append(beta_RMS5)
                alpha_data1['5thalpha'].append(alpha_RMS5)
                theta_data1['5ththeta'].append(theta_RMS5)
                delta_data1['5thdelta'].append(delta_RMS5)

                cA6, d61 = pywt.dwt(s_golay_filtered_signal6[2*128:(2+1)*128], 'db4')
                cA62, d62 = pywt.dwt(cA6, 'db4')
                cA63, d63 = pywt.dwt(cA62, 'db4')
                a64, d64 = pywt.dwt(cA63, 'db4')
                gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
                beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
                alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
                theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
                delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
                gamma_data1['6thgamma'].append(gamma_RMS6)
                beta_data1['6thbeta'].append(beta_RMS6)
                alpha_data1['6thalpha'].append(alpha_RMS6)
                theta_data1['6ththeta'].append(theta_RMS6)
                delta_data1['6thdelta'].append(delta_RMS6)


                cA7, d71 = pywt.dwt(s_golay_filtered_signal7[2*128:(2+1)*128], 'db4')
                cA72, d72 = pywt.dwt(cA7, 'db4')
                cA73, d73 = pywt.dwt(cA72, 'db4')
                a74, d74 = pywt.dwt(cA73, 'db4')
                gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
                beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
                alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
                theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
                delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
                gamma_data1['7thgamma'].append(gamma_RMS7)
                beta_data1['7thbeta'].append(beta_RMS7)
                alpha_data1['7thalpha'].append(alpha_RMS7)
                theta_data1['7ththeta'].append(theta_RMS7)
                delta_data1['7thdelta'].append(delta_RMS7)

                cA8, d81 = pywt.dwt(s_golay_filtered_signal8[2*128:(2+1)*128], 'db4')
                cA82, d82 = pywt.dwt(cA8, 'db4')
                cA83, d83 = pywt.dwt(cA82, 'db4')
                a84, d84 = pywt.dwt(cA83, 'db4')
                gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
                beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
                alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
                theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
                delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
                gamma_data1['8thgamma'].append(gamma_RMS8)
                beta_data1['8thbeta'].append(beta_RMS8)
                alpha_data1['8thalpha'].append(alpha_RMS8)
                theta_data1['8ththeta'].append(theta_RMS8)
                delta_data1['8thdelta'].append(delta_RMS8)

                cA9, d91 = pywt.dwt(s_golay_filtered_signal9[2*128:(2+1)*128], 'db4')
                cA92, d92 = pywt.dwt(cA9, 'db4')
                cA93, d93 = pywt.dwt(cA92, 'db4')
                a94, d94 = pywt.dwt(cA93, 'db4')
                gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
                beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
                alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
                theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
                delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
                gamma_data1['9thgamma'].append(gamma_RMS9)
                beta_data1['9thbeta'].append(beta_RMS9)
                alpha_data1['9thalpha'].append(alpha_RMS9)
                theta_data1['9ththeta'].append(theta_RMS9)
                delta_data1['9thdelta'].append(delta_RMS9)

                cA10, d101 = pywt.dwt(s_golay_filtered_signal10[2*128:(2+1)*128], 'db4')
                cA102, d102 = pywt.dwt(cA10, 'db4')
                cA103, d103 = pywt.dwt(cA102, 'db4')
                a104, d104 = pywt.dwt(cA103, 'db4')
                gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
                beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
                alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
                theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
                delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
                gamma_data1['10thgamma'].append(gamma_RMS10)
                beta_data1['10thbeta'].append(beta_RMS10)
                alpha_data1['10thalpha'].append(alpha_RMS10)
                theta_data1['10ththeta'].append(theta_RMS10)
                delta_data1['10thdelta'].append(delta_RMS10)

                cA11, d111 = pywt.dwt(s_golay_filtered_signal11[2*128:(2+1)*128], 'db4')
                cA113, d113 = pywt.dwt(cA112, 'db4')
                a114, d114 = pywt.dwt(cA113, 'db4')
                gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
                beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
                alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
                theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
                delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
                gamma_data1['11thgamma'].append(gamma_RMS11)
                beta_data1['11thbeta'].append(beta_RMS11)
                alpha_data1['11thalpha'].append(alpha_RMS11)
                theta_data1['11ththeta'].append(theta_RMS11)
                delta_data1['11thdelta'].append(delta_RMS11)

                cA12, d121 = pywt.dwt(s_golay_filtered_signal12[2*128:(2+1)*128], 'db4')
                cA122, d122 = pywt.dwt(cA12, 'db4')
                cA123, d123 = pywt.dwt(cA122, 'db4')
                a124, d124 = pywt.dwt(cA123, 'db4')
                gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
                beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
                alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
                theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
                delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
                gamma_data1['12thgamma'].append(gamma_RMS12)
                beta_data1['12thbeta'].append(beta_RMS12)
                alpha_data1['12thalpha'].append(alpha_RMS12)
                theta_data1['12ththeta'].append(theta_RMS12)
                delta_data1['12thdelta'].append(delta_RMS12)

                cA13, d131 = pywt.dwt(s_golay_filtered_signal13[2*128:(2+1)*128], 'db4')
                cA132, d132 = pywt.dwt(cA13, 'db4')
                cA133, d133 = pywt.dwt(cA132, 'db4')
                a134, d134 = pywt.dwt(cA133, 'db4')
                gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
                beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
                alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
                theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
                delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
                gamma_data1['13thgamma'].append(gamma_RMS13)
                beta_data1['13thbeta'].append(beta_RMS13)
                alpha_data1['13thalpha'].append(alpha_RMS13)
                theta_data1['13ththeta'].append(theta_RMS13)
                delta_data1['13thdelta'].append(delta_RMS13)

                cA14, d141 = pywt.dwt(s_golay_filtered_signal14[2*128:(2+1)*128], 'db4')
                cA142, d142 = pywt.dwt(cA14, 'db4')
                cA143, d143 = pywt.dwt(cA142, 'db4')
                a144, d144 = pywt.dwt(cA143, 'db4')
                gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
                beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
                alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
                theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
                delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
                gamma_data1['14thgamma'].append(gamma_RMS14)
                beta_data1['14thbeta'].append(beta_RMS14)
                alpha_data1['14thalpha'].append(alpha_RMS14)
                theta_data1['14ththeta'].append(theta_RMS14)
                delta_data1['14thdelta'].append(delta_RMS14)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)

# %%
results_mk={"result_theta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (theta_data1.loc[theta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = theta_data1.loc[theta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=200)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_theta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean =0.0
for i in results_mk['result_theta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_theta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
    
print(mean/len(results_mk['result_theta']),maxx,j,k)
# Out:
# 0.46299175103859946 0.6050156739811913 {'Disike': {'precision': 0.7142857142857143, 'recall': 0.7407407407407407, 'f1-score': 0.7272727272727273, 'support': 27}, 'Like': {'precision': 0.5, 'recall': 0.4666666666666667, 'f1-score': 0.4827586206896552, 'support': 15}, 'accuracy': 0.6428571428571429, 'macro avg': {'precision': 0.6071428571428572, 'recall': 0.6037037037037036, 'f1-score': 0.6050156739811913, 'support': 42}, 'weighted avg': {'precision': 0.6377551020408163, 'recall': 0.6428571428571429, 'f1-score': 0.6399462606359159, 'support': 42}} 3

# %%
results_mk={"result_gamma":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (gamma_data1.loc[gamma_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = gamma_data1.loc[gamma_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=200)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_gamma'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean =0.0
for i in results_mk['result_gamma'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_gamma'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
    
print(mean/len(results_mk['result_gamma']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.4888951124236777 0.6659090909090909 {'Disike': {'precision': 0.75, 'recall': 0.625, 'f1-score': 0.6818181818181818, 'support': 24}, 'Like': {'precision': 0.5909090909090909, 'recall': 0.7222222222222222, 'f1-score': 0.65, 'support': 18}, 'accuracy': 0.6666666666666666, 'macro avg': {'precision': 0.6704545454545454, 'recall': 0.6736111111111112, 'f1-score': 0.6659090909090909, 'support': 42}, 'weighted avg': {'precision': 0.6818181818181819, 'recall': 0.6666666666666666, 'f1-score': 0.6681818181818182, 'support': 42}} 22

# %%
results_mk={"result_beta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (beta_data1.loc[beta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = beta_data1.loc[beta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_beta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_beta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_beta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean += i['macro avg']['f1-score']
print(mean/len(results_mk['result_beta']),maxx,j,k)
# Out:
# 0.49108842193425106 0.6666666666666666 {'Disike': {'precision': 0.6666666666666666, 'recall': 0.6666666666666666, 'f1-score': 0.6666666666666666, 'support': 21}, 'Like': {'precision': 0.6666666666666666, 'recall': 0.6666666666666666, 'f1-score': 0.6666666666666666, 'support': 21}, 'accuracy': 0.6666666666666666, 'macro avg': {'precision': 0.6666666666666666, 'recall': 0.6666666666666666, 'f1-score': 0.6666666666666666, 'support': 42}, 'weighted avg': {'precision': 0.6666666666666666, 'recall': 0.6666666666666666, 'f1-score': 0.6666666666666666, 'support': 42}} 0

# %%
results_mk={"result_alpha":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (alpha_data1.loc[alpha_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = alpha_data1.loc[alpha_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=20000)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_alpha'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean = 0.0
for i in results_mk['result_alpha'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_alpha'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
print(mean/len(results_mk['result_alpha']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.4442908859653894 0.6541176470588235 {'Disike': {'precision': 0.6666666666666666, 'recall': 0.5263157894736842, 'f1-score': 0.5882352941176471, 'support': 19}, 'Like': {'precision': 0.6666666666666666, 'recall': 0.782608695652174, 'f1-score': 0.72, 'support': 23}, 'accuracy': 0.6666666666666666, 'macro avg': {'precision': 0.6666666666666666, 'recall': 0.6544622425629291, 'f1-score': 0.6541176470588235, 'support': 42}, 'weighted avg': {'precision': 0.6666666666666666, 'recall': 0.6666666666666666, 'f1-score': 0.6603921568627451, 'support': 42}} 12

# %%
results_mk={"result_delta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (delta_data1.loc[delta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = delta_data1.loc[delta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_delta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_delta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_delta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean +=i['macro avg']['f1-score'] 
print(mean/len(results_mk['result_delta']),maxx,j,k)
# Out:
# 0.4675872931318325 0.657680250783699 {'Disike': {'precision': 0.7, 'recall': 0.84, 'f1-score': 0.7636363636363636, 'support': 25}, 'Like': {'precision': 0.6666666666666666, 'recall': 0.47058823529411764, 'f1-score': 0.5517241379310345, 'support': 17}, 'accuracy': 0.6904761904761905, 'macro avg': {'precision': 0.6833333333333333, 'recall': 0.6552941176470588, 'f1-score': 0.657680250783699, 'support': 42}, 'weighted avg': {'precision': 0.6865079365079365, 'recall': 0.6904761904761905, 'f1-score': 0.6778623675175398, 'support': 42}} 16

# %%
results_mk={"result_merged":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (merged.loc[merged['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = merged.loc[merged['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_merged'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_merged'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_merged'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean += i['macro avg']['f1-score']
print(mean/len(results_mk['result_merged']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.46734566322618226 0.6636155606407322 {'Disike': {'precision': 0.631578947368421, 'recall': 0.631578947368421, 'f1-score': 0.631578947368421, 'support': 19}, 'Like': {'precision': 0.6956521739130435, 'recall': 0.6956521739130435, 'f1-score': 0.6956521739130435, 'support': 23}, 'accuracy': 0.6666666666666666, 'macro avg': {'precision': 0.6636155606407322, 'recall': 0.6636155606407322, 'f1-score': 0.6636155606407322, 'support': 42}, 'weighted avg': {'precision': 0.6666666666666666, 'recall': 0.6666666666666666, 'f1-score': 0.6666666666666666, 'support': 42}} 12

# %%
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
for i in range(1):
        labels=[]
        try_label=[]
        try_data={
            "1st":[],
            "2nd":[],
            "3rd":[],
            "4th":[],
            "5th":[],
            "6th":[],
            "7th":[],
            "8th":[],
            "9th":[],
            "10th":[],
            "11th":[],
            "12th":[],
            "13th":[],
            "14th":[],
            "username":[],
            "label":[]
        }
        gamma_data1={
            "1stgamma":[],
            "2ndgamma":[],
            "3rdgamma":[],
            "4thgamma":[],
            "5thgamma":[],
            "6thgamma":[],
            "7thgamma":[],
            "8thgamma":[],
            "9thgamma":[],
            "10thgamma":[],
            "11thgamma":[],
            "12thgamma":[],
            "13thgamma":[],
            "14thgamma":[],
        "username":[],
            "label":[]}
        beta_data1={
            "1stbeta":[],
            "2ndbeta":[],
            "3rdbeta":[],
            "4thbeta":[],
            "5thbeta":[],
            "6thbeta":[],
            "7thbeta":[],
            "8thbeta":[],
            "9thbeta":[],
            "10thbeta":[],
            "11thbeta":[],
            "12thbeta":[],
            "13thbeta":[],
            "14thbeta":[],
        "username":[],
            "label":[]}
        alpha_data1={
            "1stalpha":[],
            "2ndalpha":[],
            "3rdalpha":[],
            "4thalpha":[],
            "5thalpha":[],
            "6thalpha":[],
            "7thalpha":[],
            "8thalpha":[],
            "9thalpha":[],
            "10thalpha":[],
            "11thalpha":[],
            "12thalpha":[],
            "13thalpha":[],
            "14thalpha":[],
        "username":[],
            "label":[]}
        theta_data1={
            "1sttheta":[],
            "2ndtheta":[],
            "3rdtheta":[],
            "4ththeta":[],
            "5ththeta":[],
            "6ththeta":[],
            "7ththeta":[],
            "8ththeta":[],
            "9ththeta":[],
            "10ththeta":[],
            "11ththeta":[],
            "12ththeta":[],
            "13ththeta":[],
            "14ththeta":[],
        "username":[],
            "label":[]}
        delta_data1={
            "1stdelta":[],
            "2nddelta":[],
            "3rddelta":[],
            "4thdelta":[],
            "5thdelta":[],
            "6thdelta":[],
            "7thdelta":[],
            "8thdelta":[],
            "9thdelta":[],
            "10thdelta":[],
            "11thdelta":[],
            "12thdelta":[],
            "13thdelta":[],
            "14thdelta":[],
            "username":[],
            "label":[]}


        for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :

            for i in range(42):
                try:
                    user_data = pd.read_csv("25-users/"+name+str(i+1)+".txt", sep=" ", header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
                    user_label = pd.read_csv("labels/"+name+str(i+1)+".lab",header=None,names=["label"])
                except:
                    continue
                labels.append(user_label.values.tolist()[0][0])

                user_data.apply(lambda row : carf(row), axis = 1)

                first_electrode = user_data['1st']
                second_electrode = user_data['2nd']
                third_electrode = user_data['3rd']
                fourth_electrode = user_data['4th']
                fifth_electrode = user_data['5th']
                sixth_electrode = user_data['6th']
                seventh_electrode = user_data['7th']
                eighth_electrode = user_data['8th']
                nineth_electrode = user_data['9th']
                tenth_electrode = user_data['10th']
                eleventh_electrode = user_data['11th']
                twelveth_electrode = user_data['12th']
                thirteenth_electrode = user_data['13th']
                fouteenth_electrode = user_data['14th']

                s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
                s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
                s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
                s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
                s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
                s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
                s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
                s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
                s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
                s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
                s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
                s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
                s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
                s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)
                
                
                
                try_data["label"].append(user_label.values.tolist()[0][0])
                try_data["username"].append(name)

                gamma_data1["label"].append(user_label.values.tolist()[0][0])
                gamma_data1["username"].append(name)

                beta_data1["label"].append(user_label.values.tolist()[0][0])
                beta_data1["username"].append(name)

                alpha_data1["label"].append(user_label.values.tolist()[0][0])
                alpha_data1["username"].append(name)

                theta_data1["label"].append(user_label.values.tolist()[0][0])
                theta_data1["username"].append(name)

                delta_data1["label"].append(user_label.values.tolist()[0][0])
                delta_data1["username"].append(name)

                try_data["1st"].append(s_golay_filtered_signal1[3*128:(3+1)*128])
                try_data["2nd"].append(s_golay_filtered_signal2[3*128:(3+1)*128])
                try_data["3rd"].append(s_golay_filtered_signal3[3*128:(3+1)*128])
                try_data["4th"].append(s_golay_filtered_signal4[3*128:(3+1)*128])
                try_data["5th"].append(s_golay_filtered_signal5[3*128:(3+1)*128])
                try_data["6th"].append(s_golay_filtered_signal6[3*128:(3+1)*128])
                try_data["7th"].append(s_golay_filtered_signal7[3*128:(3+1)*128])
                try_data["8th"].append(s_golay_filtered_signal8[3*128:(3+1)*128])
                try_data["9th"].append(s_golay_filtered_signal9[3*128:(3+1)*128])
                try_data["10th"].append(s_golay_filtered_signal10[3*128:(3+1)*128])
                try_data["11th"].append(s_golay_filtered_signal11[3*128:(3+1)*128])
                try_data["12th"].append(s_golay_filtered_signal12[3*128:(3+1)*128])
                try_data["13th"].append(s_golay_filtered_signal13[3*128:(3+1)*128])
                try_data["14th"].append(s_golay_filtered_signal14[3*128:(3+1)*128])

                cA1, d11 = pywt.dwt(s_golay_filtered_signal1[3*128:(3+1)*128], 'db4')
                cA12, d12 = pywt.dwt(cA1, 'db4')
                cA13, d13 = pywt.dwt(cA12, 'db4')
                a14, d14 = pywt.dwt(cA13, 'db4')
                gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
                beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
                alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
                theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
                delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
                gamma_data1['1stgamma'].append(gamma_RMS1)
                beta_data1['1stbeta'].append(beta_RMS1)
                alpha_data1['1stalpha'].append(alpha_RMS1)
                theta_data1['1sttheta'].append(theta_RMS1)
                delta_data1['1stdelta'].append(delta_RMS1)

                cA2, d21 = pywt.dwt(s_golay_filtered_signal2[3*128:(3+1)*128], 'db4')
                cA22, d22 = pywt.dwt(cA2, 'db4')
                cA23, d23 = pywt.dwt(cA22, 'db4')
                a24, d24 = pywt.dwt(cA23, 'db4')
                gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
                beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
                alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
                theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
                delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
                gamma_data1['2ndgamma'].append(gamma_RMS2)
                beta_data1['2ndbeta'].append(beta_RMS2)
                alpha_data1['2ndalpha'].append(alpha_RMS2)
                theta_data1['2ndtheta'].append(theta_RMS2)
                delta_data1['2nddelta'].append(delta_RMS2)

                cA3, d31 = pywt.dwt(s_golay_filtered_signal3[3*128:(3+1)*128], 'db4')
                cA32, d32 = pywt.dwt(cA3, 'db4')
                cA33, d33 = pywt.dwt(cA32, 'db4')
                a34, d34 = pywt.dwt(cA33, 'db4')
                gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
                beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
                alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
                theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
                delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
                gamma_data1['3rdgamma'].append(gamma_RMS3)
                beta_data1['3rdbeta'].append(beta_RMS3)
                alpha_data1['3rdalpha'].append(alpha_RMS3)
                theta_data1['3rdtheta'].append(theta_RMS3)
                delta_data1['3rddelta'].append(delta_RMS3)

                cA4, d41 = pywt.dwt(s_golay_filtered_signal4[3*128:(3+1)*128], 'db4')
                cA42, d42 = pywt.dwt(cA4, 'db4')
                cA43, d43 = pywt.dwt(cA42, 'db4')
                a44, d44 = pywt.dwt(cA43, 'db4')
                gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
                beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
                alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
                theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
                delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
                gamma_data1['4thgamma'].append(gamma_RMS4)
                beta_data1['4thbeta'].append(beta_RMS4)
                alpha_data1['4thalpha'].append(alpha_RMS4)
                theta_data1['4ththeta'].append(theta_RMS4)
                delta_data1['4thdelta'].append(delta_RMS4)

                cA5, d51 = pywt.dwt(s_golay_filtered_signal5[3*128:(3+1)*128], 'db4')
                cA52, d52 = pywt.dwt(cA5, 'db4')
                cA53, d53 = pywt.dwt(cA52, 'db4')
                a54, d54 = pywt.dwt(cA53, 'db4')
                gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
                beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
                alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
                theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
                delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
                gamma_data1['5thgamma'].append(gamma_RMS5)
                beta_data1['5thbeta'].append(beta_RMS5)
                alpha_data1['5thalpha'].append(alpha_RMS5)
                theta_data1['5ththeta'].append(theta_RMS5)
                delta_data1['5thdelta'].append(delta_RMS5)

                cA6, d61 = pywt.dwt(s_golay_filtered_signal6[3*128:(3+1)*128], 'db4')
                cA62, d62 = pywt.dwt(cA6, 'db4')
                cA63, d63 = pywt.dwt(cA62, 'db4')
                a64, d64 = pywt.dwt(cA63, 'db4')
                gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
                beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
                alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
                theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
                delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
                gamma_data1['6thgamma'].append(gamma_RMS6)
                beta_data1['6thbeta'].append(beta_RMS6)
                alpha_data1['6thalpha'].append(alpha_RMS6)
                theta_data1['6ththeta'].append(theta_RMS6)
                delta_data1['6thdelta'].append(delta_RMS6)


                cA7, d71 = pywt.dwt(s_golay_filtered_signal7[3*128:(3+1)*128], 'db4')
                cA72, d72 = pywt.dwt(cA7, 'db4')
                cA73, d73 = pywt.dwt(cA72, 'db4')
                a74, d74 = pywt.dwt(cA73, 'db4')
                gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
                beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
                alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
                theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
                delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
                gamma_data1['7thgamma'].append(gamma_RMS7)
                beta_data1['7thbeta'].append(beta_RMS7)
                alpha_data1['7thalpha'].append(alpha_RMS7)
                theta_data1['7ththeta'].append(theta_RMS7)
                delta_data1['7thdelta'].append(delta_RMS7)

                cA8, d81 = pywt.dwt(s_golay_filtered_signal8[3*128:(3+1)*128], 'db4')
                cA82, d82 = pywt.dwt(cA8, 'db4')
                cA83, d83 = pywt.dwt(cA82, 'db4')
                a84, d84 = pywt.dwt(cA83, 'db4')
                gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
                beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
                alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
                theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
                delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
                gamma_data1['8thgamma'].append(gamma_RMS8)
                beta_data1['8thbeta'].append(beta_RMS8)
                alpha_data1['8thalpha'].append(alpha_RMS8)
                theta_data1['8ththeta'].append(theta_RMS8)
                delta_data1['8thdelta'].append(delta_RMS8)

                cA9, d91 = pywt.dwt(s_golay_filtered_signal9[3*128:(3+1)*128], 'db4')
                cA92, d92 = pywt.dwt(cA9, 'db4')
                cA93, d93 = pywt.dwt(cA92, 'db4')
                a94, d94 = pywt.dwt(cA93, 'db4')
                gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
                beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
                alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
                theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
                delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
                gamma_data1['9thgamma'].append(gamma_RMS9)
                beta_data1['9thbeta'].append(beta_RMS9)
                alpha_data1['9thalpha'].append(alpha_RMS9)
                theta_data1['9ththeta'].append(theta_RMS9)
                delta_data1['9thdelta'].append(delta_RMS9)

                cA10, d101 = pywt.dwt(s_golay_filtered_signal10[3*128:(3+1)*128], 'db4')
                cA102, d102 = pywt.dwt(cA10, 'db4')
                cA103, d103 = pywt.dwt(cA102, 'db4')
                a104, d104 = pywt.dwt(cA103, 'db4')
                gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
                beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
                alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
                theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
                delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
                gamma_data1['10thgamma'].append(gamma_RMS10)
                beta_data1['10thbeta'].append(beta_RMS10)
                alpha_data1['10thalpha'].append(alpha_RMS10)
                theta_data1['10ththeta'].append(theta_RMS10)
                delta_data1['10thdelta'].append(delta_RMS10)

                cA11, d111 = pywt.dwt(s_golay_filtered_signal11[3*128:(3+1)*128], 'db4')
                cA113, d113 = pywt.dwt(cA112, 'db4')
                a114, d114 = pywt.dwt(cA113, 'db4')
                gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
                beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
                alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
                theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
                delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
                gamma_data1['11thgamma'].append(gamma_RMS11)
                beta_data1['11thbeta'].append(beta_RMS11)
                alpha_data1['11thalpha'].append(alpha_RMS11)
                theta_data1['11ththeta'].append(theta_RMS11)
                delta_data1['11thdelta'].append(delta_RMS11)

                cA12, d121 = pywt.dwt(s_golay_filtered_signal12[3*128:(3+1)*128], 'db4')
                cA122, d122 = pywt.dwt(cA12, 'db4')
                cA123, d123 = pywt.dwt(cA122, 'db4')
                a124, d124 = pywt.dwt(cA123, 'db4')
                gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
                beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
                alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
                theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
                delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
                gamma_data1['12thgamma'].append(gamma_RMS12)
                beta_data1['12thbeta'].append(beta_RMS12)
                alpha_data1['12thalpha'].append(alpha_RMS12)
                theta_data1['12ththeta'].append(theta_RMS12)
                delta_data1['12thdelta'].append(delta_RMS12)

                cA13, d131 = pywt.dwt(s_golay_filtered_signal13[3*128:(3+1)*128], 'db4')
                cA132, d132 = pywt.dwt(cA13, 'db4')
                cA133, d133 = pywt.dwt(cA132, 'db4')
                a134, d134 = pywt.dwt(cA133, 'db4')
                gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
                beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
                alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
                theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
                delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
                gamma_data1['13thgamma'].append(gamma_RMS13)
                beta_data1['13thbeta'].append(beta_RMS13)
                alpha_data1['13thalpha'].append(alpha_RMS13)
                theta_data1['13ththeta'].append(theta_RMS13)
                delta_data1['13thdelta'].append(delta_RMS13)

                cA14, d141 = pywt.dwt(s_golay_filtered_signal14[3*128:(3+1)*128], 'db4')
                cA142, d142 = pywt.dwt(cA14, 'db4')
                cA143, d143 = pywt.dwt(cA142, 'db4')
                a144, d144 = pywt.dwt(cA143, 'db4')
                gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
                beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
                alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
                theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
                delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
                gamma_data1['14thgamma'].append(gamma_RMS14)
                beta_data1['14thbeta'].append(beta_RMS14)
                alpha_data1['14thalpha'].append(alpha_RMS14)
                theta_data1['14ththeta'].append(theta_RMS14)
                delta_data1['14thdelta'].append(delta_RMS14)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)

# %%
results_mk={"result_theta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (theta_data1.loc[theta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = theta_data1.loc[theta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=200)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_theta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean =0.0
for i in results_mk['result_theta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_theta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
    
print(mean/len(results_mk['result_theta']),maxx,j,k)
# Out:
# 0.47606886238532115 0.5931623931623933 {'Disike': {'precision': 0.55, 'recall': 0.5789473684210527, 'f1-score': 0.5641025641025641, 'support': 19}, 'Like': {'precision': 0.6363636363636364, 'recall': 0.6086956521739131, 'f1-score': 0.6222222222222223, 'support': 23}, 'accuracy': 0.5952380952380952, 'macro avg': {'precision': 0.5931818181818183, 'recall': 0.5938215102974829, 'f1-score': 0.5931623931623933, 'support': 42}, 'weighted avg': {'precision': 0.5972943722943723, 'recall': 0.5952380952380952, 'f1-score': 0.595929995929996, 'support': 42}} 12

# %%
results_mk={"result_gamma":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (gamma_data1.loc[gamma_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = gamma_data1.loc[gamma_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=200)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_gamma'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean =0.0
for i in results_mk['result_gamma'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_gamma'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
    
print(mean/len(results_mk['result_gamma']),maxx,j,k)
# Out:
# 0.474531838954492 0.6464646464646465 {'Disike': {'precision': 0.8, 'recall': 0.9032258064516129, 'f1-score': 0.8484848484848486, 'support': 31}, 'Like': {'precision': 0.5714285714285714, 'recall': 0.36363636363636365, 'f1-score': 0.4444444444444444, 'support': 11}, 'accuracy': 0.7619047619047619, 'macro avg': {'precision': 0.6857142857142857, 'recall': 0.6334310850439883, 'f1-score': 0.6464646464646465, 'support': 42}, 'weighted avg': {'precision': 0.7401360544217687, 'recall': 0.7619047619047619, 'f1-score': 0.7426647426647428, 'support': 42}} 13

# %%
results_mk={"result_beta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (beta_data1.loc[beta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = beta_data1.loc[beta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=200)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_beta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_beta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_beta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean += i['macro avg']['f1-score']
print(mean/len(results_mk['result_beta']),maxx,j,k)
# Out:
# 0.48310837977978716 0.6541176470588235 {'Disike': {'precision': 0.72, 'recall': 0.72, 'f1-score': 0.72, 'support': 25}, 'Like': {'precision': 0.5882352941176471, 'recall': 0.5882352941176471, 'f1-score': 0.5882352941176471, 'support': 17}, 'accuracy': 0.6666666666666666, 'macro avg': {'precision': 0.6541176470588235, 'recall': 0.6541176470588235, 'f1-score': 0.6541176470588235, 'support': 42}, 'weighted avg': {'precision': 0.6666666666666666, 'recall': 0.6666666666666666, 'f1-score': 0.6666666666666666, 'support': 42}} 16

# %%
results_mk={"result_alpha":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (alpha_data1.loc[alpha_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = alpha_data1.loc[alpha_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=200)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_alpha'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean = 0.0
for i in results_mk['result_alpha'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_alpha'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
print(mean/len(results_mk['result_alpha']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.46089064515465283 0.6666666666666666 {'Disike': {'precision': 0.6086956521739131, 'recall': 0.7368421052631579, 'f1-score': 0.6666666666666666, 'support': 19}, 'Like': {'precision': 0.7368421052631579, 'recall': 0.6086956521739131, 'f1-score': 0.6666666666666666, 'support': 23}, 'accuracy': 0.6666666666666666, 'macro avg': {'precision': 0.6727688787185355, 'recall': 0.6727688787185355, 'f1-score': 0.6666666666666666, 'support': 42}, 'weighted avg': {'precision': 0.6788710907704042, 'recall': 0.6666666666666666, 'f1-score': 0.6666666666666666, 'support': 42}} 18

# %%
results_mk={"result_delta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (delta_data1.loc[delta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = delta_data1.loc[delta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=200)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_delta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_delta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_delta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean +=i['macro avg']['f1-score'] 
print(mean/len(results_mk['result_delta']),maxx,j,k)
# Out:
# 0.4500763572653319 0.6038647342995169 {'Disike': {'precision': 0.6, 'recall': 0.7142857142857143, 'f1-score': 0.6521739130434783, 'support': 21}, 'Like': {'precision': 0.625, 'recall': 0.5, 'f1-score': 0.5555555555555556, 'support': 20}, 'accuracy': 0.6097560975609756, 'macro avg': {'precision': 0.6125, 'recall': 0.6071428571428572, 'f1-score': 0.6038647342995169, 'support': 41}, 'weighted avg': {'precision': 0.6121951219512195, 'recall': 0.6097560975609756, 'f1-score': 0.6050430069518087, 'support': 41}} 8

# %%
results_mk={"result_merged":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (merged.loc[merged['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = merged.loc[merged['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=200)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_merged'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_merged'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_merged'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean += i['macro avg']['f1-score']
print(mean/len(results_mk['result_merged']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.48667136821502444 0.6566985645933014 {'Disike': {'precision': 0.7058823529411765, 'recall': 0.5714285714285714, 'f1-score': 0.6315789473684211, 'support': 21}, 'Like': {'precision': 0.625, 'recall': 0.75, 'f1-score': 0.6818181818181818, 'support': 20}, 'accuracy': 0.6585365853658537, 'macro avg': {'precision': 0.6654411764705883, 'recall': 0.6607142857142857, 'f1-score': 0.6566985645933014, 'support': 41}, 'weighted avg': {'precision': 0.6664275466284075, 'recall': 0.6585365853658537, 'f1-score': 0.6560858910024507, 'support': 41}} 1
