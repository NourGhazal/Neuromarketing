# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.signal 
import pywt
from sklearn.ensemble import RandomForestClassifier as rf
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,precision_score
import statistics
from sklearn.svm import SVC
import six
import sys
sys.modules['sklearn.externals.six'] = six
from scipy.special import logsumexp
sys.modules['scipy.misc.logsumexp'] = logsumexp
from seqlearn import hmm
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn import preprocessing
from imblearn.over_sampling import SMOTE

# %%
def carf(row):
    for i,elect in row.items():
        elect-=statistics.mean(row)
        row[i]= elect
    return row

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
    "4thgamma":[],
    "5thgamma":[],
    "6thgamma":[],
    "7thgamma":[],
    "8thgamma":[],
    "9thgamma":[],
    "10thgamma":[],
    "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
    "4thbeta":[],
    "5thbeta":[],
    "6thbeta":[],
    "7thbeta":[],
    "8thbeta":[],
    "9thbeta":[],
    "10thbeta":[],
    "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
    "4thalpha":[],
    "5thalpha":[],
    "6thalpha":[],
    "7thalpha":[],
    "8thalpha":[],
    "9thalpha":[],
    "10thalpha":[],
    "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
    "4ththeta":[],
    "5ththeta":[],
    "6ththeta":[],
    "7ththeta":[],
    "8ththeta":[],
    "9ththeta":[],
    "10ththeta":[],
    "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
    "4thdelta":[],
    "5thdelta":[],
    "6thdelta":[],
    "7thdelta":[],
    "8thdelta":[],
    "9thdelta":[],
    "10thdelta":[],
    "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/youssef/"+str(i+1)+".txt",header=None,names=["label"])
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/youssef"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
        '4th':[],
        '5th':[],
        '6th':[],
        '7th':[],
        '8th':[],
        '9th':[],
        '10th':[],
        '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
        user_data['4th'].append(float(ny[3]))
        user_data['5th'].append(float(ny[4]))
        user_data['6th'].append(float(ny[5]))
        user_data['7th'].append(float(ny[6]))
        user_data['8th'].append(float(ny[7]))
        user_data['9th'].append(float(ny[8]))
        user_data['10th'].append(float(ny[9]))
        user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
    fourth_electrode = user_data['4th']
    fifth_electrode = user_data['5th']
    sixth_electrode = user_data['6th']
    seventh_electrode = user_data['7th']
    eighth_electrode = user_data['8th']
    nineth_electrode = user_data['9th']
    tenth_electrode = user_data['10th']
    eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
    s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
    s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
    s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
    s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
    s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
    s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
    s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
    s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

    cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
    cA42, d42 = pywt.dwt(cA4, 'db4')
    cA43, d43 = pywt.dwt(cA42, 'db4')
    a44, d44 = pywt.dwt(cA43, 'db4')
    gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
    beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
    alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
    theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
    delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
    gamma_data1['4thgamma'].append(gamma_RMS4)
    beta_data1['4thbeta'].append(beta_RMS4)
    alpha_data1['4thalpha'].append(alpha_RMS4)
    theta_data1['4ththeta'].append(theta_RMS4)
    delta_data1['4thdelta'].append(delta_RMS4)

    cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
    cA52, d52 = pywt.dwt(cA5, 'db4')
    cA53, d53 = pywt.dwt(cA52, 'db4')
    a54, d54 = pywt.dwt(cA53, 'db4')
    gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
    beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
    alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
    theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
    delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
    gamma_data1['5thgamma'].append(gamma_RMS5)
    beta_data1['5thbeta'].append(beta_RMS5)
    alpha_data1['5thalpha'].append(alpha_RMS5)
    theta_data1['5ththeta'].append(theta_RMS5)
    delta_data1['5thdelta'].append(delta_RMS5)

    cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
    cA62, d62 = pywt.dwt(cA6, 'db4')
    cA63, d63 = pywt.dwt(cA62, 'db4')
    a64, d64 = pywt.dwt(cA63, 'db4')
    gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
    beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
    alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
    theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
    delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
    gamma_data1['6thgamma'].append(gamma_RMS6)
    beta_data1['6thbeta'].append(beta_RMS6)
    alpha_data1['6thalpha'].append(alpha_RMS6)
    theta_data1['6ththeta'].append(theta_RMS6)
    delta_data1['6thdelta'].append(delta_RMS6)
    

    cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
    cA72, d72 = pywt.dwt(cA7, 'db4')
    cA73, d73 = pywt.dwt(cA72, 'db4')
    a74, d74 = pywt.dwt(cA73, 'db4')
    gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
    beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
    alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
    theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
    delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
    gamma_data1['7thgamma'].append(gamma_RMS7)
    beta_data1['7thbeta'].append(beta_RMS7)
    alpha_data1['7thalpha'].append(alpha_RMS7)
    theta_data1['7ththeta'].append(theta_RMS7)
    delta_data1['7thdelta'].append(delta_RMS7)

    cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
    cA82, d82 = pywt.dwt(cA8, 'db4')
    cA83, d83 = pywt.dwt(cA82, 'db4')
    a84, d84 = pywt.dwt(cA83, 'db4')
    gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
    beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
    alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
    theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
    delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
    gamma_data1['8thgamma'].append(gamma_RMS8)
    beta_data1['8thbeta'].append(beta_RMS8)
    alpha_data1['8thalpha'].append(alpha_RMS8)
    theta_data1['8ththeta'].append(theta_RMS8)
    delta_data1['8thdelta'].append(delta_RMS8)

    cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
    cA92, d92 = pywt.dwt(cA9, 'db4')
    cA93, d93 = pywt.dwt(cA92, 'db4')
    a94, d94 = pywt.dwt(cA93, 'db4')
    gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
    beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
    alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
    theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
    delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
    gamma_data1['9thgamma'].append(gamma_RMS9)
    beta_data1['9thbeta'].append(beta_RMS9)
    alpha_data1['9thalpha'].append(alpha_RMS9)
    theta_data1['9ththeta'].append(theta_RMS9)
    delta_data1['9thdelta'].append(delta_RMS9)

    cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
    cA102, d102 = pywt.dwt(cA10, 'db4')
    cA103, d103 = pywt.dwt(cA102, 'db4')
    a104, d104 = pywt.dwt(cA103, 'db4')
    gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
    beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
    alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
    theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
    delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
    gamma_data1['10thgamma'].append(gamma_RMS10)
    beta_data1['10thbeta'].append(beta_RMS10)
    alpha_data1['10thalpha'].append(alpha_RMS10)
    theta_data1['10ththeta'].append(theta_RMS10)
    delta_data1['10thdelta'].append(delta_RMS10)

    cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
    cA112, d112 = pywt.dwt(cA11, 'db4')
    cA113, d113 = pywt.dwt(cA112, 'db4')
    a114, d114 = pywt.dwt(cA113, 'db4')
    gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
    beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
    alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
    theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
    delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
    gamma_data1['11thgamma'].append(gamma_RMS11)
    beta_data1['11thbeta'].append(beta_RMS11)
    alpha_data1['11thalpha'].append(alpha_RMS11)
    theta_data1['11ththeta'].append(theta_RMS11)
    delta_data1['11thdelta'].append(delta_RMS11)

    cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
    cA122, d122 = pywt.dwt(cA12, 'db4')
    cA123, d123 = pywt.dwt(cA122, 'db4')
    a124, d124 = pywt.dwt(cA123, 'db4')
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
    gamma_data1['12thgamma'].append(gamma_RMS12)
    beta_data1['12thbeta'].append(beta_RMS12)
    alpha_data1['12thalpha'].append(alpha_RMS12)
    theta_data1['12ththeta'].append(theta_RMS12)
    delta_data1['12thdelta'].append(delta_RMS12)

    cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
    cA132, d132 = pywt.dwt(cA13, 'db4')
    cA133, d133 = pywt.dwt(cA132, 'db4')
    a134, d134 = pywt.dwt(cA133, 'db4')
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
    gamma_data1['13thgamma'].append(gamma_RMS13)
    beta_data1['13thbeta'].append(beta_RMS13)
    alpha_data1['13thalpha'].append(alpha_RMS13)
    theta_data1['13ththeta'].append(theta_RMS13)
    delta_data1['13thdelta'].append(delta_RMS13)

    cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
    cA142, d142 = pywt.dwt(cA14, 'db4')
    cA143, d143 = pywt.dwt(cA142, 'db4')
    a144, d144 = pywt.dwt(cA143, 'db4')
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
    gamma_data1['14thgamma'].append(gamma_RMS14)
    beta_data1['14thbeta'].append(beta_RMS14)
    alpha_data1['14thalpha'].append(alpha_RMS14)
    theta_data1['14ththeta'].append(theta_RMS14)
    delta_data1['14thdelta'].append(delta_RMS14)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}

for i in range(20):
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.2,stratify=labels)
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.2,stratify=labels)
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.2,stratify=labels)
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.2,stratify=labels)
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.2,stratify=labels)
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.2,stratify=labels)

    dtree1 = RandomForestClassifier(n_estimators=2000)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    dtree2 = RandomForestClassifier(n_estimators=2000)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    dtree3 = RandomForestClassifier(n_estimators=2000)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    dtree4 = RandomForestClassifier(n_estimators=2000)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    dtree5 = RandomForestClassifier(n_estimators=2000)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

    dtree6 = RandomForestClassifier(n_estimators=2000)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.294682400932401
#  beta= 0.33096533912710385
#  alpha= 0.2889492588021999
#  delta= 0.2062457250924743
#  theta= 0.30416021356810835
#  merged= 0.24902719557131325

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
    "4thgamma":[],
    "5thgamma":[],
    "6thgamma":[],
    "7thgamma":[],
    "8thgamma":[],
    "9thgamma":[],
    "10thgamma":[],
    "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
    "4thbeta":[],
    "5thbeta":[],
    "6thbeta":[],
    "7thbeta":[],
    "8thbeta":[],
    "9thbeta":[],
    "10thbeta":[],
    "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
    "4thalpha":[],
    "5thalpha":[],
    "6thalpha":[],
    "7thalpha":[],
    "8thalpha":[],
    "9thalpha":[],
    "10thalpha":[],
    "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
    "4ththeta":[],
    "5ththeta":[],
    "6ththeta":[],
    "7ththeta":[],
    "8ththeta":[],
    "9ththeta":[],
    "10ththeta":[],
    "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
    "4thdelta":[],
    "5thdelta":[],
    "6thdelta":[],
    "7thdelta":[],
    "8thdelta":[],
    "9thdelta":[],
    "10thdelta":[],
    "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/youssef/"+str(i+1)+".txt",header=None,names=["label"])
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/youssef"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
        '4th':[],
        '5th':[],
        '6th':[],
        '7th':[],
        '8th':[],
        '9th':[],
        '10th':[],
        '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
        user_data['4th'].append(float(ny[3]))
        user_data['5th'].append(float(ny[4]))
        user_data['6th'].append(float(ny[5]))
        user_data['7th'].append(float(ny[6]))
        user_data['8th'].append(float(ny[7]))
        user_data['9th'].append(float(ny[8]))
        user_data['10th'].append(float(ny[9]))
        user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
    fourth_electrode = user_data['4th']
    fifth_electrode = user_data['5th']
    sixth_electrode = user_data['6th']
    seventh_electrode = user_data['7th']
    eighth_electrode = user_data['8th']
    nineth_electrode = user_data['9th']
    tenth_electrode = user_data['10th']
    eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
    s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
    s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
    s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
    s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
    s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
    s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
    s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
    s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

    cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
    cA42, d42 = pywt.dwt(cA4, 'db4')
    cA43, d43 = pywt.dwt(cA42, 'db4')
    a44, d44 = pywt.dwt(cA43, 'db4')
    gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
    beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
    alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
    theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
    delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
    gamma_data1['4thgamma'].append(gamma_RMS4)
    beta_data1['4thbeta'].append(beta_RMS4)
    alpha_data1['4thalpha'].append(alpha_RMS4)
    theta_data1['4ththeta'].append(theta_RMS4)
    delta_data1['4thdelta'].append(delta_RMS4)

    cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
    cA52, d52 = pywt.dwt(cA5, 'db4')
    cA53, d53 = pywt.dwt(cA52, 'db4')
    a54, d54 = pywt.dwt(cA53, 'db4')
    gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
    beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
    alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
    theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
    delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
    gamma_data1['5thgamma'].append(gamma_RMS5)
    beta_data1['5thbeta'].append(beta_RMS5)
    alpha_data1['5thalpha'].append(alpha_RMS5)
    theta_data1['5ththeta'].append(theta_RMS5)
    delta_data1['5thdelta'].append(delta_RMS5)

    cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
    cA62, d62 = pywt.dwt(cA6, 'db4')
    cA63, d63 = pywt.dwt(cA62, 'db4')
    a64, d64 = pywt.dwt(cA63, 'db4')
    gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
    beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
    alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
    theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
    delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
    gamma_data1['6thgamma'].append(gamma_RMS6)
    beta_data1['6thbeta'].append(beta_RMS6)
    alpha_data1['6thalpha'].append(alpha_RMS6)
    theta_data1['6ththeta'].append(theta_RMS6)
    delta_data1['6thdelta'].append(delta_RMS6)
    

    cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
    cA72, d72 = pywt.dwt(cA7, 'db4')
    cA73, d73 = pywt.dwt(cA72, 'db4')
    a74, d74 = pywt.dwt(cA73, 'db4')
    gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
    beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
    alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
    theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
    delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
    gamma_data1['7thgamma'].append(gamma_RMS7)
    beta_data1['7thbeta'].append(beta_RMS7)
    alpha_data1['7thalpha'].append(alpha_RMS7)
    theta_data1['7ththeta'].append(theta_RMS7)
    delta_data1['7thdelta'].append(delta_RMS7)

    cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
    cA82, d82 = pywt.dwt(cA8, 'db4')
    cA83, d83 = pywt.dwt(cA82, 'db4')
    a84, d84 = pywt.dwt(cA83, 'db4')
    gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
    beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
    alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
    theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
    delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
    gamma_data1['8thgamma'].append(gamma_RMS8)
    beta_data1['8thbeta'].append(beta_RMS8)
    alpha_data1['8thalpha'].append(alpha_RMS8)
    theta_data1['8ththeta'].append(theta_RMS8)
    delta_data1['8thdelta'].append(delta_RMS8)

    cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
    cA92, d92 = pywt.dwt(cA9, 'db4')
    cA93, d93 = pywt.dwt(cA92, 'db4')
    a94, d94 = pywt.dwt(cA93, 'db4')
    gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
    beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
    alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
    theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
    delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
    gamma_data1['9thgamma'].append(gamma_RMS9)
    beta_data1['9thbeta'].append(beta_RMS9)
    alpha_data1['9thalpha'].append(alpha_RMS9)
    theta_data1['9ththeta'].append(theta_RMS9)
    delta_data1['9thdelta'].append(delta_RMS9)

    cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
    cA102, d102 = pywt.dwt(cA10, 'db4')
    cA103, d103 = pywt.dwt(cA102, 'db4')
    a104, d104 = pywt.dwt(cA103, 'db4')
    gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
    beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
    alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
    theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
    delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
    gamma_data1['10thgamma'].append(gamma_RMS10)
    beta_data1['10thbeta'].append(beta_RMS10)
    alpha_data1['10thalpha'].append(alpha_RMS10)
    theta_data1['10ththeta'].append(theta_RMS10)
    delta_data1['10thdelta'].append(delta_RMS10)

    cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
    cA112, d112 = pywt.dwt(cA11, 'db4')
    cA113, d113 = pywt.dwt(cA112, 'db4')
    a114, d114 = pywt.dwt(cA113, 'db4')
    gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
    beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
    alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
    theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
    delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
    gamma_data1['11thgamma'].append(gamma_RMS11)
    beta_data1['11thbeta'].append(beta_RMS11)
    alpha_data1['11thalpha'].append(alpha_RMS11)
    theta_data1['11ththeta'].append(theta_RMS11)
    delta_data1['11thdelta'].append(delta_RMS11)

    cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
    cA122, d122 = pywt.dwt(cA12, 'db4')
    cA123, d123 = pywt.dwt(cA122, 'db4')
    a124, d124 = pywt.dwt(cA123, 'db4')
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
    gamma_data1['12thgamma'].append(gamma_RMS12)
    beta_data1['12thbeta'].append(beta_RMS12)
    alpha_data1['12thalpha'].append(alpha_RMS12)
    theta_data1['12ththeta'].append(theta_RMS12)
    delta_data1['12thdelta'].append(delta_RMS12)

    cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
    cA132, d132 = pywt.dwt(cA13, 'db4')
    cA133, d133 = pywt.dwt(cA132, 'db4')
    a134, d134 = pywt.dwt(cA133, 'db4')
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
    gamma_data1['13thgamma'].append(gamma_RMS13)
    beta_data1['13thbeta'].append(beta_RMS13)
    alpha_data1['13thalpha'].append(alpha_RMS13)
    theta_data1['13ththeta'].append(theta_RMS13)
    delta_data1['13thdelta'].append(delta_RMS13)

    cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
    cA142, d142 = pywt.dwt(cA14, 'db4')
    cA143, d143 = pywt.dwt(cA142, 'db4')
    a144, d144 = pywt.dwt(cA143, 'db4')
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
    gamma_data1['14thgamma'].append(gamma_RMS14)
    beta_data1['14thbeta'].append(beta_RMS14)
    alpha_data1['14thalpha'].append(alpha_RMS14)
    theta_data1['14ththeta'].append(theta_RMS14)
    delta_data1['14thdelta'].append(delta_RMS14)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}

for i in range(20):
    
    standard_gamma = StandardScaler().fit_transform(gamma_data1) 
    normalised_gamma = pd.DataFrame(standard_gamma)
    pca_gamma = PCA(n_components=0.9)
    principalComponents_gamma = pca_gamma.fit_transform(standard_gamma)
    gamma_data1 = pd.DataFrame(data = principalComponents_gamma)
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.2,stratify=labels)

    standard_beta = StandardScaler().fit_transform(beta_data1) 
    normalised_beta = pd.DataFrame(standard_beta)
    pca_beta = PCA(n_components=0.9)
    principalComponents_beta = pca_beta.fit_transform(standard_beta)
    beta_data1 = pd.DataFrame(data = principalComponents_beta)
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.2,stratify=labels)

    standard_alpha = StandardScaler().fit_transform(alpha_data1) 
    normalised_alpha = pd.DataFrame(standard_alpha)
    pca_alpha = PCA(n_components=0.9)
    principalComponents_alpha = pca_alpha.fit_transform(standard_alpha)
    alpha_data1 = pd.DataFrame(data = principalComponents_alpha)
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.2,stratify=labels)

    standard_theta = StandardScaler().fit_transform(theta_data1) 
    normalised_theta = pd.DataFrame(standard_theta)
    pca_theta = PCA(n_components=0.9)
    principalComponents_theta = pca_theta.fit_transform(standard_theta)
    theta_data1 = pd.DataFrame(data = principalComponents_theta)
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.2,stratify=labels)


    standard_delta = StandardScaler().fit_transform(delta_data1) 
    normalised_delta = pd.DataFrame(standard_delta)
    pca_delta = PCA(n_components=0.9)
    principalComponents_delta = pca_delta.fit_transform(standard_delta)
    delta_data1 = pd.DataFrame(data = principalComponents_delta)
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.2,stratify=labels)

    standard_merged = StandardScaler().fit_transform(merged) 
    normalised_merged = pd.DataFrame(standard_merged)
    pca_merged = PCA(n_components=0.9)
    principalComponents_merged = pca_merged.fit_transform(standard_merged)
    merged = pd.DataFrame(data = principalComponents_merged)
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.2,stratify=labels)

    dtree1 = RandomForestClassifier(n_estimators=200)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    dtree2 = RandomForestClassifier(n_estimators=200)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    dtree3 = RandomForestClassifier(n_estimators=200)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    dtree4 = RandomForestClassifier(n_estimators=200)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    dtree5 = RandomForestClassifier(n_estimators=200)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

    dtree6 = RandomForestClassifier(n_estimators=200)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.260144555736661
#  beta= 0.3036848581701522
#  alpha= 0.2949976575711869
#  delta= 0.2567201262789499
#  theta= 0.31609863290590845
#  merged= 0.23830885617650321

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
    "4thgamma":[],
    "5thgamma":[],
    "6thgamma":[],
    "7thgamma":[],
    "8thgamma":[],
    "9thgamma":[],
    "10thgamma":[],
    "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
    "4thbeta":[],
    "5thbeta":[],
    "6thbeta":[],
    "7thbeta":[],
    "8thbeta":[],
    "9thbeta":[],
    "10thbeta":[],
    "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
    "4thalpha":[],
    "5thalpha":[],
    "6thalpha":[],
    "7thalpha":[],
    "8thalpha":[],
    "9thalpha":[],
    "10thalpha":[],
    "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
    "4ththeta":[],
    "5ththeta":[],
    "6ththeta":[],
    "7ththeta":[],
    "8ththeta":[],
    "9ththeta":[],
    "10ththeta":[],
    "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
    "4thdelta":[],
    "5thdelta":[],
    "6thdelta":[],
    "7thdelta":[],
    "8thdelta":[],
    "9thdelta":[],
    "10thdelta":[],
    "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/youssef/"+str(i+1)+".txt",header=None,names=["label"])
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/youssef"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
        '4th':[],
        '5th':[],
        '6th':[],
        '7th':[],
        '8th':[],
        '9th':[],
        '10th':[],
        '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
        user_data['4th'].append(float(ny[3]))
        user_data['5th'].append(float(ny[4]))
        user_data['6th'].append(float(ny[5]))
        user_data['7th'].append(float(ny[6]))
        user_data['8th'].append(float(ny[7]))
        user_data['9th'].append(float(ny[8]))
        user_data['10th'].append(float(ny[9]))
        user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
    fourth_electrode = user_data['4th']
    fifth_electrode = user_data['5th']
    sixth_electrode = user_data['6th']
    seventh_electrode = user_data['7th']
    eighth_electrode = user_data['8th']
    nineth_electrode = user_data['9th']
    tenth_electrode = user_data['10th']
    eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
    s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
    s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
    s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
    s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
    s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
    s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
    s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
    s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

    cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
    cA42, d42 = pywt.dwt(cA4, 'db4')
    cA43, d43 = pywt.dwt(cA42, 'db4')
    a44, d44 = pywt.dwt(cA43, 'db4')
    gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
    beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
    alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
    theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
    delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
    gamma_data1['4thgamma'].append(gamma_RMS4)
    beta_data1['4thbeta'].append(beta_RMS4)
    alpha_data1['4thalpha'].append(alpha_RMS4)
    theta_data1['4ththeta'].append(theta_RMS4)
    delta_data1['4thdelta'].append(delta_RMS4)

    cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
    cA52, d52 = pywt.dwt(cA5, 'db4')
    cA53, d53 = pywt.dwt(cA52, 'db4')
    a54, d54 = pywt.dwt(cA53, 'db4')
    gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
    beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
    alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
    theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
    delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
    gamma_data1['5thgamma'].append(gamma_RMS5)
    beta_data1['5thbeta'].append(beta_RMS5)
    alpha_data1['5thalpha'].append(alpha_RMS5)
    theta_data1['5ththeta'].append(theta_RMS5)
    delta_data1['5thdelta'].append(delta_RMS5)

    cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
    cA62, d62 = pywt.dwt(cA6, 'db4')
    cA63, d63 = pywt.dwt(cA62, 'db4')
    a64, d64 = pywt.dwt(cA63, 'db4')
    gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
    beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
    alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
    theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
    delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
    gamma_data1['6thgamma'].append(gamma_RMS6)
    beta_data1['6thbeta'].append(beta_RMS6)
    alpha_data1['6thalpha'].append(alpha_RMS6)
    theta_data1['6ththeta'].append(theta_RMS6)
    delta_data1['6thdelta'].append(delta_RMS6)
    

    cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
    cA72, d72 = pywt.dwt(cA7, 'db4')
    cA73, d73 = pywt.dwt(cA72, 'db4')
    a74, d74 = pywt.dwt(cA73, 'db4')
    gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
    beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
    alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
    theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
    delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
    gamma_data1['7thgamma'].append(gamma_RMS7)
    beta_data1['7thbeta'].append(beta_RMS7)
    alpha_data1['7thalpha'].append(alpha_RMS7)
    theta_data1['7ththeta'].append(theta_RMS7)
    delta_data1['7thdelta'].append(delta_RMS7)

    cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
    cA82, d82 = pywt.dwt(cA8, 'db4')
    cA83, d83 = pywt.dwt(cA82, 'db4')
    a84, d84 = pywt.dwt(cA83, 'db4')
    gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
    beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
    alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
    theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
    delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
    gamma_data1['8thgamma'].append(gamma_RMS8)
    beta_data1['8thbeta'].append(beta_RMS8)
    alpha_data1['8thalpha'].append(alpha_RMS8)
    theta_data1['8ththeta'].append(theta_RMS8)
    delta_data1['8thdelta'].append(delta_RMS8)

    cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
    cA92, d92 = pywt.dwt(cA9, 'db4')
    cA93, d93 = pywt.dwt(cA92, 'db4')
    a94, d94 = pywt.dwt(cA93, 'db4')
    gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
    beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
    alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
    theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
    delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
    gamma_data1['9thgamma'].append(gamma_RMS9)
    beta_data1['9thbeta'].append(beta_RMS9)
    alpha_data1['9thalpha'].append(alpha_RMS9)
    theta_data1['9ththeta'].append(theta_RMS9)
    delta_data1['9thdelta'].append(delta_RMS9)

    cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
    cA102, d102 = pywt.dwt(cA10, 'db4')
    cA103, d103 = pywt.dwt(cA102, 'db4')
    a104, d104 = pywt.dwt(cA103, 'db4')
    gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
    beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
    alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
    theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
    delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
    gamma_data1['10thgamma'].append(gamma_RMS10)
    beta_data1['10thbeta'].append(beta_RMS10)
    alpha_data1['10thalpha'].append(alpha_RMS10)
    theta_data1['10ththeta'].append(theta_RMS10)
    delta_data1['10thdelta'].append(delta_RMS10)

    cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
    cA112, d112 = pywt.dwt(cA11, 'db4')
    cA113, d113 = pywt.dwt(cA112, 'db4')
    a114, d114 = pywt.dwt(cA113, 'db4')
    gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
    beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
    alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
    theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
    delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
    gamma_data1['11thgamma'].append(gamma_RMS11)
    beta_data1['11thbeta'].append(beta_RMS11)
    alpha_data1['11thalpha'].append(alpha_RMS11)
    theta_data1['11ththeta'].append(theta_RMS11)
    delta_data1['11thdelta'].append(delta_RMS11)

    cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
    cA122, d122 = pywt.dwt(cA12, 'db4')
    cA123, d123 = pywt.dwt(cA122, 'db4')
    a124, d124 = pywt.dwt(cA123, 'db4')
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
    gamma_data1['12thgamma'].append(gamma_RMS12)
    beta_data1['12thbeta'].append(beta_RMS12)
    alpha_data1['12thalpha'].append(alpha_RMS12)
    theta_data1['12ththeta'].append(theta_RMS12)
    delta_data1['12thdelta'].append(delta_RMS12)

    cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
    cA132, d132 = pywt.dwt(cA13, 'db4')
    cA133, d133 = pywt.dwt(cA132, 'db4')
    a134, d134 = pywt.dwt(cA133, 'db4')
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
    gamma_data1['13thgamma'].append(gamma_RMS13)
    beta_data1['13thbeta'].append(beta_RMS13)
    alpha_data1['13thalpha'].append(alpha_RMS13)
    theta_data1['13ththeta'].append(theta_RMS13)
    delta_data1['13thdelta'].append(delta_RMS13)

    cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
    cA142, d142 = pywt.dwt(cA14, 'db4')
    cA143, d143 = pywt.dwt(cA142, 'db4')
    a144, d144 = pywt.dwt(cA143, 'db4')
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
    gamma_data1['14thgamma'].append(gamma_RMS14)
    beta_data1['14thbeta'].append(beta_RMS14)
    alpha_data1['14thalpha'].append(alpha_RMS14)
    theta_data1['14ththeta'].append(theta_RMS14)
    delta_data1['14thdelta'].append(delta_RMS14)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}

for i in range(20):
    
    pca_gamma = PCA(n_components=0.9)
    principalComponents_gamma = pca_gamma.fit_transform(gamma_data1)
    gamma_data1 = pd.DataFrame(data = principalComponents_gamma)
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.1,stratify=labels)


    pca_beta = PCA(n_components=0.9)
    principalComponents_beta = pca_beta.fit_transform(beta_data1)
    beta_data1 = pd.DataFrame(data = principalComponents_beta)
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.2,stratify=labels)


    pca_alpha = PCA(n_components=0.9)
    principalComponents_alpha = pca_alpha.fit_transform(alpha_data1)
    alpha_data1 = pd.DataFrame(data = principalComponents_alpha)
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.2,stratify=labels)


    pca_theta = PCA(n_components=0.9)
    principalComponents_theta = pca_theta.fit_transform(theta_data1)
    theta_data1 = pd.DataFrame(data = principalComponents_theta)
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.2,stratify=labels)



    pca_delta = PCA(n_components=0.9)
    principalComponents_delta = pca_delta.fit_transform(delta_data1)
    delta_data1 = pd.DataFrame(data = principalComponents_delta)
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.2,stratify=labels)


    pca_merged = PCA(n_components=0.9)
    principalComponents_merged = pca_merged.fit_transform(merged)
    merged = pd.DataFrame(data = principalComponents_merged)
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.2,stratify=labels)

    dtree1 = RandomForestClassifier(n_estimators=200)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    dtree2 = RandomForestClassifier(n_estimators=200)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    dtree3 = RandomForestClassifier(n_estimators=200)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    dtree4 = RandomForestClassifier(n_estimators=200)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    dtree5 = RandomForestClassifier(n_estimators=200)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

    dtree6 = RandomForestClassifier(n_estimators=200)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.3693518518518518
#  beta= 0.30777509527509533
#  alpha= 0.21972324244383068
#  delta= 0.23672565996095404
#  theta= 0.29439694564694563
#  merged= 0.3174115535880242

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
    "4thgamma":[],
    "5thgamma":[],
    "6thgamma":[],
    "7thgamma":[],
    "8thgamma":[],
    "9thgamma":[],
    "10thgamma":[],
    "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
    "4thbeta":[],
    "5thbeta":[],
    "6thbeta":[],
    "7thbeta":[],
    "8thbeta":[],
    "9thbeta":[],
    "10thbeta":[],
    "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
    "4thalpha":[],
    "5thalpha":[],
    "6thalpha":[],
    "7thalpha":[],
    "8thalpha":[],
    "9thalpha":[],
    "10thalpha":[],
    "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
    "4ththeta":[],
    "5ththeta":[],
    "6ththeta":[],
    "7ththeta":[],
    "8ththeta":[],
    "9ththeta":[],
    "10ththeta":[],
    "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
    "4thdelta":[],
    "5thdelta":[],
    "6thdelta":[],
    "7thdelta":[],
    "8thdelta":[],
    "9thdelta":[],
    "10thdelta":[],
    "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/ziaaad/"+str(i+1)+".txt",header=None,names=["label"])
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/ziaaad_"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
        '4th':[],
        '5th':[],
        '6th':[],
        '7th':[],
        '8th':[],
        '9th':[],
        '10th':[],
        '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
        user_data['4th'].append(float(ny[3]))
        user_data['5th'].append(float(ny[4]))
        user_data['6th'].append(float(ny[5]))
        user_data['7th'].append(float(ny[6]))
        user_data['8th'].append(float(ny[7]))
        user_data['9th'].append(float(ny[8]))
        user_data['10th'].append(float(ny[9]))
        user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
    fourth_electrode = user_data['4th']
    fifth_electrode = user_data['5th']
    sixth_electrode = user_data['6th']
    seventh_electrode = user_data['7th']
    eighth_electrode = user_data['8th']
    nineth_electrode = user_data['9th']
    tenth_electrode = user_data['10th']
    eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
    s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
    s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
    s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
    s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
    s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
    s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
    s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
    s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

    cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
    cA42, d42 = pywt.dwt(cA4, 'db4')
    cA43, d43 = pywt.dwt(cA42, 'db4')
    a44, d44 = pywt.dwt(cA43, 'db4')
    gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
    beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
    alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
    theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
    delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
    gamma_data1['4thgamma'].append(gamma_RMS4)
    beta_data1['4thbeta'].append(beta_RMS4)
    alpha_data1['4thalpha'].append(alpha_RMS4)
    theta_data1['4ththeta'].append(theta_RMS4)
    delta_data1['4thdelta'].append(delta_RMS4)

    cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
    cA52, d52 = pywt.dwt(cA5, 'db4')
    cA53, d53 = pywt.dwt(cA52, 'db4')
    a54, d54 = pywt.dwt(cA53, 'db4')
    gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
    beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
    alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
    theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
    delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
    gamma_data1['5thgamma'].append(gamma_RMS5)
    beta_data1['5thbeta'].append(beta_RMS5)
    alpha_data1['5thalpha'].append(alpha_RMS5)
    theta_data1['5ththeta'].append(theta_RMS5)
    delta_data1['5thdelta'].append(delta_RMS5)

    cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
    cA62, d62 = pywt.dwt(cA6, 'db4')
    cA63, d63 = pywt.dwt(cA62, 'db4')
    a64, d64 = pywt.dwt(cA63, 'db4')
    gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
    beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
    alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
    theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
    delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
    gamma_data1['6thgamma'].append(gamma_RMS6)
    beta_data1['6thbeta'].append(beta_RMS6)
    alpha_data1['6thalpha'].append(alpha_RMS6)
    theta_data1['6ththeta'].append(theta_RMS6)
    delta_data1['6thdelta'].append(delta_RMS6)
    

    cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
    cA72, d72 = pywt.dwt(cA7, 'db4')
    cA73, d73 = pywt.dwt(cA72, 'db4')
    a74, d74 = pywt.dwt(cA73, 'db4')
    gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
    beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
    alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
    theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
    delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
    gamma_data1['7thgamma'].append(gamma_RMS7)
    beta_data1['7thbeta'].append(beta_RMS7)
    alpha_data1['7thalpha'].append(alpha_RMS7)
    theta_data1['7ththeta'].append(theta_RMS7)
    delta_data1['7thdelta'].append(delta_RMS7)

    cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
    cA82, d82 = pywt.dwt(cA8, 'db4')
    cA83, d83 = pywt.dwt(cA82, 'db4')
    a84, d84 = pywt.dwt(cA83, 'db4')
    gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
    beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
    alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
    theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
    delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
    gamma_data1['8thgamma'].append(gamma_RMS8)
    beta_data1['8thbeta'].append(beta_RMS8)
    alpha_data1['8thalpha'].append(alpha_RMS8)
    theta_data1['8ththeta'].append(theta_RMS8)
    delta_data1['8thdelta'].append(delta_RMS8)

    cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
    cA92, d92 = pywt.dwt(cA9, 'db4')
    cA93, d93 = pywt.dwt(cA92, 'db4')
    a94, d94 = pywt.dwt(cA93, 'db4')
    gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
    beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
    alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
    theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
    delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
    gamma_data1['9thgamma'].append(gamma_RMS9)
    beta_data1['9thbeta'].append(beta_RMS9)
    alpha_data1['9thalpha'].append(alpha_RMS9)
    theta_data1['9ththeta'].append(theta_RMS9)
    delta_data1['9thdelta'].append(delta_RMS9)

    cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
    cA102, d102 = pywt.dwt(cA10, 'db4')
    cA103, d103 = pywt.dwt(cA102, 'db4')
    a104, d104 = pywt.dwt(cA103, 'db4')
    gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
    beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
    alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
    theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
    delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
    gamma_data1['10thgamma'].append(gamma_RMS10)
    beta_data1['10thbeta'].append(beta_RMS10)
    alpha_data1['10thalpha'].append(alpha_RMS10)
    theta_data1['10ththeta'].append(theta_RMS10)
    delta_data1['10thdelta'].append(delta_RMS10)

    cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
    cA112, d112 = pywt.dwt(cA11, 'db4')
    cA113, d113 = pywt.dwt(cA112, 'db4')
    a114, d114 = pywt.dwt(cA113, 'db4')
    gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
    beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
    alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
    theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
    delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
    gamma_data1['11thgamma'].append(gamma_RMS11)
    beta_data1['11thbeta'].append(beta_RMS11)
    alpha_data1['11thalpha'].append(alpha_RMS11)
    theta_data1['11ththeta'].append(theta_RMS11)
    delta_data1['11thdelta'].append(delta_RMS11)

    cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
    cA122, d122 = pywt.dwt(cA12, 'db4')
    cA123, d123 = pywt.dwt(cA122, 'db4')
    a124, d124 = pywt.dwt(cA123, 'db4')
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
    gamma_data1['12thgamma'].append(gamma_RMS12)
    beta_data1['12thbeta'].append(beta_RMS12)
    alpha_data1['12thalpha'].append(alpha_RMS12)
    theta_data1['12ththeta'].append(theta_RMS12)
    delta_data1['12thdelta'].append(delta_RMS12)

    cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
    cA132, d132 = pywt.dwt(cA13, 'db4')
    cA133, d133 = pywt.dwt(cA132, 'db4')
    a134, d134 = pywt.dwt(cA133, 'db4')
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
    gamma_data1['13thgamma'].append(gamma_RMS13)
    beta_data1['13thbeta'].append(beta_RMS13)
    alpha_data1['13thalpha'].append(alpha_RMS13)
    theta_data1['13ththeta'].append(theta_RMS13)
    delta_data1['13thdelta'].append(delta_RMS13)

    cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
    cA142, d142 = pywt.dwt(cA14, 'db4')
    cA143, d143 = pywt.dwt(cA142, 'db4')
    a144, d144 = pywt.dwt(cA143, 'db4')
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
    gamma_data1['14thgamma'].append(gamma_RMS14)
    beta_data1['14thbeta'].append(beta_RMS14)
    alpha_data1['14thalpha'].append(alpha_RMS14)
    theta_data1['14ththeta'].append(theta_RMS14)
    delta_data1['14thdelta'].append(delta_RMS14)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}

for i in range(20):
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.2,stratify=labels)
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.2,stratify=labels)
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.2,stratify=labels)
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.2,stratify=labels)
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.2,stratify=labels)
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.2,stratify=labels)

    dtree1 = RandomForestClassifier(n_estimators=2000)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    dtree2 = RandomForestClassifier(n_estimators=2000)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    dtree3 = RandomForestClassifier(n_estimators=2000)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    dtree4 = RandomForestClassifier(n_estimators=2000)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    dtree5 = RandomForestClassifier(n_estimators=2000)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

    dtree6 = RandomForestClassifier(n_estimators=2000)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.268576790020726
#  beta= 0.32021929824561396
#  alpha= 0.27923162223875647
#  delta= 0.3409504529685577
#  theta= 0.29197229459243185
#  merged= 0.314703749932583

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
    "4thgamma":[],
    "5thgamma":[],
    "6thgamma":[],
    "7thgamma":[],
    "8thgamma":[],
    "9thgamma":[],
    "10thgamma":[],
    "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
    "4thbeta":[],
    "5thbeta":[],
    "6thbeta":[],
    "7thbeta":[],
    "8thbeta":[],
    "9thbeta":[],
    "10thbeta":[],
    "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
    "4thalpha":[],
    "5thalpha":[],
    "6thalpha":[],
    "7thalpha":[],
    "8thalpha":[],
    "9thalpha":[],
    "10thalpha":[],
    "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
    "4ththeta":[],
    "5ththeta":[],
    "6ththeta":[],
    "7ththeta":[],
    "8ththeta":[],
    "9ththeta":[],
    "10ththeta":[],
    "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
    "4thdelta":[],
    "5thdelta":[],
    "6thdelta":[],
    "7thdelta":[],
    "8thdelta":[],
    "9thdelta":[],
    "10thdelta":[],
    "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/ziaaad/"+str(i+1)+".txt",header=None,names=["label"])
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/ziaaad_"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
        '4th':[],
        '5th':[],
        '6th':[],
        '7th':[],
        '8th':[],
        '9th':[],
        '10th':[],
        '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
        user_data['4th'].append(float(ny[3]))
        user_data['5th'].append(float(ny[4]))
        user_data['6th'].append(float(ny[5]))
        user_data['7th'].append(float(ny[6]))
        user_data['8th'].append(float(ny[7]))
        user_data['9th'].append(float(ny[8]))
        user_data['10th'].append(float(ny[9]))
        user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
    fourth_electrode = user_data['4th']
    fifth_electrode = user_data['5th']
    sixth_electrode = user_data['6th']
    seventh_electrode = user_data['7th']
    eighth_electrode = user_data['8th']
    nineth_electrode = user_data['9th']
    tenth_electrode = user_data['10th']
    eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
    s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
    s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
    s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
    s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
    s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
    s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
    s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
    s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

    cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
    cA42, d42 = pywt.dwt(cA4, 'db4')
    cA43, d43 = pywt.dwt(cA42, 'db4')
    a44, d44 = pywt.dwt(cA43, 'db4')
    gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
    beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
    alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
    theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
    delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
    gamma_data1['4thgamma'].append(gamma_RMS4)
    beta_data1['4thbeta'].append(beta_RMS4)
    alpha_data1['4thalpha'].append(alpha_RMS4)
    theta_data1['4ththeta'].append(theta_RMS4)
    delta_data1['4thdelta'].append(delta_RMS4)

    cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
    cA52, d52 = pywt.dwt(cA5, 'db4')
    cA53, d53 = pywt.dwt(cA52, 'db4')
    a54, d54 = pywt.dwt(cA53, 'db4')
    gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
    beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
    alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
    theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
    delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
    gamma_data1['5thgamma'].append(gamma_RMS5)
    beta_data1['5thbeta'].append(beta_RMS5)
    alpha_data1['5thalpha'].append(alpha_RMS5)
    theta_data1['5ththeta'].append(theta_RMS5)
    delta_data1['5thdelta'].append(delta_RMS5)

    cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
    cA62, d62 = pywt.dwt(cA6, 'db4')
    cA63, d63 = pywt.dwt(cA62, 'db4')
    a64, d64 = pywt.dwt(cA63, 'db4')
    gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
    beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
    alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
    theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
    delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
    gamma_data1['6thgamma'].append(gamma_RMS6)
    beta_data1['6thbeta'].append(beta_RMS6)
    alpha_data1['6thalpha'].append(alpha_RMS6)
    theta_data1['6ththeta'].append(theta_RMS6)
    delta_data1['6thdelta'].append(delta_RMS6)
    

    cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
    cA72, d72 = pywt.dwt(cA7, 'db4')
    cA73, d73 = pywt.dwt(cA72, 'db4')
    a74, d74 = pywt.dwt(cA73, 'db4')
    gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
    beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
    alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
    theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
    delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
    gamma_data1['7thgamma'].append(gamma_RMS7)
    beta_data1['7thbeta'].append(beta_RMS7)
    alpha_data1['7thalpha'].append(alpha_RMS7)
    theta_data1['7ththeta'].append(theta_RMS7)
    delta_data1['7thdelta'].append(delta_RMS7)

    cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
    cA82, d82 = pywt.dwt(cA8, 'db4')
    cA83, d83 = pywt.dwt(cA82, 'db4')
    a84, d84 = pywt.dwt(cA83, 'db4')
    gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
    beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
    alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
    theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
    delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
    gamma_data1['8thgamma'].append(gamma_RMS8)
    beta_data1['8thbeta'].append(beta_RMS8)
    alpha_data1['8thalpha'].append(alpha_RMS8)
    theta_data1['8ththeta'].append(theta_RMS8)
    delta_data1['8thdelta'].append(delta_RMS8)

    cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
    cA92, d92 = pywt.dwt(cA9, 'db4')
    cA93, d93 = pywt.dwt(cA92, 'db4')
    a94, d94 = pywt.dwt(cA93, 'db4')
    gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
    beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
    alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
    theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
    delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
    gamma_data1['9thgamma'].append(gamma_RMS9)
    beta_data1['9thbeta'].append(beta_RMS9)
    alpha_data1['9thalpha'].append(alpha_RMS9)
    theta_data1['9ththeta'].append(theta_RMS9)
    delta_data1['9thdelta'].append(delta_RMS9)

    cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
    cA102, d102 = pywt.dwt(cA10, 'db4')
    cA103, d103 = pywt.dwt(cA102, 'db4')
    a104, d104 = pywt.dwt(cA103, 'db4')
    gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
    beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
    alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
    theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
    delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
    gamma_data1['10thgamma'].append(gamma_RMS10)
    beta_data1['10thbeta'].append(beta_RMS10)
    alpha_data1['10thalpha'].append(alpha_RMS10)
    theta_data1['10ththeta'].append(theta_RMS10)
    delta_data1['10thdelta'].append(delta_RMS10)

    cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
    cA112, d112 = pywt.dwt(cA11, 'db4')
    cA113, d113 = pywt.dwt(cA112, 'db4')
    a114, d114 = pywt.dwt(cA113, 'db4')
    gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
    beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
    alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
    theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
    delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
    gamma_data1['11thgamma'].append(gamma_RMS11)
    beta_data1['11thbeta'].append(beta_RMS11)
    alpha_data1['11thalpha'].append(alpha_RMS11)
    theta_data1['11ththeta'].append(theta_RMS11)
    delta_data1['11thdelta'].append(delta_RMS11)

    cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
    cA122, d122 = pywt.dwt(cA12, 'db4')
    cA123, d123 = pywt.dwt(cA122, 'db4')
    a124, d124 = pywt.dwt(cA123, 'db4')
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
    gamma_data1['12thgamma'].append(gamma_RMS12)
    beta_data1['12thbeta'].append(beta_RMS12)
    alpha_data1['12thalpha'].append(alpha_RMS12)
    theta_data1['12ththeta'].append(theta_RMS12)
    delta_data1['12thdelta'].append(delta_RMS12)

    cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
    cA132, d132 = pywt.dwt(cA13, 'db4')
    cA133, d133 = pywt.dwt(cA132, 'db4')
    a134, d134 = pywt.dwt(cA133, 'db4')
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
    gamma_data1['13thgamma'].append(gamma_RMS13)
    beta_data1['13thbeta'].append(beta_RMS13)
    alpha_data1['13thalpha'].append(alpha_RMS13)
    theta_data1['13ththeta'].append(theta_RMS13)
    delta_data1['13thdelta'].append(delta_RMS13)

    cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
    cA142, d142 = pywt.dwt(cA14, 'db4')
    cA143, d143 = pywt.dwt(cA142, 'db4')
    a144, d144 = pywt.dwt(cA143, 'db4')
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
    gamma_data1['14thgamma'].append(gamma_RMS14)
    beta_data1['14thbeta'].append(beta_RMS14)
    alpha_data1['14thalpha'].append(alpha_RMS14)
    theta_data1['14ththeta'].append(theta_RMS14)
    delta_data1['14thdelta'].append(delta_RMS14)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}

for i in range(20):
    
    standard_gamma = StandardScaler().fit_transform(gamma_data1) 
    normalised_gamma = pd.DataFrame(standard_gamma)
    pca_gamma = PCA(n_components=0.9)
    principalComponents_gamma = pca_gamma.fit_transform(standard_gamma)
    gamma_data1 = pd.DataFrame(data = principalComponents_gamma)
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.2,stratify=labels)

    standard_beta = StandardScaler().fit_transform(beta_data1) 
    normalised_beta = pd.DataFrame(standard_beta)
    pca_beta = PCA(n_components=0.9)
    principalComponents_beta = pca_beta.fit_transform(standard_beta)
    beta_data1 = pd.DataFrame(data = principalComponents_beta)
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.2,stratify=labels)

    standard_alpha = StandardScaler().fit_transform(alpha_data1) 
    normalised_alpha = pd.DataFrame(standard_alpha)
    pca_alpha = PCA(n_components=0.9)
    principalComponents_alpha = pca_alpha.fit_transform(standard_alpha)
    alpha_data1 = pd.DataFrame(data = principalComponents_alpha)
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.2,stratify=labels)

    standard_theta = StandardScaler().fit_transform(theta_data1) 
    normalised_theta = pd.DataFrame(standard_theta)
    pca_theta = PCA(n_components=0.9)
    principalComponents_theta = pca_theta.fit_transform(standard_theta)
    theta_data1 = pd.DataFrame(data = principalComponents_theta)
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.2,stratify=labels)


    standard_delta = StandardScaler().fit_transform(delta_data1) 
    normalised_delta = pd.DataFrame(standard_delta)
    pca_delta = PCA(n_components=0.9)
    principalComponents_delta = pca_delta.fit_transform(standard_delta)
    delta_data1 = pd.DataFrame(data = principalComponents_delta)
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.2,stratify=labels)

    standard_merged = StandardScaler().fit_transform(merged) 
    normalised_merged = pd.DataFrame(standard_merged)
    pca_merged = PCA(n_components=0.9)
    principalComponents_merged = pca_merged.fit_transform(standard_merged)
    merged = pd.DataFrame(data = principalComponents_merged)
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.2,stratify=labels)

    dtree1 = RandomForestClassifier(n_estimators=200)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    dtree2 = RandomForestClassifier(n_estimators=200)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    dtree3 = RandomForestClassifier(n_estimators=200)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    dtree4 = RandomForestClassifier(n_estimators=200)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    dtree5 = RandomForestClassifier(n_estimators=200)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

    dtree6 = RandomForestClassifier(n_estimators=200)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.20609708883669037
#  beta= 0.3229322303083913
#  alpha= 0.29020631806336483
#  delta= 0.3308674315021064
#  theta= 0.4141296013354837
#  merged= 0.3228860399532765

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
    "4thgamma":[],
    "5thgamma":[],
    "6thgamma":[],
    "7thgamma":[],
    "8thgamma":[],
    "9thgamma":[],
    "10thgamma":[],
    "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
    "4thbeta":[],
    "5thbeta":[],
    "6thbeta":[],
    "7thbeta":[],
    "8thbeta":[],
    "9thbeta":[],
    "10thbeta":[],
    "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
    "4thalpha":[],
    "5thalpha":[],
    "6thalpha":[],
    "7thalpha":[],
    "8thalpha":[],
    "9thalpha":[],
    "10thalpha":[],
    "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
    "4ththeta":[],
    "5ththeta":[],
    "6ththeta":[],
    "7ththeta":[],
    "8ththeta":[],
    "9ththeta":[],
    "10ththeta":[],
    "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
    "4thdelta":[],
    "5thdelta":[],
    "6thdelta":[],
    "7thdelta":[],
    "8thdelta":[],
    "9thdelta":[],
    "10thdelta":[],
    "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/ziaaad/"+str(i+1)+".txt",header=None,names=["label"])
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/ziaaad_"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
        '4th':[],
        '5th':[],
        '6th':[],
        '7th':[],
        '8th':[],
        '9th':[],
        '10th':[],
        '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
        user_data['4th'].append(float(ny[3]))
        user_data['5th'].append(float(ny[4]))
        user_data['6th'].append(float(ny[5]))
        user_data['7th'].append(float(ny[6]))
        user_data['8th'].append(float(ny[7]))
        user_data['9th'].append(float(ny[8]))
        user_data['10th'].append(float(ny[9]))
        user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
    fourth_electrode = user_data['4th']
    fifth_electrode = user_data['5th']
    sixth_electrode = user_data['6th']
    seventh_electrode = user_data['7th']
    eighth_electrode = user_data['8th']
    nineth_electrode = user_data['9th']
    tenth_electrode = user_data['10th']
    eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
    s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
    s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
    s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
    s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
    s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
    s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
    s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
    s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

    cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
    cA42, d42 = pywt.dwt(cA4, 'db4')
    cA43, d43 = pywt.dwt(cA42, 'db4')
    a44, d44 = pywt.dwt(cA43, 'db4')
    gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
    beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
    alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
    theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
    delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
    gamma_data1['4thgamma'].append(gamma_RMS4)
    beta_data1['4thbeta'].append(beta_RMS4)
    alpha_data1['4thalpha'].append(alpha_RMS4)
    theta_data1['4ththeta'].append(theta_RMS4)
    delta_data1['4thdelta'].append(delta_RMS4)

    cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
    cA52, d52 = pywt.dwt(cA5, 'db4')
    cA53, d53 = pywt.dwt(cA52, 'db4')
    a54, d54 = pywt.dwt(cA53, 'db4')
    gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
    beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
    alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
    theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
    delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
    gamma_data1['5thgamma'].append(gamma_RMS5)
    beta_data1['5thbeta'].append(beta_RMS5)
    alpha_data1['5thalpha'].append(alpha_RMS5)
    theta_data1['5ththeta'].append(theta_RMS5)
    delta_data1['5thdelta'].append(delta_RMS5)

    cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
    cA62, d62 = pywt.dwt(cA6, 'db4')
    cA63, d63 = pywt.dwt(cA62, 'db4')
    a64, d64 = pywt.dwt(cA63, 'db4')
    gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
    beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
    alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
    theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
    delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
    gamma_data1['6thgamma'].append(gamma_RMS6)
    beta_data1['6thbeta'].append(beta_RMS6)
    alpha_data1['6thalpha'].append(alpha_RMS6)
    theta_data1['6ththeta'].append(theta_RMS6)
    delta_data1['6thdelta'].append(delta_RMS6)
    

    cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
    cA72, d72 = pywt.dwt(cA7, 'db4')
    cA73, d73 = pywt.dwt(cA72, 'db4')
    a74, d74 = pywt.dwt(cA73, 'db4')
    gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
    beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
    alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
    theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
    delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
    gamma_data1['7thgamma'].append(gamma_RMS7)
    beta_data1['7thbeta'].append(beta_RMS7)
    alpha_data1['7thalpha'].append(alpha_RMS7)
    theta_data1['7ththeta'].append(theta_RMS7)
    delta_data1['7thdelta'].append(delta_RMS7)

    cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
    cA82, d82 = pywt.dwt(cA8, 'db4')
    cA83, d83 = pywt.dwt(cA82, 'db4')
    a84, d84 = pywt.dwt(cA83, 'db4')
    gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
    beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
    alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
    theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
    delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
    gamma_data1['8thgamma'].append(gamma_RMS8)
    beta_data1['8thbeta'].append(beta_RMS8)
    alpha_data1['8thalpha'].append(alpha_RMS8)
    theta_data1['8ththeta'].append(theta_RMS8)
    delta_data1['8thdelta'].append(delta_RMS8)

    cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
    cA92, d92 = pywt.dwt(cA9, 'db4')
    cA93, d93 = pywt.dwt(cA92, 'db4')
    a94, d94 = pywt.dwt(cA93, 'db4')
    gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
    beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
    alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
    theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
    delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
    gamma_data1['9thgamma'].append(gamma_RMS9)
    beta_data1['9thbeta'].append(beta_RMS9)
    alpha_data1['9thalpha'].append(alpha_RMS9)
    theta_data1['9ththeta'].append(theta_RMS9)
    delta_data1['9thdelta'].append(delta_RMS9)

    cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
    cA102, d102 = pywt.dwt(cA10, 'db4')
    cA103, d103 = pywt.dwt(cA102, 'db4')
    a104, d104 = pywt.dwt(cA103, 'db4')
    gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
    beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
    alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
    theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
    delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
    gamma_data1['10thgamma'].append(gamma_RMS10)
    beta_data1['10thbeta'].append(beta_RMS10)
    alpha_data1['10thalpha'].append(alpha_RMS10)
    theta_data1['10ththeta'].append(theta_RMS10)
    delta_data1['10thdelta'].append(delta_RMS10)

    cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
    cA112, d112 = pywt.dwt(cA11, 'db4')
    cA113, d113 = pywt.dwt(cA112, 'db4')
    a114, d114 = pywt.dwt(cA113, 'db4')
    gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
    beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
    alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
    theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
    delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
    gamma_data1['11thgamma'].append(gamma_RMS11)
    beta_data1['11thbeta'].append(beta_RMS11)
    alpha_data1['11thalpha'].append(alpha_RMS11)
    theta_data1['11ththeta'].append(theta_RMS11)
    delta_data1['11thdelta'].append(delta_RMS11)

    cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
    cA122, d122 = pywt.dwt(cA12, 'db4')
    cA123, d123 = pywt.dwt(cA122, 'db4')
    a124, d124 = pywt.dwt(cA123, 'db4')
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
    gamma_data1['12thgamma'].append(gamma_RMS12)
    beta_data1['12thbeta'].append(beta_RMS12)
    alpha_data1['12thalpha'].append(alpha_RMS12)
    theta_data1['12ththeta'].append(theta_RMS12)
    delta_data1['12thdelta'].append(delta_RMS12)

    cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
    cA132, d132 = pywt.dwt(cA13, 'db4')
    cA133, d133 = pywt.dwt(cA132, 'db4')
    a134, d134 = pywt.dwt(cA133, 'db4')
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
    gamma_data1['13thgamma'].append(gamma_RMS13)
    beta_data1['13thbeta'].append(beta_RMS13)
    alpha_data1['13thalpha'].append(alpha_RMS13)
    theta_data1['13ththeta'].append(theta_RMS13)
    delta_data1['13thdelta'].append(delta_RMS13)

    cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
    cA142, d142 = pywt.dwt(cA14, 'db4')
    cA143, d143 = pywt.dwt(cA142, 'db4')
    a144, d144 = pywt.dwt(cA143, 'db4')
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
    gamma_data1['14thgamma'].append(gamma_RMS14)
    beta_data1['14thbeta'].append(beta_RMS14)
    alpha_data1['14thalpha'].append(alpha_RMS14)
    theta_data1['14ththeta'].append(theta_RMS14)
    delta_data1['14thdelta'].append(delta_RMS14)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}

for i in range(20):
    
    pca_gamma = PCA(n_components=0.9)
    principalComponents_gamma = pca_gamma.fit_transform(gamma_data1)
    gamma_data1 = pd.DataFrame(data = principalComponents_gamma)
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.1,stratify=labels)


    pca_beta = PCA(n_components=0.9)
    principalComponents_beta = pca_beta.fit_transform(beta_data1)
    beta_data1 = pd.DataFrame(data = principalComponents_beta)
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.2,stratify=labels)


    pca_alpha = PCA(n_components=0.9)
    principalComponents_alpha = pca_alpha.fit_transform(alpha_data1)
    alpha_data1 = pd.DataFrame(data = principalComponents_alpha)
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.2,stratify=labels)


    pca_theta = PCA(n_components=0.9)
    principalComponents_theta = pca_theta.fit_transform(theta_data1)
    theta_data1 = pd.DataFrame(data = principalComponents_theta)
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.2,stratify=labels)



    pca_delta = PCA(n_components=0.9)
    principalComponents_delta = pca_delta.fit_transform(delta_data1)
    delta_data1 = pd.DataFrame(data = principalComponents_delta)
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.2,stratify=labels)


    pca_merged = PCA(n_components=0.9)
    principalComponents_merged = pca_merged.fit_transform(merged)
    merged = pd.DataFrame(data = principalComponents_merged)
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.2,stratify=labels)

    dtree1 = RandomForestClassifier(n_estimators=200)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    dtree2 = RandomForestClassifier(n_estimators=200)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    dtree3 = RandomForestClassifier(n_estimators=200)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    dtree4 = RandomForestClassifier(n_estimators=200)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    dtree5 = RandomForestClassifier(n_estimators=200)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

    dtree6 = RandomForestClassifier(n_estimators=200)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.2385305435305436
#  beta= 0.2543684895542481
#  alpha= 0.42330878733372346
#  delta= 0.2782842175024839
#  theta= 0.3978692046998683
#  merged= 0.2958667228597569

# %%
print(len(results['result_gamma']))
# Out:
# 20

# %%
i=0
j=0
k=0
for label in labels:
    if label=='Liked':
        i+=1
    if label=="Dislike":
        j+=1
    if label =="Neutral":
        k+=1
print(i,'\n',j,'\n',k)
# Out:
# 43
#  26
#  11

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
    "4thgamma":[],
    "5thgamma":[],
    "6thgamma":[],
    "7thgamma":[],
    "8thgamma":[],
    "9thgamma":[],
    "10thgamma":[],
    "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
    "4thbeta":[],
    "5thbeta":[],
    "6thbeta":[],
    "7thbeta":[],
    "8thbeta":[],
    "9thbeta":[],
    "10thbeta":[],
    "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
    "4thalpha":[],
    "5thalpha":[],
    "6thalpha":[],
    "7thalpha":[],
    "8thalpha":[],
    "9thalpha":[],
    "10thalpha":[],
    "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
    "4ththeta":[],
    "5ththeta":[],
    "6ththeta":[],
    "7ththeta":[],
    "8ththeta":[],
    "9ththeta":[],
    "10ththeta":[],
    "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
    "4thdelta":[],
    "5thdelta":[],
    "6thdelta":[],
    "7thdelta":[],
    "8thdelta":[],
    "9thdelta":[],
    "10thdelta":[],
    "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/ziaaad/"+str(i+1)+".txt",header=None,names=["label"])
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/ziaaad_"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
        '4th':[],
        '5th':[],
        '6th':[],
        '7th':[],
        '8th':[],
        '9th':[],
        '10th':[],
        '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
        user_data['4th'].append(float(ny[3]))
        user_data['5th'].append(float(ny[4]))
        user_data['6th'].append(float(ny[5]))
        user_data['7th'].append(float(ny[6]))
        user_data['8th'].append(float(ny[7]))
        user_data['9th'].append(float(ny[8]))
        user_data['10th'].append(float(ny[9]))
        user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
    fourth_electrode = user_data['4th']
    fifth_electrode = user_data['5th']
    sixth_electrode = user_data['6th']
    seventh_electrode = user_data['7th']
    eighth_electrode = user_data['8th']
    nineth_electrode = user_data['9th']
    tenth_electrode = user_data['10th']
    eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
    s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
    s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
    s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
    s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
    s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
    s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
    s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
    s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

    cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
    cA42, d42 = pywt.dwt(cA4, 'db4')
    cA43, d43 = pywt.dwt(cA42, 'db4')
    a44, d44 = pywt.dwt(cA43, 'db4')
    gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
    beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
    alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
    theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
    delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
    gamma_data1['4thgamma'].append(gamma_RMS4)
    beta_data1['4thbeta'].append(beta_RMS4)
    alpha_data1['4thalpha'].append(alpha_RMS4)
    theta_data1['4ththeta'].append(theta_RMS4)
    delta_data1['4thdelta'].append(delta_RMS4)

    cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
    cA52, d52 = pywt.dwt(cA5, 'db4')
    cA53, d53 = pywt.dwt(cA52, 'db4')
    a54, d54 = pywt.dwt(cA53, 'db4')
    gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
    beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
    alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
    theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
    delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
    gamma_data1['5thgamma'].append(gamma_RMS5)
    beta_data1['5thbeta'].append(beta_RMS5)
    alpha_data1['5thalpha'].append(alpha_RMS5)
    theta_data1['5ththeta'].append(theta_RMS5)
    delta_data1['5thdelta'].append(delta_RMS5)

    cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
    cA62, d62 = pywt.dwt(cA6, 'db4')
    cA63, d63 = pywt.dwt(cA62, 'db4')
    a64, d64 = pywt.dwt(cA63, 'db4')
    gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
    beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
    alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
    theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
    delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
    gamma_data1['6thgamma'].append(gamma_RMS6)
    beta_data1['6thbeta'].append(beta_RMS6)
    alpha_data1['6thalpha'].append(alpha_RMS6)
    theta_data1['6ththeta'].append(theta_RMS6)
    delta_data1['6thdelta'].append(delta_RMS6)
    

    cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
    cA72, d72 = pywt.dwt(cA7, 'db4')
    cA73, d73 = pywt.dwt(cA72, 'db4')
    a74, d74 = pywt.dwt(cA73, 'db4')
    gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
    beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
    alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
    theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
    delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
    gamma_data1['7thgamma'].append(gamma_RMS7)
    beta_data1['7thbeta'].append(beta_RMS7)
    alpha_data1['7thalpha'].append(alpha_RMS7)
    theta_data1['7ththeta'].append(theta_RMS7)
    delta_data1['7thdelta'].append(delta_RMS7)

    cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
    cA82, d82 = pywt.dwt(cA8, 'db4')
    cA83, d83 = pywt.dwt(cA82, 'db4')
    a84, d84 = pywt.dwt(cA83, 'db4')
    gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
    beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
    alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
    theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
    delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
    gamma_data1['8thgamma'].append(gamma_RMS8)
    beta_data1['8thbeta'].append(beta_RMS8)
    alpha_data1['8thalpha'].append(alpha_RMS8)
    theta_data1['8ththeta'].append(theta_RMS8)
    delta_data1['8thdelta'].append(delta_RMS8)

    cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
    cA92, d92 = pywt.dwt(cA9, 'db4')
    cA93, d93 = pywt.dwt(cA92, 'db4')
    a94, d94 = pywt.dwt(cA93, 'db4')
    gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
    beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
    alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
    theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
    delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
    gamma_data1['9thgamma'].append(gamma_RMS9)
    beta_data1['9thbeta'].append(beta_RMS9)
    alpha_data1['9thalpha'].append(alpha_RMS9)
    theta_data1['9ththeta'].append(theta_RMS9)
    delta_data1['9thdelta'].append(delta_RMS9)

    cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
    cA102, d102 = pywt.dwt(cA10, 'db4')
    cA103, d103 = pywt.dwt(cA102, 'db4')
    a104, d104 = pywt.dwt(cA103, 'db4')
    gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
    beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
    alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
    theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
    delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
    gamma_data1['10thgamma'].append(gamma_RMS10)
    beta_data1['10thbeta'].append(beta_RMS10)
    alpha_data1['10thalpha'].append(alpha_RMS10)
    theta_data1['10ththeta'].append(theta_RMS10)
    delta_data1['10thdelta'].append(delta_RMS10)

    cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
    cA112, d112 = pywt.dwt(cA11, 'db4')
    cA113, d113 = pywt.dwt(cA112, 'db4')
    a114, d114 = pywt.dwt(cA113, 'db4')
    gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
    beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
    alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
    theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
    delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
    gamma_data1['11thgamma'].append(gamma_RMS11)
    beta_data1['11thbeta'].append(beta_RMS11)
    alpha_data1['11thalpha'].append(alpha_RMS11)
    theta_data1['11ththeta'].append(theta_RMS11)
    delta_data1['11thdelta'].append(delta_RMS11)

    cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
    cA122, d122 = pywt.dwt(cA12, 'db4')
    cA123, d123 = pywt.dwt(cA122, 'db4')
    a124, d124 = pywt.dwt(cA123, 'db4')
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
    gamma_data1['12thgamma'].append(gamma_RMS12)
    beta_data1['12thbeta'].append(beta_RMS12)
    alpha_data1['12thalpha'].append(alpha_RMS12)
    theta_data1['12ththeta'].append(theta_RMS12)
    delta_data1['12thdelta'].append(delta_RMS12)

    cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
    cA132, d132 = pywt.dwt(cA13, 'db4')
    cA133, d133 = pywt.dwt(cA132, 'db4')
    a134, d134 = pywt.dwt(cA133, 'db4')
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
    gamma_data1['13thgamma'].append(gamma_RMS13)
    beta_data1['13thbeta'].append(beta_RMS13)
    alpha_data1['13thalpha'].append(alpha_RMS13)
    theta_data1['13ththeta'].append(theta_RMS13)
    delta_data1['13thdelta'].append(delta_RMS13)

    cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
    cA142, d142 = pywt.dwt(cA14, 'db4')
    cA143, d143 = pywt.dwt(cA142, 'db4')
    a144, d144 = pywt.dwt(cA143, 'db4')
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
    gamma_data1['14thgamma'].append(gamma_RMS14)
    beta_data1['14thbeta'].append(beta_RMS14)
    alpha_data1['14thalpha'].append(alpha_RMS14)
    theta_data1['14ththeta'].append(theta_RMS14)
    delta_data1['14thdelta'].append(delta_RMS14)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}

for i in range(20):
    
    pca_gamma = PCA(n_components=0.9)
    principalComponents_gamma = pca_gamma.fit_transform(gamma_data1)
    gamma_data1 = pd.DataFrame(data = principalComponents_gamma)
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.1,stratify=labels)


    pca_beta = PCA(n_components=0.9)
    principalComponents_beta = pca_beta.fit_transform(beta_data1)
    beta_data1 = pd.DataFrame(data = principalComponents_beta)
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.2,stratify=labels)


    pca_alpha = PCA(n_components=0.9)
    principalComponents_alpha = pca_alpha.fit_transform(alpha_data1)
    alpha_data1 = pd.DataFrame(data = principalComponents_alpha)
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.2,stratify=labels)


    pca_theta = PCA(n_components=0.9)
    principalComponents_theta = pca_theta.fit_transform(theta_data1)
    theta_data1 = pd.DataFrame(data = principalComponents_theta)
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.2,stratify=labels)



    pca_delta = PCA(n_components=0.9)
    principalComponents_delta = pca_delta.fit_transform(delta_data1)
    delta_data1 = pd.DataFrame(data = principalComponents_delta)
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.2,stratify=labels)


    pca_merged = PCA(n_components=0.9)
    principalComponents_merged = pca_merged.fit_transform(merged)
    merged = pd.DataFrame(data = principalComponents_merged)
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.2,stratify=labels)

    dtree1 = RandomForestClassifier(n_estimators=200)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    dtree2 = RandomForestClassifier(n_estimators=200)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    dtree3 = RandomForestClassifier(n_estimators=200)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    dtree4 = RandomForestClassifier(n_estimators=200)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    dtree5 = RandomForestClassifier(n_estimators=200)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

    dtree6 = RandomForestClassifier(n_estimators=200)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.25331168831168827
#  beta= 0.26195004370700964
#  alpha= 0.3987757277695358
#  delta= 0.2580203886241038
#  theta= 0.39353627223596266
#  merged= 0.2859288146207651

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
    "4thgamma":[],
    "5thgamma":[],
    "6thgamma":[],
    "7thgamma":[],
#     "8thgamma":[],
#     "9thgamma":[],
#     "10thgamma":[],
#     "11thgamma":[],
#     "12thgamma":[],
#     "13thgamma":[],
#     "14thgamma":[]
}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
    "4thbeta":[],
    "5thbeta":[],
    "6thbeta":[],
    "7thbeta":[],
#     "8thbeta":[],
#     "9thbeta":[],
#     "10thbeta":[],
#     "11thbeta":[],
#     "12thbeta":[],
#     "13thbeta":[],
#     "14thbeta":[]
}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
    "4thalpha":[],
    "5thalpha":[],
    "6thalpha":[],
    "7thalpha":[],
#     "8thalpha":[],
#     "9thalpha":[],
#     "10thalpha":[],
#     "11thalpha":[],
#     "12thalpha":[],
#     "13thalpha":[],
#     "14thalpha":[]
}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
    "4ththeta":[],
    "5ththeta":[],
    "6ththeta":[],
    "7ththeta":[],
#     "8ththeta":[],
#     "9ththeta":[],
#     "10ththeta":[],
#     "11ththeta":[],
#     "12ththeta":[],
#     "13ththeta":[],
#     "14ththeta":[]
}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
    "4thdelta":[],
    "5thdelta":[],
    "6thdelta":[],
    "7thdelta":[],
#     "8thdelta":[],
#     "9thdelta":[],
#     "10thdelta":[],
#     "11thdelta":[],
#     "12thdelta":[],
#     "13thdelta":[],
#     "14thdelta":[]
}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/ziaaad/"+str(i+1)+".txt",header=None,names=["label"])
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/ziaaad_"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
        '4th':[],
        '5th':[],
        '6th':[],
        '7th':[],
#         '8th':[],
#         '9th':[],
#         '10th':[],
#         '11th':[],
#         '12th':[],
#         '13th':[],
#         '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
        user_data['4th'].append(float(ny[3]))
        user_data['5th'].append(float(ny[4]))
        user_data['6th'].append(float(ny[5]))
        user_data['7th'].append(float(ny[6]))
#         user_data['8th'].append(float(ny[7]))
#         user_data['9th'].append(float(ny[8]))
#         user_data['10th'].append(float(ny[9]))
#         user_data['11th'].append(float(ny[10]))
#         user_data['12th'].append(float(ny[11]))
#         user_data['13th'].append(float(ny[12]))
#         user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
    fourth_electrode = user_data['4th']
    fifth_electrode = user_data['5th']
    sixth_electrode = user_data['6th']
    seventh_electrode = user_data['7th']
#     eighth_electrode = user_data['8th']
#     nineth_electrode = user_data['9th']
#     tenth_electrode = user_data['10th']
#     eleventh_electrode = user_data['11th']
#     twelveth_electrode = user_data['12th']
#     thirteenth_electrode = user_data['13th']
#     fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
    s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
    s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
    s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
    s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
#     s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
#     s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
#     s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
#     s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
#     s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
#     s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
#     s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

    cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
    cA42, d42 = pywt.dwt(cA4, 'db4')
    cA43, d43 = pywt.dwt(cA42, 'db4')
    a44, d44 = pywt.dwt(cA43, 'db4')
    gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
    beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
    alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
    theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
    delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
    gamma_data1['4thgamma'].append(gamma_RMS4)
    beta_data1['4thbeta'].append(beta_RMS4)
    alpha_data1['4thalpha'].append(alpha_RMS4)
    theta_data1['4ththeta'].append(theta_RMS4)
    delta_data1['4thdelta'].append(delta_RMS4)

    cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
    cA52, d52 = pywt.dwt(cA5, 'db4')
    cA53, d53 = pywt.dwt(cA52, 'db4')
    a54, d54 = pywt.dwt(cA53, 'db4')
    gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
    beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
    alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
    theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
    delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
    gamma_data1['5thgamma'].append(gamma_RMS5)
    beta_data1['5thbeta'].append(beta_RMS5)
    alpha_data1['5thalpha'].append(alpha_RMS5)
    theta_data1['5ththeta'].append(theta_RMS5)
    delta_data1['5thdelta'].append(delta_RMS5)

    cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
    cA62, d62 = pywt.dwt(cA6, 'db4')
    cA63, d63 = pywt.dwt(cA62, 'db4')
    a64, d64 = pywt.dwt(cA63, 'db4')
    gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
    beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
    alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
    theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
    delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
    gamma_data1['6thgamma'].append(gamma_RMS6)
    beta_data1['6thbeta'].append(beta_RMS6)
    alpha_data1['6thalpha'].append(alpha_RMS6)
    theta_data1['6ththeta'].append(theta_RMS6)
    delta_data1['6thdelta'].append(delta_RMS6)
    

    cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
    cA72, d72 = pywt.dwt(cA7, 'db4')
    cA73, d73 = pywt.dwt(cA72, 'db4')
    a74, d74 = pywt.dwt(cA73, 'db4')
    gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
    beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
    alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
    theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
    delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
    gamma_data1['7thgamma'].append(gamma_RMS7)
    beta_data1['7thbeta'].append(beta_RMS7)
    alpha_data1['7thalpha'].append(alpha_RMS7)
    theta_data1['7ththeta'].append(theta_RMS7)
    delta_data1['7thdelta'].append(delta_RMS7)

#     cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
#     cA82, d82 = pywt.dwt(cA8, 'db4')
#     cA83, d83 = pywt.dwt(cA82, 'db4')
#     a84, d84 = pywt.dwt(cA83, 'db4')
#     gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
#     beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
#     alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
#     theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
#     delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
#     gamma_data1['8thgamma'].append(gamma_RMS8)
#     beta_data1['8thbeta'].append(beta_RMS8)
#     alpha_data1['8thalpha'].append(alpha_RMS8)
#     theta_data1['8ththeta'].append(theta_RMS8)
#     delta_data1['8thdelta'].append(delta_RMS8)

#     cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
#     cA92, d92 = pywt.dwt(cA9, 'db4')
#     cA93, d93 = pywt.dwt(cA92, 'db4')
#     a94, d94 = pywt.dwt(cA93, 'db4')
#     gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
#     beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
#     alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
#     theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
#     delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
#     gamma_data1['9thgamma'].append(gamma_RMS9)
#     beta_data1['9thbeta'].append(beta_RMS9)
#     alpha_data1['9thalpha'].append(alpha_RMS9)
#     theta_data1['9ththeta'].append(theta_RMS9)
#     delta_data1['9thdelta'].append(delta_RMS9)

#     cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
#     cA102, d102 = pywt.dwt(cA10, 'db4')
#     cA103, d103 = pywt.dwt(cA102, 'db4')
#     a104, d104 = pywt.dwt(cA103, 'db4')
#     gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
#     beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
#     alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
#     theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
#     delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
#     gamma_data1['10thgamma'].append(gamma_RMS10)
#     beta_data1['10thbeta'].append(beta_RMS10)
#     alpha_data1['10thalpha'].append(alpha_RMS10)
#     theta_data1['10ththeta'].append(theta_RMS10)
#     delta_data1['10thdelta'].append(delta_RMS10)

#     cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
#     cA112, d112 = pywt.dwt(cA11, 'db4')
#     cA113, d113 = pywt.dwt(cA112, 'db4')
#     a114, d114 = pywt.dwt(cA113, 'db4')
#     gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
#     beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
#     alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
#     theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
#     delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
#     gamma_data1['11thgamma'].append(gamma_RMS11)
#     beta_data1['11thbeta'].append(beta_RMS11)
#     alpha_data1['11thalpha'].append(alpha_RMS11)
#     theta_data1['11ththeta'].append(theta_RMS11)
#     delta_data1['11thdelta'].append(delta_RMS11)

#     cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
#     cA122, d122 = pywt.dwt(cA12, 'db4')
#     cA123, d123 = pywt.dwt(cA122, 'db4')
#     a124, d124 = pywt.dwt(cA123, 'db4')
#     gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
#     beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
#     alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
#     theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
#     delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
#     gamma_data1['12thgamma'].append(gamma_RMS12)
#     beta_data1['12thbeta'].append(beta_RMS12)
#     alpha_data1['12thalpha'].append(alpha_RMS12)
#     theta_data1['12ththeta'].append(theta_RMS12)
#     delta_data1['12thdelta'].append(delta_RMS12)

#     cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
#     cA132, d132 = pywt.dwt(cA13, 'db4')
#     cA133, d133 = pywt.dwt(cA132, 'db4')
#     a134, d134 = pywt.dwt(cA133, 'db4')
#     gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
#     beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
#     alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
#     theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
#     delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
#     gamma_data1['13thgamma'].append(gamma_RMS13)
#     beta_data1['13thbeta'].append(beta_RMS13)
#     alpha_data1['13thalpha'].append(alpha_RMS13)
#     theta_data1['13ththeta'].append(theta_RMS13)
#     delta_data1['13thdelta'].append(delta_RMS13)

#     cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
#     cA142, d142 = pywt.dwt(cA14, 'db4')
#     cA143, d143 = pywt.dwt(cA142, 'db4')
#     a144, d144 = pywt.dwt(cA143, 'db4')
#     gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
#     beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
#     alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
#     theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
#     delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
#     gamma_data1['14thgamma'].append(gamma_RMS14)
#     beta_data1['14thbeta'].append(beta_RMS14)
#     alpha_data1['14thalpha'].append(alpha_RMS14)
#     theta_data1['14ththeta'].append(theta_RMS14)
#     delta_data1['14thdelta'].append(delta_RMS14)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}

for i in range(20):
    
    standard_gamma = StandardScaler().fit_transform(gamma_data1) 
    normalised_gamma = pd.DataFrame(standard_gamma)
    pca_gamma = PCA(n_components=0.5)
    principalComponents_gamma = pca_gamma.fit_transform(standard_gamma)
    gamma_data1 = pd.DataFrame(data = principalComponents_gamma)
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.2,stratify=labels)

    standard_beta = StandardScaler().fit_transform(beta_data1) 
    normalised_beta = pd.DataFrame(standard_beta)
    pca_beta = PCA(n_components=0.5)
    principalComponents_beta = pca_beta.fit_transform(standard_beta)
    beta_data1 = pd.DataFrame(data = principalComponents_beta)
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.2,stratify=labels)

    standard_alpha = StandardScaler().fit_transform(alpha_data1) 
    normalised_alpha = pd.DataFrame(standard_alpha)
    pca_alpha = PCA(n_components=0.5)
    principalComponents_alpha = pca_alpha.fit_transform(standard_alpha)
    alpha_data1 = pd.DataFrame(data = principalComponents_alpha)
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.2,stratify=labels)

    standard_theta = StandardScaler().fit_transform(theta_data1) 
    normalised_theta = pd.DataFrame(standard_theta)
    pca_theta = PCA(n_components=0.5)
    principalComponents_theta = pca_theta.fit_transform(standard_theta)
    theta_data1 = pd.DataFrame(data = principalComponents_theta)
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.2,stratify=labels)


    standard_delta = StandardScaler().fit_transform(delta_data1) 
    normalised_delta = pd.DataFrame(standard_delta)
    pca_delta = PCA(n_components=0.5)
    principalComponents_delta = pca_delta.fit_transform(standard_delta)
    delta_data1 = pd.DataFrame(data = principalComponents_delta)
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.2,stratify=labels)

    standard_merged = StandardScaler().fit_transform(merged) 
    normalised_merged = pd.DataFrame(standard_merged)
    pca_merged = PCA(n_components=0.5)
    principalComponents_merged = pca_merged.fit_transform(standard_merged)
    merged = pd.DataFrame(data = principalComponents_merged)
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.2,stratify=labels)

    dtree1 = RandomForestClassifier(n_estimators=400)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    dtree2 = RandomForestClassifier(n_estimators=400)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    dtree3 = RandomForestClassifier(n_estimators=400)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    dtree4 = RandomForestClassifier(n_estimators=400)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    dtree5 = RandomForestClassifier(n_estimators=400)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

    dtree6 = RandomForestClassifier(n_estimators=400)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.34907319096526934
#  beta= 0.42200782948847965
#  alpha= 0.3578554556611832
#  delta= 0.4235047145263864
#  theta= 0.315513346159631
#  merged= 0.27926148570498416

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
    "4thgamma":[],
    "5thgamma":[],
    "6thgamma":[],
#     "7thgamma":[],
#     "8thgamma":[],
#     "9thgamma":[],
#     "10thgamma":[],
#     "11thgamma":[],
#     "12thgamma":[],
#     "13thgamma":[],
#     "14thgamma":[]
}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
    "4thbeta":[],
    "5thbeta":[],
    "6thbeta":[],
#     "7thbeta":[],
#     "8thbeta":[],
#     "9thbeta":[],
#     "10thbeta":[],
#     "11thbeta":[],
#     "12thbeta":[],
#     "13thbeta":[],
#     "14thbeta":[]
}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
    "4thalpha":[],
    "5thalpha":[],
    "6thalpha":[],
#     "7thalpha":[],
#     "8thalpha":[],
#     "9thalpha":[],
#     "10thalpha":[],
#     "11thalpha":[],
#     "12thalpha":[],
#     "13thalpha":[],
#     "14thalpha":[]
}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
    "4ththeta":[],
    "5ththeta":[],
    "6ththeta":[],
#     "7ththeta":[],
#     "8ththeta":[],
#     "9ththeta":[],
#     "10ththeta":[],
#     "11ththeta":[],
#     "12ththeta":[],
#     "13ththeta":[],
#     "14ththeta":[]
}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
    "4thdelta":[],
    "5thdelta":[],
    "6thdelta":[],
#     "7thdelta":[],
#     "8thdelta":[],
#     "9thdelta":[],
#     "10thdelta":[],
#     "11thdelta":[],
#     "12thdelta":[],
#     "13thdelta":[],
#     "14thdelta":[]
}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/ziaaad/"+str(i+1)+".txt",header=None,names=["label"])
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/ziaaad_"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
        '4th':[],
        '5th':[],
        '6th':[],
#         '7th':[],
#         '8th':[],
#         '9th':[],
#         '10th':[],
#         '11th':[],
#         '12th':[],
#         '13th':[],
#         '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
        user_data['4th'].append(float(ny[3]))
        user_data['5th'].append(float(ny[4]))
        user_data['6th'].append(float(ny[5]))
#         user_data['7th'].append(float(ny[6]))
#         user_data['8th'].append(float(ny[7]))
#         user_data['9th'].append(float(ny[8]))
#         user_data['10th'].append(float(ny[9]))
#         user_data['11th'].append(float(ny[10]))
#         user_data['12th'].append(float(ny[11]))
#         user_data['13th'].append(float(ny[12]))
#         user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
    fourth_electrode = user_data['4th']
    fifth_electrode = user_data['5th']
    sixth_electrode = user_data['6th']
#     seventh_electrode = user_data['7th']
#     eighth_electrode = user_data['8th']
#     nineth_electrode = user_data['9th']
#     tenth_electrode = user_data['10th']
#     eleventh_electrode = user_data['11th']
#     twelveth_electrode = user_data['12th']
#     thirteenth_electrode = user_data['13th']
#     fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
    s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
    s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
    s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
    s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
#     s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
#     s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
#     s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
#     s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
#     s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
#     s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
#     s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

    cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
    cA42, d42 = pywt.dwt(cA4, 'db4')
    cA43, d43 = pywt.dwt(cA42, 'db4')
    a44, d44 = pywt.dwt(cA43, 'db4')
    gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
    beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
    alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
    theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
    delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
    gamma_data1['4thgamma'].append(gamma_RMS4)
    beta_data1['4thbeta'].append(beta_RMS4)
    alpha_data1['4thalpha'].append(alpha_RMS4)
    theta_data1['4ththeta'].append(theta_RMS4)
    delta_data1['4thdelta'].append(delta_RMS4)

    cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
    cA52, d52 = pywt.dwt(cA5, 'db4')
    cA53, d53 = pywt.dwt(cA52, 'db4')
    a54, d54 = pywt.dwt(cA53, 'db4')
    gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
    beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
    alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
    theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
    delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
    gamma_data1['5thgamma'].append(gamma_RMS5)
    beta_data1['5thbeta'].append(beta_RMS5)
    alpha_data1['5thalpha'].append(alpha_RMS5)
    theta_data1['5ththeta'].append(theta_RMS5)
    delta_data1['5thdelta'].append(delta_RMS5)

    cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
    cA62, d62 = pywt.dwt(cA6, 'db4')
    cA63, d63 = pywt.dwt(cA62, 'db4')
    a64, d64 = pywt.dwt(cA63, 'db4')
    gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
    beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
    alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
    theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
    delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
    gamma_data1['6thgamma'].append(gamma_RMS6)
    beta_data1['6thbeta'].append(beta_RMS6)
    alpha_data1['6thalpha'].append(alpha_RMS6)
    theta_data1['6ththeta'].append(theta_RMS6)
    delta_data1['6thdelta'].append(delta_RMS6)
    

#     cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
#     cA72, d72 = pywt.dwt(cA7, 'db4')
#     cA73, d73 = pywt.dwt(cA72, 'db4')
#     a74, d74 = pywt.dwt(cA73, 'db4')
#     gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
#     beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
#     alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
#     theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
#     delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
#     gamma_data1['7thgamma'].append(gamma_RMS7)
#     beta_data1['7thbeta'].append(beta_RMS7)
#     alpha_data1['7thalpha'].append(alpha_RMS7)
#     theta_data1['7ththeta'].append(theta_RMS7)
#     delta_data1['7thdelta'].append(delta_RMS7)

#     cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
#     cA82, d82 = pywt.dwt(cA8, 'db4')
#     cA83, d83 = pywt.dwt(cA82, 'db4')
#     a84, d84 = pywt.dwt(cA83, 'db4')
#     gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
#     beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
#     alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
#     theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
#     delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
#     gamma_data1['8thgamma'].append(gamma_RMS8)
#     beta_data1['8thbeta'].append(beta_RMS8)
#     alpha_data1['8thalpha'].append(alpha_RMS8)
#     theta_data1['8ththeta'].append(theta_RMS8)
#     delta_data1['8thdelta'].append(delta_RMS8)

#     cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
#     cA92, d92 = pywt.dwt(cA9, 'db4')
#     cA93, d93 = pywt.dwt(cA92, 'db4')
#     a94, d94 = pywt.dwt(cA93, 'db4')
#     gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
#     beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
#     alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
#     theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
#     delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
#     gamma_data1['9thgamma'].append(gamma_RMS9)
#     beta_data1['9thbeta'].append(beta_RMS9)
#     alpha_data1['9thalpha'].append(alpha_RMS9)
#     theta_data1['9ththeta'].append(theta_RMS9)
#     delta_data1['9thdelta'].append(delta_RMS9)

#     cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
#     cA102, d102 = pywt.dwt(cA10, 'db4')
#     cA103, d103 = pywt.dwt(cA102, 'db4')
#     a104, d104 = pywt.dwt(cA103, 'db4')
#     gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
#     beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
#     alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
#     theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
#     delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
#     gamma_data1['10thgamma'].append(gamma_RMS10)
#     beta_data1['10thbeta'].append(beta_RMS10)
#     alpha_data1['10thalpha'].append(alpha_RMS10)
#     theta_data1['10ththeta'].append(theta_RMS10)
#     delta_data1['10thdelta'].append(delta_RMS10)

#     cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
#     cA112, d112 = pywt.dwt(cA11, 'db4')
#     cA113, d113 = pywt.dwt(cA112, 'db4')
#     a114, d114 = pywt.dwt(cA113, 'db4')
#     gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
#     beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
#     alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
#     theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
#     delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
#     gamma_data1['11thgamma'].append(gamma_RMS11)
#     beta_data1['11thbeta'].append(beta_RMS11)
#     alpha_data1['11thalpha'].append(alpha_RMS11)
#     theta_data1['11ththeta'].append(theta_RMS11)
#     delta_data1['11thdelta'].append(delta_RMS11)

#     cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
#     cA122, d122 = pywt.dwt(cA12, 'db4')
#     cA123, d123 = pywt.dwt(cA122, 'db4')
#     a124, d124 = pywt.dwt(cA123, 'db4')
#     gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
#     beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
#     alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
#     theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
#     delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
#     gamma_data1['12thgamma'].append(gamma_RMS12)
#     beta_data1['12thbeta'].append(beta_RMS12)
#     alpha_data1['12thalpha'].append(alpha_RMS12)
#     theta_data1['12ththeta'].append(theta_RMS12)
#     delta_data1['12thdelta'].append(delta_RMS12)

#     cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
#     cA132, d132 = pywt.dwt(cA13, 'db4')
#     cA133, d133 = pywt.dwt(cA132, 'db4')
#     a134, d134 = pywt.dwt(cA133, 'db4')
#     gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
#     beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
#     alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
#     theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
#     delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
#     gamma_data1['13thgamma'].append(gamma_RMS13)
#     beta_data1['13thbeta'].append(beta_RMS13)
#     alpha_data1['13thalpha'].append(alpha_RMS13)
#     theta_data1['13ththeta'].append(theta_RMS13)
#     delta_data1['13thdelta'].append(delta_RMS13)

#     cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
#     cA142, d142 = pywt.dwt(cA14, 'db4')
#     cA143, d143 = pywt.dwt(cA142, 'db4')
#     a144, d144 = pywt.dwt(cA143, 'db4')
#     gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
#     beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
#     alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
#     theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
#     delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
#     gamma_data1['14thgamma'].append(gamma_RMS14)
#     beta_data1['14thbeta'].append(beta_RMS14)
#     alpha_data1['14thalpha'].append(alpha_RMS14)
#     theta_data1['14ththeta'].append(theta_RMS14)
#     delta_data1['14thdelta'].append(delta_RMS14)

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.3516245679558373
#  beta= 0.2804156199550936
#  alpha= 0.31574184000267597
#  delta= 0.4312723691284062
#  theta= 0.22692620660499915
#  merged= 0.3140222088712801

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
    "4thgamma":[],
#     "5thgamma":[],
#     "6thgamma":[],
#     "7thgamma":[],
#     "8thgamma":[],
#     "9thgamma":[],
#     "10thgamma":[],
    "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]
}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
    "4thbeta":[],
#     "5thbeta":[],
#     "6thbeta":[],
#     "7thbeta":[],
#     "8thbeta":[],
#     "9thbeta":[],
#     "10thbeta":[],
    "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]
}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
    "4thalpha":[],
#     "5thalpha":[],
#     "6thalpha":[],
#     "7thalpha":[],
#     "8thalpha":[],
#     "9thalpha":[],
#     "10thalpha":[],
    "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]
}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
    "4ththeta":[],
#     "5ththeta":[],
#     "6ththeta":[],
#     "7ththeta":[],
#     "8ththeta":[],
#     "9ththeta":[],
#     "10ththeta":[],
    "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]
}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
    "4thdelta":[],
#     "5thdelta":[],
#     "6thdelta":[],
#     "7thdelta":[],
#     "8thdelta":[],
#     "9thdelta":[],
#     "10thdelta":[],
    "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]
}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/mostafa/"+str(i+1)+".txt",header=None,names=["label"])
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/mostafa/mostafa_"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
        '4th':[],
#         '5th':[],
#         '6th':[],
#         '7th':[],
#         '8th':[],
#         '9th':[],
#         '10th':[],
        '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
        user_data['4th'].append(float(ny[3]))
#         user_data['5th'].append(float(ny[4]))
#         user_data['6th'].append(float(ny[5]))
#         user_data['7th'].append(float(ny[6]))
#         user_data['8th'].append(float(ny[7]))
#         user_data['9th'].append(float(ny[8]))
#         user_data['10th'].append(float(ny[9]))
        user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
    fourth_electrode = user_data['4th']
#     fifth_electrode = user_data['5th']
#     sixth_electrode = user_data['6th']
#     seventh_electrode = user_data['7th']
#     eighth_electrode = user_data['8th']
#     nineth_electrode = user_data['9th']
#     tenth_electrode = user_data['10th']
    eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
    s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
#     s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
#     s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
#     s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
#     s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
#     s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
#     s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
    s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

    cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
    cA42, d42 = pywt.dwt(cA4, 'db4')
    cA43, d43 = pywt.dwt(cA42, 'db4')
    a44, d44 = pywt.dwt(cA43, 'db4')
    gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
    beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
    alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
    theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
    delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
    gamma_data1['4thgamma'].append(gamma_RMS4)
    beta_data1['4thbeta'].append(beta_RMS4)
    alpha_data1['4thalpha'].append(alpha_RMS4)
    theta_data1['4ththeta'].append(theta_RMS4)
    delta_data1['4thdelta'].append(delta_RMS4)

#     cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
#     cA52, d52 = pywt.dwt(cA5, 'db4')
#     cA53, d53 = pywt.dwt(cA52, 'db4')
#     a54, d54 = pywt.dwt(cA53, 'db4')
#     gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
#     beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
#     alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
#     theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
#     delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
#     gamma_data1['5thgamma'].append(gamma_RMS5)
#     beta_data1['5thbeta'].append(beta_RMS5)
#     alpha_data1['5thalpha'].append(alpha_RMS5)
#     theta_data1['5ththeta'].append(theta_RMS5)
#     delta_data1['5thdelta'].append(delta_RMS5)

#     cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
#     cA62, d62 = pywt.dwt(cA6, 'db4')
#     cA63, d63 = pywt.dwt(cA62, 'db4')
#     a64, d64 = pywt.dwt(cA63, 'db4')
#     gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
#     beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
#     alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
#     theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
#     delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
#     gamma_data1['6thgamma'].append(gamma_RMS6)
#     beta_data1['6thbeta'].append(beta_RMS6)
#     alpha_data1['6thalpha'].append(alpha_RMS6)
#     theta_data1['6ththeta'].append(theta_RMS6)
#     delta_data1['6thdelta'].append(delta_RMS6)
    

#     cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
#     cA72, d72 = pywt.dwt(cA7, 'db4')
#     cA73, d73 = pywt.dwt(cA72, 'db4')
#     a74, d74 = pywt.dwt(cA73, 'db4')
#     gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
#     beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
#     alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
#     theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
#     delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
#     gamma_data1['7thgamma'].append(gamma_RMS7)
#     beta_data1['7thbeta'].append(beta_RMS7)
#     alpha_data1['7thalpha'].append(alpha_RMS7)
#     theta_data1['7ththeta'].append(theta_RMS7)
#     delta_data1['7thdelta'].append(delta_RMS7)

#     cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
#     cA82, d82 = pywt.dwt(cA8, 'db4')
#     cA83, d83 = pywt.dwt(cA82, 'db4')
#     a84, d84 = pywt.dwt(cA83, 'db4')
#     gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
#     beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
#     alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
#     theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
#     delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
#     gamma_data1['8thgamma'].append(gamma_RMS8)
#     beta_data1['8thbeta'].append(beta_RMS8)
#     alpha_data1['8thalpha'].append(alpha_RMS8)
#     theta_data1['8ththeta'].append(theta_RMS8)
#     delta_data1['8thdelta'].append(delta_RMS8)

#     cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
#     cA92, d92 = pywt.dwt(cA9, 'db4')
#     cA93, d93 = pywt.dwt(cA92, 'db4')
#     a94, d94 = pywt.dwt(cA93, 'db4')
#     gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
#     beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
#     alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
#     theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
#     delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
#     gamma_data1['9thgamma'].append(gamma_RMS9)
#     beta_data1['9thbeta'].append(beta_RMS9)
#     alpha_data1['9thalpha'].append(alpha_RMS9)
#     theta_data1['9ththeta'].append(theta_RMS9)
#     delta_data1['9thdelta'].append(delta_RMS9)

#     cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
#     cA102, d102 = pywt.dwt(cA10, 'db4')
#     cA103, d103 = pywt.dwt(cA102, 'db4')
#     a104, d104 = pywt.dwt(cA103, 'db4')
#     gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
#     beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
#     alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
#     theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
#     delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
#     gamma_data1['10thgamma'].append(gamma_RMS10)
#     beta_data1['10thbeta'].append(beta_RMS10)
#     alpha_data1['10thalpha'].append(alpha_RMS10)
#     theta_data1['10ththeta'].append(theta_RMS10)
#     delta_data1['10thdelta'].append(delta_RMS10)

    cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
    cA112, d112 = pywt.dwt(cA11, 'db4')
    cA113, d113 = pywt.dwt(cA112, 'db4')
    a114, d114 = pywt.dwt(cA113, 'db4')
    gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
    beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
    alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
    theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
    delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
    gamma_data1['11thgamma'].append(gamma_RMS11)
    beta_data1['11thbeta'].append(beta_RMS11)
    alpha_data1['11thalpha'].append(alpha_RMS11)
    theta_data1['11ththeta'].append(theta_RMS11)
    delta_data1['11thdelta'].append(delta_RMS11)

    cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
    cA122, d122 = pywt.dwt(cA12, 'db4')
    cA123, d123 = pywt.dwt(cA122, 'db4')
    a124, d124 = pywt.dwt(cA123, 'db4')
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
    gamma_data1['12thgamma'].append(gamma_RMS12)
    beta_data1['12thbeta'].append(beta_RMS12)
    alpha_data1['12thalpha'].append(alpha_RMS12)
    theta_data1['12ththeta'].append(theta_RMS12)
    delta_data1['12thdelta'].append(delta_RMS12)

    cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
    cA132, d132 = pywt.dwt(cA13, 'db4')
    cA133, d133 = pywt.dwt(cA132, 'db4')
    a134, d134 = pywt.dwt(cA133, 'db4')
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
    gamma_data1['13thgamma'].append(gamma_RMS13)
    beta_data1['13thbeta'].append(beta_RMS13)
    alpha_data1['13thalpha'].append(alpha_RMS13)
    theta_data1['13ththeta'].append(theta_RMS13)
    delta_data1['13thdelta'].append(delta_RMS13)

    cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
    cA142, d142 = pywt.dwt(cA14, 'db4')
    cA143, d143 = pywt.dwt(cA142, 'db4')
    a144, d144 = pywt.dwt(cA143, 'db4')
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
    gamma_data1['14thgamma'].append(gamma_RMS14)
    beta_data1['14thbeta'].append(beta_RMS14)
    alpha_data1['14thalpha'].append(alpha_RMS14)
    theta_data1['14ththeta'].append(theta_RMS14)
    delta_data1['14thdelta'].append(delta_RMS14)

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.2972748547748547
#  beta= 0.3841821141821141
#  alpha= 0.3513923113923113
#  delta= 0.3242300292300292
#  theta= 0.3641832704332704
#  merged= 0.18385484885484887

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
#     "4thgamma":[],
#     "5thgamma":[],
#     "6thgamma":[],
#     "7thgamma":[],
#     "8thgamma":[],
#     "9thgamma":[],
#     "10thgamma":[],
#     "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]
}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
#     "4thbeta":[],
#     "5thbeta":[],
#     "6thbeta":[],
#     "7thbeta":[],
#     "8thbeta":[],
#     "9thbeta":[],
#     "10thbeta":[],
#     "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]
}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
#     "4thalpha":[],
#     "5thalpha":[],
#     "6thalpha":[],
#     "7thalpha":[],
#     "8thalpha":[],
#     "9thalpha":[],
#     "10thalpha":[],
#     "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]
}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
#     "4ththeta":[],
#     "5ththeta":[],
#     "6ththeta":[],
#     "7ththeta":[],
#     "8ththeta":[],
#     "9ththeta":[],
#     "10ththeta":[],
#     "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]
}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
#     "4thdelta":[],
#     "5thdelta":[],
#     "6thdelta":[],
#     "7thdelta":[],
#     "8thdelta":[],
#     "9thdelta":[],
#     "10thdelta":[],
#     "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]
}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/mostafa/"+str(i+1)+".txt",header=None,names=["label"])
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/mostafa/mostafa_"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
#         '4th':[],
#         '5th':[],
#         '6th':[],
#         '7th':[],
#         '8th':[],
#         '9th':[],
#         '10th':[],
#         '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
#         user_data['4th'].append(float(ny[3]))
#         user_data['5th'].append(float(ny[4]))
#         user_data['6th'].append(float(ny[5]))
#         user_data['7th'].append(float(ny[6]))
#         user_data['8th'].append(float(ny[7]))
#         user_data['9th'].append(float(ny[8]))
#         user_data['10th'].append(float(ny[9]))
#         user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
#     fourth_electrode = user_data['4th']
#     fifth_electrode = user_data['5th']
#     sixth_electrode = user_data['6th']
#     seventh_electrode = user_data['7th']
#     eighth_electrode = user_data['8th']
#     nineth_electrode = user_data['9th']
#     tenth_electrode = user_data['10th']
#     eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
#     s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
#     s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
#     s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
#     s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
#     s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
#     s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
#     s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
#     s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

#     cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
#     cA42, d42 = pywt.dwt(cA4, 'db4')
#     cA43, d43 = pywt.dwt(cA42, 'db4')
#     a44, d44 = pywt.dwt(cA43, 'db4')
#     gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
#     beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
#     alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
#     theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
#     delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
#     gamma_data1['4thgamma'].append(gamma_RMS4)
#     beta_data1['4thbeta'].append(beta_RMS4)
#     alpha_data1['4thalpha'].append(alpha_RMS4)
#     theta_data1['4ththeta'].append(theta_RMS4)
#     delta_data1['4thdelta'].append(delta_RMS4)

#     cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
#     cA52, d52 = pywt.dwt(cA5, 'db4')
#     cA53, d53 = pywt.dwt(cA52, 'db4')
#     a54, d54 = pywt.dwt(cA53, 'db4')
#     gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
#     beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
#     alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
#     theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
#     delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
#     gamma_data1['5thgamma'].append(gamma_RMS5)
#     beta_data1['5thbeta'].append(beta_RMS5)
#     alpha_data1['5thalpha'].append(alpha_RMS5)
#     theta_data1['5ththeta'].append(theta_RMS5)
#     delta_data1['5thdelta'].append(delta_RMS5)

#     cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
#     cA62, d62 = pywt.dwt(cA6, 'db4')
#     cA63, d63 = pywt.dwt(cA62, 'db4')
#     a64, d64 = pywt.dwt(cA63, 'db4')
#     gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
#     beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
#     alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
#     theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
#     delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
#     gamma_data1['6thgamma'].append(gamma_RMS6)
#     beta_data1['6thbeta'].append(beta_RMS6)
#     alpha_data1['6thalpha'].append(alpha_RMS6)
#     theta_data1['6ththeta'].append(theta_RMS6)
#     delta_data1['6thdelta'].append(delta_RMS6)
    

#     cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
#     cA72, d72 = pywt.dwt(cA7, 'db4')
#     cA73, d73 = pywt.dwt(cA72, 'db4')
#     a74, d74 = pywt.dwt(cA73, 'db4')
#     gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
#     beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
#     alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
#     theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
#     delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
#     gamma_data1['7thgamma'].append(gamma_RMS7)
#     beta_data1['7thbeta'].append(beta_RMS7)
#     alpha_data1['7thalpha'].append(alpha_RMS7)
#     theta_data1['7ththeta'].append(theta_RMS7)
#     delta_data1['7thdelta'].append(delta_RMS7)

#     cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
#     cA82, d82 = pywt.dwt(cA8, 'db4')
#     cA83, d83 = pywt.dwt(cA82, 'db4')
#     a84, d84 = pywt.dwt(cA83, 'db4')
#     gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
#     beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
#     alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
#     theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
#     delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
#     gamma_data1['8thgamma'].append(gamma_RMS8)
#     beta_data1['8thbeta'].append(beta_RMS8)
#     alpha_data1['8thalpha'].append(alpha_RMS8)
#     theta_data1['8ththeta'].append(theta_RMS8)
#     delta_data1['8thdelta'].append(delta_RMS8)

#     cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
#     cA92, d92 = pywt.dwt(cA9, 'db4')
#     cA93, d93 = pywt.dwt(cA92, 'db4')
#     a94, d94 = pywt.dwt(cA93, 'db4')
#     gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
#     beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
#     alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
#     theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
#     delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
#     gamma_data1['9thgamma'].append(gamma_RMS9)
#     beta_data1['9thbeta'].append(beta_RMS9)
#     alpha_data1['9thalpha'].append(alpha_RMS9)
#     theta_data1['9ththeta'].append(theta_RMS9)
#     delta_data1['9thdelta'].append(delta_RMS9)

#     cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
#     cA102, d102 = pywt.dwt(cA10, 'db4')
#     cA103, d103 = pywt.dwt(cA102, 'db4')
#     a104, d104 = pywt.dwt(cA103, 'db4')
#     gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
#     beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
#     alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
#     theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
#     delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
#     gamma_data1['10thgamma'].append(gamma_RMS10)
#     beta_data1['10thbeta'].append(beta_RMS10)
#     alpha_data1['10thalpha'].append(alpha_RMS10)
#     theta_data1['10ththeta'].append(theta_RMS10)
#     delta_data1['10thdelta'].append(delta_RMS10)

#     cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
#     cA112, d112 = pywt.dwt(cA11, 'db4')
#     cA113, d113 = pywt.dwt(cA112, 'db4')
#     a114, d114 = pywt.dwt(cA113, 'db4')
#     gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
#     beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
#     alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
#     theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
#     delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
#     gamma_data1['11thgamma'].append(gamma_RMS11)
#     beta_data1['11thbeta'].append(beta_RMS11)
#     alpha_data1['11thalpha'].append(alpha_RMS11)
#     theta_data1['11ththeta'].append(theta_RMS11)
#     delta_data1['11thdelta'].append(delta_RMS11)

    cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
    cA122, d122 = pywt.dwt(cA12, 'db4')
    cA123, d123 = pywt.dwt(cA122, 'db4')
    a124, d124 = pywt.dwt(cA123, 'db4')
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
    gamma_data1['12thgamma'].append(gamma_RMS12)
    beta_data1['12thbeta'].append(beta_RMS12)
    alpha_data1['12thalpha'].append(alpha_RMS12)
    theta_data1['12ththeta'].append(theta_RMS12)
    delta_data1['12thdelta'].append(delta_RMS12)

    cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
    cA132, d132 = pywt.dwt(cA13, 'db4')
    cA133, d133 = pywt.dwt(cA132, 'db4')
    a134, d134 = pywt.dwt(cA133, 'db4')
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
    gamma_data1['13thgamma'].append(gamma_RMS13)
    beta_data1['13thbeta'].append(beta_RMS13)
    alpha_data1['13thalpha'].append(alpha_RMS13)
    theta_data1['13ththeta'].append(theta_RMS13)
    delta_data1['13thdelta'].append(delta_RMS13)

    cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
    cA142, d142 = pywt.dwt(cA14, 'db4')
    cA143, d143 = pywt.dwt(cA142, 'db4')
    a144, d144 = pywt.dwt(cA143, 'db4')
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
    gamma_data1['14thgamma'].append(gamma_RMS14)
    beta_data1['14thbeta'].append(beta_RMS14)
    alpha_data1['14thalpha'].append(alpha_RMS14)
    theta_data1['14ththeta'].append(theta_RMS14)
    delta_data1['14thdelta'].append(delta_RMS14)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
standard_gamma = StandardScaler().fit_transform(gamma_data1) 
normalised_gamma = pd.DataFrame(standard_gamma)
pca_gamma = PCA(n_components=0.5)
principalComponents_gamma = pca_gamma.fit_transform(standard_gamma)
gamma_data1 = pd.DataFrame(data = principalComponents_gamma)


standard_beta = StandardScaler().fit_transform(beta_data1) 
normalised_beta = pd.DataFrame(standard_beta)
pca_beta = PCA(n_components=0.5)
principalComponents_beta = pca_beta.fit_transform(standard_beta)
beta_data1 = pd.DataFrame(data = principalComponents_beta)

standard_alpha = StandardScaler().fit_transform(alpha_data1) 
normalised_alpha = pd.DataFrame(standard_alpha)
pca_alpha = PCA(n_components=0.5)
principalComponents_alpha = pca_alpha.fit_transform(standard_alpha)
alpha_data1 = pd.DataFrame(data = principalComponents_alpha)

standard_theta = StandardScaler().fit_transform(theta_data1) 
normalised_theta = pd.DataFrame(standard_theta)
pca_theta = PCA(n_components=0.5)
principalComponents_theta = pca_theta.fit_transform(standard_theta)
theta_data1 = pd.DataFrame(data = principalComponents_theta)

standard_delta = StandardScaler().fit_transform(delta_data1) 
normalised_delta = pd.DataFrame(standard_delta)
pca_delta = PCA(n_components=0.5)
principalComponents_delta = pca_delta.fit_transform(standard_delta)
delta_data1 = pd.DataFrame(data = principalComponents_delta)

standard_merged = StandardScaler().fit_transform(merged) 
normalised_merged = pd.DataFrame(standard_merged)
pca_merged = PCA(n_components=0.5)
principalComponents_merged = pca_merged.fit_transform(standard_merged)
merged = pd.DataFrame(data = principalComponents_merged)
    


for i in range(20):

    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.2,stratify=labels)

   
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.2,stratify=labels)

    
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.2,stratify=labels)

    
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.2,stratify=labels)


    
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.2,stratify=labels)

    
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.2,stratify=labels)

    
    
    model_gamma= SVC(kernel='linear')
    model_gamma.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = model_gamma.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    model_beta= SVC(kernel='linear')
    model_beta.fit(data_train_beta,label_train_beta)
    predictions_beta = model_beta.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    model_alpha= SVC(kernel='linear')
    model_alpha.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = model_alpha.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    model_theta= SVC(kernel='linear')
    model_theta.fit(data_train_theta,label_train_theta)
    predictions_theta = model_theta.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    model_delta= SVC(kernel='linear')
    model_delta.fit(data_train_delta,label_train_delta)
    predictions_delta = model_delta.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))
    
    model_merged= SVC(kernel='linear')
    model_merged.fit(data_train_merged,label_train_merged)
    predictions_merged = model_merged.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_merged,output_dict=True))
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.31307072557072557
#  beta= 0.33071041703394644
#  alpha= 0.222426179341814
#  delta= 0.23544576682347582
#  theta= 0.21798574347335956
#  merged= 0.35950001766952233

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
#     "4thgamma":[],
#     "5thgamma":[],
#     "6thgamma":[],
#     "7thgamma":[],
#     "8thgamma":[],
#     "9thgamma":[],
#     "10thgamma":[],
#     "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]
}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
#     "4thbeta":[],
#     "5thbeta":[],
#     "6thbeta":[],
#     "7thbeta":[],
#     "8thbeta":[],
#     "9thbeta":[],
#     "10thbeta":[],
#     "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]
}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
#     "4thalpha":[],
#     "5thalpha":[],
#     "6thalpha":[],
#     "7thalpha":[],
#     "8thalpha":[],
#     "9thalpha":[],
#     "10thalpha":[],
#     "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]
}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
#     "4ththeta":[],
#     "5ththeta":[],
#     "6ththeta":[],
#     "7ththeta":[],
#     "8ththeta":[],
#     "9ththeta":[],
#     "10ththeta":[],
#     "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]
}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
#     "4thdelta":[],
#     "5thdelta":[],
#     "6thdelta":[],
#     "7thdelta":[],
#     "8thdelta":[],
#     "9thdelta":[],
#     "10thdelta":[],
#     "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]
}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/mostafa/"+str(i+1)+".txt",header=None,names=["label"])
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/mostafa/mostafa_"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
#         '4th':[],
#         '5th':[],
#         '6th':[],
#         '7th':[],
#         '8th':[],
#         '9th':[],
#         '10th':[],
#         '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
#         user_data['4th'].append(float(ny[3]))
#         user_data['5th'].append(float(ny[4]))
#         user_data['6th'].append(float(ny[5]))
#         user_data['7th'].append(float(ny[6]))
#         user_data['8th'].append(float(ny[7]))
#         user_data['9th'].append(float(ny[8]))
#         user_data['10th'].append(float(ny[9]))
#         user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
#     fourth_electrode = user_data['4th']
#     fifth_electrode = user_data['5th']
#     sixth_electrode = user_data['6th']
#     seventh_electrode = user_data['7th']
#     eighth_electrode = user_data['8th']
#     nineth_electrode = user_data['9th']
#     tenth_electrode = user_data['10th']
#     eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
#     s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
#     s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
#     s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
#     s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
#     s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
#     s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
#     s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
#     s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

#     cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
#     cA42, d42 = pywt.dwt(cA4, 'db4')
#     cA43, d43 = pywt.dwt(cA42, 'db4')
#     a44, d44 = pywt.dwt(cA43, 'db4')
#     gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
#     beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
#     alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
#     theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
#     delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
#     gamma_data1['4thgamma'].append(gamma_RMS4)
#     beta_data1['4thbeta'].append(beta_RMS4)
#     alpha_data1['4thalpha'].append(alpha_RMS4)
#     theta_data1['4ththeta'].append(theta_RMS4)
#     delta_data1['4thdelta'].append(delta_RMS4)

#     cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
#     cA52, d52 = pywt.dwt(cA5, 'db4')
#     cA53, d53 = pywt.dwt(cA52, 'db4')
#     a54, d54 = pywt.dwt(cA53, 'db4')
#     gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
#     beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
#     alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
#     theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
#     delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
#     gamma_data1['5thgamma'].append(gamma_RMS5)
#     beta_data1['5thbeta'].append(beta_RMS5)
#     alpha_data1['5thalpha'].append(alpha_RMS5)
#     theta_data1['5ththeta'].append(theta_RMS5)
#     delta_data1['5thdelta'].append(delta_RMS5)

#     cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
#     cA62, d62 = pywt.dwt(cA6, 'db4')
#     cA63, d63 = pywt.dwt(cA62, 'db4')
#     a64, d64 = pywt.dwt(cA63, 'db4')
#     gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
#     beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
#     alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
#     theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
#     delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
#     gamma_data1['6thgamma'].append(gamma_RMS6)
#     beta_data1['6thbeta'].append(beta_RMS6)
#     alpha_data1['6thalpha'].append(alpha_RMS6)
#     theta_data1['6ththeta'].append(theta_RMS6)
#     delta_data1['6thdelta'].append(delta_RMS6)
    

#     cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
#     cA72, d72 = pywt.dwt(cA7, 'db4')
#     cA73, d73 = pywt.dwt(cA72, 'db4')
#     a74, d74 = pywt.dwt(cA73, 'db4')
#     gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
#     beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
#     alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
#     theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
#     delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
#     gamma_data1['7thgamma'].append(gamma_RMS7)
#     beta_data1['7thbeta'].append(beta_RMS7)
#     alpha_data1['7thalpha'].append(alpha_RMS7)
#     theta_data1['7ththeta'].append(theta_RMS7)
#     delta_data1['7thdelta'].append(delta_RMS7)

#     cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
#     cA82, d82 = pywt.dwt(cA8, 'db4')
#     cA83, d83 = pywt.dwt(cA82, 'db4')
#     a84, d84 = pywt.dwt(cA83, 'db4')
#     gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
#     beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
#     alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
#     theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
#     delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
#     gamma_data1['8thgamma'].append(gamma_RMS8)
#     beta_data1['8thbeta'].append(beta_RMS8)
#     alpha_data1['8thalpha'].append(alpha_RMS8)
#     theta_data1['8ththeta'].append(theta_RMS8)
#     delta_data1['8thdelta'].append(delta_RMS8)

#     cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
#     cA92, d92 = pywt.dwt(cA9, 'db4')
#     cA93, d93 = pywt.dwt(cA92, 'db4')
#     a94, d94 = pywt.dwt(cA93, 'db4')
#     gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
#     beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
#     alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
#     theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
#     delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
#     gamma_data1['9thgamma'].append(gamma_RMS9)
#     beta_data1['9thbeta'].append(beta_RMS9)
#     alpha_data1['9thalpha'].append(alpha_RMS9)
#     theta_data1['9ththeta'].append(theta_RMS9)
#     delta_data1['9thdelta'].append(delta_RMS9)

#     cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
#     cA102, d102 = pywt.dwt(cA10, 'db4')
#     cA103, d103 = pywt.dwt(cA102, 'db4')
#     a104, d104 = pywt.dwt(cA103, 'db4')
#     gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
#     beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
#     alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
#     theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
#     delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
#     gamma_data1['10thgamma'].append(gamma_RMS10)
#     beta_data1['10thbeta'].append(beta_RMS10)
#     alpha_data1['10thalpha'].append(alpha_RMS10)
#     theta_data1['10ththeta'].append(theta_RMS10)
#     delta_data1['10thdelta'].append(delta_RMS10)

#     cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
#     cA112, d112 = pywt.dwt(cA11, 'db4')
#     cA113, d113 = pywt.dwt(cA112, 'db4')
#     a114, d114 = pywt.dwt(cA113, 'db4')
#     gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
#     beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
#     alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
#     theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
#     delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
#     gamma_data1['11thgamma'].append(gamma_RMS11)
#     beta_data1['11thbeta'].append(beta_RMS11)
#     alpha_data1['11thalpha'].append(alpha_RMS11)
#     theta_data1['11ththeta'].append(theta_RMS11)
#     delta_data1['11thdelta'].append(delta_RMS11)

    cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
    cA122, d122 = pywt.dwt(cA12, 'db4')
    cA123, d123 = pywt.dwt(cA122, 'db4')
    a124, d124 = pywt.dwt(cA123, 'db4')
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
    gamma_data1['12thgamma'].append(gamma_RMS12)
    beta_data1['12thbeta'].append(beta_RMS12)
    alpha_data1['12thalpha'].append(alpha_RMS12)
    theta_data1['12ththeta'].append(theta_RMS12)
    delta_data1['12thdelta'].append(delta_RMS12)

    cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
    cA132, d132 = pywt.dwt(cA13, 'db4')
    cA133, d133 = pywt.dwt(cA132, 'db4')
    a134, d134 = pywt.dwt(cA133, 'db4')
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
    gamma_data1['13thgamma'].append(gamma_RMS13)
    beta_data1['13thbeta'].append(beta_RMS13)
    alpha_data1['13thalpha'].append(alpha_RMS13)
    theta_data1['13ththeta'].append(theta_RMS13)
    delta_data1['13thdelta'].append(delta_RMS13)

    cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
    cA142, d142 = pywt.dwt(cA14, 'db4')
    cA143, d143 = pywt.dwt(cA142, 'db4')
    a144, d144 = pywt.dwt(cA143, 'db4')
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
    gamma_data1['14thgamma'].append(gamma_RMS14)
    beta_data1['14thbeta'].append(beta_RMS14)
    alpha_data1['14thalpha'].append(alpha_RMS14)
    theta_data1['14ththeta'].append(theta_RMS14)
    delta_data1['14thdelta'].append(delta_RMS14)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
standard_gamma = StandardScaler().fit_transform(gamma_data1) 
normalised_gamma = pd.DataFrame(standard_gamma)
pca_gamma = PCA(n_components=0.9)
principalComponents_gamma = pca_gamma.fit_transform(standard_gamma)
gamma_data1 = pd.DataFrame(data = principalComponents_gamma)


standard_beta = StandardScaler().fit_transform(beta_data1) 
normalised_beta = pd.DataFrame(standard_beta)
pca_beta = PCA(n_components=0.9)
principalComponents_beta = pca_beta.fit_transform(standard_beta)
beta_data1 = pd.DataFrame(data = principalComponents_beta)

standard_alpha = StandardScaler().fit_transform(alpha_data1) 
normalised_alpha = pd.DataFrame(standard_alpha)
pca_alpha = PCA(n_components=0.9)
principalComponents_alpha = pca_alpha.fit_transform(standard_alpha)
alpha_data1 = pd.DataFrame(data = principalComponents_alpha)

standard_theta = StandardScaler().fit_transform(theta_data1) 
normalised_theta = pd.DataFrame(standard_theta)
pca_theta = PCA(n_components=0.9)
principalComponents_theta = pca_theta.fit_transform(standard_theta)
theta_data1 = pd.DataFrame(data = principalComponents_theta)

standard_delta = StandardScaler().fit_transform(delta_data1) 
normalised_delta = pd.DataFrame(standard_delta)
pca_delta = PCA(n_components=0.9)
principalComponents_delta = pca_delta.fit_transform(standard_delta)
delta_data1 = pd.DataFrame(data = principalComponents_delta)

standard_merged = StandardScaler().fit_transform(merged) 
normalised_merged = pd.DataFrame(standard_merged)
pca_merged = PCA(n_components=0.9)
principalComponents_merged = pca_merged.fit_transform(standard_merged)
merged = pd.DataFrame(data = principalComponents_merged)
for i in range(20):
    
   
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.2,stratify=labels)

    
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.2,stratify=labels)

    
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.2,stratify=labels)

    
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.2,stratify=labels)


   
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.2,stratify=labels)

   
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.2,stratify=labels)

    dtree1 = RandomForestClassifier(n_estimators=400)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    dtree2 = RandomForestClassifier(n_estimators=400)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    dtree3 = RandomForestClassifier(n_estimators=400)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    dtree4 = RandomForestClassifier(n_estimators=400)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    dtree5 = RandomForestClassifier(n_estimators=400)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

    dtree6 = RandomForestClassifier(n_estimators=400)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.2715546490546491
#  beta= 0.3647749472749472
#  alpha= 0.38864066489066484
#  delta= 0.27722249972249974
#  theta= 0.4684241684241684
#  merged= 0.38191035816035823

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
#     "4thgamma":[],
#     "5thgamma":[],
#     "6thgamma":[],
#     "7thgamma":[],
#     "8thgamma":[],
#     "9thgamma":[],
#     "10thgamma":[],
    "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]
}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
#     "4thbeta":[],
#     "5thbeta":[],
#     "6thbeta":[],
#     "7thbeta":[],
#     "8thbeta":[],
#     "9thbeta":[],
#     "10thbeta":[],
    "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]
}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
#     "4thalpha":[],
#     "5thalpha":[],
#     "6thalpha":[],
#     "7thalpha":[],
#     "8thalpha":[],
#     "9thalpha":[],
#     "10thalpha":[],
    "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]
}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
#     "4ththeta":[],
#     "5ththeta":[],
#     "6ththeta":[],
#     "7ththeta":[],
#     "8ththeta":[],
#     "9ththeta":[],
#     "10ththeta":[],
    "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]
}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
#     "4thdelta":[],
#     "5thdelta":[],
#     "6thdelta":[],
#     "7thdelta":[],
#     "8thdelta":[],
#     "9thdelta":[],
#     "10thdelta":[],
    "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]
}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/mostafa/"+str(i+1)+".txt",header=None,names=["label"])
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/mostafa/mostafa_"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
#         '4th':[],
#         '5th':[],
#         '6th':[],
#         '7th':[],
#         '8th':[],
#         '9th':[],
#         '10th':[],
        '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
#         user_data['4th'].append(float(ny[3]))
#         user_data['5th'].append(float(ny[4]))
#         user_data['6th'].append(float(ny[5]))
#         user_data['7th'].append(float(ny[6]))
#         user_data['8th'].append(float(ny[7]))
#         user_data['9th'].append(float(ny[8]))
#         user_data['10th'].append(float(ny[9]))
        user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
#     fourth_electrode = user_data['4th']
#     fifth_electrode = user_data['5th']
#     sixth_electrode = user_data['6th']
#     seventh_electrode = user_data['7th']
#     eighth_electrode = user_data['8th']
#     nineth_electrode = user_data['9th']
#     tenth_electrode = user_data['10th']
    eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
#     s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
#     s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
#     s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
#     s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
#     s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
#     s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
#     s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
    s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

#     cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
#     cA42, d42 = pywt.dwt(cA4, 'db4')
#     cA43, d43 = pywt.dwt(cA42, 'db4')
#     a44, d44 = pywt.dwt(cA43, 'db4')
#     gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
#     beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
#     alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
#     theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
#     delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
#     gamma_data1['4thgamma'].append(gamma_RMS4)
#     beta_data1['4thbeta'].append(beta_RMS4)
#     alpha_data1['4thalpha'].append(alpha_RMS4)
#     theta_data1['4ththeta'].append(theta_RMS4)
#     delta_data1['4thdelta'].append(delta_RMS4)

#     cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
#     cA52, d52 = pywt.dwt(cA5, 'db4')
#     cA53, d53 = pywt.dwt(cA52, 'db4')
#     a54, d54 = pywt.dwt(cA53, 'db4')
#     gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
#     beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
#     alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
#     theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
#     delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
#     gamma_data1['5thgamma'].append(gamma_RMS5)
#     beta_data1['5thbeta'].append(beta_RMS5)
#     alpha_data1['5thalpha'].append(alpha_RMS5)
#     theta_data1['5ththeta'].append(theta_RMS5)
#     delta_data1['5thdelta'].append(delta_RMS5)

#     cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
#     cA62, d62 = pywt.dwt(cA6, 'db4')
#     cA63, d63 = pywt.dwt(cA62, 'db4')
#     a64, d64 = pywt.dwt(cA63, 'db4')
#     gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
#     beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
#     alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
#     theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
#     delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
#     gamma_data1['6thgamma'].append(gamma_RMS6)
#     beta_data1['6thbeta'].append(beta_RMS6)
#     alpha_data1['6thalpha'].append(alpha_RMS6)
#     theta_data1['6ththeta'].append(theta_RMS6)
#     delta_data1['6thdelta'].append(delta_RMS6)
    

#     cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
#     cA72, d72 = pywt.dwt(cA7, 'db4')
#     cA73, d73 = pywt.dwt(cA72, 'db4')
#     a74, d74 = pywt.dwt(cA73, 'db4')
#     gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
#     beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
#     alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
#     theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
#     delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
#     gamma_data1['7thgamma'].append(gamma_RMS7)
#     beta_data1['7thbeta'].append(beta_RMS7)
#     alpha_data1['7thalpha'].append(alpha_RMS7)
#     theta_data1['7ththeta'].append(theta_RMS7)
#     delta_data1['7thdelta'].append(delta_RMS7)

#     cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
#     cA82, d82 = pywt.dwt(cA8, 'db4')
#     cA83, d83 = pywt.dwt(cA82, 'db4')
#     a84, d84 = pywt.dwt(cA83, 'db4')
#     gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
#     beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
#     alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
#     theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
#     delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
#     gamma_data1['8thgamma'].append(gamma_RMS8)
#     beta_data1['8thbeta'].append(beta_RMS8)
#     alpha_data1['8thalpha'].append(alpha_RMS8)
#     theta_data1['8ththeta'].append(theta_RMS8)
#     delta_data1['8thdelta'].append(delta_RMS8)

#     cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
#     cA92, d92 = pywt.dwt(cA9, 'db4')
#     cA93, d93 = pywt.dwt(cA92, 'db4')
#     a94, d94 = pywt.dwt(cA93, 'db4')
#     gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
#     beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
#     alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
#     theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
#     delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
#     gamma_data1['9thgamma'].append(gamma_RMS9)
#     beta_data1['9thbeta'].append(beta_RMS9)
#     alpha_data1['9thalpha'].append(alpha_RMS9)
#     theta_data1['9ththeta'].append(theta_RMS9)
#     delta_data1['9thdelta'].append(delta_RMS9)

#     cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
#     cA102, d102 = pywt.dwt(cA10, 'db4')
#     cA103, d103 = pywt.dwt(cA102, 'db4')
#     a104, d104 = pywt.dwt(cA103, 'db4')
#     gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
#     beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
#     alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
#     theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
#     delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
#     gamma_data1['10thgamma'].append(gamma_RMS10)
#     beta_data1['10thbeta'].append(beta_RMS10)
#     alpha_data1['10thalpha'].append(alpha_RMS10)
#     theta_data1['10ththeta'].append(theta_RMS10)
#     delta_data1['10thdelta'].append(delta_RMS10)

    cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
    cA112, d112 = pywt.dwt(cA11, 'db4')
    cA113, d113 = pywt.dwt(cA112, 'db4')
    a114, d114 = pywt.dwt(cA113, 'db4')
    gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
    beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
    alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
    theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
    delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
    gamma_data1['11thgamma'].append(gamma_RMS11)
    beta_data1['11thbeta'].append(beta_RMS11)
    alpha_data1['11thalpha'].append(alpha_RMS11)
    theta_data1['11ththeta'].append(theta_RMS11)
    delta_data1['11thdelta'].append(delta_RMS11)

    cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
    cA122, d122 = pywt.dwt(cA12, 'db4')
    cA123, d123 = pywt.dwt(cA122, 'db4')
    a124, d124 = pywt.dwt(cA123, 'db4')
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
    gamma_data1['12thgamma'].append(gamma_RMS12)
    beta_data1['12thbeta'].append(beta_RMS12)
    alpha_data1['12thalpha'].append(alpha_RMS12)
    theta_data1['12ththeta'].append(theta_RMS12)
    delta_data1['12thdelta'].append(delta_RMS12)

    cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
    cA132, d132 = pywt.dwt(cA13, 'db4')
    cA133, d133 = pywt.dwt(cA132, 'db4')
    a134, d134 = pywt.dwt(cA133, 'db4')
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
    gamma_data1['13thgamma'].append(gamma_RMS13)
    beta_data1['13thbeta'].append(beta_RMS13)
    alpha_data1['13thalpha'].append(alpha_RMS13)
    theta_data1['13ththeta'].append(theta_RMS13)
    delta_data1['13thdelta'].append(delta_RMS13)

    cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
    cA142, d142 = pywt.dwt(cA14, 'db4')
    cA143, d143 = pywt.dwt(cA142, 'db4')
    a144, d144 = pywt.dwt(cA143, 'db4')
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
    gamma_data1['14thgamma'].append(gamma_RMS14)
    beta_data1['14thbeta'].append(beta_RMS14)
    alpha_data1['14thalpha'].append(alpha_RMS14)
    theta_data1['14ththeta'].append(theta_RMS14)
    delta_data1['14thdelta'].append(delta_RMS14)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
standard_gamma = StandardScaler().fit_transform(gamma_data1) 
normalised_gamma = pd.DataFrame(standard_gamma)
pca_gamma = PCA(n_components=0.9)
principalComponents_gamma = pca_gamma.fit_transform(standard_gamma)
gamma_data1 = pd.DataFrame(data = principalComponents_gamma)


standard_beta = StandardScaler().fit_transform(beta_data1) 
normalised_beta = pd.DataFrame(standard_beta)
pca_beta = PCA(n_components=0.9)
principalComponents_beta = pca_beta.fit_transform(standard_beta)
beta_data1 = pd.DataFrame(data = principalComponents_beta)

standard_alpha = StandardScaler().fit_transform(alpha_data1) 
normalised_alpha = pd.DataFrame(standard_alpha)
pca_alpha = PCA(n_components=0.9)
principalComponents_alpha = pca_alpha.fit_transform(standard_alpha)
alpha_data1 = pd.DataFrame(data = principalComponents_alpha)

standard_theta = StandardScaler().fit_transform(theta_data1) 
normalised_theta = pd.DataFrame(standard_theta)
pca_theta = PCA(n_components=0.9)
principalComponents_theta = pca_theta.fit_transform(standard_theta)
theta_data1 = pd.DataFrame(data = principalComponents_theta)

standard_delta = StandardScaler().fit_transform(delta_data1) 
normalised_delta = pd.DataFrame(standard_delta)
pca_delta = PCA(n_components=0.9)
principalComponents_delta = pca_delta.fit_transform(standard_delta)
delta_data1 = pd.DataFrame(data = principalComponents_delta)

standard_merged = StandardScaler().fit_transform(merged) 
normalised_merged = pd.DataFrame(standard_merged)
pca_merged = PCA(n_components=0.9)
principalComponents_merged = pca_merged.fit_transform(standard_merged)
merged = pd.DataFrame(data = principalComponents_merged)
for i in range(20):
    
   
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.2,stratify=labels)

    
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.2,stratify=labels)

    
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.2,stratify=labels)

    
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.2,stratify=labels)


   
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.2,stratify=labels)

   
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.2,stratify=labels)

    dtree1 = RandomForestClassifier(n_estimators=400)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    dtree2 = RandomForestClassifier(n_estimators=400)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    dtree3 = RandomForestClassifier(n_estimators=400)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    dtree4 = RandomForestClassifier(n_estimators=400)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    dtree5 = RandomForestClassifier(n_estimators=400)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

    dtree6 = RandomForestClassifier(n_estimators=400)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.27593334769805355
#  beta= 0.36999061124061117
#  alpha= 0.31518278018278023
#  delta= 0.3396883209383209
#  theta= 0.4033217925864984
#  merged= 0.42284178784178783

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
    "4thgamma":[],
#     "5thgamma":[],
#     "6thgamma":[],
#     "7thgamma":[],
#     "8thgamma":[],
#     "9thgamma":[],
#     "10thgamma":[],
    "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]
}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
    "4thbeta":[],
#     "5thbeta":[],
#     "6thbeta":[],
#     "7thbeta":[],
#     "8thbeta":[],
#     "9thbeta":[],
#     "10thbeta":[],
    "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]
}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
    "4thalpha":[],
#     "5thalpha":[],
#     "6thalpha":[],
#     "7thalpha":[],
#     "8thalpha":[],
#     "9thalpha":[],
#     "10thalpha":[],
    "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]
}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
    "4ththeta":[],
#     "5ththeta":[],
#     "6ththeta":[],
#     "7ththeta":[],
#     "8ththeta":[],
#     "9ththeta":[],
#     "10ththeta":[],
    "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]
}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
    "4thdelta":[],
#     "5thdelta":[],
#     "6thdelta":[],
#     "7thdelta":[],
#     "8thdelta":[],
#     "9thdelta":[],
#     "10thdelta":[],
    "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]
}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/mostafa/"+str(i+1)+".txt",header=None,names=["label"])
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/mostafa/mostafa_"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
        '4th':[],
#         '5th':[],
#         '6th':[],
#         '7th':[],
#         '8th':[],
#         '9th':[],
#         '10th':[],
        '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
        user_data['4th'].append(float(ny[3]))
#         user_data['5th'].append(float(ny[4]))
#         user_data['6th'].append(float(ny[5]))
#         user_data['7th'].append(float(ny[6]))
#         user_data['8th'].append(float(ny[7]))
#         user_data['9th'].append(float(ny[8]))
#         user_data['10th'].append(float(ny[9]))
        user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
    fourth_electrode = user_data['4th']
#     fifth_electrode = user_data['5th']
#     sixth_electrode = user_data['6th']
#     seventh_electrode = user_data['7th']
#     eighth_electrode = user_data['8th']
#     nineth_electrode = user_data['9th']
#     tenth_electrode = user_data['10th']
    eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
    s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
#     s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
#     s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
#     s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
#     s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
#     s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
#     s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
    s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

    cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
    cA42, d42 = pywt.dwt(cA4, 'db4')
    cA43, d43 = pywt.dwt(cA42, 'db4')
    a44, d44 = pywt.dwt(cA43, 'db4')
    gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
    beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
    alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
    theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
    delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
    gamma_data1['4thgamma'].append(gamma_RMS4)
    beta_data1['4thbeta'].append(beta_RMS4)
    alpha_data1['4thalpha'].append(alpha_RMS4)
    theta_data1['4ththeta'].append(theta_RMS4)
    delta_data1['4thdelta'].append(delta_RMS4)

#     cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
#     cA52, d52 = pywt.dwt(cA5, 'db4')
#     cA53, d53 = pywt.dwt(cA52, 'db4')
#     a54, d54 = pywt.dwt(cA53, 'db4')
#     gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
#     beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
#     alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
#     theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
#     delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
#     gamma_data1['5thgamma'].append(gamma_RMS5)
#     beta_data1['5thbeta'].append(beta_RMS5)
#     alpha_data1['5thalpha'].append(alpha_RMS5)
#     theta_data1['5ththeta'].append(theta_RMS5)
#     delta_data1['5thdelta'].append(delta_RMS5)

#     cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
#     cA62, d62 = pywt.dwt(cA6, 'db4')
#     cA63, d63 = pywt.dwt(cA62, 'db4')
#     a64, d64 = pywt.dwt(cA63, 'db4')
#     gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
#     beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
#     alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
#     theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
#     delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
#     gamma_data1['6thgamma'].append(gamma_RMS6)
#     beta_data1['6thbeta'].append(beta_RMS6)
#     alpha_data1['6thalpha'].append(alpha_RMS6)
#     theta_data1['6ththeta'].append(theta_RMS6)
#     delta_data1['6thdelta'].append(delta_RMS6)
    

#     cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
#     cA72, d72 = pywt.dwt(cA7, 'db4')
#     cA73, d73 = pywt.dwt(cA72, 'db4')
#     a74, d74 = pywt.dwt(cA73, 'db4')
#     gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
#     beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
#     alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
#     theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
#     delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
#     gamma_data1['7thgamma'].append(gamma_RMS7)
#     beta_data1['7thbeta'].append(beta_RMS7)
#     alpha_data1['7thalpha'].append(alpha_RMS7)
#     theta_data1['7ththeta'].append(theta_RMS7)
#     delta_data1['7thdelta'].append(delta_RMS7)

#     cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
#     cA82, d82 = pywt.dwt(cA8, 'db4')
#     cA83, d83 = pywt.dwt(cA82, 'db4')
#     a84, d84 = pywt.dwt(cA83, 'db4')
#     gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
#     beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
#     alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
#     theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
#     delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
#     gamma_data1['8thgamma'].append(gamma_RMS8)
#     beta_data1['8thbeta'].append(beta_RMS8)
#     alpha_data1['8thalpha'].append(alpha_RMS8)
#     theta_data1['8ththeta'].append(theta_RMS8)
#     delta_data1['8thdelta'].append(delta_RMS8)

#     cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
#     cA92, d92 = pywt.dwt(cA9, 'db4')
#     cA93, d93 = pywt.dwt(cA92, 'db4')
#     a94, d94 = pywt.dwt(cA93, 'db4')
#     gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
#     beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
#     alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
#     theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
#     delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
#     gamma_data1['9thgamma'].append(gamma_RMS9)
#     beta_data1['9thbeta'].append(beta_RMS9)
#     alpha_data1['9thalpha'].append(alpha_RMS9)
#     theta_data1['9ththeta'].append(theta_RMS9)
#     delta_data1['9thdelta'].append(delta_RMS9)

#     cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
#     cA102, d102 = pywt.dwt(cA10, 'db4')
#     cA103, d103 = pywt.dwt(cA102, 'db4')
#     a104, d104 = pywt.dwt(cA103, 'db4')
#     gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
#     beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
#     alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
#     theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
#     delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
#     gamma_data1['10thgamma'].append(gamma_RMS10)
#     beta_data1['10thbeta'].append(beta_RMS10)
#     alpha_data1['10thalpha'].append(alpha_RMS10)
#     theta_data1['10ththeta'].append(theta_RMS10)
#     delta_data1['10thdelta'].append(delta_RMS10)

    cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
    cA112, d112 = pywt.dwt(cA11, 'db4')
    cA113, d113 = pywt.dwt(cA112, 'db4')
    a114, d114 = pywt.dwt(cA113, 'db4')
    gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
    beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
    alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
    theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
    delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
    gamma_data1['11thgamma'].append(gamma_RMS11)
    beta_data1['11thbeta'].append(beta_RMS11)
    alpha_data1['11thalpha'].append(alpha_RMS11)
    theta_data1['11ththeta'].append(theta_RMS11)
    delta_data1['11thdelta'].append(delta_RMS11)

    cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
    cA122, d122 = pywt.dwt(cA12, 'db4')
    cA123, d123 = pywt.dwt(cA122, 'db4')
    a124, d124 = pywt.dwt(cA123, 'db4')
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
    gamma_data1['12thgamma'].append(gamma_RMS12)
    beta_data1['12thbeta'].append(beta_RMS12)
    alpha_data1['12thalpha'].append(alpha_RMS12)
    theta_data1['12ththeta'].append(theta_RMS12)
    delta_data1['12thdelta'].append(delta_RMS12)

    cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
    cA132, d132 = pywt.dwt(cA13, 'db4')
    cA133, d133 = pywt.dwt(cA132, 'db4')
    a134, d134 = pywt.dwt(cA133, 'db4')
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
    gamma_data1['13thgamma'].append(gamma_RMS13)
    beta_data1['13thbeta'].append(beta_RMS13)
    alpha_data1['13thalpha'].append(alpha_RMS13)
    theta_data1['13ththeta'].append(theta_RMS13)
    delta_data1['13thdelta'].append(delta_RMS13)

    cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
    cA142, d142 = pywt.dwt(cA14, 'db4')
    cA143, d143 = pywt.dwt(cA142, 'db4')
    a144, d144 = pywt.dwt(cA143, 'db4')
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
    gamma_data1['14thgamma'].append(gamma_RMS14)
    beta_data1['14thbeta'].append(beta_RMS14)
    alpha_data1['14thalpha'].append(alpha_RMS14)
    theta_data1['14ththeta'].append(theta_RMS14)
    delta_data1['14thdelta'].append(delta_RMS14)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
standard_gamma = StandardScaler().fit_transform(gamma_data1) 
normalised_gamma = pd.DataFrame(standard_gamma)
pca_gamma = PCA(n_components=0.9)
principalComponents_gamma = pca_gamma.fit_transform(standard_gamma)
gamma_data1 = pd.DataFrame(data = principalComponents_gamma)


standard_beta = StandardScaler().fit_transform(beta_data1) 
normalised_beta = pd.DataFrame(standard_beta)
pca_beta = PCA(n_components=0.9)
principalComponents_beta = pca_beta.fit_transform(standard_beta)
beta_data1 = pd.DataFrame(data = principalComponents_beta)

standard_alpha = StandardScaler().fit_transform(alpha_data1) 
normalised_alpha = pd.DataFrame(standard_alpha)
pca_alpha = PCA(n_components=0.9)
principalComponents_alpha = pca_alpha.fit_transform(standard_alpha)
alpha_data1 = pd.DataFrame(data = principalComponents_alpha)

standard_theta = StandardScaler().fit_transform(theta_data1) 
normalised_theta = pd.DataFrame(standard_theta)
pca_theta = PCA(n_components=0.9)
principalComponents_theta = pca_theta.fit_transform(standard_theta)
theta_data1 = pd.DataFrame(data = principalComponents_theta)

standard_delta = StandardScaler().fit_transform(delta_data1) 
normalised_delta = pd.DataFrame(standard_delta)
pca_delta = PCA(n_components=0.9)
principalComponents_delta = pca_delta.fit_transform(standard_delta)
delta_data1 = pd.DataFrame(data = principalComponents_delta)

standard_merged = StandardScaler().fit_transform(merged) 
normalised_merged = pd.DataFrame(standard_merged)
pca_merged = PCA(n_components=0.9)
principalComponents_merged = pca_merged.fit_transform(standard_merged)
merged = pd.DataFrame(data = principalComponents_merged)
for i in range(20):
    
   
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.2,stratify=labels)

    
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.2,stratify=labels)

    
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.2,stratify=labels)

    
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.2,stratify=labels)


   
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.2,stratify=labels)

   
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.2,stratify=labels)

    dtree1 = RandomForestClassifier(n_estimators=400)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    dtree2 = RandomForestClassifier(n_estimators=400)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    dtree3 = RandomForestClassifier(n_estimators=400)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    dtree4 = RandomForestClassifier(n_estimators=400)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    dtree5 = RandomForestClassifier(n_estimators=400)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

    dtree6 = RandomForestClassifier(n_estimators=400)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.22222388722388722
#  beta= 0.38933836860307447
#  alpha= 0.3294953194953195
#  delta= 0.37007622007622004
#  theta= 0.29092065342065343
#  merged= 0.41748715064891534

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
#     "4thgamma":[],
#     "5thgamma":[],
#     "6thgamma":[],
#     "7thgamma":[],
#     "8thgamma":[],
#     "9thgamma":[],
#     "10thgamma":[],
#     "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]
}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
#     "4thbeta":[],
#     "5thbeta":[],
#     "6thbeta":[],
#     "7thbeta":[],
#     "8thbeta":[],
#     "9thbeta":[],
#     "10thbeta":[],
#     "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]
}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
#     "4thalpha":[],
#     "5thalpha":[],
#     "6thalpha":[],
#     "7thalpha":[],
#     "8thalpha":[],
#     "9thalpha":[],
#     "10thalpha":[],
#     "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]
}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
#     "4ththeta":[],
#     "5ththeta":[],
#     "6ththeta":[],
#     "7ththeta":[],
#     "8ththeta":[],
#     "9ththeta":[],
#     "10ththeta":[],
#     "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]
}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
#     "4thdelta":[],
#     "5thdelta":[],
#     "6thdelta":[],
#     "7thdelta":[],
#     "8thdelta":[],
#     "9thdelta":[],
#     "10thdelta":[],
#     "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]
}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/mostafa/"+str(i+1)+".txt",header=None,names=["label"])
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/mostafa/mostafa_"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
#         '4th':[],
#         '5th':[],
#         '6th':[],
#         '7th':[],
#         '8th':[],
#         '9th':[],
#         '10th':[],
#         '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
#         user_data['4th'].append(float(ny[3]))
#         user_data['5th'].append(float(ny[4]))
#         user_data['6th'].append(float(ny[5]))
#         user_data['7th'].append(float(ny[6]))
#         user_data['8th'].append(float(ny[7]))
#         user_data['9th'].append(float(ny[8]))
#         user_data['10th'].append(float(ny[9]))
#         user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
#     fourth_electrode = user_data['4th']
#     fifth_electrode = user_data['5th']
#     sixth_electrode = user_data['6th']
#     seventh_electrode = user_data['7th']
#     eighth_electrode = user_data['8th']
#     nineth_electrode = user_data['9th']
#     tenth_electrode = user_data['10th']
#     eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
#     s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
#     s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
#     s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
#     s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
#     s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
#     s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
#     s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
#     s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)
    
    
    
    b, a = scipy.signal.butter(8, 0.5, 'hp')
    d11=scipy.signal.lfilter(b, a,s_golay_filtered_signal1)
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    
    b, a = scipy.signal.butter(8, [0.25,0.484375], 'band')
    d12=scipy.signal.lfilter(b, a,s_golay_filtered_signal1)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    
    b, a = scipy.signal.butter(8, [0.125, 0.234375], 'band')
    d13=scipy.signal.lfilter(b, a,s_golay_filtered_signal1) 
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    
    b, a = scipy.signal.butter(8, [0.0625,0.109375 ], 'band')
    d14=scipy.signal.lfilter(b, a,s_golay_filtered_signal1)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    
    b, a = scipy.signal.butter(8, 0.0625, 'low')
    a14=scipy.signal.lfilter(b, a,s_golay_filtered_signal1)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
   
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    b, a = scipy.signal.butter(8, 0.5, 'hp')
    d21=scipy.signal.lfilter(b, a,s_golay_filtered_signal2)
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    
    b, a = scipy.signal.butter(8, [0.25,0.484375], 'band')
    d22=scipy.signal.lfilter(b, a,s_golay_filtered_signal2)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    
    b, a = scipy.signal.butter(8, [0.125, 0.234375], 'band')
    d23=scipy.signal.lfilter(b, a,s_golay_filtered_signal2) 
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    
    b, a = scipy.signal.butter(8, [0.0625,0.109375 ], 'band')
    d24=scipy.signal.lfilter(b, a,s_golay_filtered_signal2)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    
    b, a = scipy.signal.butter(8, 0.0625, 'low')
    a24=scipy.signal.lfilter(b, a,s_golay_filtered_signal2)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
   
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    
    b, a = scipy.signal.butter(8, 0.5, 'hp')
    d31=scipy.signal.lfilter(b, a,s_golay_filtered_signal3)
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    
    b, a = scipy.signal.butter(8, [0.25,0.484375], 'band')
    d32=scipy.signal.lfilter(b, a,s_golay_filtered_signal3)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    
    b, a = scipy.signal.butter(8, [0.125, 0.234375], 'band')
    d33=scipy.signal.lfilter(b, a,s_golay_filtered_signal3) 
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    
    b, a = scipy.signal.butter(8, [0.0625,0.109375 ], 'band')
    d34=scipy.signal.lfilter(b, a,s_golay_filtered_signal3)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    
    b, a = scipy.signal.butter(8, 0.0625, 'low')
    a34=scipy.signal.lfilter(b, a,s_golay_filtered_signal3)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    
    
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

#     cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
#     cA42, d42 = pywt.dwt(cA4, 'db4')
#     cA43, d43 = pywt.dwt(cA42, 'db4')
#     a44, d44 = pywt.dwt(cA43, 'db4')
#     gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
#     beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
#     alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
#     theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
#     delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
#     gamma_data1['4thgamma'].append(gamma_RMS4)
#     beta_data1['4thbeta'].append(beta_RMS4)
#     alpha_data1['4thalpha'].append(alpha_RMS4)
#     theta_data1['4ththeta'].append(theta_RMS4)
#     delta_data1['4thdelta'].append(delta_RMS4)

#     cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
#     cA52, d52 = pywt.dwt(cA5, 'db4')
#     cA53, d53 = pywt.dwt(cA52, 'db4')
#     a54, d54 = pywt.dwt(cA53, 'db4')
#     gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
#     beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
#     alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
#     theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
#     delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
#     gamma_data1['5thgamma'].append(gamma_RMS5)
#     beta_data1['5thbeta'].append(beta_RMS5)
#     alpha_data1['5thalpha'].append(alpha_RMS5)
#     theta_data1['5ththeta'].append(theta_RMS5)
#     delta_data1['5thdelta'].append(delta_RMS5)

#     cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
#     cA62, d62 = pywt.dwt(cA6, 'db4')
#     cA63, d63 = pywt.dwt(cA62, 'db4')
#     a64, d64 = pywt.dwt(cA63, 'db4')
#     gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
#     beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
#     alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
#     theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
#     delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
#     gamma_data1['6thgamma'].append(gamma_RMS6)
#     beta_data1['6thbeta'].append(beta_RMS6)
#     alpha_data1['6thalpha'].append(alpha_RMS6)
#     theta_data1['6ththeta'].append(theta_RMS6)
#     delta_data1['6thdelta'].append(delta_RMS6)
    

#     cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
#     cA72, d72 = pywt.dwt(cA7, 'db4')
#     cA73, d73 = pywt.dwt(cA72, 'db4')
#     a74, d74 = pywt.dwt(cA73, 'db4')
#     gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
#     beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
#     alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
#     theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
#     delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
#     gamma_data1['7thgamma'].append(gamma_RMS7)
#     beta_data1['7thbeta'].append(beta_RMS7)
#     alpha_data1['7thalpha'].append(alpha_RMS7)
#     theta_data1['7ththeta'].append(theta_RMS7)
#     delta_data1['7thdelta'].append(delta_RMS7)

#     cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
#     cA82, d82 = pywt.dwt(cA8, 'db4')
#     cA83, d83 = pywt.dwt(cA82, 'db4')
#     a84, d84 = pywt.dwt(cA83, 'db4')
#     gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
#     beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
#     alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
#     theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
#     delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
#     gamma_data1['8thgamma'].append(gamma_RMS8)
#     beta_data1['8thbeta'].append(beta_RMS8)
#     alpha_data1['8thalpha'].append(alpha_RMS8)
#     theta_data1['8ththeta'].append(theta_RMS8)
#     delta_data1['8thdelta'].append(delta_RMS8)

#     cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
#     cA92, d92 = pywt.dwt(cA9, 'db4')
#     cA93, d93 = pywt.dwt(cA92, 'db4')
#     a94, d94 = pywt.dwt(cA93, 'db4')
#     gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
#     beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
#     alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
#     theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
#     delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
#     gamma_data1['9thgamma'].append(gamma_RMS9)
#     beta_data1['9thbeta'].append(beta_RMS9)
#     alpha_data1['9thalpha'].append(alpha_RMS9)
#     theta_data1['9ththeta'].append(theta_RMS9)
#     delta_data1['9thdelta'].append(delta_RMS9)

#     cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
#     cA102, d102 = pywt.dwt(cA10, 'db4')
#     cA103, d103 = pywt.dwt(cA102, 'db4')
#     a104, d104 = pywt.dwt(cA103, 'db4')
#     gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
#     beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
#     alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
#     theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
#     delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
#     gamma_data1['10thgamma'].append(gamma_RMS10)
#     beta_data1['10thbeta'].append(beta_RMS10)
#     alpha_data1['10thalpha'].append(alpha_RMS10)
#     theta_data1['10ththeta'].append(theta_RMS10)
#     delta_data1['10thdelta'].append(delta_RMS10)

#     b, a = scipy.signal.butter(8, 0.5, 'hp')
#     d111=scipy.signal.lfilter(b, a,s_golay_filtered_signal11)
#     gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
    
#     b, a = scipy.signal.butter(8, [0.25,0.484375], 'band')
#     d112=scipy.signal.lfilter(b, a,s_golay_filtered_signal11)
#     beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
    
#     b, a = scipy.signal.butter(8, [0.125, 0.234375], 'band')
#     d113=scipy.signal.lfilter(b, a,s_golay_filtered_signal11) 
#     alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
    
#     b, a = scipy.signal.butter(8, [0.0625,0.109375 ], 'band')
#     d114=scipy.signal.lfilter(b, a,s_golay_filtered_signal11)
#     theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
    
#     b, a = scipy.signal.butter(8, 0.0625, 'low')
#     a114=scipy.signal.lfilter(b, a,s_golay_filtered_signal11)
#     delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
    
    
#     gamma_data1['11thgamma'].append(gamma_RMS11)
#     beta_data1['11thbeta'].append(beta_RMS11)
#     alpha_data1['11thalpha'].append(alpha_RMS11)
#     theta_data1['11ththeta'].append(theta_RMS11)
#     delta_data1['11thdelta'].append(delta_RMS11)
    
    
    b, a = scipy.signal.butter(8, 0.5, 'hp')
    d121=scipy.signal.lfilter(b, a,s_golay_filtered_signal12)
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d121.size)
    
    b, a = scipy.signal.butter(8, [0.25,0.484375], 'band')
    d122=scipy.signal.lfilter(b, a,s_golay_filtered_signal12)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d122.size)
    
    b, a = scipy.signal.butter(8, [0.125, 0.234375], 'band')
    d123=scipy.signal.lfilter(b, a,s_golay_filtered_signal12) 
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d123.size)
    
    b, a = scipy.signal.butter(8, [0.0625,0.109375 ], 'band')
    d124=scipy.signal.lfilter(b, a,s_golay_filtered_signal12)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d124.size)
    
    b, a = scipy.signal.butter(8, 0.0625, 'low')
    a124=scipy.signal.lfilter(b, a,s_golay_filtered_signal12)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a124.size)
    
    
    
    gamma_data1['12thgamma'].append(gamma_RMS12)
    beta_data1['12thbeta'].append(beta_RMS12)
    alpha_data1['12thalpha'].append(alpha_RMS12)
    theta_data1['12ththeta'].append(theta_RMS12)
    delta_data1['12thdelta'].append(delta_RMS12)
    
    
    b, a = scipy.signal.butter(4, 0.5, 'hp')
    d131=scipy.signal.lfilter(b, a,s_golay_filtered_signal13)
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    
    b, a = scipy.signal.butter(4, [0.25,0.484375], 'band')
    d132=scipy.signal.lfilter(b, a,s_golay_filtered_signal13)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d132.size)
    
    b, a = scipy.signal.butter(4, [0.125, 0.234375], 'band')
    d133=scipy.signal.lfilter(b, a,s_golay_filtered_signal13) 
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d133.size)
    
    b, a = scipy.signal.butter(4, [0.0625,0.109375 ], 'band')
    d134=scipy.signal.lfilter(b, a,s_golay_filtered_signal13)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d134.size)
    
    b, a = scipy.signal.butter(4, 0.0625, 'low')
    a134=scipy.signal.lfilter(b, a,s_golay_filtered_signal13)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a134.size)
    
    
    gamma_data1['13thgamma'].append(gamma_RMS13)
    beta_data1['13thbeta'].append(beta_RMS13)
    alpha_data1['13thalpha'].append(alpha_RMS13)
    theta_data1['13ththeta'].append(theta_RMS13)
    delta_data1['13thdelta'].append(delta_RMS13)
    
    b, a = scipy.signal.butter(8, 0.5, 'hp')
    d141=scipy.signal.lfilter(b, a,s_golay_filtered_signal14)
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    
    b, a = scipy.signal.butter(8, [0.25,0.484375], 'band')
    d142=scipy.signal.lfilter(b, a,s_golay_filtered_signal14)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    
    b, a = scipy.signal.butter(8, [0.125, 0.234375], 'band')
    d143=scipy.signal.lfilter(b, a,s_golay_filtered_signal14) 
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    
    b, a = scipy.signal.butter(8, [0.0625,0.109375 ], 'band')
    d144=scipy.signal.lfilter(b, a,s_golay_filtered_signal14)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    
    b, a = scipy.signal.butter(8, 0.0625, 'low')
    a144=scipy.signal.lfilter(b, a,s_golay_filtered_signal14)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)

    
    gamma_data1['14thgamma'].append(gamma_RMS14)
    beta_data1['14thbeta'].append(beta_RMS14)
    alpha_data1['14thalpha'].append(alpha_RMS14)
    theta_data1['14ththeta'].append(theta_RMS14)
    delta_data1['14thdelta'].append(delta_RMS14)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
standard_gamma = StandardScaler().fit_transform(gamma_data1) 
normalised_gamma = pd.DataFrame(standard_gamma)
pca_gamma = PCA(n_components=0.9)
principalComponents_gamma = pca_gamma.fit_transform(standard_gamma)
gamma_data1 = pd.DataFrame(data = principalComponents_gamma)


standard_beta = StandardScaler().fit_transform(beta_data1) 
normalised_beta = pd.DataFrame(standard_beta)
pca_beta = PCA(n_components=0.9)
principalComponents_beta = pca_beta.fit_transform(standard_beta)
beta_data1 = pd.DataFrame(data = principalComponents_beta)

standard_alpha = StandardScaler().fit_transform(alpha_data1) 
normalised_alpha = pd.DataFrame(standard_alpha)
pca_alpha = PCA(n_components=0.9)
principalComponents_alpha = pca_alpha.fit_transform(standard_alpha)
alpha_data1 = pd.DataFrame(data = principalComponents_alpha)

standard_theta = StandardScaler().fit_transform(theta_data1) 
normalised_theta = pd.DataFrame(standard_theta)
pca_theta = PCA(n_components=0.9)
principalComponents_theta = pca_theta.fit_transform(standard_theta)
theta_data1 = pd.DataFrame(data = principalComponents_theta)

standard_delta = StandardScaler().fit_transform(delta_data1) 
normalised_delta = pd.DataFrame(standard_delta)
pca_delta = PCA(n_components=0.9)
principalComponents_delta = pca_delta.fit_transform(standard_delta)
delta_data1 = pd.DataFrame(data = principalComponents_delta)

standard_merged = StandardScaler().fit_transform(merged) 
normalised_merged = pd.DataFrame(standard_merged)
pca_merged = PCA(n_components=0.9)
principalComponents_merged = pca_merged.fit_transform(standard_merged)
merged = pd.DataFrame(data = principalComponents_merged)
for i in range(20):
    
   
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.2,stratify=labels)
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.2,stratify=labels)
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.2,stratify=labels)
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.2,stratify=labels)
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.2,stratify=labels)
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.2,stratify=labels)

    dtree1 = RandomForestClassifier(n_estimators=1000)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    dtree2 = RandomForestClassifier(n_estimators=1000)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    dtree3 = RandomForestClassifier(n_estimators=1000)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    dtree4 = RandomForestClassifier(n_estimators=1000)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    dtree5 = RandomForestClassifier(n_estimators=1000)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

    dtree6 = RandomForestClassifier(n_estimators=1000)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.35343045843045845
#  beta= 0.2835658785658786
#  alpha= 0.34285830727007194
#  delta= 0.4039785214785215
#  theta= 0.39932622932622935
#  merged= 0.3222176897176897

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
#     "4thgamma":[],
#     "5thgamma":[],
#     "6thgamma":[],
#     "7thgamma":[],
#     "8thgamma":[],
#     "9thgamma":[],
#     "10thgamma":[],
#     "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]
}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
#     "4thbeta":[],
#     "5thbeta":[],
#     "6thbeta":[],
#     "7thbeta":[],
#     "8thbeta":[],
#     "9thbeta":[],
#     "10thbeta":[],
#     "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]
}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
#     "4thalpha":[],
#     "5thalpha":[],
#     "6thalpha":[],
#     "7thalpha":[],
#     "8thalpha":[],
#     "9thalpha":[],
#     "10thalpha":[],
#     "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]
}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
#     "4ththeta":[],
#     "5ththeta":[],
#     "6ththeta":[],
#     "7ththeta":[],
#     "8ththeta":[],
#     "9ththeta":[],
#     "10ththeta":[],
#     "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]
}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
#     "4thdelta":[],
#     "5thdelta":[],
#     "6thdelta":[],
#     "7thdelta":[],
#     "8thdelta":[],
#     "9thdelta":[],
#     "10thdelta":[],
#     "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]
}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/mostafa/"+str(i+1)+".txt",header=None,names=["label"])
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/mostafa/mostafa_"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
#         '4th':[],
#         '5th':[],
#         '6th':[],
#         '7th':[],
#         '8th':[],
#         '9th':[],
#         '10th':[],
#         '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
#         user_data['4th'].append(float(ny[3]))
#         user_data['5th'].append(float(ny[4]))
#         user_data['6th'].append(float(ny[5]))
#         user_data['7th'].append(float(ny[6]))
#         user_data['8th'].append(float(ny[7]))
#         user_data['9th'].append(float(ny[8]))
#         user_data['10th'].append(float(ny[9]))
#         user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
#     fourth_electrode = user_data['4th']
#     fifth_electrode = user_data['5th']
#     sixth_electrode = user_data['6th']
#     seventh_electrode = user_data['7th']
#     eighth_electrode = user_data['8th']
#     nineth_electrode = user_data['9th']
#     tenth_electrode = user_data['10th']
#     eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
#     s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
#     s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
#     s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
#     s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
#     s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
#     s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
#     s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
#     s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

#     cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
#     cA42, d42 = pywt.dwt(cA4, 'db4')
#     cA43, d43 = pywt.dwt(cA42, 'db4')
#     a44, d44 = pywt.dwt(cA43, 'db4')
#     gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
#     beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
#     alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
#     theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
#     delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
#     gamma_data1['4thgamma'].append(gamma_RMS4)
#     beta_data1['4thbeta'].append(beta_RMS4)
#     alpha_data1['4thalpha'].append(alpha_RMS4)
#     theta_data1['4ththeta'].append(theta_RMS4)
#     delta_data1['4thdelta'].append(delta_RMS4)

#     cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
#     cA52, d52 = pywt.dwt(cA5, 'db4')
#     cA53, d53 = pywt.dwt(cA52, 'db4')
#     a54, d54 = pywt.dwt(cA53, 'db4')
#     gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
#     beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
#     alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
#     theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
#     delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
#     gamma_data1['5thgamma'].append(gamma_RMS5)
#     beta_data1['5thbeta'].append(beta_RMS5)
#     alpha_data1['5thalpha'].append(alpha_RMS5)
#     theta_data1['5ththeta'].append(theta_RMS5)
#     delta_data1['5thdelta'].append(delta_RMS5)

#     cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
#     cA62, d62 = pywt.dwt(cA6, 'db4')
#     cA63, d63 = pywt.dwt(cA62, 'db4')
#     a64, d64 = pywt.dwt(cA63, 'db4')
#     gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
#     beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
#     alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
#     theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
#     delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
#     gamma_data1['6thgamma'].append(gamma_RMS6)
#     beta_data1['6thbeta'].append(beta_RMS6)
#     alpha_data1['6thalpha'].append(alpha_RMS6)
#     theta_data1['6ththeta'].append(theta_RMS6)
#     delta_data1['6thdelta'].append(delta_RMS6)
    

#     cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
#     cA72, d72 = pywt.dwt(cA7, 'db4')
#     cA73, d73 = pywt.dwt(cA72, 'db4')
#     a74, d74 = pywt.dwt(cA73, 'db4')
#     gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
#     beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
#     alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
#     theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
#     delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
#     gamma_data1['7thgamma'].append(gamma_RMS7)
#     beta_data1['7thbeta'].append(beta_RMS7)
#     alpha_data1['7thalpha'].append(alpha_RMS7)
#     theta_data1['7ththeta'].append(theta_RMS7)
#     delta_data1['7thdelta'].append(delta_RMS7)

#     cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
#     cA82, d82 = pywt.dwt(cA8, 'db4')
#     cA83, d83 = pywt.dwt(cA82, 'db4')
#     a84, d84 = pywt.dwt(cA83, 'db4')
#     gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
#     beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
#     alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
#     theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
#     delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
#     gamma_data1['8thgamma'].append(gamma_RMS8)
#     beta_data1['8thbeta'].append(beta_RMS8)
#     alpha_data1['8thalpha'].append(alpha_RMS8)
#     theta_data1['8ththeta'].append(theta_RMS8)
#     delta_data1['8thdelta'].append(delta_RMS8)

#     cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
#     cA92, d92 = pywt.dwt(cA9, 'db4')
#     cA93, d93 = pywt.dwt(cA92, 'db4')
#     a94, d94 = pywt.dwt(cA93, 'db4')
#     gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
#     beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
#     alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
#     theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
#     delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
#     gamma_data1['9thgamma'].append(gamma_RMS9)
#     beta_data1['9thbeta'].append(beta_RMS9)
#     alpha_data1['9thalpha'].append(alpha_RMS9)
#     theta_data1['9ththeta'].append(theta_RMS9)
#     delta_data1['9thdelta'].append(delta_RMS9)

#     cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
#     cA102, d102 = pywt.dwt(cA10, 'db4')
#     cA103, d103 = pywt.dwt(cA102, 'db4')
#     a104, d104 = pywt.dwt(cA103, 'db4')
#     gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
#     beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
#     alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
#     theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
#     delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
#     gamma_data1['10thgamma'].append(gamma_RMS10)
#     beta_data1['10thbeta'].append(beta_RMS10)
#     alpha_data1['10thalpha'].append(alpha_RMS10)
#     theta_data1['10ththeta'].append(theta_RMS10)
#     delta_data1['10thdelta'].append(delta_RMS10)

#     cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
#     cA112, d112 = pywt.dwt(cA11, 'db4')
#     cA113, d113 = pywt.dwt(cA112, 'db4')
#     a114, d114 = pywt.dwt(cA113, 'db4')
#     gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
#     beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
#     alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
#     theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
#     delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
#     gamma_data1['11thgamma'].append(gamma_RMS11)
#     beta_data1['11thbeta'].append(beta_RMS11)
#     alpha_data1['11thalpha'].append(alpha_RMS11)
#     theta_data1['11ththeta'].append(theta_RMS11)
#     delta_data1['11thdelta'].append(delta_RMS11)

    cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
    cA122, d122 = pywt.dwt(cA12, 'db4')
    cA123, d123 = pywt.dwt(cA122, 'db4')
    a124, d124 = pywt.dwt(cA123, 'db4')
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
    gamma_data1['12thgamma'].append(gamma_RMS12)
    beta_data1['12thbeta'].append(beta_RMS12)
    alpha_data1['12thalpha'].append(alpha_RMS12)
    theta_data1['12ththeta'].append(theta_RMS12)
    delta_data1['12thdelta'].append(delta_RMS12)

    cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
    cA132, d132 = pywt.dwt(cA13, 'db4')
    cA133, d133 = pywt.dwt(cA132, 'db4')
    a134, d134 = pywt.dwt(cA133, 'db4')
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
    gamma_data1['13thgamma'].append(gamma_RMS13)
    beta_data1['13thbeta'].append(beta_RMS13)
    alpha_data1['13thalpha'].append(alpha_RMS13)
    theta_data1['13ththeta'].append(theta_RMS13)
    delta_data1['13thdelta'].append(delta_RMS13)

    cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
    cA142, d142 = pywt.dwt(cA14, 'db4')
    cA143, d143 = pywt.dwt(cA142, 'db4')
    a144, d144 = pywt.dwt(cA143, 'db4')
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
    gamma_data1['14thgamma'].append(gamma_RMS14)
    beta_data1['14thbeta'].append(beta_RMS14)
    alpha_data1['14thalpha'].append(alpha_RMS14)
    theta_data1['14ththeta'].append(theta_RMS14)
    delta_data1['14thdelta'].append(delta_RMS14)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}


standard_gamma = preprocessing.normalize(gamma_data1) 
normalised_gamma = pd.DataFrame(standard_gamma)
pca_gamma = PCA(n_components=0.9)
principalComponents_gamma = pca_gamma.fit_transform(standard_gamma)
gamma_data1 = pd.DataFrame(data = principalComponents_gamma)


standard_beta = preprocessing.normalize(beta_data1)
normalised_beta = pd.DataFrame(standard_beta)
pca_beta = PCA(n_components=0.9)
principalComponents_beta = pca_beta.fit_transform(standard_beta)
beta_data1 = pd.DataFrame(data = principalComponents_beta)


standard_alpha = preprocessing.normalize(alpha_data1)
normalised_alpha = pd.DataFrame(standard_alpha)
pca_alpha = PCA(n_components=0.9)
principalComponents_alpha = pca_alpha.fit_transform(standard_alpha)
alpha_data1 = pd.DataFrame(data = principalComponents_alpha)


standard_theta = preprocessing.normalize(theta_data1) 
normalised_theta = pd.DataFrame(standard_theta)
pca_theta = PCA(n_components=0.9)
principalComponents_theta = pca_theta.fit_transform(standard_theta)
theta_data1 = pd.DataFrame(data = principalComponents_theta)


standard_delta = preprocessing.normalize(delta_data1)
normalised_delta = pd.DataFrame(standard_delta)
pca_delta = PCA(n_components=0.9)
principalComponents_delta = pca_delta.fit_transform(standard_delta)
delta_data1 = pd.DataFrame(data = principalComponents_delta)


standard_merged = preprocessing.normalize(merged) 
normalised_merged = pd.DataFrame(standard_merged)
pca_merged = PCA(n_components=0.9)
principalComponents_merged = pca_merged.fit_transform(standard_merged)
merged = pd.DataFrame(data = principalComponents_merged)
for i in range(20):
    
   
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.2,stratify=labels)
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.2,stratify=labels)
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.2,stratify=labels)
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.2,stratify=labels)
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.2,stratify=labels)
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.2,stratify=labels)

    dtree1 = RandomForestClassifier(n_estimators=1000)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    dtree2 = RandomForestClassifier(n_estimators=1000)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    dtree3 = RandomForestClassifier(n_estimators=1000)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    dtree4 = RandomForestClassifier(n_estimators=1000)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    dtree5 = RandomForestClassifier(n_estimators=1000)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

    dtree6 = RandomForestClassifier(n_estimators=1000)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.3348126492244139
#  beta= 0.2840883190883191
#  alpha= 0.351484718984719
#  delta= 0.3022240722240722
#  theta= 0.37343211254975955
#  merged= 0.2878123347240994

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
#     "4thgamma":[],
#     "5thgamma":[],
#     "6thgamma":[],
#     "7thgamma":[],
#     "8thgamma":[],
#     "9thgamma":[],
#     "10thgamma":[],
#     "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]
}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
#     "4thbeta":[],
#     "5thbeta":[],
#     "6thbeta":[],
#     "7thbeta":[],
#     "8thbeta":[],
#     "9thbeta":[],
#     "10thbeta":[],
#     "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]
}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
#     "4thalpha":[],
#     "5thalpha":[],
#     "6thalpha":[],
#     "7thalpha":[],
#     "8thalpha":[],
#     "9thalpha":[],
#     "10thalpha":[],
#     "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]
}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
#     "4ththeta":[],
#     "5ththeta":[],
#     "6ththeta":[],
#     "7ththeta":[],
#     "8ththeta":[],
#     "9ththeta":[],
#     "10ththeta":[],
#     "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]
}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
#     "4thdelta":[],
#     "5thdelta":[],
#     "6thdelta":[],
#     "7thdelta":[],
#     "8thdelta":[],
#     "9thdelta":[],
#     "10thdelta":[],
#     "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]
}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/mostafa/"+str(i+1)+".txt",header=None,names=["label"])
    if(user_label.values.tolist()[0][0]=="Neutral"):
        continue
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/mostafa/mostafa_"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
#         '4th':[],
#         '5th':[],
#         '6th':[],
#         '7th':[],
#         '8th':[],
#         '9th':[],
#         '10th':[],
#         '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
#         user_data['4th'].append(float(ny[3]))
#         user_data['5th'].append(float(ny[4]))
#         user_data['6th'].append(float(ny[5]))
#         user_data['7th'].append(float(ny[6]))
#         user_data['8th'].append(float(ny[7]))
#         user_data['9th'].append(float(ny[8]))
#         user_data['10th'].append(float(ny[9]))
#         user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
#     fourth_electrode = user_data['4th']
#     fifth_electrode = user_data['5th']
#     sixth_electrode = user_data['6th']
#     seventh_electrode = user_data['7th']
#     eighth_electrode = user_data['8th']
#     nineth_electrode = user_data['9th']
#     tenth_electrode = user_data['10th']
#     eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']

 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
#     s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
#     s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
#     s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
#     s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
#     s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
#     s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
#     s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
#     s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

#     cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
#     cA42, d42 = pywt.dwt(cA4, 'db4')
#     cA43, d43 = pywt.dwt(cA42, 'db4')
#     a44, d44 = pywt.dwt(cA43, 'db4')
#     gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
#     beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
#     alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
#     theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
#     delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
#     gamma_data1['4thgamma'].append(gamma_RMS4)
#     beta_data1['4thbeta'].append(beta_RMS4)
#     alpha_data1['4thalpha'].append(alpha_RMS4)
#     theta_data1['4ththeta'].append(theta_RMS4)
#     delta_data1['4thdelta'].append(delta_RMS4)

#     cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
#     cA52, d52 = pywt.dwt(cA5, 'db4')
#     cA53, d53 = pywt.dwt(cA52, 'db4')
#     a54, d54 = pywt.dwt(cA53, 'db4')
#     gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
#     beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
#     alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
#     theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
#     delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
#     gamma_data1['5thgamma'].append(gamma_RMS5)
#     beta_data1['5thbeta'].append(beta_RMS5)
#     alpha_data1['5thalpha'].append(alpha_RMS5)
#     theta_data1['5ththeta'].append(theta_RMS5)
#     delta_data1['5thdelta'].append(delta_RMS5)

#     cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
#     cA62, d62 = pywt.dwt(cA6, 'db4')
#     cA63, d63 = pywt.dwt(cA62, 'db4')
#     a64, d64 = pywt.dwt(cA63, 'db4')
#     gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
#     beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
#     alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
#     theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
#     delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
#     gamma_data1['6thgamma'].append(gamma_RMS6)
#     beta_data1['6thbeta'].append(beta_RMS6)
#     alpha_data1['6thalpha'].append(alpha_RMS6)
#     theta_data1['6ththeta'].append(theta_RMS6)
#     delta_data1['6thdelta'].append(delta_RMS6)
    

#     cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
#     cA72, d72 = pywt.dwt(cA7, 'db4')
#     cA73, d73 = pywt.dwt(cA72, 'db4')
#     a74, d74 = pywt.dwt(cA73, 'db4')
#     gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
#     beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
#     alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
#     theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
#     delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
#     gamma_data1['7thgamma'].append(gamma_RMS7)
#     beta_data1['7thbeta'].append(beta_RMS7)
#     alpha_data1['7thalpha'].append(alpha_RMS7)
#     theta_data1['7ththeta'].append(theta_RMS7)
#     delta_data1['7thdelta'].append(delta_RMS7)

#     cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
#     cA82, d82 = pywt.dwt(cA8, 'db4')
#     cA83, d83 = pywt.dwt(cA82, 'db4')
#     a84, d84 = pywt.dwt(cA83, 'db4')
#     gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
#     beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
#     alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
#     theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
#     delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
#     gamma_data1['8thgamma'].append(gamma_RMS8)
#     beta_data1['8thbeta'].append(beta_RMS8)
#     alpha_data1['8thalpha'].append(alpha_RMS8)
#     theta_data1['8ththeta'].append(theta_RMS8)
#     delta_data1['8thdelta'].append(delta_RMS8)

#     cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
#     cA92, d92 = pywt.dwt(cA9, 'db4')
#     cA93, d93 = pywt.dwt(cA92, 'db4')
#     a94, d94 = pywt.dwt(cA93, 'db4')
#     gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
#     beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
#     alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
#     theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
#     delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
#     gamma_data1['9thgamma'].append(gamma_RMS9)
#     beta_data1['9thbeta'].append(beta_RMS9)
#     alpha_data1['9thalpha'].append(alpha_RMS9)
#     theta_data1['9ththeta'].append(theta_RMS9)
#     delta_data1['9thdelta'].append(delta_RMS9)

#     cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
#     cA102, d102 = pywt.dwt(cA10, 'db4')
#     cA103, d103 = pywt.dwt(cA102, 'db4')
#     a104, d104 = pywt.dwt(cA103, 'db4')
#     gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
#     beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
#     alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
#     theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
#     delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
#     gamma_data1['10thgamma'].append(gamma_RMS10)
#     beta_data1['10thbeta'].append(beta_RMS10)
#     alpha_data1['10thalpha'].append(alpha_RMS10)
#     theta_data1['10ththeta'].append(theta_RMS10)
#     delta_data1['10thdelta'].append(delta_RMS10)

#     cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
#     cA112, d112 = pywt.dwt(cA11, 'db4')
#     cA113, d113 = pywt.dwt(cA112, 'db4')
#     a114, d114 = pywt.dwt(cA113, 'db4')
#     gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
#     beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
#     alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
#     theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
#     delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
#     gamma_data1['11thgamma'].append(gamma_RMS11)
#     beta_data1['11thbeta'].append(beta_RMS11)
#     alpha_data1['11thalpha'].append(alpha_RMS11)
#     theta_data1['11ththeta'].append(theta_RMS11)
#     delta_data1['11thdelta'].append(delta_RMS11)

    cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
    cA122, d122 = pywt.dwt(cA12, 'db4')
    cA123, d123 = pywt.dwt(cA122, 'db4')
    a124, d124 = pywt.dwt(cA123, 'db4')
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
    gamma_data1['12thgamma'].append(gamma_RMS12)
    beta_data1['12thbeta'].append(beta_RMS12)
    alpha_data1['12thalpha'].append(alpha_RMS12)
    theta_data1['12ththeta'].append(theta_RMS12)
    delta_data1['12thdelta'].append(delta_RMS12)

    cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
    cA132, d132 = pywt.dwt(cA13, 'db4')
    cA133, d133 = pywt.dwt(cA132, 'db4')
    a134, d134 = pywt.dwt(cA133, 'db4')
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
    gamma_data1['13thgamma'].append(gamma_RMS13)
    beta_data1['13thbeta'].append(beta_RMS13)
    alpha_data1['13thalpha'].append(alpha_RMS13)
    theta_data1['13ththeta'].append(theta_RMS13)
    delta_data1['13thdelta'].append(delta_RMS13)

    cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
    cA142, d142 = pywt.dwt(cA14, 'db4')
    cA143, d143 = pywt.dwt(cA142, 'db4')
    a144, d144 = pywt.dwt(cA143, 'db4')
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
    gamma_data1['14thgamma'].append(gamma_RMS14)
    beta_data1['14thbeta'].append(beta_RMS14)
    alpha_data1['14thalpha'].append(alpha_RMS14)
    theta_data1['14ththeta'].append(theta_RMS14)
    delta_data1['14thdelta'].append(delta_RMS14)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
print(len(labels))
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
standard_gamma = StandardScaler().fit_transform(gamma_data1) 
normalised_gamma = pd.DataFrame(standard_gamma)
pca_gamma = PCA(n_components=0.9)
principalComponents_gamma = pca_gamma.fit_transform(standard_gamma)
gamma_data1 = pd.DataFrame(data = principalComponents_gamma)


standard_beta = StandardScaler().fit_transform(beta_data1) 
normalised_beta = pd.DataFrame(standard_beta)
pca_beta = PCA(n_components=0.9)
principalComponents_beta = pca_beta.fit_transform(standard_beta)
beta_data1 = pd.DataFrame(data = principalComponents_beta)

standard_alpha = StandardScaler().fit_transform(alpha_data1) 
normalised_alpha = pd.DataFrame(standard_alpha)
pca_alpha = PCA(n_components=0.9)
principalComponents_alpha = pca_alpha.fit_transform(standard_alpha)
alpha_data1 = pd.DataFrame(data = principalComponents_alpha)

standard_theta = StandardScaler().fit_transform(theta_data1) 
normalised_theta = pd.DataFrame(standard_theta)
pca_theta = PCA(n_components=0.9)
principalComponents_theta = pca_theta.fit_transform(standard_theta)
theta_data1 = pd.DataFrame(data = principalComponents_theta)

standard_delta = StandardScaler().fit_transform(delta_data1) 
normalised_delta = pd.DataFrame(standard_delta)
pca_delta = PCA(n_components=0.9)
principalComponents_delta = pca_delta.fit_transform(standard_delta)
delta_data1 = pd.DataFrame(data = principalComponents_delta)

standard_merged = StandardScaler().fit_transform(merged) 
normalised_merged = pd.DataFrame(standard_merged)
pca_merged = PCA(n_components=0.9)
principalComponents_merged = pca_merged.fit_transform(standard_merged)
merged = pd.DataFrame(data = principalComponents_merged)
for i in range(20):
    
   
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.2,stratify=labels)
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.2,stratify=labels)
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.2,stratify=labels)
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.2,stratify=labels)
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.2,stratify=labels)
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.2,stratify=labels)

    dtree1 = RandomForestClassifier(n_estimators=1000)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    dtree2 = RandomForestClassifier(n_estimators=1000)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    dtree3 = RandomForestClassifier(n_estimators=1000)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    dtree4 = RandomForestClassifier(n_estimators=1000)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    dtree5 = RandomForestClassifier(n_estimators=1000)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

    dtree6 = RandomForestClassifier(n_estimators=1000)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))
# Out:
# 54
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.4855627705627705
#  beta= 0.5851469363969363
#  alpha= 0.46984418359418356
#  delta= 0.5119642857142856
#  theta= 0.6094587193851897
#  merged= 0.6838317238317237

# %%
# Out:
#            0         1         2
# 0  -0.224080 -0.192274  0.631673
# 1  -0.685330  0.334638 -0.438670
# 2  -1.211833 -1.233961 -0.577462
# 3   4.151589 -0.276034  0.143969
# 4   4.414402 -0.275480  0.039966
# 5   0.937685  1.267433 -0.179960
# 6  -0.215688  1.127051 -0.333240
# 7  -1.029314  0.427895 -0.826977
# 8  -0.083932 -0.593816 -0.279350
# 9  -1.271313 -0.358624  1.191037
# 10 -1.168383  0.540259 -0.134820
# 11 -2.220612 -0.924037  0.105821
# 12  3.901323  0.356273  0.267729
# 13 -0.633763 -0.139617  0.461361
# 14 -2.292720 -0.720024 -0.408130
# 15 -1.818974 -0.220403  0.506276
# 16 -2.673169 -0.355722 -0.120516
# 17  2.228260  0.243478 -0.333195
# 18 -0.410246 -0.231149 -0.870119
# 19 -1.668256  2.570396 -0.126017
# 20  1.234755  1.227285  0.304061
# 21 -1.040998  0.270891  0.099537
# 22 -1.495543  0.141210 -0.682545
# 23 -1.248490 -1.148753  0.016687
# 24 -0.309892  0.265203  0.350966
# 25 -1.013909  1.007844 -0.603030
# 26 -2.446834 -0.126584 -0.096798
# 27 -0.390528  0.270210 -0.022522
# 28  0.177288 -0.428954  0.626844
# 29  2.023852 -2.567141 -0.127110
# 30 -0.894423  0.511125  0.449073
# 31 -1.508535  0.026727  0.204004
# 32 -0.931989  0.933310  0.398840
# 33  2.398073 -2.116865 -1.655226
# 34 -1.929645 -0.976883  0.152168
# 35  4.710262 -0.130611  0.846578
# 36  3.967633  0.521295  0.402244
# 37 -2.187745  1.586146 -1.015072
# 38  4.000899  2.749352  0.228806
# 39 -1.258390 -0.903813  0.444777
# 40 -2.254343 -0.448764  2.001936
# 41  0.498777 -0.579250  1.849247
# 42  1.365436  0.014885 -1.643209
# 43 -0.755955  0.384010 -1.095952
# 44 -2.236216 -0.063316  0.111286
# 45  0.009826  0.563572 -0.412862
# 46 -0.574556 -0.546634  0.439671
# 47 -0.230760 -0.373156  0.460911
# 48 -1.655916  0.538185 -0.303289
# 49 -1.762992 -0.150724 -0.403381
# 50  1.986145 -1.126511 -1.328512
# 51  3.224966  0.240166  0.267877
# 52  2.913201 -1.005102  0.051583
# 53 -0.409098  0.095360  0.963038

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
#     "4thgamma":[],
#     "5thgamma":[],
#     "6thgamma":[],
#     "7thgamma":[],
#     "8thgamma":[],
#     "9thgamma":[],
#     "10thgamma":[],
#     "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]
}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
#     "4thbeta":[],
#     "5thbeta":[],
#     "6thbeta":[],
#     "7thbeta":[],
#     "8thbeta":[],
#     "9thbeta":[],
#     "10thbeta":[],
#     "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]
}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
#     "4thalpha":[],
#     "5thalpha":[],
#     "6thalpha":[],
#     "7thalpha":[],
#     "8thalpha":[],
#     "9thalpha":[],
#     "10thalpha":[],
#     "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]
}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
#     "4ththeta":[],
#     "5ththeta":[],
#     "6ththeta":[],
#     "7ththeta":[],
#     "8ththeta":[],
#     "9ththeta":[],
#     "10ththeta":[],
#     "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]
}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
#     "4thdelta":[],
#     "5thdelta":[],
#     "6thdelta":[],
#     "7thdelta":[],
#     "8thdelta":[],
#     "9thdelta":[],
#     "10thdelta":[],
#     "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]
}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/ziaaad/"+str(i+1)+".txt",header=None,names=["label"])
    if(user_label.values.tolist()[0][0]=="Neutral"):
        continue
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/ziaaad/ziaaad_"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
#         '4th':[],
#         '5th':[],
#         '6th':[],
#         '7th':[],
#         '8th':[],
#         '9th':[],
#         '10th':[],
#         '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
#         user_data['4th'].append(float(ny[3]))
#         user_data['5th'].append(float(ny[4]))
#         user_data['6th'].append(float(ny[5]))
#         user_data['7th'].append(float(ny[6]))
#         user_data['8th'].append(float(ny[7]))
#         user_data['9th'].append(float(ny[8]))
#         user_data['10th'].append(float(ny[9]))
#         user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
#     fourth_electrode = user_data['4th']
#     fifth_electrode = user_data['5th']
#     sixth_electrode = user_data['6th']
#     seventh_electrode = user_data['7th']
#     eighth_electrode = user_data['8th']
#     nineth_electrode = user_data['9th']
#     tenth_electrode = user_data['10th']
#     eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']
    
 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
#     s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
#     s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
#     s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
#     s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
#     s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
#     s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
#     s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
#     s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(gamma_RMS1)
    beta_data1['1stbeta'].append(beta_RMS1)
    alpha_data1['1stalpha'].append(alpha_RMS1)
    theta_data1['1sttheta'].append(theta_RMS1)
    delta_data1['1stdelta'].append(delta_RMS1)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(gamma_RMS2)
    beta_data1['2ndbeta'].append(beta_RMS2)
    alpha_data1['2ndalpha'].append(alpha_RMS2)
    theta_data1['2ndtheta'].append(theta_RMS2)
    delta_data1['2nddelta'].append(delta_RMS2)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(gamma_RMS3)
    beta_data1['3rdbeta'].append(beta_RMS3)
    alpha_data1['3rdalpha'].append(alpha_RMS3)
    theta_data1['3rdtheta'].append(theta_RMS3)
    delta_data1['3rddelta'].append(delta_RMS3)

#     cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
#     cA42, d42 = pywt.dwt(cA4, 'db4')
#     cA43, d43 = pywt.dwt(cA42, 'db4')
#     a44, d44 = pywt.dwt(cA43, 'db4')
#     gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
#     beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
#     alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
#     theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
#     delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
#     gamma_data1['4thgamma'].append(gamma_RMS4)
#     beta_data1['4thbeta'].append(beta_RMS4)
#     alpha_data1['4thalpha'].append(alpha_RMS4)
#     theta_data1['4ththeta'].append(theta_RMS4)
#     delta_data1['4thdelta'].append(delta_RMS4)

#     cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
#     cA52, d52 = pywt.dwt(cA5, 'db4')
#     cA53, d53 = pywt.dwt(cA52, 'db4')
#     a54, d54 = pywt.dwt(cA53, 'db4')
#     gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
#     beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
#     alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
#     theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
#     delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
#     gamma_data1['5thgamma'].append(gamma_RMS5)
#     beta_data1['5thbeta'].append(beta_RMS5)
#     alpha_data1['5thalpha'].append(alpha_RMS5)
#     theta_data1['5ththeta'].append(theta_RMS5)
#     delta_data1['5thdelta'].append(delta_RMS5)

#     cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
#     cA62, d62 = pywt.dwt(cA6, 'db4')
#     cA63, d63 = pywt.dwt(cA62, 'db4')
#     a64, d64 = pywt.dwt(cA63, 'db4')
#     gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
#     beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
#     alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
#     theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
#     delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
#     gamma_data1['6thgamma'].append(gamma_RMS6)
#     beta_data1['6thbeta'].append(beta_RMS6)
#     alpha_data1['6thalpha'].append(alpha_RMS6)
#     theta_data1['6ththeta'].append(theta_RMS6)
#     delta_data1['6thdelta'].append(delta_RMS6)
    

#     cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
#     cA72, d72 = pywt.dwt(cA7, 'db4')
#     cA73, d73 = pywt.dwt(cA72, 'db4')
#     a74, d74 = pywt.dwt(cA73, 'db4')
#     gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
#     beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
#     alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
#     theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
#     delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
#     gamma_data1['7thgamma'].append(gamma_RMS7)
#     beta_data1['7thbeta'].append(beta_RMS7)
#     alpha_data1['7thalpha'].append(alpha_RMS7)
#     theta_data1['7ththeta'].append(theta_RMS7)
#     delta_data1['7thdelta'].append(delta_RMS7)

#     cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
#     cA82, d82 = pywt.dwt(cA8, 'db4')
#     cA83, d83 = pywt.dwt(cA82, 'db4')
#     a84, d84 = pywt.dwt(cA83, 'db4')
#     gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
#     beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
#     alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
#     theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
#     delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
#     gamma_data1['8thgamma'].append(gamma_RMS8)
#     beta_data1['8thbeta'].append(beta_RMS8)
#     alpha_data1['8thalpha'].append(alpha_RMS8)
#     theta_data1['8ththeta'].append(theta_RMS8)
#     delta_data1['8thdelta'].append(delta_RMS8)

#     cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
#     cA92, d92 = pywt.dwt(cA9, 'db4')
#     cA93, d93 = pywt.dwt(cA92, 'db4')
#     a94, d94 = pywt.dwt(cA93, 'db4')
#     gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
#     beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
#     alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
#     theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
#     delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
#     gamma_data1['9thgamma'].append(gamma_RMS9)
#     beta_data1['9thbeta'].append(beta_RMS9)
#     alpha_data1['9thalpha'].append(alpha_RMS9)
#     theta_data1['9ththeta'].append(theta_RMS9)
#     delta_data1['9thdelta'].append(delta_RMS9)

#     cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
#     cA102, d102 = pywt.dwt(cA10, 'db4')
#     cA103, d103 = pywt.dwt(cA102, 'db4')
#     a104, d104 = pywt.dwt(cA103, 'db4')
#     gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
#     beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
#     alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
#     theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
#     delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
#     gamma_data1['10thgamma'].append(gamma_RMS10)
#     beta_data1['10thbeta'].append(beta_RMS10)
#     alpha_data1['10thalpha'].append(alpha_RMS10)
#     theta_data1['10ththeta'].append(theta_RMS10)
#     delta_data1['10thdelta'].append(delta_RMS10)

#     cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
#     cA112, d112 = pywt.dwt(cA11, 'db4')
#     cA113, d113 = pywt.dwt(cA112, 'db4')
#     a114, d114 = pywt.dwt(cA113, 'db4')
#     gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
#     beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
#     alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
#     theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
#     delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
#     gamma_data1['11thgamma'].append(gamma_RMS11)
#     beta_data1['11thbeta'].append(beta_RMS11)
#     alpha_data1['11thalpha'].append(alpha_RMS11)
#     theta_data1['11ththeta'].append(theta_RMS11)
#     delta_data1['11thdelta'].append(delta_RMS11)

    cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
    cA122, d122 = pywt.dwt(cA12, 'db4')
    cA123, d123 = pywt.dwt(cA122, 'db4')
    a124, d124 = pywt.dwt(cA123, 'db4')
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
    gamma_data1['12thgamma'].append(gamma_RMS12)
    beta_data1['12thbeta'].append(beta_RMS12)
    alpha_data1['12thalpha'].append(alpha_RMS12)
    theta_data1['12ththeta'].append(theta_RMS12)
    delta_data1['12thdelta'].append(delta_RMS12)

    cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
    cA132, d132 = pywt.dwt(cA13, 'db4')
    cA133, d133 = pywt.dwt(cA132, 'db4')
    a134, d134 = pywt.dwt(cA133, 'db4')
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
    gamma_data1['13thgamma'].append(gamma_RMS13)
    beta_data1['13thbeta'].append(beta_RMS13)
    alpha_data1['13thalpha'].append(alpha_RMS13)
    theta_data1['13ththeta'].append(theta_RMS13)
    delta_data1['13thdelta'].append(delta_RMS13)

    cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
    cA142, d142 = pywt.dwt(cA14, 'db4')
    cA143, d143 = pywt.dwt(cA142, 'db4')
    a144, d144 = pywt.dwt(cA143, 'db4')
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
    gamma_data1['14thgamma'].append(gamma_RMS14)
    beta_data1['14thbeta'].append(beta_RMS14)
    alpha_data1['14thalpha'].append(alpha_RMS14)
    theta_data1['14ththeta'].append(theta_RMS14)
    delta_data1['14thdelta'].append(delta_RMS14)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}

standard_gamma = StandardScaler().fit_transform(gamma_data1) 
normalised_gamma = pd.DataFrame(standard_gamma)
pca_gamma = PCA(n_components=0.7)
principalComponents_gamma = pca_gamma.fit_transform(standard_gamma)
gamma_data1 = pd.DataFrame(data = principalComponents_gamma)


standard_beta = StandardScaler().fit_transform(beta_data1) 
normalised_beta = pd.DataFrame(standard_beta)
pca_beta = PCA(n_components=0.7)
principalComponents_beta = pca_beta.fit_transform(standard_beta)
beta_data1 = pd.DataFrame(data = principalComponents_beta)

standard_alpha = StandardScaler().fit_transform(alpha_data1) 
normalised_alpha = pd.DataFrame(standard_alpha)
pca_alpha = PCA(n_components=0.7)
principalComponents_alpha = pca_alpha.fit_transform(standard_alpha)
alpha_data1 = pd.DataFrame(data = principalComponents_alpha)

standard_theta = StandardScaler().fit_transform(theta_data1) 
normalised_theta = pd.DataFrame(standard_theta)
pca_theta = PCA(n_components=0.7)
principalComponents_theta = pca_theta.fit_transform(standard_theta)
theta_data1 = pd.DataFrame(data = principalComponents_theta)

standard_delta = StandardScaler().fit_transform(delta_data1) 
normalised_delta = pd.DataFrame(standard_delta)
pca_delta = PCA(n_components=0.7)
principalComponents_delta = pca_delta.fit_transform(standard_delta)
delta_data1 = pd.DataFrame(data = principalComponents_delta)

standard_merged = StandardScaler().fit_transform(merged) 
normalised_merged = pd.DataFrame(standard_merged)
pca_merged = PCA(n_components=0.7)
principalComponents_merged = pca_merged.fit_transform(standard_merged)
merged = pd.DataFrame(data = principalComponents_merged)
for i in range(20):
    
   
    labels_gamma=labels
    labels_beta=labels
    labels_alpha=labels
    labels_theta=labels
    labels_delta=labels
    labels_merged=labels
    gamma_data2 = gamma_data1
    beta_data2 = beta_data1
    alpha_data2 = alpha_data1
    theta_data2 = theta_data1
    delta_data2 = delta_data1
    merged2 = merged
    
    sm = SMOTE()
    gamma_data2, labels_gamma = sm.fit_resample(gamma_data2, labels)
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data2, labels_gamma, test_size=0.2,stratify=labels_gamma)
    
    sm = SMOTE()
    beta_data2, labels_beta = sm.fit_resample(beta_data2, labels)
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data2, labels_beta, test_size=0.2,stratify=labels_beta)
    
    sm = SMOTE()
    alpha_data2, labels_alpha = sm.fit_resample(alpha_data2, labels)
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data2, labels_alpha, test_size=0.2,stratify=labels_alpha)
    
    sm = SMOTE()
    theta_data2, labels_theta = sm.fit_resample(theta_data2, labels)
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data2, labels_theta, test_size=0.2,stratify=labels_theta)
    
    sm = SMOTE()
    delta_data2, labels_delta = sm.fit_resample(delta_data2, labels)
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data2, labels_delta, test_size=0.2,stratify=labels_delta)
    
    sm = SMOTE()
    merged2, labels_merged = sm.fit_resample(merged2, labels)
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged2, labels_merged, test_size=0.2,stratify=labels_merged)

    dtree1 = RandomForestClassifier(n_estimators=1000)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    dtree2 = RandomForestClassifier(n_estimators=1000)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    dtree3 = RandomForestClassifier(n_estimators=1000)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    dtree4 = RandomForestClassifier(n_estimators=1000)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    dtree5 = RandomForestClassifier(n_estimators=1000)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

    dtree6 = RandomForestClassifier(n_estimators=1000)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')
# Out:
# gamma= 0.4378202473761264
#  beta= 0.4934648508526219
#  alpha= 0.6266160694740417
#  delta= 0.6461767771029615
#  theta= 0.5002372011410914
#  merged= 0.5907448266387895

# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
#     "4thgamma":[],
#     "5thgamma":[],
#     "6thgamma":[],
#     "7thgamma":[],
#     "8thgamma":[],
#     "9thgamma":[],
#     "10thgamma":[],
#     "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]
}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
#     "4thbeta":[],
#     "5thbeta":[],
#     "6thbeta":[],
#     "7thbeta":[],
#     "8thbeta":[],
#     "9thbeta":[],
#     "10thbeta":[],
#     "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]
}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
#     "4thalpha":[],
#     "5thalpha":[],
#     "6thalpha":[],
#     "7thalpha":[],
#     "8thalpha":[],
#     "9thalpha":[],
#     "10thalpha":[],
#     "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]
}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
#     "4ththeta":[],
#     "5ththeta":[],
#     "6ththeta":[],
#     "7ththeta":[],
#     "8ththeta":[],
#     "9ththeta":[],
#     "10ththeta":[],
#     "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]
}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
#     "4thdelta":[],
#     "5thdelta":[],
#     "6thdelta":[],
#     "7thdelta":[],
#     "8thdelta":[],
#     "9thdelta":[],
#     "10thdelta":[],
#     "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]
}


for i in range(80):
    
#     user_data = pd.read_csv("GUI/data/noursecond_"+str(i+1)+".txt", sep="\t",lineterminator='\r', header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
    user_label = pd.read_csv("labels/mostafa/"+str(i+1)+".txt",header=None,names=["label"])
    if(user_label.values.tolist()[0][0]=="Neutral"):
        continue
    labels.append(user_label.values.tolist()[0][0])
    f = open("data/mostafa/mostafa_"+str(i+1)+".txt", "r")
    string =f.read()
    user_data ={
        '1st':[],
        '2nd':[],
        '3rd':[],
#         '4th':[],
#         '5th':[],
#         '6th':[],
#         '7th':[],
#         '8th':[],
#         '9th':[],
#         '10th':[],
#         '11th':[],
        '12th':[],
        '13th':[],
        '14th':[]
    }
    my = string.split('\n')
    ny=[]
    for electrode in my :
        ny = electrode.split('\t')
        if(ny[0]==''):
            break
        user_data['1st'].append(float(ny[0]))
        user_data['2nd'].append(float(ny[1]))
        user_data['3rd'].append(float(ny[2]))
#         user_data['4th'].append(float(ny[3]))
#         user_data['5th'].append(float(ny[4]))
#         user_data['6th'].append(float(ny[5]))
#         user_data['7th'].append(float(ny[6]))
#         user_data['8th'].append(float(ny[7]))
#         user_data['9th'].append(float(ny[8]))
#         user_data['10th'].append(float(ny[9]))
#         user_data['11th'].append(float(ny[10]))
        user_data['12th'].append(float(ny[11]))
        user_data['13th'].append(float(ny[12]))
        user_data['14th'].append(float(ny[13]))
#     print(user_data)
    user_data= pd.DataFrame.from_dict(user_data)
    first_electrode = user_data['1st']
    second_electrode = user_data['2nd']
    third_electrode = user_data['3rd']
#     fourth_electrode = user_data['4th']
#     fifth_electrode = user_data['5th']
#     sixth_electrode = user_data['6th']
#     seventh_electrode = user_data['7th']
#     eighth_electrode = user_data['8th']
#     nineth_electrode = user_data['9th']
#     tenth_electrode = user_data['10th']
#     eleventh_electrode = user_data['11th']
    twelveth_electrode = user_data['12th']
    thirteenth_electrode = user_data['13th']
    fouteenth_electrode = user_data['14th']

 
    user_data.apply(lambda row : carf(row), axis = 1)
   
    s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
    s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
    s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
#     s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
#     s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
#     s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
#     s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
#     s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
#     s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
#     s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
#     s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
    s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
    s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
    s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


    cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
    cA12, d12 = pywt.dwt(cA1, 'db4')
    cA13, d13 = pywt.dwt(cA12, 'db4')
    a14, d14 = pywt.dwt(cA13, 'db4')
    gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
    beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
    alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
    theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
    delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
    gamma_data1['1stgamma'].append(d11)
    beta_data1['1stbeta'].append(d12)
    alpha_data1['1stalpha'].append(d13)
    theta_data1['1sttheta'].append(d14)
    delta_data1['1stdelta'].append(a14)
    
    cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
    cA22, d22 = pywt.dwt(cA2, 'db4')
    cA23, d23 = pywt.dwt(cA22, 'db4')
    a24, d24 = pywt.dwt(cA23, 'db4')
    gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
    beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
    alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
    theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
    delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
    gamma_data1['2ndgamma'].append(d21)
    beta_data1['2ndbeta'].append(d22)
    alpha_data1['2ndalpha'].append(d23)
    theta_data1['2ndtheta'].append(d24)
    delta_data1['2nddelta'].append(a24)
    
    cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
    cA32, d32 = pywt.dwt(cA3, 'db4')
    cA33, d33 = pywt.dwt(cA32, 'db4')
    a34, d34 = pywt.dwt(cA33, 'db4')
    gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
    beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
    alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
    theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
    delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
    gamma_data1['3rdgamma'].append(d31)
    beta_data1['3rdbeta'].append(d32)
    alpha_data1['3rdalpha'].append(d33)
    theta_data1['3rdtheta'].append(d34)
    delta_data1['3rddelta'].append(a34)

#     cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
#     cA42, d42 = pywt.dwt(cA4, 'db4')
#     cA43, d43 = pywt.dwt(cA42, 'db4')
#     a44, d44 = pywt.dwt(cA43, 'db4')
#     gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
#     beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
#     alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
#     theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
#     delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
#     gamma_data1['4thgamma'].append(gamma_RMS4)
#     beta_data1['4thbeta'].append(beta_RMS4)
#     alpha_data1['4thalpha'].append(alpha_RMS4)
#     theta_data1['4ththeta'].append(theta_RMS4)
#     delta_data1['4thdelta'].append(delta_RMS4)

#     cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
#     cA52, d52 = pywt.dwt(cA5, 'db4')
#     cA53, d53 = pywt.dwt(cA52, 'db4')
#     a54, d54 = pywt.dwt(cA53, 'db4')
#     gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
#     beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
#     alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
#     theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
#     delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
#     gamma_data1['5thgamma'].append(gamma_RMS5)
#     beta_data1['5thbeta'].append(beta_RMS5)
#     alpha_data1['5thalpha'].append(alpha_RMS5)
#     theta_data1['5ththeta'].append(theta_RMS5)
#     delta_data1['5thdelta'].append(delta_RMS5)

#     cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
#     cA62, d62 = pywt.dwt(cA6, 'db4')
#     cA63, d63 = pywt.dwt(cA62, 'db4')
#     a64, d64 = pywt.dwt(cA63, 'db4')
#     gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
#     beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
#     alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
#     theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
#     delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
#     gamma_data1['6thgamma'].append(gamma_RMS6)
#     beta_data1['6thbeta'].append(beta_RMS6)
#     alpha_data1['6thalpha'].append(alpha_RMS6)
#     theta_data1['6ththeta'].append(theta_RMS6)
#     delta_data1['6thdelta'].append(delta_RMS6)
    

#     cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
#     cA72, d72 = pywt.dwt(cA7, 'db4')
#     cA73, d73 = pywt.dwt(cA72, 'db4')
#     a74, d74 = pywt.dwt(cA73, 'db4')
#     gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
#     beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
#     alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
#     theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
#     delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
#     gamma_data1['7thgamma'].append(gamma_RMS7)
#     beta_data1['7thbeta'].append(beta_RMS7)
#     alpha_data1['7thalpha'].append(alpha_RMS7)
#     theta_data1['7ththeta'].append(theta_RMS7)
#     delta_data1['7thdelta'].append(delta_RMS7)

#     cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
#     cA82, d82 = pywt.dwt(cA8, 'db4')
#     cA83, d83 = pywt.dwt(cA82, 'db4')
#     a84, d84 = pywt.dwt(cA83, 'db4')
#     gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
#     beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
#     alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
#     theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
#     delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
#     gamma_data1['8thgamma'].append(gamma_RMS8)
#     beta_data1['8thbeta'].append(beta_RMS8)
#     alpha_data1['8thalpha'].append(alpha_RMS8)
#     theta_data1['8ththeta'].append(theta_RMS8)
#     delta_data1['8thdelta'].append(delta_RMS8)

#     cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
#     cA92, d92 = pywt.dwt(cA9, 'db4')
#     cA93, d93 = pywt.dwt(cA92, 'db4')
#     a94, d94 = pywt.dwt(cA93, 'db4')
#     gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
#     beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
#     alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
#     theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
#     delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
#     gamma_data1['9thgamma'].append(gamma_RMS9)
#     beta_data1['9thbeta'].append(beta_RMS9)
#     alpha_data1['9thalpha'].append(alpha_RMS9)
#     theta_data1['9ththeta'].append(theta_RMS9)
#     delta_data1['9thdelta'].append(delta_RMS9)

#     cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
#     cA102, d102 = pywt.dwt(cA10, 'db4')
#     cA103, d103 = pywt.dwt(cA102, 'db4')
#     a104, d104 = pywt.dwt(cA103, 'db4')
#     gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
#     beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
#     alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
#     theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
#     delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
#     gamma_data1['10thgamma'].append(gamma_RMS10)
#     beta_data1['10thbeta'].append(beta_RMS10)
#     alpha_data1['10thalpha'].append(alpha_RMS10)
#     theta_data1['10ththeta'].append(theta_RMS10)
#     delta_data1['10thdelta'].append(delta_RMS10)

#     cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
#     cA112, d112 = pywt.dwt(cA11, 'db4')
#     cA113, d113 = pywt.dwt(cA112, 'db4')
#     a114, d114 = pywt.dwt(cA113, 'db4')
#     gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
#     beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
#     alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
#     theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
#     delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
#     gamma_data1['11thgamma'].append(gamma_RMS11)
#     beta_data1['11thbeta'].append(beta_RMS11)
#     alpha_data1['11thalpha'].append(alpha_RMS11)
#     theta_data1['11ththeta'].append(theta_RMS11)
#     delta_data1['11thdelta'].append(delta_RMS11)

    cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
    cA122, d122 = pywt.dwt(cA12, 'db4')
    cA123, d123 = pywt.dwt(cA122, 'db4')
    a124, d124 = pywt.dwt(cA123, 'db4')
    gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
    beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
    alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
    theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
    delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
    gamma_data1['12thgamma'].append(d121)
    beta_data1['12thbeta'].append(d122)
    alpha_data1['12thalpha'].append(d123)
    theta_data1['12ththeta'].append(d124)
    delta_data1['12thdelta'].append(a124)

    cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
    cA132, d132 = pywt.dwt(cA13, 'db4')
    cA133, d133 = pywt.dwt(cA132, 'db4')
    a134, d134 = pywt.dwt(cA133, 'db4')
    gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
    beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
    alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
    theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
    delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
    gamma_data1['13thgamma'].append(d131)
    beta_data1['13thbeta'].append(d132)
    alpha_data1['13thalpha'].append(d133)
    theta_data1['13ththeta'].append(d134)
    delta_data1['13thdelta'].append(a134)

    cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
    cA142, d142 = pywt.dwt(cA14, 'db4')
    cA143, d143 = pywt.dwt(cA142, 'db4')
    a144, d144 = pywt.dwt(cA143, 'db4')
    gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
    beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
    alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
    theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
    delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
    gamma_data1['14thgamma'].append(d141)
    beta_data1['14thbeta'].append(d142)
    alpha_data1['14thalpha'].append(d143)
    theta_data1['14ththeta'].append(d144)
    delta_data1['14thdelta'].append(a144)

# %%
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
# standard_gamma = StandardScaler().fit_transform(gamma_data1) 
# normalised_gamma = pd.DataFrame(standard_gamma)
# pca_gamma = PCA(n_components=0.9)
# principalComponents_gamma = pca_gamma.fit_transform(standard_gamma)
# gamma_data1 = pd.DataFrame(data = principalComponents_gamma)


# standard_beta = StandardScaler().fit_transform(beta_data1) 
# normalised_beta = pd.DataFrame(standard_beta)
# pca_beta = PCA(n_components=0.9)
# principalComponents_beta = pca_beta.fit_transform(standard_beta)
# beta_data1 = pd.DataFrame(data = principalComponents_beta)

# standard_alpha = StandardScaler().fit_transform(alpha_data1) 
# normalised_alpha = pd.DataFrame(standard_alpha)
# pca_alpha = PCA(n_components=0.9)
# principalComponents_alpha = pca_alpha.fit_transform(standard_alpha)
# alpha_data1 = pd.DataFrame(data = principalComponents_alpha)

# standard_theta = StandardScaler().fit_transform(theta_data1) 
# normalised_theta = pd.DataFrame(standard_theta)
# pca_theta = PCA(n_components=0.9)
# principalComponents_theta = pca_theta.fit_transform(standard_theta)
# theta_data1 = pd.DataFrame(data = principalComponents_theta)

# standard_delta = StandardScaler().fit_transform(delta_data1) 
# normalised_delta = pd.DataFrame(standard_delta)
# pca_delta = PCA(n_components=0.9)
# principalComponents_delta = pca_delta.fit_transform(standard_delta)
# delta_data1 = pd.DataFrame(data = principalComponents_delta)

# standard_merged = StandardScaler().fit_transform(merged) 
# normalised_merged = pd.DataFrame(standard_merged)
# pca_merged = PCA(n_components=0.9)
# principalComponents_merged = pca_merged.fit_transform(standard_merged)
# merged = pd.DataFrame(data = principalComponents_merged)

for i in range(20):  
   
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.2,stratify=labels)
    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.2,stratify=labels)
    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.2,stratify=labels)
    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.2,stratify=labels)
    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.2,stratify=labels)
    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.2,stratify=labels)
        
    dtree1 = RandomForestClassifier(n_estimators=1000)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

    dtree2 = RandomForestClassifier(n_estimators=1000)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

    dtree3 = RandomForestClassifier(n_estimators=1000)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

    dtree4 = RandomForestClassifier(n_estimators=1000)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

    dtree5 = RandomForestClassifier(n_estimators=1000)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

    dtree6 = RandomForestClassifier(n_estimators=1000)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-d4c6f141c071> in <module>
#      61
#      62     dtree1 = RandomForestClassifier(n_estimators=1000)
# ---> 63     dtree1.fit(data_train_gamma,label_train_gamma)
#      64     predictions_gamma = dtree1.predict(data_test_gamma)
#      65     results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))
#
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     302                 "sparse multilabel-indicator for y is not supported."
#     303             )
# --> 304         X, y = self._validate_data(X, y, multi_output=True,
#     305                                    accept_sparse="csc", dtype=DTYPE)
#     306         if sample_weight is not None:
#
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     812         raise ValueError("y cannot be None")
#     813
# --> 814     X = check_array(X, accept_sparse=accept_sparse,
#     815                     accept_large_sparse=accept_large_sparse,
#     816                     dtype=dtype, order=order, copy=copy,
#
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1897
#    1898     def __array__(self, dtype=None) -> np.ndarray:
# -> 1899         return np.asarray(self._values, dtype=dtype)
#    1900
#    1901     def __array_wrap__(
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: setting an array element with a sequence.

# %%
mean1 =0
mean2 =0
mean3 =0
mean4 =0
mean5 =0
mean6 =0
for i in results['result_gamma'] :
    mean1+=(i['macro avg']['f1-score'])
for i in results['result_beta'] :
    mean2+=(i['macro avg']['f1-score'])
for i in results['result_alpha'] :
    mean3+=(i['macro avg']['f1-score'])
for i in results['result_theta'] :
    mean4+=(i['macro avg']['f1-score'])
for i in results['result_delta'] :
    mean5+=(i['macro avg']['f1-score'])
for i in results['result_merged'] :
    mean6+=(i['macro avg']['f1-score'])
print('gamma=',mean1/20,'\n','beta=',mean2/20,'\n','alpha=',mean3/20,'\n','delta=',mean5/20,'\n','theta=',mean4/20,'\n','merged=',mean6/20,'\n','')

# %%
# Out:
# 4

# %%
# Out:
# 3

# %%
# Out:
#      1stbeta   2ndbeta   3rdbeta  12thbeta  13thbeta  14thbeta
# 0   2.343553  2.909542  3.693737  4.019623  2.635576  5.397503
# 1   2.239471  2.715237  3.359831  3.965710  2.878850  4.512900
# 2   2.468659  2.803249  2.960430  3.485519  2.690749  4.193252
# 3   2.316832  3.363464  3.943405  4.917138  3.548371  6.039236
# 4   2.578626  4.118792  4.378443  4.754445  2.398060  5.615130
# 5   2.485928  3.784331  4.110495  5.138254  2.786977  6.225496
# 6   2.446592  3.028889  3.843760  4.490692  2.342402  5.193441
# 7   1.951267  3.149522  3.395958  4.102678  2.496784  4.955477
# 8   2.447097  2.902203  3.272957  3.908966  2.523312  4.535024
# 9   2.138461  2.770756  3.081124  3.416171  2.402779  4.688061
# 10  2.270352  2.581432  2.829930  3.393719  2.662954  4.112808
# 11  2.422734  2.583569  3.043296  4.033570  2.383233  4.524525
# 12  2.411248  3.400867  4.480465  5.333939  3.533234  6.289555
# 13  2.253049  2.581393  3.575674  3.971595  2.198960  5.207397
# 14  2.277821  2.781034  3.055101  3.307173  2.910706  4.027131
# 15  2.643957  3.414005  3.343865  3.743015  2.654268  4.769374
# 16  2.205153  2.310161  2.725385  3.162451  2.447916  4.292030
# 17  2.389561  3.482744  4.197556  4.983835  2.878211  5.773110
# 18  2.291422  3.510157  4.304305  5.030657  2.952183  5.885224
# 19  2.484274  2.900921  3.300946  3.402276  2.326912  4.205760
# 20  2.532381  2.831799  3.636921  4.245681  2.486843  4.993931
# 21  2.179398  2.848117  3.622731  3.917345  2.691207  5.071802
# 22  2.750973  2.971905  3.807638  3.977937  2.442933  5.271098
# 23  2.262146  3.400067  3.243886  3.763396  2.466375  5.054664
# 24  2.386926  2.964816  3.634413  4.366398  2.457766  4.952914
# 25  2.396298  2.686299  3.451252  3.982014  2.432194  4.513977
# 26  2.161237  2.409195  3.176060  3.471141  2.290880  4.857361
# 27  2.192322  2.845177  3.160955  3.750185  2.432725  4.481625
# 28  2.225668  3.620293  4.126952  4.503012  3.551917  5.885377
# 29  2.335335  3.018488  4.052547  4.014440  3.031983  5.667059
# 30  2.102263  2.735815  3.073994  3.650742  2.767387  4.741588
# 31  2.191825  2.801561  3.253488  3.919643  2.592259  4.086435
# 32  2.115212  2.880144  3.202696  3.786215  2.291145  4.437028
# 33  2.409339  4.080928  3.794767  4.326457  5.300411  5.438013
# 34  2.426881  2.731069  3.388901  3.270466  2.303645  4.441374
# 35  2.592018  3.725853  4.267327  5.125136  3.246548  6.332998
# 36  2.521691  3.411119  4.335579  4.976288  3.203776  6.274354
# 37  2.266018  2.512704  3.396445  3.599890  2.643338  4.367703
# 38  4.531769  3.497758  5.402270  4.689088  2.921555  5.104741
# 39  2.513264  2.590041  3.450325  4.149764  2.245054  4.986121
# 40  2.396894  2.500773  2.798191  3.616308  2.222130  4.011868
# 41  2.471683  3.897892  4.205621  4.717800  2.586046  6.025452
# 42  2.492191  3.027316  3.496031  4.299821  2.736697  5.349846
# 43  2.372046  3.496466  3.320689  3.930933  2.644356  4.855394
# 44  2.041619  2.470655  2.952421  3.292130  2.374055  4.255326
# 45  2.137082  2.963496  3.445401  3.798818  2.729427  4.919453
# 46  2.248888  3.597163  4.567712  5.258696  2.299095  6.422719
# 47  2.315308  4.421347  3.431919  3.989535  2.658177  4.563997
# 48  2.223523  2.782412  2.827129  3.190871  2.298653  4.498611
# 49  2.273119  2.626147  3.044794  3.702380  2.516783  4.295417
# 50  2.592136  6.607710  3.398470  3.694243  5.776798  5.266530
# 51  2.292159  3.184715  3.582221  4.195853  3.210316  5.531561
# 52  2.455450  3.351378  3.950808  4.628822  2.647290  5.864727
# 53  2.243078  2.693672  3.220393  3.719501  2.651653  4.637023
