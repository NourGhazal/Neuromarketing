# %%
labels=[]
gamma_data1={
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
    "4thgamma":[],
    "5thgamma":[],
    "6thgamma":[],
    "7thgamma":[],
    "8thgamma":[],
    "9thgamma":[],
    "10thgamma":[],
    "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]}
beta_data1={
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
    "4thbeta":[],
    "5thbeta":[],
    "6thbeta":[],
    "7thbeta":[],
    "8thbeta":[],
    "9thbeta":[],
    "10thbeta":[],
    "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]}
alpha_data1={
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
    "4thalpha":[],
    "5thalpha":[],
    "6thalpha":[],
    "7thalpha":[],
    "8thalpha":[],
    "9thalpha":[],
    "10thalpha":[],
    "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]}
theta_data1={
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
    "4ththeta":[],
    "5ththeta":[],
    "6ththeta":[],
    "7ththeta":[],
    "8ththeta":[],
    "9ththeta":[],
    "10ththeta":[],
    "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]}
delta_data1={
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
    "4thdelta":[],
    "5thdelta":[],
    "6thdelta":[],
    "7thdelta":[],
    "8thdelta":[],
    "9thdelta":[],
    "10thdelta":[],
    "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]}


for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    
    for i in range(42):
        try:
            user_data = pd.read_csv("25-users/"+name+str(i+1)+".txt", sep=" ", header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
            user_label = pd.read_csv("labels/"+name+str(i+1)+".lab",header=None,names=["label"])
        except:
            continue
        labels.append(user_label.values.tolist()[0][0])
        
        user_data.apply(lambda row : carf(row), axis = 1)
        
        first_electrode = user_data['1st']
        second_electrode = user_data['2nd']
        third_electrode = user_data['3rd']
        fourth_electrode = user_data['4th']
        fifth_electrode = user_data['5th']
        sixth_electrode = user_data['6th']
        seventh_electrode = user_data['7th']
        eighth_electrode = user_data['8th']
        nineth_electrode = user_data['9th']
        tenth_electrode = user_data['10th']
        eleventh_electrode = user_data['11th']
        twelveth_electrode = user_data['12th']
        thirteenth_electrode = user_data['13th']
        fouteenth_electrode = user_data['14th']
        
        s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
        s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
        s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
        s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
        s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
        s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
        s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
        s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
        s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
        s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
        s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
        s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
        s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
        s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


        cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
        cA12, d12 = pywt.dwt(cA1, 'db4')
        cA13, d13 = pywt.dwt(cA12, 'db4')
        a14, d14 = pywt.dwt(cA13, 'db4')
        gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
        beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
        alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
        theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
        delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
        gamma_data1['1stgamma'].append(gamma_RMS1)
        beta_data1['1stbeta'].append(beta_RMS1)
        alpha_data1['1stalpha'].append(alpha_RMS1)
        theta_data1['1sttheta'].append(theta_RMS1)
        delta_data1['1stdelta'].append(delta_RMS1)

        cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
        cA22, d22 = pywt.dwt(cA2, 'db4')
        cA23, d23 = pywt.dwt(cA22, 'db4')
        a24, d24 = pywt.dwt(cA23, 'db4')
        gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
        beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
        alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
        theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
        delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
        gamma_data1['2ndgamma'].append(gamma_RMS2)
        beta_data1['2ndbeta'].append(beta_RMS2)
        alpha_data1['2ndalpha'].append(alpha_RMS2)
        theta_data1['2ndtheta'].append(theta_RMS2)
        delta_data1['2nddelta'].append(delta_RMS2)

        cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
        cA32, d32 = pywt.dwt(cA3, 'db4')
        cA33, d33 = pywt.dwt(cA32, 'db4')
        a34, d34 = pywt.dwt(cA33, 'db4')
        gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
        beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
        alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
        theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
        delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
        gamma_data1['3rdgamma'].append(gamma_RMS3)
        beta_data1['3rdbeta'].append(beta_RMS3)
        alpha_data1['3rdalpha'].append(alpha_RMS3)
        theta_data1['3rdtheta'].append(theta_RMS3)
        delta_data1['3rddelta'].append(delta_RMS3)

        cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
        cA42, d42 = pywt.dwt(cA4, 'db4')
        cA43, d43 = pywt.dwt(cA42, 'db4')
        a44, d44 = pywt.dwt(cA43, 'db4')
        gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
        beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
        alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
        theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
        delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
        gamma_data1['4thgamma'].append(gamma_RMS4)
        beta_data1['4thbeta'].append(beta_RMS4)
        alpha_data1['4thalpha'].append(alpha_RMS4)
        theta_data1['4ththeta'].append(theta_RMS4)
        delta_data1['4thdelta'].append(delta_RMS4)

        cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
        cA52, d52 = pywt.dwt(cA5, 'db4')
        cA53, d53 = pywt.dwt(cA52, 'db4')
        a54, d54 = pywt.dwt(cA53, 'db4')
        gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
        beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
        alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
        theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
        delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
        gamma_data1['5thgamma'].append(gamma_RMS5)
        beta_data1['5thbeta'].append(beta_RMS5)
        alpha_data1['5thalpha'].append(alpha_RMS5)
        theta_data1['5ththeta'].append(theta_RMS5)
        delta_data1['5thdelta'].append(delta_RMS5)

        cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
        cA62, d62 = pywt.dwt(cA6, 'db4')
        cA63, d63 = pywt.dwt(cA62, 'db4')
        a64, d64 = pywt.dwt(cA63, 'db4')
        gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
        beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
        alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
        theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
        delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
        gamma_data1['6thgamma'].append(gamma_RMS6)
        beta_data1['6thbeta'].append(beta_RMS6)
        alpha_data1['6thalpha'].append(alpha_RMS6)
        theta_data1['6ththeta'].append(theta_RMS6)
        delta_data1['6thdelta'].append(delta_RMS6)


        cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
        cA72, d72 = pywt.dwt(cA7, 'db4')
        cA73, d73 = pywt.dwt(cA72, 'db4')
        a74, d74 = pywt.dwt(cA73, 'db4')
        gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
        beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
        alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
        theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
        delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
        gamma_data1['7thgamma'].append(gamma_RMS7)
        beta_data1['7thbeta'].append(beta_RMS7)
        alpha_data1['7thalpha'].append(alpha_RMS7)
        theta_data1['7ththeta'].append(theta_RMS7)
        delta_data1['7thdelta'].append(delta_RMS7)

        cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
        cA82, d82 = pywt.dwt(cA8, 'db4')
        cA83, d83 = pywt.dwt(cA82, 'db4')
        a84, d84 = pywt.dwt(cA83, 'db4')
        gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
        beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
        alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
        theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
        delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
        gamma_data1['8thgamma'].append(gamma_RMS8)
        beta_data1['8thbeta'].append(beta_RMS8)
        alpha_data1['8thalpha'].append(alpha_RMS8)
        theta_data1['8ththeta'].append(theta_RMS8)
        delta_data1['8thdelta'].append(delta_RMS8)

        cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
        cA92, d92 = pywt.dwt(cA9, 'db4')
        cA93, d93 = pywt.dwt(cA92, 'db4')
        a94, d94 = pywt.dwt(cA93, 'db4')
        gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
        beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
        alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
        theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
        delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
        gamma_data1['9thgamma'].append(gamma_RMS9)
        beta_data1['9thbeta'].append(beta_RMS9)
        alpha_data1['9thalpha'].append(alpha_RMS9)
        theta_data1['9ththeta'].append(theta_RMS9)
        delta_data1['9thdelta'].append(delta_RMS9)

        cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
        cA102, d102 = pywt.dwt(cA10, 'db4')
        cA103, d103 = pywt.dwt(cA102, 'db4')
        a104, d104 = pywt.dwt(cA103, 'db4')
        gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
        beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
        alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
        theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
        delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
        gamma_data1['10thgamma'].append(gamma_RMS10)
        beta_data1['10thbeta'].append(beta_RMS10)
        alpha_data1['10thalpha'].append(alpha_RMS10)
        theta_data1['10ththeta'].append(theta_RMS10)
        delta_data1['10thdelta'].append(delta_RMS10)

        cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
        cA112, d112 = pywt.dwt(cA11, 'db4')
        cA113, d113 = pywt.dwt(cA112, 'db4')
        a114, d114 = pywt.dwt(cA113, 'db4')
        gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
        beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
        alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
        theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
        delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
        gamma_data1['11thgamma'].append(gamma_RMS11)
        beta_data1['11thbeta'].append(beta_RMS11)
        alpha_data1['11thalpha'].append(alpha_RMS11)
        theta_data1['11ththeta'].append(theta_RMS11)
        delta_data1['11thdelta'].append(delta_RMS11)

        cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
        cA122, d122 = pywt.dwt(cA12, 'db4')
        cA123, d123 = pywt.dwt(cA122, 'db4')
        a124, d124 = pywt.dwt(cA123, 'db4')
        gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
        beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
        alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
        theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
        delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
        gamma_data1['12thgamma'].append(gamma_RMS12)
        beta_data1['12thbeta'].append(beta_RMS12)
        alpha_data1['12thalpha'].append(alpha_RMS12)
        theta_data1['12ththeta'].append(theta_RMS12)
        delta_data1['12thdelta'].append(delta_RMS12)

        cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
        cA132, d132 = pywt.dwt(cA13, 'db4')
        cA133, d133 = pywt.dwt(cA132, 'db4')
        a134, d134 = pywt.dwt(cA133, 'db4')
        gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
        beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
        alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
        theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
        delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
        gamma_data1['13thgamma'].append(gamma_RMS13)
        beta_data1['13thbeta'].append(beta_RMS13)
        alpha_data1['13thalpha'].append(alpha_RMS13)
        theta_data1['13ththeta'].append(theta_RMS13)
        delta_data1['13thdelta'].append(delta_RMS13)

        cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
        cA142, d142 = pywt.dwt(cA14, 'db4')
        cA143, d143 = pywt.dwt(cA142, 'db4')
        a144, d144 = pywt.dwt(cA143, 'db4')
        gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
        beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
        alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
        theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
        delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
        gamma_data1['14thgamma'].append(gamma_RMS14)
        beta_data1['14thbeta'].append(beta_RMS14)
        alpha_data1['14thalpha'].append(alpha_RMS14)
        theta_data1['14ththeta'].append(theta_RMS14)
        delta_data1['14thdelta'].append(delta_RMS14)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.signal 
import pywt
from sklearn.ensemble import RandomForestClassifier as rf
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,precision_score
import statistics
from sklearn.svm import SVC
import six
import sys
sys.modules['sklearn.externals.six'] = six
from scipy.special import logsumexp
sys.modules['scipy.misc.logsumexp'] = logsumexp
from seqlearn import hmm
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
def carf(row):
    for i,elect in row.items():
        elect-=statistics.mean(row)
        row[i]= elect
    return row

# %%
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
beta_data1=pd.DataFrame.from_dict(beta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)



results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}

for i in range(25):
    data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.1,stratify=labels)

    data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.1,stratify=labels)

    data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.1,stratify=labels)

    data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.1,stratify=labels)

    data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.1,stratify=labels)

    data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.1,stratify=labels)
    
    dtree1 = RandomForestClassifier(n_estimators=10000)
    dtree1.fit(data_train_gamma,label_train_gamma)
    predictions_gamma = dtree1.predict(data_test_gamma)
    results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma),output_dict=True)
    
    dtree2 = RandomForestClassifier(n_estimators=10000)
    dtree2.fit(data_train_beta,label_train_beta)
    predictions_beta = dtree2.predict(data_test_beta)
    results['result_beta'].append(classification_report(label_test_beta,predictions_beta),output_dict=True)
    
    dtree3 = RandomForestClassifier(n_estimators=10000)
    dtree3.fit(data_train_alpha,label_train_alpha)
    predictions_alpha = dtree3.predict(data_test_alpha)
    results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha),output_dict=True)
    
    dtree4 = RandomForestClassifier(n_estimators=10000)
    dtree4.fit(data_train_theta,label_train_theta)
    predictions_theta = dtree4.predict(data_test_theta)
    results['result_theta'].append(classification_report(label_test_theta,predictions_theta),output_dict=True)

    dtree5 = RandomForestClassifier(n_estimators=10000)
    dtree5.fit(data_train_delta,label_train_delta)
    predictions_delta = dtree5.predict(data_test_delta)
    results['result_delta'].append(classification_report(label_test_delta,predictions_delta),output_dict=True)
    
    dtree6 = RandomForestClassifier(n_estimators=10000)
    dtree6.fit(data_train_merged,label_train_merged)
    predictions_mereged = dtree6.predict(data_test_merged)
    results['result_merged'].append(classification_report(label_merged,predictions_mereged),output_dict=True)

# %%
mean_gama=0.0
mean_beta=0.0
mean_alpha=0.0
mean_theta=0.0
mean_delta=0.0
mean_merged=0.0

for i in results['result_gamma'] :
    mean_gama+=i['macro avg']['f1-score']
for i in results['result_beta'] :
    mean_beta+=i['macro avg']['f1-score']
for i in results['result_alpha'] :
    mean_alpha+=i['macro avg']['f1-score']
for i in results['result_theta'] :
    mean_theta+=i['macro avg']['f1-score']
for i in results['result_delta'] :
    mean_delta+=i['macro avg']['f1-score']
for i in results['result_merged'] :
    mean_merged+=i['macro avg']['f1-score']
print('mean gamma=',mean_gama/25,'mean beta=',mean_beta/25,'mean alpha =',mean_alpha/25,'mean theta =',mean_theta/25,'mean delta=',mean_delta/25,'mean combined =',mean_merged/25)
# Out:
#               precision    recall  f1-score   support
#
#       Disike       0.58      0.73      0.65        59
#         Like       0.48      0.33      0.39        46
#
#     accuracy                           0.55       105
#    macro avg       0.53      0.53      0.52       105
# weighted avg       0.54      0.55      0.53       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.63      0.71      0.67        59
#         Like       0.55      0.46      0.50        46
#
#     accuracy                           0.60       105
#    macro avg       0.59      0.58      0.58       105
# weighted avg       0.59      0.60      0.59       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.59      0.75      0.66        59
#         Like       0.52      0.35      0.42        46
#
#     accuracy                           0.57       105
#    macro avg       0.56      0.55      0.54       105
# weighted avg       0.56      0.57      0.55       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.68      0.78      0.72        59
#         Like       0.65      0.52      0.58        46
#
#     accuracy                           0.67       105
#    macro avg       0.66      0.65      0.65       105
# weighted avg       0.66      0.67      0.66       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.62      0.71      0.66        59
#         Like       0.54      0.43      0.48        46
#
#     accuracy                           0.59       105
#    macro avg       0.58      0.57      0.57       105
# weighted avg       0.58      0.59      0.58       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.66      0.85      0.74        59
#         Like       0.69      0.43      0.53        46
#
#     accuracy                           0.67       105
#    macro avg       0.67      0.64      0.64       105
# weighted avg       0.67      0.67      0.65       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.58      0.68      0.63        59
#         Like       0.47      0.37      0.41        46
#
#     accuracy                           0.54       105
#    macro avg       0.53      0.52      0.52       105
# weighted avg       0.53      0.54      0.53       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.57      0.71      0.63        59
#         Like       0.45      0.30      0.36        46
#
#     accuracy                           0.53       105
#    macro avg       0.51      0.51      0.50       105
# weighted avg       0.52      0.53      0.51       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.64      0.78      0.70        59
#         Like       0.61      0.43      0.51        46
#
#     accuracy                           0.63       105
#    macro avg       0.62      0.61      0.60       105
# weighted avg       0.62      0.63      0.62       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.61      0.76      0.68        59
#         Like       0.55      0.37      0.44        46
#
#     accuracy                           0.59       105
#    macro avg       0.58      0.57      0.56       105
# weighted avg       0.58      0.59      0.57       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.64      0.73      0.68        59
#         Like       0.58      0.48      0.52        46
#
#     accuracy                           0.62       105
#    macro avg       0.61      0.60      0.60       105
# weighted avg       0.61      0.62      0.61       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.65      0.71      0.68        59
#         Like       0.57      0.50      0.53        46
#
#     accuracy                           0.62       105
#    macro avg       0.61      0.61      0.61       105
# weighted avg       0.61      0.62      0.61       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.60      0.69      0.65        59
#         Like       0.51      0.41      0.46        46
#
#     accuracy                           0.57       105
#    macro avg       0.56      0.55      0.55       105
# weighted avg       0.56      0.57      0.56       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.60      0.71      0.65        59
#         Like       0.51      0.39      0.44        46
#
#     accuracy                           0.57       105
#    macro avg       0.56      0.55      0.55       105
# weighted avg       0.56      0.57      0.56       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.64      0.73      0.68        59
#         Like       0.58      0.48      0.52        46
#
#     accuracy                           0.62       105
#    macro avg       0.61      0.60      0.60       105
# weighted avg       0.61      0.62      0.61       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.62      0.68      0.65        59
#         Like       0.53      0.46      0.49        46
#
#     accuracy                           0.58       105
#    macro avg       0.57      0.57      0.57       105
# weighted avg       0.58      0.58      0.58       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.61      0.66      0.63        59
#         Like       0.51      0.46      0.48        46
#
#     accuracy                           0.57       105
#    macro avg       0.56      0.56      0.56       105
# weighted avg       0.57      0.57      0.57       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.54      0.66      0.60        59
#         Like       0.39      0.28      0.33        46
#
#     accuracy                           0.50       105
#    macro avg       0.47      0.47      0.46       105
# weighted avg       0.48      0.50      0.48       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.61      0.61      0.61        59
#         Like       0.50      0.50      0.50        46
#
#     accuracy                           0.56       105
#    macro avg       0.56      0.56      0.56       105
# weighted avg       0.56      0.56      0.56       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.63      0.80      0.70        59
#         Like       0.60      0.39      0.47        46
#
#     accuracy                           0.62       105
#    macro avg       0.61      0.59      0.59       105
# weighted avg       0.61      0.62      0.60       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.60      0.56      0.58        59
#         Like       0.48      0.52      0.50        46
#
#     accuracy                           0.54       105
#    macro avg       0.54      0.54      0.54       105
# weighted avg       0.55      0.54      0.54       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.61      0.80      0.69        59
#         Like       0.57      0.35      0.43        46
#
#     accuracy                           0.60       105
#    macro avg       0.59      0.57      0.56       105
# weighted avg       0.59      0.60      0.58       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.59      0.64      0.62        59
#         Like       0.49      0.43      0.46        46
#
#     accuracy                           0.55       105
#    macro avg       0.54      0.54      0.54       105
# weighted avg       0.55      0.55      0.55       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.62      0.68      0.65        59
#         Like       0.53      0.46      0.49        46
#
#     accuracy                           0.58       105
#    macro avg       0.57      0.57      0.57       105
# weighted avg       0.58      0.58      0.58       105
#
#               precision    recall  f1-score   support
#
#       Disike       0.62      0.69      0.66        59
#         Like       0.54      0.46      0.49        46
#
#     accuracy                           0.59       105
#    macro avg       0.58      0.58      0.58       105
# weighted avg       0.58      0.59      0.59       105
#
# mean gamma= 0.0 mean beta= 0.0 mean alpha = 0.0 mean theta = 0.0 mean delta= 0.0 mean combined = 0.0

# %%
def carf(row):
    for i,elect in row.items():
        elect-=statistics.mean(row)
        row[i]= elect
    return row

# %% [markdown]
# # Start Here

# %%
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
for i in range(25):
        labels=[]
        gamma_data1={
            "1stgamma":[],
            "2ndgamma":[],
            "3rdgamma":[],
            "4thgamma":[],
            "5thgamma":[],
            "6thgamma":[],
            "7thgamma":[],
            "8thgamma":[],
            "9thgamma":[],
            "10thgamma":[],
            "11thgamma":[],
            "12thgamma":[],
            "13thgamma":[],
            "14thgamma":[]}
        beta_data1={
            "1stbeta":[],
            "2ndbeta":[],
            "3rdbeta":[],
            "4thbeta":[],
            "5thbeta":[],
            "6thbeta":[],
            "7thbeta":[],
            "8thbeta":[],
            "9thbeta":[],
            "10thbeta":[],
            "11thbeta":[],
            "12thbeta":[],
            "13thbeta":[],
            "14thbeta":[]}
        alpha_data1={
            "1stalpha":[],
            "2ndalpha":[],
            "3rdalpha":[],
            "4thalpha":[],
            "5thalpha":[],
            "6thalpha":[],
            "7thalpha":[],
            "8thalpha":[],
            "9thalpha":[],
            "10thalpha":[],
            "11thalpha":[],
            "12thalpha":[],
            "13thalpha":[],
            "14thalpha":[]}
        theta_data1={
            "1sttheta":[],
            "2ndtheta":[],
            "3rdtheta":[],
            "4ththeta":[],
            "5ththeta":[],
            "6ththeta":[],
            "7ththeta":[],
            "8ththeta":[],
            "9ththeta":[],
            "10ththeta":[],
            "11ththeta":[],
            "12ththeta":[],
            "13ththeta":[],
            "14ththeta":[]}
        delta_data1={
            "1stdelta":[],
            "2nddelta":[],
            "3rddelta":[],
            "4thdelta":[],
            "5thdelta":[],
            "6thdelta":[],
            "7thdelta":[],
            "8thdelta":[],
            "9thdelta":[],
            "10thdelta":[],
            "11thdelta":[],
            "12thdelta":[],
            "13thdelta":[],
            "14thdelta":[]}


        for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :

            for i in range(42):
                try:
                    user_data = pd.read_csv("25-users/"+name+str(i+1)+".txt", sep=" ", header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
                    user_label = pd.read_csv("labels/"+name+str(i+1)+".lab",header=None,names=["label"])
                except:
                    continue
                labels.append(user_label.values.tolist()[0][0])

                user_data.apply(lambda row : carf(row), axis = 1)

                first_electrode = user_data['1st']
                second_electrode = user_data['2nd']
                third_electrode = user_data['3rd']
                fourth_electrode = user_data['4th']
                fifth_electrode = user_data['5th']
                sixth_electrode = user_data['6th']
                seventh_electrode = user_data['7th']
                eighth_electrode = user_data['8th']
                nineth_electrode = user_data['9th']
                tenth_electrode = user_data['10th']
                eleventh_electrode = user_data['11th']
                twelveth_electrode = user_data['12th']
                thirteenth_electrode = user_data['13th']
                fouteenth_electrode = user_data['14th']

                s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
                s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
                s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
                s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
                s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
                s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
                s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
                s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
                s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
                s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
                s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
                s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
                s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
                s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


                cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
                cA12, d12 = pywt.dwt(cA1, 'db4')
                cA13, d13 = pywt.dwt(cA12, 'db4')
                a14, d14 = pywt.dwt(cA13, 'db4')
                gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
                beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
                alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
                theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
                delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
                gamma_data1['1stgamma'].append(gamma_RMS1)
                beta_data1['1stbeta'].append(beta_RMS1)
                alpha_data1['1stalpha'].append(alpha_RMS1)
                theta_data1['1sttheta'].append(theta_RMS1)
                delta_data1['1stdelta'].append(delta_RMS1)

                cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
                cA22, d22 = pywt.dwt(cA2, 'db4')
                cA23, d23 = pywt.dwt(cA22, 'db4')
                a24, d24 = pywt.dwt(cA23, 'db4')
                gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
                beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
                alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
                theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
                delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
                gamma_data1['2ndgamma'].append(gamma_RMS2)
                beta_data1['2ndbeta'].append(beta_RMS2)
                alpha_data1['2ndalpha'].append(alpha_RMS2)
                theta_data1['2ndtheta'].append(theta_RMS2)
                delta_data1['2nddelta'].append(delta_RMS2)

                cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
                cA32, d32 = pywt.dwt(cA3, 'db4')
                cA33, d33 = pywt.dwt(cA32, 'db4')
                a34, d34 = pywt.dwt(cA33, 'db4')
                gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
                beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
                alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
                theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
                delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
                gamma_data1['3rdgamma'].append(gamma_RMS3)
                beta_data1['3rdbeta'].append(beta_RMS3)
                alpha_data1['3rdalpha'].append(alpha_RMS3)
                theta_data1['3rdtheta'].append(theta_RMS3)
                delta_data1['3rddelta'].append(delta_RMS3)

                cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
                cA42, d42 = pywt.dwt(cA4, 'db4')
                cA43, d43 = pywt.dwt(cA42, 'db4')
                a44, d44 = pywt.dwt(cA43, 'db4')
                gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
                beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
                alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
                theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
                delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
                gamma_data1['4thgamma'].append(gamma_RMS4)
                beta_data1['4thbeta'].append(beta_RMS4)
                alpha_data1['4thalpha'].append(alpha_RMS4)
                theta_data1['4ththeta'].append(theta_RMS4)
                delta_data1['4thdelta'].append(delta_RMS4)

                cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
                cA52, d52 = pywt.dwt(cA5, 'db4')
                cA53, d53 = pywt.dwt(cA52, 'db4')
                a54, d54 = pywt.dwt(cA53, 'db4')
                gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
                beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
                alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
                theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
                delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
                gamma_data1['5thgamma'].append(gamma_RMS5)
                beta_data1['5thbeta'].append(beta_RMS5)
                alpha_data1['5thalpha'].append(alpha_RMS5)
                theta_data1['5ththeta'].append(theta_RMS5)
                delta_data1['5thdelta'].append(delta_RMS5)

                cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
                cA62, d62 = pywt.dwt(cA6, 'db4')
                cA63, d63 = pywt.dwt(cA62, 'db4')
                a64, d64 = pywt.dwt(cA63, 'db4')
                gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
                beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
                alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
                theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
                delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
                gamma_data1['6thgamma'].append(gamma_RMS6)
                beta_data1['6thbeta'].append(beta_RMS6)
                alpha_data1['6thalpha'].append(alpha_RMS6)
                theta_data1['6ththeta'].append(theta_RMS6)
                delta_data1['6thdelta'].append(delta_RMS6)


                cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
                cA72, d72 = pywt.dwt(cA7, 'db4')
                cA73, d73 = pywt.dwt(cA72, 'db4')
                a74, d74 = pywt.dwt(cA73, 'db4')
                gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
                beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
                alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
                theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
                delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
                gamma_data1['7thgamma'].append(gamma_RMS7)
                beta_data1['7thbeta'].append(beta_RMS7)
                alpha_data1['7thalpha'].append(alpha_RMS7)
                theta_data1['7ththeta'].append(theta_RMS7)
                delta_data1['7thdelta'].append(delta_RMS7)

                cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
                cA82, d82 = pywt.dwt(cA8, 'db4')
                cA83, d83 = pywt.dwt(cA82, 'db4')
                a84, d84 = pywt.dwt(cA83, 'db4')
                gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
                beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
                alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
                theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
                delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
                gamma_data1['8thgamma'].append(gamma_RMS8)
                beta_data1['8thbeta'].append(beta_RMS8)
                alpha_data1['8thalpha'].append(alpha_RMS8)
                theta_data1['8ththeta'].append(theta_RMS8)
                delta_data1['8thdelta'].append(delta_RMS8)

                cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
                cA92, d92 = pywt.dwt(cA9, 'db4')
                cA93, d93 = pywt.dwt(cA92, 'db4')
                a94, d94 = pywt.dwt(cA93, 'db4')
                gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
                beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
                alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
                theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
                delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
                gamma_data1['9thgamma'].append(gamma_RMS9)
                beta_data1['9thbeta'].append(beta_RMS9)
                alpha_data1['9thalpha'].append(alpha_RMS9)
                theta_data1['9ththeta'].append(theta_RMS9)
                delta_data1['9thdelta'].append(delta_RMS9)

                cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
                cA102, d102 = pywt.dwt(cA10, 'db4')
                cA103, d103 = pywt.dwt(cA102, 'db4')
                a104, d104 = pywt.dwt(cA103, 'db4')
                gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
                beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
                alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
                theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
                delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
                gamma_data1['10thgamma'].append(gamma_RMS10)
                beta_data1['10thbeta'].append(beta_RMS10)
                alpha_data1['10thalpha'].append(alpha_RMS10)
                theta_data1['10ththeta'].append(theta_RMS10)
                delta_data1['10thdelta'].append(delta_RMS10)

                cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
                cA112, d112 = pywt.dwt(cA11, 'db4')
                cA113, d113 = pywt.dwt(cA112, 'db4')
                a114, d114 = pywt.dwt(cA113, 'db4')
                gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
                beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
                alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
                theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
                delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
                gamma_data1['11thgamma'].append(gamma_RMS11)
                beta_data1['11thbeta'].append(beta_RMS11)
                alpha_data1['11thalpha'].append(alpha_RMS11)
                theta_data1['11ththeta'].append(theta_RMS11)
                delta_data1['11thdelta'].append(delta_RMS11)

                cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
                cA122, d122 = pywt.dwt(cA12, 'db4')
                cA123, d123 = pywt.dwt(cA122, 'db4')
                a124, d124 = pywt.dwt(cA123, 'db4')
                gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
                beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
                alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
                theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
                delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
                gamma_data1['12thgamma'].append(gamma_RMS12)
                beta_data1['12thbeta'].append(beta_RMS12)
                alpha_data1['12thalpha'].append(alpha_RMS12)
                theta_data1['12ththeta'].append(theta_RMS12)
                delta_data1['12thdelta'].append(delta_RMS12)

                cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
                cA132, d132 = pywt.dwt(cA13, 'db4')
                cA133, d133 = pywt.dwt(cA132, 'db4')
                a134, d134 = pywt.dwt(cA133, 'db4')
                gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
                beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
                alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
                theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
                delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
                gamma_data1['13thgamma'].append(gamma_RMS13)
                beta_data1['13thbeta'].append(beta_RMS13)
                alpha_data1['13thalpha'].append(alpha_RMS13)
                theta_data1['13ththeta'].append(theta_RMS13)
                delta_data1['13thdelta'].append(delta_RMS13)

                cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
                cA142, d142 = pywt.dwt(cA14, 'db4')
                cA143, d143 = pywt.dwt(cA142, 'db4')
                a144, d144 = pywt.dwt(cA143, 'db4')
                gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
                beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
                alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
                theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
                delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
                gamma_data1['14thgamma'].append(gamma_RMS14)
                beta_data1['14thbeta'].append(beta_RMS14)
                alpha_data1['14thalpha'].append(alpha_RMS14)
                theta_data1['14ththeta'].append(theta_RMS14)
                delta_data1['14thdelta'].append(delta_RMS14)

        merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
        merged= pd.DataFrame.from_dict(merged)
        gamma_data1=pd.DataFrame.from_dict(gamma_data1)
        beta_data1=pd.DataFrame.from_dict(beta_data1)
        alpha_data1=pd.DataFrame.from_dict(alpha_data1)
        theta_data1=pd.DataFrame.from_dict(theta_data1)
        delta_data1=pd.DataFrame.from_dict(delta_data1)
        
        data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.1,stratify=labels)
        data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.1,stratify=labels)
        data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.1,stratify=labels)
        data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.1,stratify=labels)
        data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.1,stratify=labels)
        data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.1,stratify=labels)

        
        dtree1 = RandomForestClassifier(n_estimators=20000)
        dtree1.fit(data_train_gamma,label_train_gamma)
        predictions_gamma = dtree1.predict(data_test_gamma)
        results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

        dtree2 = RandomForestClassifier(n_estimators=20000)
        dtree2.fit(data_train_beta,label_train_beta)
        predictions_beta = dtree2.predict(data_test_beta)
        results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

        dtree3 = RandomForestClassifier(n_estimators=20000)
        dtree3.fit(data_train_alpha,label_train_alpha)
        predictions_alpha = dtree3.predict(data_test_alpha)
        results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

        dtree4 = RandomForestClassifier(n_estimators=20000)
        dtree4.fit(data_train_theta,label_train_theta)
        predictions_theta = dtree4.predict(data_test_theta)
        results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

        dtree5 = RandomForestClassifier(n_estimators=20000)
        dtree5.fit(data_train_delta,label_train_delta)
        predictions_delta = dtree5.predict(data_test_delta)
        results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

        dtree6 = RandomForestClassifier(n_estimators=20000)
        dtree6.fit(data_train_merged,label_train_merged)
        predictions_mereged = dtree6.predict(data_test_merged)
        results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))

# %%
mean_gama=0.0
mean_beta=0.0
mean_alpha=0.0
mean_theta=0.0
mean_delta=0.0
mean_merged=0.0

for i in results['result_gamma'] :
    mean_gama+=i['macro avg']['f1-score']
for i in results['result_beta'] :
    mean_beta+=i['macro avg']['f1-score']
for i in results['result_alpha'] :
    mean_alpha+=i['macro avg']['f1-score']
for i in results['result_theta'] :
    mean_theta+=i['macro avg']['f1-score']
for i in results['result_delta'] :
    mean_delta+=i['macro avg']['f1-score']
for i in results['result_merged'] :
    mean_merged+=i['macro avg']['f1-score']
print('mean gamma=',mean_gama/25,'mean beta=',mean_beta/25,'mean alpha =',mean_alpha/25,'mean theta =',mean_theta/25,'mean delta=',mean_delta/25,'mean combined =',mean_merged/25)
# Out:
# mean gamma= 0.5589374372979361 mean beta= 0.6010530993952813 mean alpha = 0.5523329047765684 mean theta = 0.5554074510268197 mean delta= 0.5385386636183767 mean combined = 0.5997112320773872

# %%
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
for i in range(25):
        labels=[]
        gamma_data1={
            "1stgamma":[],
            "2ndgamma":[],
            "3rdgamma":[],
            "4thgamma":[],
            "5thgamma":[],
            "6thgamma":[],
            "7thgamma":[],
            "8thgamma":[],
            "9thgamma":[],
            "10thgamma":[],
            "11thgamma":[],
            "12thgamma":[],
            "13thgamma":[],
            "14thgamma":[]}
        beta_data1={
            "1stbeta":[],
            "2ndbeta":[],
            "3rdbeta":[],
            "4thbeta":[],
            "5thbeta":[],
            "6thbeta":[],
            "7thbeta":[],
            "8thbeta":[],
            "9thbeta":[],
            "10thbeta":[],
            "11thbeta":[],
            "12thbeta":[],
            "13thbeta":[],
            "14thbeta":[]}
        alpha_data1={
            "1stalpha":[],
            "2ndalpha":[],
            "3rdalpha":[],
            "4thalpha":[],
            "5thalpha":[],
            "6thalpha":[],
            "7thalpha":[],
            "8thalpha":[],
            "9thalpha":[],
            "10thalpha":[],
            "11thalpha":[],
            "12thalpha":[],
            "13thalpha":[],
            "14thalpha":[]}
        theta_data1={
            "1sttheta":[],
            "2ndtheta":[],
            "3rdtheta":[],
            "4ththeta":[],
            "5ththeta":[],
            "6ththeta":[],
            "7ththeta":[],
            "8ththeta":[],
            "9ththeta":[],
            "10ththeta":[],
            "11ththeta":[],
            "12ththeta":[],
            "13ththeta":[],
            "14ththeta":[]}
        delta_data1={
            "1stdelta":[],
            "2nddelta":[],
            "3rddelta":[],
            "4thdelta":[],
            "5thdelta":[],
            "6thdelta":[],
            "7thdelta":[],
            "8thdelta":[],
            "9thdelta":[],
            "10thdelta":[],
            "11thdelta":[],
            "12thdelta":[],
            "13thdelta":[],
            "14thdelta":[]}


        for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :

            for i in range(42):
                try:
                    user_data = pd.read_csv("25-users/"+name+str(i+1)+".txt", sep=" ", header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
                    user_label = pd.read_csv("labels/"+name+str(i+1)+".lab",header=None,names=["label"])
                except:
                    continue
                labels.append(user_label.values.tolist()[0][0])

                user_data.apply(lambda row : carf(row), axis = 1)

                first_electrode = user_data['1st']
                second_electrode = user_data['2nd']
                third_electrode = user_data['3rd']
                fourth_electrode = user_data['4th']
                fifth_electrode = user_data['5th']
                sixth_electrode = user_data['6th']
                seventh_electrode = user_data['7th']
                eighth_electrode = user_data['8th']
                nineth_electrode = user_data['9th']
                tenth_electrode = user_data['10th']
                eleventh_electrode = user_data['11th']
                twelveth_electrode = user_data['12th']
                thirteenth_electrode = user_data['13th']
                fouteenth_electrode = user_data['14th']

                s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
                s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
                s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
                s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
                s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
                s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
                s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
                s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
                s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
                s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
                s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
                s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
                s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
                s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


                cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
                cA12, d12 = pywt.dwt(cA1, 'db4')
                cA13, d13 = pywt.dwt(cA12, 'db4')
                a14, d14 = pywt.dwt(cA13, 'db4')
                gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
                beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
                alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
                theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
                delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
                gamma_data1['1stgamma'].append(gamma_RMS1)
                beta_data1['1stbeta'].append(beta_RMS1)
                alpha_data1['1stalpha'].append(alpha_RMS1)
                theta_data1['1sttheta'].append(theta_RMS1)
                delta_data1['1stdelta'].append(delta_RMS1)

                cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
                cA22, d22 = pywt.dwt(cA2, 'db4')
                cA23, d23 = pywt.dwt(cA22, 'db4')
                a24, d24 = pywt.dwt(cA23, 'db4')
                gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
                beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
                alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
                theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
                delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
                gamma_data1['2ndgamma'].append(gamma_RMS2)
                beta_data1['2ndbeta'].append(beta_RMS2)
                alpha_data1['2ndalpha'].append(alpha_RMS2)
                theta_data1['2ndtheta'].append(theta_RMS2)
                delta_data1['2nddelta'].append(delta_RMS2)

                cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
                cA32, d32 = pywt.dwt(cA3, 'db4')
                cA33, d33 = pywt.dwt(cA32, 'db4')
                a34, d34 = pywt.dwt(cA33, 'db4')
                gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
                beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
                alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
                theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
                delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
                gamma_data1['3rdgamma'].append(gamma_RMS3)
                beta_data1['3rdbeta'].append(beta_RMS3)
                alpha_data1['3rdalpha'].append(alpha_RMS3)
                theta_data1['3rdtheta'].append(theta_RMS3)
                delta_data1['3rddelta'].append(delta_RMS3)

                cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
                cA42, d42 = pywt.dwt(cA4, 'db4')
                cA43, d43 = pywt.dwt(cA42, 'db4')
                a44, d44 = pywt.dwt(cA43, 'db4')
                gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
                beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
                alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
                theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
                delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
                gamma_data1['4thgamma'].append(gamma_RMS4)
                beta_data1['4thbeta'].append(beta_RMS4)
                alpha_data1['4thalpha'].append(alpha_RMS4)
                theta_data1['4ththeta'].append(theta_RMS4)
                delta_data1['4thdelta'].append(delta_RMS4)

                cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
                cA52, d52 = pywt.dwt(cA5, 'db4')
                cA53, d53 = pywt.dwt(cA52, 'db4')
                a54, d54 = pywt.dwt(cA53, 'db4')
                gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
                beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
                alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
                theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
                delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
                gamma_data1['5thgamma'].append(gamma_RMS5)
                beta_data1['5thbeta'].append(beta_RMS5)
                alpha_data1['5thalpha'].append(alpha_RMS5)
                theta_data1['5ththeta'].append(theta_RMS5)
                delta_data1['5thdelta'].append(delta_RMS5)

                cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
                cA62, d62 = pywt.dwt(cA6, 'db4')
                cA63, d63 = pywt.dwt(cA62, 'db4')
                a64, d64 = pywt.dwt(cA63, 'db4')
                gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
                beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
                alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
                theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
                delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
                gamma_data1['6thgamma'].append(gamma_RMS6)
                beta_data1['6thbeta'].append(beta_RMS6)
                alpha_data1['6thalpha'].append(alpha_RMS6)
                theta_data1['6ththeta'].append(theta_RMS6)
                delta_data1['6thdelta'].append(delta_RMS6)


                cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
                cA72, d72 = pywt.dwt(cA7, 'db4')
                cA73, d73 = pywt.dwt(cA72, 'db4')
                a74, d74 = pywt.dwt(cA73, 'db4')
                gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
                beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
                alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
                theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
                delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
                gamma_data1['7thgamma'].append(gamma_RMS7)
                beta_data1['7thbeta'].append(beta_RMS7)
                alpha_data1['7thalpha'].append(alpha_RMS7)
                theta_data1['7ththeta'].append(theta_RMS7)
                delta_data1['7thdelta'].append(delta_RMS7)

                cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
                cA82, d82 = pywt.dwt(cA8, 'db4')
                cA83, d83 = pywt.dwt(cA82, 'db4')
                a84, d84 = pywt.dwt(cA83, 'db4')
                gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
                beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
                alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
                theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
                delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
                gamma_data1['8thgamma'].append(gamma_RMS8)
                beta_data1['8thbeta'].append(beta_RMS8)
                alpha_data1['8thalpha'].append(alpha_RMS8)
                theta_data1['8ththeta'].append(theta_RMS8)
                delta_data1['8thdelta'].append(delta_RMS8)

                cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
                cA92, d92 = pywt.dwt(cA9, 'db4')
                cA93, d93 = pywt.dwt(cA92, 'db4')
                a94, d94 = pywt.dwt(cA93, 'db4')
                gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
                beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
                alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
                theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
                delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
                gamma_data1['9thgamma'].append(gamma_RMS9)
                beta_data1['9thbeta'].append(beta_RMS9)
                alpha_data1['9thalpha'].append(alpha_RMS9)
                theta_data1['9ththeta'].append(theta_RMS9)
                delta_data1['9thdelta'].append(delta_RMS9)

                cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
                cA102, d102 = pywt.dwt(cA10, 'db4')
                cA103, d103 = pywt.dwt(cA102, 'db4')
                a104, d104 = pywt.dwt(cA103, 'db4')
                gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
                beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
                alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
                theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
                delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
                gamma_data1['10thgamma'].append(gamma_RMS10)
                beta_data1['10thbeta'].append(beta_RMS10)
                alpha_data1['10thalpha'].append(alpha_RMS10)
                theta_data1['10ththeta'].append(theta_RMS10)
                delta_data1['10thdelta'].append(delta_RMS10)

                cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
                cA112, d112 = pywt.dwt(cA11, 'db4')
                cA113, d113 = pywt.dwt(cA112, 'db4')
                a114, d114 = pywt.dwt(cA113, 'db4')
                gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
                beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
                alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
                theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
                delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
                gamma_data1['11thgamma'].append(gamma_RMS11)
                beta_data1['11thbeta'].append(beta_RMS11)
                alpha_data1['11thalpha'].append(alpha_RMS11)
                theta_data1['11ththeta'].append(theta_RMS11)
                delta_data1['11thdelta'].append(delta_RMS11)

                cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
                cA122, d122 = pywt.dwt(cA12, 'db4')
                cA123, d123 = pywt.dwt(cA122, 'db4')
                a124, d124 = pywt.dwt(cA123, 'db4')
                gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
                beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
                alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
                theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
                delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
                gamma_data1['12thgamma'].append(gamma_RMS12)
                beta_data1['12thbeta'].append(beta_RMS12)
                alpha_data1['12thalpha'].append(alpha_RMS12)
                theta_data1['12ththeta'].append(theta_RMS12)
                delta_data1['12thdelta'].append(delta_RMS12)

                cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
                cA132, d132 = pywt.dwt(cA13, 'db4')
                cA133, d133 = pywt.dwt(cA132, 'db4')
                a134, d134 = pywt.dwt(cA133, 'db4')
                gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
                beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
                alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
                theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
                delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
                gamma_data1['13thgamma'].append(gamma_RMS13)
                beta_data1['13thbeta'].append(beta_RMS13)
                alpha_data1['13thalpha'].append(alpha_RMS13)
                theta_data1['13ththeta'].append(theta_RMS13)
                delta_data1['13thdelta'].append(delta_RMS13)

                cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
                cA142, d142 = pywt.dwt(cA14, 'db4')
                cA143, d143 = pywt.dwt(cA142, 'db4')
                a144, d144 = pywt.dwt(cA143, 'db4')
                gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
                beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
                alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
                theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
                delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
                gamma_data1['14thgamma'].append(gamma_RMS14)
                beta_data1['14thbeta'].append(beta_RMS14)
                alpha_data1['14thalpha'].append(alpha_RMS14)
                theta_data1['14ththeta'].append(theta_RMS14)
                delta_data1['14thdelta'].append(delta_RMS14)

        merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
        merged= pd.DataFrame.from_dict(merged)
        gamma_data1=pd.DataFrame.from_dict(gamma_data1)
        beta_data1=pd.DataFrame.from_dict(beta_data1)
        alpha_data1=pd.DataFrame.from_dict(alpha_data1)
        theta_data1=pd.DataFrame.from_dict(theta_data1)
        delta_data1=pd.DataFrame.from_dict(delta_data1)
        
        standard_gamma = StandardScaler().fit_transform(gamma_data1) 
        normalised_gamma = pd.DataFrame(standard_gamma)
        pca_gamma = PCA(n_components=0.9)
        principalComponents_gamma = pca_gamma.fit_transform(standard_gamma)
        gamma_data1 = pd.DataFrame(data = principalComponents_gamma)
        data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.1,stratify=labels)

        standard_beta = StandardScaler().fit_transform(beta_data1) 
        normalised_beta = pd.DataFrame(standard_beta)
        pca_beta = PCA(n_components=0.9)
        principalComponents_beta = pca_beta.fit_transform(standard_beta)
        beta_data1 = pd.DataFrame(data = principalComponents_beta)
        data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.1,stratify=labels)

        standard_alpha = StandardScaler().fit_transform(alpha_data1) 
        normalised_alpha = pd.DataFrame(standard_alpha)
        pca_alpha = PCA(n_components=0.9)
        principalComponents_alpha = pca_alpha.fit_transform(standard_alpha)
        alpha_data1 = pd.DataFrame(data = principalComponents_alpha)
        data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.1,stratify=labels)

        standard_theta = StandardScaler().fit_transform(theta_data1) 
        normalised_theta = pd.DataFrame(standard_theta)
        pca_theta = PCA(n_components=0.9)
        principalComponents_theta = pca_theta.fit_transform(standard_theta)
        theta_data1 = pd.DataFrame(data = principalComponents_theta)
        data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.1,stratify=labels)


        standard_delta = StandardScaler().fit_transform(delta_data1) 
        normalised_delta = pd.DataFrame(standard_delta)
        pca_delta = PCA(n_components=0.9)
        principalComponents_delta = pca_delta.fit_transform(standard_delta)
        delta_data1 = pd.DataFrame(data = principalComponents_delta)
        data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.1,stratify=labels)

        standard_merged = StandardScaler().fit_transform(merged) 
        normalised_merged = pd.DataFrame(standard_merged)
        pca_merged = PCA(n_components=0.9)
        principalComponents_merged = pca_merged.fit_transform(standard_merged)
        merged = pd.DataFrame(data = principalComponents_merged)
        data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.1,stratify=labels)
    
        dtree1 = RandomForestClassifier(n_estimators=20000)
        dtree1.fit(data_train_gamma,label_train_gamma)
        predictions_gamma = dtree1.predict(data_test_gamma)
        results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

        dtree2 = RandomForestClassifier(n_estimators=20000)
        dtree2.fit(data_train_beta,label_train_beta)
        predictions_beta = dtree2.predict(data_test_beta)
        results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

        dtree3 = RandomForestClassifier(n_estimators=20000)
        dtree3.fit(data_train_alpha,label_train_alpha)
        predictions_alpha = dtree3.predict(data_test_alpha)
        results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

        dtree4 = RandomForestClassifier(n_estimators=20000)
        dtree4.fit(data_train_theta,label_train_theta)
        predictions_theta = dtree4.predict(data_test_theta)
        results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

        dtree5 = RandomForestClassifier(n_estimators=20000)
        dtree5.fit(data_train_delta,label_train_delta)
        predictions_delta = dtree5.predict(data_test_delta)
        results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

        dtree6 = RandomForestClassifier(n_estimators=20000)
        dtree6.fit(data_train_merged,label_train_merged)
        predictions_mereged = dtree6.predict(data_test_merged)
        results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))

# %%
mean_gama=0.0
mean_beta=0.0
mean_alpha=0.0
mean_theta=0.0
mean_delta=0.0
mean_merged=0.0

for i in results['result_gamma'] :
    mean_gama+=i['macro avg']['f1-score']
for i in results['result_beta'] :
    mean_beta+=i['macro avg']['f1-score']
for i in results['result_alpha'] :
    mean_alpha+=i['macro avg']['f1-score']
for i in results['result_theta'] :
    mean_theta+=i['macro avg']['f1-score']
for i in results['result_delta'] :
    mean_delta+=i['macro avg']['f1-score']
for i in results['result_merged'] :
    mean_merged+=i['macro avg']['f1-score']
print('mean gamma=',mean_gama/25,'mean beta=',mean_beta/25,'mean alpha =',mean_alpha/25,'mean theta =',mean_theta/25,'mean delta=',mean_delta/25,'mean combined =',mean_merged/25)
# Out:
# mean gamma= 0.5443506285719052 mean beta= 0.5430046717481314 mean alpha = 0.5590202179613982 mean theta = 0.6126230720969548 mean delta= 0.4955999902010737 mean combined = 0.5872334121766548

# %%
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
for i in range(25):
        labels=[]
        gamma_data1={
            "1stgamma":[],
            "2ndgamma":[],
            "3rdgamma":[],
            "4thgamma":[],
            "5thgamma":[],
            "6thgamma":[],
            "7thgamma":[],
            "8thgamma":[],
            "9thgamma":[],
            "10thgamma":[],
            "11thgamma":[],
            "12thgamma":[],
            "13thgamma":[],
            "14thgamma":[]}
        beta_data1={
            "1stbeta":[],
            "2ndbeta":[],
            "3rdbeta":[],
            "4thbeta":[],
            "5thbeta":[],
            "6thbeta":[],
            "7thbeta":[],
            "8thbeta":[],
            "9thbeta":[],
            "10thbeta":[],
            "11thbeta":[],
            "12thbeta":[],
            "13thbeta":[],
            "14thbeta":[]}
        alpha_data1={
            "1stalpha":[],
            "2ndalpha":[],
            "3rdalpha":[],
            "4thalpha":[],
            "5thalpha":[],
            "6thalpha":[],
            "7thalpha":[],
            "8thalpha":[],
            "9thalpha":[],
            "10thalpha":[],
            "11thalpha":[],
            "12thalpha":[],
            "13thalpha":[],
            "14thalpha":[]}
        theta_data1={
            "1sttheta":[],
            "2ndtheta":[],
            "3rdtheta":[],
            "4ththeta":[],
            "5ththeta":[],
            "6ththeta":[],
            "7ththeta":[],
            "8ththeta":[],
            "9ththeta":[],
            "10ththeta":[],
            "11ththeta":[],
            "12ththeta":[],
            "13ththeta":[],
            "14ththeta":[]}
        delta_data1={
            "1stdelta":[],
            "2nddelta":[],
            "3rddelta":[],
            "4thdelta":[],
            "5thdelta":[],
            "6thdelta":[],
            "7thdelta":[],
            "8thdelta":[],
            "9thdelta":[],
            "10thdelta":[],
            "11thdelta":[],
            "12thdelta":[],
            "13thdelta":[],
            "14thdelta":[]}


        for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :

            for i in range(42):
                try:
                    user_data = pd.read_csv("25-users/"+name+str(i+1)+".txt", sep=" ", header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
                    user_label = pd.read_csv("labels/"+name+str(i+1)+".lab",header=None,names=["label"])
                except:
                    continue
                labels.append(user_label.values.tolist()[0][0])

                user_data.apply(lambda row : carf(row), axis = 1)

                first_electrode = user_data['1st']
                second_electrode = user_data['2nd']
                third_electrode = user_data['3rd']
                fourth_electrode = user_data['4th']
                fifth_electrode = user_data['5th']
                sixth_electrode = user_data['6th']
                seventh_electrode = user_data['7th']
                eighth_electrode = user_data['8th']
                nineth_electrode = user_data['9th']
                tenth_electrode = user_data['10th']
                eleventh_electrode = user_data['11th']
                twelveth_electrode = user_data['12th']
                thirteenth_electrode = user_data['13th']
                fouteenth_electrode = user_data['14th']

                s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
                s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
                s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
                s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
                s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
                s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
                s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
                s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
                s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
                s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
                s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
                s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
                s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
                s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


                cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
                cA12, d12 = pywt.dwt(cA1, 'db4')
                cA13, d13 = pywt.dwt(cA12, 'db4')
                a14, d14 = pywt.dwt(cA13, 'db4')
                gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
                beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
                alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
                theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
                delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
                gamma_data1['1stgamma'].append(gamma_RMS1)
                beta_data1['1stbeta'].append(beta_RMS1)
                alpha_data1['1stalpha'].append(alpha_RMS1)
                theta_data1['1sttheta'].append(theta_RMS1)
                delta_data1['1stdelta'].append(delta_RMS1)

                cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
                cA22, d22 = pywt.dwt(cA2, 'db4')
                cA23, d23 = pywt.dwt(cA22, 'db4')
                a24, d24 = pywt.dwt(cA23, 'db4')
                gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
                beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
                alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
                theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
                delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
                gamma_data1['2ndgamma'].append(gamma_RMS2)
                beta_data1['2ndbeta'].append(beta_RMS2)
                alpha_data1['2ndalpha'].append(alpha_RMS2)
                theta_data1['2ndtheta'].append(theta_RMS2)
                delta_data1['2nddelta'].append(delta_RMS2)

                cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
                cA32, d32 = pywt.dwt(cA3, 'db4')
                cA33, d33 = pywt.dwt(cA32, 'db4')
                a34, d34 = pywt.dwt(cA33, 'db4')
                gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
                beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
                alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
                theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
                delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
                gamma_data1['3rdgamma'].append(gamma_RMS3)
                beta_data1['3rdbeta'].append(beta_RMS3)
                alpha_data1['3rdalpha'].append(alpha_RMS3)
                theta_data1['3rdtheta'].append(theta_RMS3)
                delta_data1['3rddelta'].append(delta_RMS3)

                cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
                cA42, d42 = pywt.dwt(cA4, 'db4')
                cA43, d43 = pywt.dwt(cA42, 'db4')
                a44, d44 = pywt.dwt(cA43, 'db4')
                gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
                beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
                alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
                theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
                delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
                gamma_data1['4thgamma'].append(gamma_RMS4)
                beta_data1['4thbeta'].append(beta_RMS4)
                alpha_data1['4thalpha'].append(alpha_RMS4)
                theta_data1['4ththeta'].append(theta_RMS4)
                delta_data1['4thdelta'].append(delta_RMS4)

                cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
                cA52, d52 = pywt.dwt(cA5, 'db4')
                cA53, d53 = pywt.dwt(cA52, 'db4')
                a54, d54 = pywt.dwt(cA53, 'db4')
                gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
                beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
                alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
                theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
                delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
                gamma_data1['5thgamma'].append(gamma_RMS5)
                beta_data1['5thbeta'].append(beta_RMS5)
                alpha_data1['5thalpha'].append(alpha_RMS5)
                theta_data1['5ththeta'].append(theta_RMS5)
                delta_data1['5thdelta'].append(delta_RMS5)

                cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
                cA62, d62 = pywt.dwt(cA6, 'db4')
                cA63, d63 = pywt.dwt(cA62, 'db4')
                a64, d64 = pywt.dwt(cA63, 'db4')
                gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
                beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
                alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
                theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
                delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
                gamma_data1['6thgamma'].append(gamma_RMS6)
                beta_data1['6thbeta'].append(beta_RMS6)
                alpha_data1['6thalpha'].append(alpha_RMS6)
                theta_data1['6ththeta'].append(theta_RMS6)
                delta_data1['6thdelta'].append(delta_RMS6)


                cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
                cA72, d72 = pywt.dwt(cA7, 'db4')
                cA73, d73 = pywt.dwt(cA72, 'db4')
                a74, d74 = pywt.dwt(cA73, 'db4')
                gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
                beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
                alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
                theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
                delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
                gamma_data1['7thgamma'].append(gamma_RMS7)
                beta_data1['7thbeta'].append(beta_RMS7)
                alpha_data1['7thalpha'].append(alpha_RMS7)
                theta_data1['7ththeta'].append(theta_RMS7)
                delta_data1['7thdelta'].append(delta_RMS7)

                cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
                cA82, d82 = pywt.dwt(cA8, 'db4')
                cA83, d83 = pywt.dwt(cA82, 'db4')
                a84, d84 = pywt.dwt(cA83, 'db4')
                gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
                beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
                alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
                theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
                delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
                gamma_data1['8thgamma'].append(gamma_RMS8)
                beta_data1['8thbeta'].append(beta_RMS8)
                alpha_data1['8thalpha'].append(alpha_RMS8)
                theta_data1['8ththeta'].append(theta_RMS8)
                delta_data1['8thdelta'].append(delta_RMS8)

                cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
                cA92, d92 = pywt.dwt(cA9, 'db4')
                cA93, d93 = pywt.dwt(cA92, 'db4')
                a94, d94 = pywt.dwt(cA93, 'db4')
                gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
                beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
                alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
                theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
                delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
                gamma_data1['9thgamma'].append(gamma_RMS9)
                beta_data1['9thbeta'].append(beta_RMS9)
                alpha_data1['9thalpha'].append(alpha_RMS9)
                theta_data1['9ththeta'].append(theta_RMS9)
                delta_data1['9thdelta'].append(delta_RMS9)

                cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
                cA102, d102 = pywt.dwt(cA10, 'db4')
                cA103, d103 = pywt.dwt(cA102, 'db4')
                a104, d104 = pywt.dwt(cA103, 'db4')
                gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
                beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
                alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
                theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
                delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
                gamma_data1['10thgamma'].append(gamma_RMS10)
                beta_data1['10thbeta'].append(beta_RMS10)
                alpha_data1['10thalpha'].append(alpha_RMS10)
                theta_data1['10ththeta'].append(theta_RMS10)
                delta_data1['10thdelta'].append(delta_RMS10)

                cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
                cA112, d112 = pywt.dwt(cA11, 'db4')
                cA113, d113 = pywt.dwt(cA112, 'db4')
                a114, d114 = pywt.dwt(cA113, 'db4')
                gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
                beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
                alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
                theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
                delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
                gamma_data1['11thgamma'].append(gamma_RMS11)
                beta_data1['11thbeta'].append(beta_RMS11)
                alpha_data1['11thalpha'].append(alpha_RMS11)
                theta_data1['11ththeta'].append(theta_RMS11)
                delta_data1['11thdelta'].append(delta_RMS11)

                cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
                cA122, d122 = pywt.dwt(cA12, 'db4')
                cA123, d123 = pywt.dwt(cA122, 'db4')
                a124, d124 = pywt.dwt(cA123, 'db4')
                gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
                beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
                alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
                theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
                delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
                gamma_data1['12thgamma'].append(gamma_RMS12)
                beta_data1['12thbeta'].append(beta_RMS12)
                alpha_data1['12thalpha'].append(alpha_RMS12)
                theta_data1['12ththeta'].append(theta_RMS12)
                delta_data1['12thdelta'].append(delta_RMS12)

                cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
                cA132, d132 = pywt.dwt(cA13, 'db4')
                cA133, d133 = pywt.dwt(cA132, 'db4')
                a134, d134 = pywt.dwt(cA133, 'db4')
                gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
                beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
                alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
                theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
                delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
                gamma_data1['13thgamma'].append(gamma_RMS13)
                beta_data1['13thbeta'].append(beta_RMS13)
                alpha_data1['13thalpha'].append(alpha_RMS13)
                theta_data1['13ththeta'].append(theta_RMS13)
                delta_data1['13thdelta'].append(delta_RMS13)

                cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
                cA142, d142 = pywt.dwt(cA14, 'db4')
                cA143, d143 = pywt.dwt(cA142, 'db4')
                a144, d144 = pywt.dwt(cA143, 'db4')
                gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
                beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
                alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
                theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
                delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
                gamma_data1['14thgamma'].append(gamma_RMS14)
                beta_data1['14thbeta'].append(beta_RMS14)
                alpha_data1['14thalpha'].append(alpha_RMS14)
                theta_data1['14ththeta'].append(theta_RMS14)
                delta_data1['14thdelta'].append(delta_RMS14)

        merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
        merged= pd.DataFrame.from_dict(merged)
        gamma_data1=pd.DataFrame.from_dict(gamma_data1)
        beta_data1=pd.DataFrame.from_dict(beta_data1)
        alpha_data1=pd.DataFrame.from_dict(alpha_data1)
        theta_data1=pd.DataFrame.from_dict(theta_data1)
        delta_data1=pd.DataFrame.from_dict(delta_data1)
        
        
        pca_gamma = PCA(n_components=0.9)
        principalComponents_gamma = pca_gamma.fit_transform(gamma_data1)
        gamma_data1 = pd.DataFrame(data = principalComponents_gamma)
        data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.1,stratify=labels)

    
        pca_beta = PCA(n_components=0.9)
        principalComponents_beta = pca_beta.fit_transform(beta_data1)
        beta_data1 = pd.DataFrame(data = principalComponents_beta)
        data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.1,stratify=labels)

       
        pca_alpha = PCA(n_components=0.9)
        principalComponents_alpha = pca_alpha.fit_transform(alpha_data1)
        alpha_data1 = pd.DataFrame(data = principalComponents_alpha)
        data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.1,stratify=labels)

        
        pca_theta = PCA(n_components=0.9)
        principalComponents_theta = pca_theta.fit_transform(theta_data1)
        theta_data1 = pd.DataFrame(data = principalComponents_theta)
        data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.1,stratify=labels)



        pca_delta = PCA(n_components=0.9)
        principalComponents_delta = pca_delta.fit_transform(delta_data1)
        delta_data1 = pd.DataFrame(data = principalComponents_delta)
        data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.1,stratify=labels)


        pca_merged = PCA(n_components=0.9)
        principalComponents_merged = pca_merged.fit_transform(merged)
        merged = pd.DataFrame(data = principalComponents_merged)
        data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.1,stratify=labels)
    
        dtree1 = RandomForestClassifier(n_estimators=20000)
        dtree1.fit(data_train_gamma,label_train_gamma)
        predictions_gamma = dtree1.predict(data_test_gamma)
        results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

        dtree2 = RandomForestClassifier(n_estimators=20000)
        dtree2.fit(data_train_beta,label_train_beta)
        predictions_beta = dtree2.predict(data_test_beta)
        results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

        dtree3 = RandomForestClassifier(n_estimators=20000)
        dtree3.fit(data_train_alpha,label_train_alpha)
        predictions_alpha = dtree3.predict(data_test_alpha)
        results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

        dtree4 = RandomForestClassifier(n_estimators=20000)
        dtree4.fit(data_train_theta,label_train_theta)
        predictions_theta = dtree4.predict(data_test_theta)
        results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

        dtree5 = RandomForestClassifier(n_estimators=20000)
        dtree5.fit(data_train_delta,label_train_delta)
        predictions_delta = dtree5.predict(data_test_delta)
        results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

        dtree6 = RandomForestClassifier(n_estimators=20000)
        dtree6.fit(data_train_merged,label_train_merged)
        predictions_mereged = dtree6.predict(data_test_merged)
        results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))

# %%
mean_gama=0.0
mean_beta=0.0
mean_alpha=0.0
mean_theta=0.0
mean_delta=0.0
mean_merged=0.0

for i in results['result_gamma'] :
    mean_gama+=i['macro avg']['f1-score']
for i in results['result_beta'] :
    mean_beta+=i['macro avg']['f1-score']
for i in results['result_alpha'] :
    mean_alpha+=i['macro avg']['f1-score']
for i in results['result_theta'] :
    mean_theta+=i['macro avg']['f1-score']
for i in results['result_delta'] :
    mean_delta+=i['macro avg']['f1-score']
for i in results['result_merged'] :
    mean_merged+=i['macro avg']['f1-score']
print('mean gamma=',mean_gama/25,'mean beta=',mean_beta/25,'mean alpha =',mean_alpha/25,'mean theta =',mean_theta/25,'mean delta=',mean_delta/25,'mean combined =',mean_merged/25)
# Out:
# mean gamma= 0.5413703183141185 mean beta= 0.5461254535822797 mean alpha = 0.5116694984539536 mean theta = 0.5383920039359387 mean delta= 0.5213877447779255 mean combined = 0.5331290274768213

# %% [markdown]
# # splitting like paper

# %%
labels=[]
gamma_data1={
    "label":[],
    "username":[],
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
    "4thgamma":[],
    "5thgamma":[],
    "6thgamma":[],
    "7thgamma":[],
    "8thgamma":[],
    "9thgamma":[],
    "10thgamma":[],
    "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]}
beta_data1={
    "label":[],
    "username":[],
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
    "4thbeta":[],
    "5thbeta":[],
    "6thbeta":[],
    "7thbeta":[],
    "8thbeta":[],
    "9thbeta":[],
    "10thbeta":[],
    "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]}
alpha_data1={
    "label":[],
    "username":[],
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
    "4thalpha":[],
    "5thalpha":[],
    "6thalpha":[],
    "7thalpha":[],
    "8thalpha":[],
    "9thalpha":[],
    "10thalpha":[],
    "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]}
theta_data1={
    "label":[],
    "username":[],
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
    "4ththeta":[],
    "5ththeta":[],
    "6ththeta":[],
    "7ththeta":[],
    "8ththeta":[],
    "9ththeta":[],
    "10ththeta":[],
    "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]}
delta_data1={
    "label":[],
    "username":[],
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
    "4thdelta":[],
    "5thdelta":[],
    "6thdelta":[],
    "7thdelta":[],
    "8thdelta":[],
    "9thdelta":[],
    "10thdelta":[],
    "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]}


for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    
    for i in range(42):
        try:
            user_data = pd.read_csv("25-users/"+name+str(i+1)+".txt", sep=" ", header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
            user_label = pd.read_csv("labels/"+name+str(i+1)+".lab",header=None,names=["label"])
        except:
            continue
        labels.append(user_label.values.tolist()[0][0])
    
        gamma_data1['username'].append(name)
        beta_data1['username'].append(name)
        alpha_data1['username'].append(name)
        theta_data1['username'].append(name)
        delta_data1['username'].append(name)
        
        gamma_data1['label'].append(user_label.values.tolist()[0][0])
        beta_data1['label'].append(user_label.values.tolist()[0][0])
        alpha_data1['label'].append(user_label.values.tolist()[0][0])
        theta_data1['label'].append(user_label.values.tolist()[0][0])
        delta_data1['label'].append(user_label.values.tolist()[0][0])
        
        first_electrode = user_data['1st']
        second_electrode = user_data['2nd']
        third_electrode = user_data['3rd']
        fourth_electrode = user_data['4th']
        fifth_electrode = user_data['5th']
        sixth_electrode = user_data['6th']
        seventh_electrode = user_data['7th']
        eighth_electrode = user_data['8th']
        nineth_electrode = user_data['9th']
        tenth_electrode = user_data['10th']
        eleventh_electrode = user_data['11th']
        twelveth_electrode = user_data['12th']
        thirteenth_electrode = user_data['13th']
        fouteenth_electrode = user_data['14th']
        user_data.apply(lambda row : carf(row), axis = 1)

        first_electrode = user_data['1st']
        second_electrode = user_data['2nd']
        third_electrode = user_data['3rd']
        fourth_electrode = user_data['4th']
        fifth_electrode = user_data['5th']
        sixth_electrode = user_data['6th']
        seventh_electrode = user_data['7th']
        eighth_electrode = user_data['8th']
        nineth_electrode = user_data['9th']
        tenth_electrode = user_data['10th']
        eleventh_electrode = user_data['11th']
        twelveth_electrode = user_data['12th']
        thirteenth_electrode = user_data['13th']
        fouteenth_electrode = user_data['14th']

        s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
        s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
        s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
        s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
        s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
        s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
        s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
        s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
        s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
        s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
        s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
        s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
        s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
        s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


        cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
        cA12, d12 = pywt.dwt(cA1, 'db4')
        cA13, d13 = pywt.dwt(cA12, 'db4')
        a14, d14 = pywt.dwt(cA13, 'db4')
        gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
        beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
        alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
        theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
        delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
        gamma_data1['1stgamma'].append(gamma_RMS1)
        beta_data1['1stbeta'].append(beta_RMS1)
        alpha_data1['1stalpha'].append(alpha_RMS1)
        theta_data1['1sttheta'].append(theta_RMS1)
        delta_data1['1stdelta'].append(delta_RMS1)

        cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
        cA22, d22 = pywt.dwt(cA2, 'db4')
        cA23, d23 = pywt.dwt(cA22, 'db4')
        a24, d24 = pywt.dwt(cA23, 'db4')
        gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
        beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
        alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
        theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
        delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
        gamma_data1['2ndgamma'].append(gamma_RMS2)
        beta_data1['2ndbeta'].append(beta_RMS2)
        alpha_data1['2ndalpha'].append(alpha_RMS2)
        theta_data1['2ndtheta'].append(theta_RMS2)
        delta_data1['2nddelta'].append(delta_RMS2)

        cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
        cA32, d32 = pywt.dwt(cA3, 'db4')
        cA33, d33 = pywt.dwt(cA32, 'db4')
        a34, d34 = pywt.dwt(cA33, 'db4')
        gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
        beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
        alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
        theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
        delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
        gamma_data1['3rdgamma'].append(gamma_RMS3)
        beta_data1['3rdbeta'].append(beta_RMS3)
        alpha_data1['3rdalpha'].append(alpha_RMS3)
        theta_data1['3rdtheta'].append(theta_RMS3)
        delta_data1['3rddelta'].append(delta_RMS3)

        cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
        cA42, d42 = pywt.dwt(cA4, 'db4')
        cA43, d43 = pywt.dwt(cA42, 'db4')
        a44, d44 = pywt.dwt(cA43, 'db4')
        gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
        beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
        alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
        theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
        delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
        gamma_data1['4thgamma'].append(gamma_RMS4)
        beta_data1['4thbeta'].append(beta_RMS4)
        alpha_data1['4thalpha'].append(alpha_RMS4)
        theta_data1['4ththeta'].append(theta_RMS4)
        delta_data1['4thdelta'].append(delta_RMS4)

        cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
        cA52, d52 = pywt.dwt(cA5, 'db4')
        cA53, d53 = pywt.dwt(cA52, 'db4')
        a54, d54 = pywt.dwt(cA53, 'db4')
        gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
        beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
        alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
        theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
        delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
        gamma_data1['5thgamma'].append(gamma_RMS5)
        beta_data1['5thbeta'].append(beta_RMS5)
        alpha_data1['5thalpha'].append(alpha_RMS5)
        theta_data1['5ththeta'].append(theta_RMS5)
        delta_data1['5thdelta'].append(delta_RMS5)

        cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
        cA62, d62 = pywt.dwt(cA6, 'db4')
        cA63, d63 = pywt.dwt(cA62, 'db4')
        a64, d64 = pywt.dwt(cA63, 'db4')
        gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
        beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
        alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
        theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
        delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
        gamma_data1['6thgamma'].append(gamma_RMS6)
        beta_data1['6thbeta'].append(beta_RMS6)
        alpha_data1['6thalpha'].append(alpha_RMS6)
        theta_data1['6ththeta'].append(theta_RMS6)
        delta_data1['6thdelta'].append(delta_RMS6)


        cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
        cA72, d72 = pywt.dwt(cA7, 'db4')
        cA73, d73 = pywt.dwt(cA72, 'db4')
        a74, d74 = pywt.dwt(cA73, 'db4')
        gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
        beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
        alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
        theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
        delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
        gamma_data1['7thgamma'].append(gamma_RMS7)
        beta_data1['7thbeta'].append(beta_RMS7)
        alpha_data1['7thalpha'].append(alpha_RMS7)
        theta_data1['7ththeta'].append(theta_RMS7)
        delta_data1['7thdelta'].append(delta_RMS7)

        cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
        cA82, d82 = pywt.dwt(cA8, 'db4')
        cA83, d83 = pywt.dwt(cA82, 'db4')
        a84, d84 = pywt.dwt(cA83, 'db4')
        gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
        beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
        alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
        theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
        delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
        gamma_data1['8thgamma'].append(gamma_RMS8)
        beta_data1['8thbeta'].append(beta_RMS8)
        alpha_data1['8thalpha'].append(alpha_RMS8)
        theta_data1['8ththeta'].append(theta_RMS8)
        delta_data1['8thdelta'].append(delta_RMS8)

        cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
        cA92, d92 = pywt.dwt(cA9, 'db4')
        cA93, d93 = pywt.dwt(cA92, 'db4')
        a94, d94 = pywt.dwt(cA93, 'db4')
        gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
        beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
        alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
        theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
        delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
        gamma_data1['9thgamma'].append(gamma_RMS9)
        beta_data1['9thbeta'].append(beta_RMS9)
        alpha_data1['9thalpha'].append(alpha_RMS9)
        theta_data1['9ththeta'].append(theta_RMS9)
        delta_data1['9thdelta'].append(delta_RMS9)

        cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
        cA102, d102 = pywt.dwt(cA10, 'db4')
        cA103, d103 = pywt.dwt(cA102, 'db4')
        a104, d104 = pywt.dwt(cA103, 'db4')
        gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
        beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
        alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
        theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
        delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
        gamma_data1['10thgamma'].append(gamma_RMS10)
        beta_data1['10thbeta'].append(beta_RMS10)
        alpha_data1['10thalpha'].append(alpha_RMS10)
        theta_data1['10ththeta'].append(theta_RMS10)
        delta_data1['10thdelta'].append(delta_RMS10)

        cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
        cA112, d112 = pywt.dwt(cA11, 'db4')
        cA113, d113 = pywt.dwt(cA112, 'db4')
        a114, d114 = pywt.dwt(cA113, 'db4')
        gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
        beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
        alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
        theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
        delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
        gamma_data1['11thgamma'].append(gamma_RMS11)
        beta_data1['11thbeta'].append(beta_RMS11)
        alpha_data1['11thalpha'].append(alpha_RMS11)
        theta_data1['11ththeta'].append(theta_RMS11)
        delta_data1['11thdelta'].append(delta_RMS11)

        cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
        cA122, d122 = pywt.dwt(cA12, 'db4')
        cA123, d123 = pywt.dwt(cA122, 'db4')
        a124, d124 = pywt.dwt(cA123, 'db4')
        gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
        beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
        alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
        theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
        delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
        gamma_data1['12thgamma'].append(gamma_RMS12)
        beta_data1['12thbeta'].append(beta_RMS12)
        alpha_data1['12thalpha'].append(alpha_RMS12)
        theta_data1['12ththeta'].append(theta_RMS12)
        delta_data1['12thdelta'].append(delta_RMS12)

        cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
        cA132, d132 = pywt.dwt(cA13, 'db4')
        cA133, d133 = pywt.dwt(cA132, 'db4')
        a134, d134 = pywt.dwt(cA133, 'db4')
        gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
        beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
        alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
        theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
        delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
        gamma_data1['13thgamma'].append(gamma_RMS13)
        beta_data1['13thbeta'].append(beta_RMS13)
        alpha_data1['13thalpha'].append(alpha_RMS13)
        theta_data1['13ththeta'].append(theta_RMS13)
        delta_data1['13thdelta'].append(delta_RMS13)

        cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
        cA142, d142 = pywt.dwt(cA14, 'db4')
        cA143, d143 = pywt.dwt(cA142, 'db4')
        a144, d144 = pywt.dwt(cA143, 'db4')
        gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
        beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
        alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
        theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
        delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
        gamma_data1['14thgamma'].append(gamma_RMS14)
        beta_data1['14thbeta'].append(beta_RMS14)
        alpha_data1['14thalpha'].append(alpha_RMS14)
        theta_data1['14ththeta'].append(theta_RMS14)
        delta_data1['14thdelta'].append(delta_RMS14)
        
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
beta_data1=pd.DataFrame.from_dict(beta_data1)

# %%
results_mk={"result_theta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (theta_data1.loc[theta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = theta_data1.loc[theta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=20000)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_theta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean =0.0
for i in results_mk['result_theta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_theta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
    
print(mean/len(results_mk['result_theta']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.4513221504251918 0.6076555023923446 {'Disike': {'precision': 0.6086956521739131, 'recall': 0.6666666666666666, 'f1-score': 0.6363636363636365, 'support': 21}, 'Like': {'precision': 0.6111111111111112, 'recall': 0.55, 'f1-score': 0.5789473684210527, 'support': 20}, 'accuracy': 0.6097560975609756, 'macro avg': {'precision': 0.6099033816425121, 'recall': 0.6083333333333334, 'f1-score': 0.6076555023923446, 'support': 41}, 'weighted avg': {'precision': 0.6098739248262048, 'recall': 0.6097560975609756, 'f1-score': 0.6083557007818883, 'support': 41}} 1

# %%
results_mk={"result_gamma":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (gamma_data1.loc[gamma_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = gamma_data1.loc[gamma_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=20000)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_gamma'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean =0.0
for i in results_mk['result_gamma'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_gamma'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
    
print(mean/len(results_mk['result_gamma']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.4585828392936721 0.6111111111111112 {'Disike': {'precision': 0.9411764705882353, 'recall': 0.5161290322580645, 'f1-score': 0.6666666666666666, 'support': 31}, 'Like': {'precision': 0.4, 'recall': 0.9090909090909091, 'f1-score': 0.5555555555555556, 'support': 11}, 'accuracy': 0.6190476190476191, 'macro avg': {'precision': 0.6705882352941177, 'recall': 0.7126099706744868, 'f1-score': 0.6111111111111112, 'support': 42}, 'weighted avg': {'precision': 0.7994397759103642, 'recall': 0.6190476190476191, 'f1-score': 0.6375661375661374, 'support': 42}} 24

# %%
results_mk={"result_beta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (beta_data1.loc[beta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = beta_data1.loc[beta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=20000)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_beta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_beta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_beta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean += i['macro avg']['f1-score']
print(mean/len(results_mk['result_beta']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.46404640070730935 0.6755793226381461 {'Disike': {'precision': 0.7307692307692307, 'recall': 0.76, 'f1-score': 0.7450980392156863, 'support': 25}, 'Like': {'precision': 0.625, 'recall': 0.5882352941176471, 'f1-score': 0.6060606060606061, 'support': 17}, 'accuracy': 0.6904761904761905, 'macro avg': {'precision': 0.6778846153846154, 'recall': 0.6741176470588235, 'f1-score': 0.6755793226381461, 'support': 42}, 'weighted avg': {'precision': 0.6879578754578753, 'recall': 0.6904761904761905, 'f1-score': 0.68882098293863, 'support': 42}} 4

# %%
results_mk={"result_alpha":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (alpha_data1.loc[alpha_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = alpha_data1.loc[alpha_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=20000)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_alpha'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean = 0.0
for i in results_mk['result_alpha'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_alpha'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
print(mean/len(results_mk['result_alpha']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.42402653696370846 0.5851851851851853 {'Disike': {'precision': 0.6363636363636364, 'recall': 0.3684210526315789, 'f1-score': 0.4666666666666667, 'support': 19}, 'Like': {'precision': 0.6129032258064516, 'recall': 0.8260869565217391, 'f1-score': 0.7037037037037037, 'support': 23}, 'accuracy': 0.6190476190476191, 'macro avg': {'precision': 0.624633431085044, 'recall': 0.597254004576659, 'f1-score': 0.5851851851851853, 'support': 42}, 'weighted avg': {'precision': 0.623516268677559, 'recall': 0.6190476190476191, 'f1-score': 0.5964726631393299, 'support': 42}} 12

# %%
results_mk={"result_delta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (delta_data1.loc[delta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = delta_data1.loc[delta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=20000)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_delta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_delta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_delta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean +=i['macro avg']['f1-score'] 
print(mean/len(results_mk['result_delta']),maxx,j,k)
# Out:
# 0.4554145177012777 0.625668449197861 {'Disike': {'precision': 0.6923076923076923, 'recall': 0.72, 'f1-score': 0.7058823529411765, 'support': 25}, 'Like': {'precision': 0.5625, 'recall': 0.5294117647058824, 'f1-score': 0.5454545454545455, 'support': 17}, 'accuracy': 0.6428571428571429, 'macro avg': {'precision': 0.6274038461538461, 'recall': 0.6247058823529412, 'f1-score': 0.625668449197861, 'support': 42}, 'weighted avg': {'precision': 0.6397664835164835, 'recall': 0.6428571428571429, 'f1-score': 0.6409472880061116, 'support': 42}} 4

# %%
results_mk={"result_merged":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (merged.loc[merged['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = merged.loc[merged['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=20000)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_merged'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_merged'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_merged'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean += i['macro avg']['f1-score']
print(mean/len(results_mk['result_merged']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.44176190219420997 0.7367521367521368 {'Disike': {'precision': 0.7, 'recall': 0.7368421052631579, 'f1-score': 0.717948717948718, 'support': 19}, 'Like': {'precision': 0.7727272727272727, 'recall': 0.7391304347826086, 'f1-score': 0.7555555555555555, 'support': 23}, 'accuracy': 0.7380952380952381, 'macro avg': {'precision': 0.7363636363636363, 'recall': 0.7379862700228832, 'f1-score': 0.7367521367521368, 'support': 42}, 'weighted avg': {'precision': 0.7398268398268397, 'recall': 0.7380952380952381, 'f1-score': 0.7385429385429385, 'support': 42}} 18

# %%
labels=[]
gamma_data1={
    "label":[],
    "username":[],
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
    "4thgamma":[],
    "5thgamma":[],
    "6thgamma":[],
    "7thgamma":[],
    "8thgamma":[],
    "9thgamma":[],
    "10thgamma":[],
    "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]}
beta_data1={
    "label":[],
    "username":[],
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
    "4thbeta":[],
    "5thbeta":[],
    "6thbeta":[],
    "7thbeta":[],
    "8thbeta":[],
    "9thbeta":[],
    "10thbeta":[],
    "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]}
alpha_data1={
    "label":[],
    "username":[],
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
    "4thalpha":[],
    "5thalpha":[],
    "6thalpha":[],
    "7thalpha":[],
    "8thalpha":[],
    "9thalpha":[],
    "10thalpha":[],
    "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]}
theta_data1={
    "label":[],
    "username":[],
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
    "4ththeta":[],
    "5ththeta":[],
    "6ththeta":[],
    "7ththeta":[],
    "8ththeta":[],
    "9ththeta":[],
    "10ththeta":[],
    "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]}
delta_data1={
    "label":[],
    "username":[],
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
    "4thdelta":[],
    "5thdelta":[],
    "6thdelta":[],
    "7thdelta":[],
    "8thdelta":[],
    "9thdelta":[],
    "10thdelta":[],
    "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]}


for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    
    for i in range(42):
        try:
            user_data = pd.read_csv("25-users/"+name+str(i+1)+".txt", sep=" ", header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
            user_label = pd.read_csv("labels/"+name+str(i+1)+".lab",header=None,names=["label"])
        except:
            continue
        labels.append(user_label.values.tolist()[0][0])
    
        gamma_data1['username'].append(name)
        beta_data1['username'].append(name)
        alpha_data1['username'].append(name)
        theta_data1['username'].append(name)
        delta_data1['username'].append(name)
        
        gamma_data1['label'].append(user_label.values.tolist()[0][0])
        beta_data1['label'].append(user_label.values.tolist()[0][0])
        alpha_data1['label'].append(user_label.values.tolist()[0][0])
        theta_data1['label'].append(user_label.values.tolist()[0][0])
        delta_data1['label'].append(user_label.values.tolist()[0][0])
        
        first_electrode = user_data['1st']
        second_electrode = user_data['2nd']
        third_electrode = user_data['3rd']
        fourth_electrode = user_data['4th']
        fifth_electrode = user_data['5th']
        sixth_electrode = user_data['6th']
        seventh_electrode = user_data['7th']
        eighth_electrode = user_data['8th']
        nineth_electrode = user_data['9th']
        tenth_electrode = user_data['10th']
        eleventh_electrode = user_data['11th']
        twelveth_electrode = user_data['12th']
        thirteenth_electrode = user_data['13th']
        fouteenth_electrode = user_data['14th']
        user_data.apply(lambda row : carf(row), axis = 1)

        first_electrode = user_data['1st']
        second_electrode = user_data['2nd']
        third_electrode = user_data['3rd']
        fourth_electrode = user_data['4th']
        fifth_electrode = user_data['5th']
        sixth_electrode = user_data['6th']
        seventh_electrode = user_data['7th']
        eighth_electrode = user_data['8th']
        nineth_electrode = user_data['9th']
        tenth_electrode = user_data['10th']
        eleventh_electrode = user_data['11th']
        twelveth_electrode = user_data['12th']
        thirteenth_electrode = user_data['13th']
        fouteenth_electrode = user_data['14th']

        s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
        s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
        s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
        s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
        s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
        s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
        s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
        s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
        s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
        s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
        s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
        s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
        s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
        s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


        cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
        cA12, d12 = pywt.dwt(cA1, 'db4')
        cA13, d13 = pywt.dwt(cA12, 'db4')
        a14, d14 = pywt.dwt(cA13, 'db4')
        gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
        beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
        alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
        theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
        delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
        gamma_data1['1stgamma'].append(gamma_RMS1)
        beta_data1['1stbeta'].append(beta_RMS1)
        alpha_data1['1stalpha'].append(alpha_RMS1)
        theta_data1['1sttheta'].append(theta_RMS1)
        delta_data1['1stdelta'].append(delta_RMS1)

        cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
        cA22, d22 = pywt.dwt(cA2, 'db4')
        cA23, d23 = pywt.dwt(cA22, 'db4')
        a24, d24 = pywt.dwt(cA23, 'db4')
        gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
        beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
        alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
        theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
        delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
        gamma_data1['2ndgamma'].append(gamma_RMS2)
        beta_data1['2ndbeta'].append(beta_RMS2)
        alpha_data1['2ndalpha'].append(alpha_RMS2)
        theta_data1['2ndtheta'].append(theta_RMS2)
        delta_data1['2nddelta'].append(delta_RMS2)

        cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
        cA32, d32 = pywt.dwt(cA3, 'db4')
        cA33, d33 = pywt.dwt(cA32, 'db4')
        a34, d34 = pywt.dwt(cA33, 'db4')
        gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
        beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
        alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
        theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
        delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
        gamma_data1['3rdgamma'].append(gamma_RMS3)
        beta_data1['3rdbeta'].append(beta_RMS3)
        alpha_data1['3rdalpha'].append(alpha_RMS3)
        theta_data1['3rdtheta'].append(theta_RMS3)
        delta_data1['3rddelta'].append(delta_RMS3)

        cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
        cA42, d42 = pywt.dwt(cA4, 'db4')
        cA43, d43 = pywt.dwt(cA42, 'db4')
        a44, d44 = pywt.dwt(cA43, 'db4')
        gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
        beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
        alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
        theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
        delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
        gamma_data1['4thgamma'].append(gamma_RMS4)
        beta_data1['4thbeta'].append(beta_RMS4)
        alpha_data1['4thalpha'].append(alpha_RMS4)
        theta_data1['4ththeta'].append(theta_RMS4)
        delta_data1['4thdelta'].append(delta_RMS4)

        cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
        cA52, d52 = pywt.dwt(cA5, 'db4')
        cA53, d53 = pywt.dwt(cA52, 'db4')
        a54, d54 = pywt.dwt(cA53, 'db4')
        gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
        beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
        alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
        theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
        delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
        gamma_data1['5thgamma'].append(gamma_RMS5)
        beta_data1['5thbeta'].append(beta_RMS5)
        alpha_data1['5thalpha'].append(alpha_RMS5)
        theta_data1['5ththeta'].append(theta_RMS5)
        delta_data1['5thdelta'].append(delta_RMS5)

        cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
        cA62, d62 = pywt.dwt(cA6, 'db4')
        cA63, d63 = pywt.dwt(cA62, 'db4')
        a64, d64 = pywt.dwt(cA63, 'db4')
        gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
        beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
        alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
        theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
        delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
        gamma_data1['6thgamma'].append(gamma_RMS6)
        beta_data1['6thbeta'].append(beta_RMS6)
        alpha_data1['6thalpha'].append(alpha_RMS6)
        theta_data1['6ththeta'].append(theta_RMS6)
        delta_data1['6thdelta'].append(delta_RMS6)


        cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
        cA72, d72 = pywt.dwt(cA7, 'db4')
        cA73, d73 = pywt.dwt(cA72, 'db4')
        a74, d74 = pywt.dwt(cA73, 'db4')
        gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
        beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
        alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
        theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
        delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
        gamma_data1['7thgamma'].append(gamma_RMS7)
        beta_data1['7thbeta'].append(beta_RMS7)
        alpha_data1['7thalpha'].append(alpha_RMS7)
        theta_data1['7ththeta'].append(theta_RMS7)
        delta_data1['7thdelta'].append(delta_RMS7)

        cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
        cA82, d82 = pywt.dwt(cA8, 'db4')
        cA83, d83 = pywt.dwt(cA82, 'db4')
        a84, d84 = pywt.dwt(cA83, 'db4')
        gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
        beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
        alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
        theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
        delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
        gamma_data1['8thgamma'].append(gamma_RMS8)
        beta_data1['8thbeta'].append(beta_RMS8)
        alpha_data1['8thalpha'].append(alpha_RMS8)
        theta_data1['8ththeta'].append(theta_RMS8)
        delta_data1['8thdelta'].append(delta_RMS8)

        cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
        cA92, d92 = pywt.dwt(cA9, 'db4')
        cA93, d93 = pywt.dwt(cA92, 'db4')
        a94, d94 = pywt.dwt(cA93, 'db4')
        gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
        beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
        alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
        theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
        delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
        gamma_data1['9thgamma'].append(gamma_RMS9)
        beta_data1['9thbeta'].append(beta_RMS9)
        alpha_data1['9thalpha'].append(alpha_RMS9)
        theta_data1['9ththeta'].append(theta_RMS9)
        delta_data1['9thdelta'].append(delta_RMS9)

        cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
        cA102, d102 = pywt.dwt(cA10, 'db4')
        cA103, d103 = pywt.dwt(cA102, 'db4')
        a104, d104 = pywt.dwt(cA103, 'db4')
        gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
        beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
        alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
        theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
        delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
        gamma_data1['10thgamma'].append(gamma_RMS10)
        beta_data1['10thbeta'].append(beta_RMS10)
        alpha_data1['10thalpha'].append(alpha_RMS10)
        theta_data1['10ththeta'].append(theta_RMS10)
        delta_data1['10thdelta'].append(delta_RMS10)

        cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
        cA112, d112 = pywt.dwt(cA11, 'db4')
        cA113, d113 = pywt.dwt(cA112, 'db4')
        a114, d114 = pywt.dwt(cA113, 'db4')
        gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
        beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
        alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
        theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
        delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
        gamma_data1['11thgamma'].append(gamma_RMS11)
        beta_data1['11thbeta'].append(beta_RMS11)
        alpha_data1['11thalpha'].append(alpha_RMS11)
        theta_data1['11ththeta'].append(theta_RMS11)
        delta_data1['11thdelta'].append(delta_RMS11)

        cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
        cA122, d122 = pywt.dwt(cA12, 'db4')
        cA123, d123 = pywt.dwt(cA122, 'db4')
        a124, d124 = pywt.dwt(cA123, 'db4')
        gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
        beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
        alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
        theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
        delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
        gamma_data1['12thgamma'].append(gamma_RMS12)
        beta_data1['12thbeta'].append(beta_RMS12)
        alpha_data1['12thalpha'].append(alpha_RMS12)
        theta_data1['12ththeta'].append(theta_RMS12)
        delta_data1['12thdelta'].append(delta_RMS12)

        cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
        cA132, d132 = pywt.dwt(cA13, 'db4')
        cA133, d133 = pywt.dwt(cA132, 'db4')
        a134, d134 = pywt.dwt(cA133, 'db4')
        gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
        beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
        alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
        theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
        delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
        gamma_data1['13thgamma'].append(gamma_RMS13)
        beta_data1['13thbeta'].append(beta_RMS13)
        alpha_data1['13thalpha'].append(alpha_RMS13)
        theta_data1['13ththeta'].append(theta_RMS13)
        delta_data1['13thdelta'].append(delta_RMS13)

        cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
        cA142, d142 = pywt.dwt(cA14, 'db4')
        cA143, d143 = pywt.dwt(cA142, 'db4')
        a144, d144 = pywt.dwt(cA143, 'db4')
        gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
        beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
        alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
        theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
        delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
        gamma_data1['14thgamma'].append(gamma_RMS14)
        beta_data1['14thbeta'].append(beta_RMS14)
        alpha_data1['14thalpha'].append(alpha_RMS14)
        theta_data1['14ththeta'].append(theta_RMS14)
        delta_data1['14thdelta'].append(delta_RMS14)
        
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
beta_data1=pd.DataFrame.from_dict(beta_data1)
standard_gamma = StandardScaler().fit_transform(gamma_data1.drop(['username','label'],axis=1)) 
normalised_gamma = pd.DataFrame(standard_gamma)
pca_gamma = PCA(n_components=0.9)
principalComponents_gamma = pca_gamma.fit_transform(standard_gamma)
gamma_data11 = pd.DataFrame(data = principalComponents_gamma)
gamma_data11['label']=gamma_data1['label']
gamma_data11['username']=gamma_data1['username']
gamma_data1=gamma_data11


standard_beta = StandardScaler().fit_transform(beta_data1.drop(['username','label'],axis=1)) 
normalised_beta = pd.DataFrame(standard_beta)
pca_beta = PCA(n_components=0.9)
principalComponents_beta = pca_beta.fit_transform(standard_beta)
beta_data11 = pd.DataFrame(data = principalComponents_beta)
beta_data11['label']=beta_data1['label']
beta_data11['username']=beta_data1['username']
beta_data1=beta_data11

standard_alpha = StandardScaler().fit_transform(alpha_data1.drop(['username','label'],axis=1)) 
normalised_alpha = pd.DataFrame(standard_alpha)
pca_alpha = PCA(n_components=0.9)
principalComponents_alpha = pca_alpha.fit_transform(standard_alpha)
alpha_data11 = pd.DataFrame(data = principalComponents_alpha)
alpha_data11['label']=alpha_data1['label']
alpha_data11['username']=alpha_data1['username']
alpha_data1=alpha_data11

standard_theta = StandardScaler().fit_transform(theta_data1.drop(['username','label'],axis=1)) 
normalised_theta = pd.DataFrame(standard_theta)
pca_theta = PCA(n_components=0.9)
principalComponents_theta = pca_theta.fit_transform(standard_theta)
theta_data11 = pd.DataFrame(data = principalComponents_theta)
theta_data11['label']=theta_data1['label']
theta_data11['username']=theta_data1['username']
theta_data1=theta_data11

standard_delta = StandardScaler().fit_transform(delta_data1.drop(['username','label'],axis=1)) 
normalised_delta = pd.DataFrame(standard_delta)
pca_delta = PCA(n_components=0.9)
principalComponents_delta = pca_delta.fit_transform(standard_delta)
delta_data11 = pd.DataFrame(data = principalComponents_delta)
delta_data11['label']=delta_data1['label']
delta_data11['username']=delta_data1['username']
delta_data1=delta_data11

standard_merged = StandardScaler().fit_transform(merged.drop(['username','label'],axis=1)) 
normalised_merged = pd.DataFrame(standard_merged)
pca_merged = PCA(n_components=0.9)
principalComponents_merged = pca_merged.fit_transform(standard_merged)
merged1 = pd.DataFrame(data = principalComponents_merged)
merged1['label']=merged['label']
merged1['username']=merged['username']
merged=merged1

# %%
print(gamma_data1)
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.556613 -0.305458 -0.413547 -0.514605 -0.307827  0.162678  0.229711
# 1    -0.853127 -0.040367  0.092093 -0.323563  0.054494  0.198460  0.235446
# 2     1.014624 -0.578670  0.046324 -1.753536 -1.024093  2.273014  1.306454
# 3     0.361528  1.567975 -0.983194 -2.084245  1.156332  0.773725  0.960362
# 4     0.896400 -0.236523 -0.195358 -1.196587 -0.743103  1.711781  1.045948
# ...        ...       ...       ...       ...       ...       ...       ...
# 1040 -1.546491 -0.039128 -0.059989 -0.404780  0.019934  0.298817  0.140612
# 1041 -1.785600  0.063254 -0.091529 -0.275841  0.104785  0.192205  0.101318
# 1042 -1.712626  0.023181 -0.034578 -0.274168  0.056874  0.209421  0.109498
# 1043 -1.467598  0.084743 -0.261495 -0.483052  0.087799  0.118546  0.155017
# 1044 -1.700707 -0.079329 -0.063504 -0.352305 -0.050872  0.301946  0.106676
#
#        label   username
# 0       Like  Abhishek_
# 1       Like  Abhishek_
# 2     Disike  Abhishek_
# 3       Like  Abhishek_
# 4     Disike  Abhishek_
# ...      ...        ...
# 1040    Like   Viraj_1_
# 1041  Disike   Viraj_1_
# 1042    Like   Viraj_1_
# 1043  Disike   Viraj_1_
# 1044  Disike   Viraj_1_
#
# [1045 rows x 9 columns]

# %%
results_mk={"result_theta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (theta_data1.loc[theta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = theta_data1.loc[theta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=20000)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_theta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean =0.0
for i in results_mk['result_theta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_theta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
    
print(mean/len(results_mk['result_theta']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.48191195680127835 0.7071428571428571 {'Disike': {'precision': 0.7368421052631579, 'recall': 0.6666666666666666, 'f1-score': 0.7, 'support': 21}, 'Like': {'precision': 0.6818181818181818, 'recall': 0.75, 'f1-score': 0.7142857142857143, 'support': 20}, 'accuracy': 0.7073170731707317, 'macro avg': {'precision': 0.7093301435406698, 'recall': 0.7083333333333333, 'f1-score': 0.7071428571428571, 'support': 41}, 'weighted avg': {'precision': 0.7100011669973159, 'recall': 0.7073170731707317, 'f1-score': 0.7069686411149826, 'support': 41}} 1

# %%
results_mk={"result_gamma":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (gamma_data1.loc[gamma_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = gamma_data1.loc[gamma_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=20000)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_gamma'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean =0.0
for i in results_mk['result_gamma'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_gamma'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
    
print(mean/len(results_mk['result_gamma']),maxx,j,k)
# Out:
# 0.4820838567655169 0.6050156739811912 {'Disike': {'precision': 0.8333333333333334, 'recall': 0.6451612903225806, 'f1-score': 0.7272727272727272, 'support': 31}, 'Like': {'precision': 0.3888888888888889, 'recall': 0.6363636363636364, 'f1-score': 0.4827586206896552, 'support': 11}, 'accuracy': 0.6428571428571429, 'macro avg': {'precision': 0.6111111111111112, 'recall': 0.6407624633431085, 'f1-score': 0.6050156739811912, 'support': 42}, 'weighted avg': {'precision': 0.716931216931217, 'recall': 0.6428571428571429, 'f1-score': 0.6632333184057322, 'support': 42}} 24

# %%
results_mk={"result_beta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (beta_data1.loc[beta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = beta_data1.loc[beta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=20000)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_beta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_beta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_beta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean += i['macro avg']['f1-score']
print(mean/len(results_mk['result_beta']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.44575581369278977 0.6190476190476191 {'Disike': {'precision': 0.5652173913043478, 'recall': 0.6842105263157895, 'f1-score': 0.6190476190476191, 'support': 19}, 'Like': {'precision': 0.6842105263157895, 'recall': 0.5652173913043478, 'f1-score': 0.6190476190476191, 'support': 23}, 'accuracy': 0.6190476190476191, 'macro avg': {'precision': 0.6247139588100686, 'recall': 0.6247139588100686, 'f1-score': 0.6190476190476191, 'support': 42}, 'weighted avg': {'precision': 0.6303802985725182, 'recall': 0.6190476190476191, 'f1-score': 0.6190476190476191, 'support': 42}} 18

# %%
results_mk={"result_alpha":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (alpha_data1.loc[alpha_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = alpha_data1.loc[alpha_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=20000)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_alpha'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean = 0.0
for i in results_mk['result_alpha'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_alpha'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
print(mean/len(results_mk['result_alpha']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.45065083455513616 0.6111111111111112 {'Disike': {'precision': 0.7619047619047619, 'recall': 0.5925925925925926, 'f1-score': 0.6666666666666666, 'support': 27}, 'Like': {'precision': 0.47619047619047616, 'recall': 0.6666666666666666, 'f1-score': 0.5555555555555556, 'support': 15}, 'accuracy': 0.6190476190476191, 'macro avg': {'precision': 0.6190476190476191, 'recall': 0.6296296296296295, 'f1-score': 0.6111111111111112, 'support': 42}, 'weighted avg': {'precision': 0.6598639455782312, 'recall': 0.6190476190476191, 'f1-score': 0.6269841269841271, 'support': 42}} 3

# %%
results_mk={"result_delta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (delta_data1.loc[delta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = delta_data1.loc[delta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=20000)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_delta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_delta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_delta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean +=i['macro avg']['f1-score'] 
print(mean/len(results_mk['result_delta']),maxx,j,k)
# Out:
# 0.44613291400632454 0.6181818181818182 {'Disike': {'precision': 0.6086956521739131, 'recall': 0.6666666666666666, 'f1-score': 0.6363636363636365, 'support': 21}, 'Like': {'precision': 0.631578947368421, 'recall': 0.5714285714285714, 'f1-score': 0.6, 'support': 21}, 'accuracy': 0.6190476190476191, 'macro avg': {'precision': 0.620137299771167, 'recall': 0.6190476190476191, 'f1-score': 0.6181818181818182, 'support': 42}, 'weighted avg': {'precision': 0.620137299771167, 'recall': 0.6190476190476191, 'f1-score': 0.6181818181818182, 'support': 42}} 23

# %%
results_mk={"result_merged":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (merged.loc[merged['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = merged.loc[merged['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=20000)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_merged'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_merged'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_merged'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean += i['macro avg']['f1-score']
print(mean/len(results_mk['result_merged']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.45710205368514534 0.690300623936472 {'Disike': {'precision': 0.6363636363636364, 'recall': 0.7368421052631579, 'f1-score': 0.6829268292682926, 'support': 19}, 'Like': {'precision': 0.75, 'recall': 0.6521739130434783, 'f1-score': 0.6976744186046512, 'support': 23}, 'accuracy': 0.6904761904761905, 'macro avg': {'precision': 0.6931818181818181, 'recall': 0.694508009153318, 'f1-score': 0.690300623936472, 'support': 42}, 'weighted avg': {'precision': 0.6985930735930735, 'recall': 0.6904761904761905, 'f1-score': 0.6910028900953461, 'support': 42}} 18

# %%
labels=[]
gamma_data1={
    "label":[],
    "username":[],
    "1stgamma":[],
    "2ndgamma":[],
    "3rdgamma":[],
    "4thgamma":[],
    "5thgamma":[],
    "6thgamma":[],
    "7thgamma":[],
    "8thgamma":[],
    "9thgamma":[],
    "10thgamma":[],
    "11thgamma":[],
    "12thgamma":[],
    "13thgamma":[],
    "14thgamma":[]}
beta_data1={
    "label":[],
    "username":[],
    "1stbeta":[],
    "2ndbeta":[],
    "3rdbeta":[],
    "4thbeta":[],
    "5thbeta":[],
    "6thbeta":[],
    "7thbeta":[],
    "8thbeta":[],
    "9thbeta":[],
    "10thbeta":[],
    "11thbeta":[],
    "12thbeta":[],
    "13thbeta":[],
    "14thbeta":[]}
alpha_data1={
    "label":[],
    "username":[],
    "1stalpha":[],
    "2ndalpha":[],
    "3rdalpha":[],
    "4thalpha":[],
    "5thalpha":[],
    "6thalpha":[],
    "7thalpha":[],
    "8thalpha":[],
    "9thalpha":[],
    "10thalpha":[],
    "11thalpha":[],
    "12thalpha":[],
    "13thalpha":[],
    "14thalpha":[]}
theta_data1={
    "label":[],
    "username":[],
    "1sttheta":[],
    "2ndtheta":[],
    "3rdtheta":[],
    "4ththeta":[],
    "5ththeta":[],
    "6ththeta":[],
    "7ththeta":[],
    "8ththeta":[],
    "9ththeta":[],
    "10ththeta":[],
    "11ththeta":[],
    "12ththeta":[],
    "13ththeta":[],
    "14ththeta":[]}
delta_data1={
    "label":[],
    "username":[],
    "1stdelta":[],
    "2nddelta":[],
    "3rddelta":[],
    "4thdelta":[],
    "5thdelta":[],
    "6thdelta":[],
    "7thdelta":[],
    "8thdelta":[],
    "9thdelta":[],
    "10thdelta":[],
    "11thdelta":[],
    "12thdelta":[],
    "13thdelta":[],
    "14thdelta":[]}


for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    
    for i in range(42):
        try:
            user_data = pd.read_csv("25-users/"+name+str(i+1)+".txt", sep=" ", header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
            user_label = pd.read_csv("labels/"+name+str(i+1)+".lab",header=None,names=["label"])
        except:
            continue
        labels.append(user_label.values.tolist()[0][0])
    
        gamma_data1['username'].append(name)
        beta_data1['username'].append(name)
        alpha_data1['username'].append(name)
        theta_data1['username'].append(name)
        delta_data1['username'].append(name)
        
        gamma_data1['label'].append(user_label.values.tolist()[0][0])
        beta_data1['label'].append(user_label.values.tolist()[0][0])
        alpha_data1['label'].append(user_label.values.tolist()[0][0])
        theta_data1['label'].append(user_label.values.tolist()[0][0])
        delta_data1['label'].append(user_label.values.tolist()[0][0])
        
        first_electrode = user_data['1st']
        second_electrode = user_data['2nd']
        third_electrode = user_data['3rd']
        fourth_electrode = user_data['4th']
        fifth_electrode = user_data['5th']
        sixth_electrode = user_data['6th']
        seventh_electrode = user_data['7th']
        eighth_electrode = user_data['8th']
        nineth_electrode = user_data['9th']
        tenth_electrode = user_data['10th']
        eleventh_electrode = user_data['11th']
        twelveth_electrode = user_data['12th']
        thirteenth_electrode = user_data['13th']
        fouteenth_electrode = user_data['14th']
        user_data.apply(lambda row : carf(row), axis = 1)

        first_electrode = user_data['1st']
        second_electrode = user_data['2nd']
        third_electrode = user_data['3rd']
        fourth_electrode = user_data['4th']
        fifth_electrode = user_data['5th']
        sixth_electrode = user_data['6th']
        seventh_electrode = user_data['7th']
        eighth_electrode = user_data['8th']
        nineth_electrode = user_data['9th']
        tenth_electrode = user_data['10th']
        eleventh_electrode = user_data['11th']
        twelveth_electrode = user_data['12th']
        thirteenth_electrode = user_data['13th']
        fouteenth_electrode = user_data['14th']

        s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
        s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
        s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
        s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
        s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
        s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
        s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
        s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
        s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
        s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
        s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
        s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
        s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
        s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


        cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
        cA12, d12 = pywt.dwt(cA1, 'db4')
        cA13, d13 = pywt.dwt(cA12, 'db4')
        a14, d14 = pywt.dwt(cA13, 'db4')
        gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
        beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
        alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
        theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
        delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
        gamma_data1['1stgamma'].append(gamma_RMS1)
        beta_data1['1stbeta'].append(beta_RMS1)
        alpha_data1['1stalpha'].append(alpha_RMS1)
        theta_data1['1sttheta'].append(theta_RMS1)
        delta_data1['1stdelta'].append(delta_RMS1)

        cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
        cA22, d22 = pywt.dwt(cA2, 'db4')
        cA23, d23 = pywt.dwt(cA22, 'db4')
        a24, d24 = pywt.dwt(cA23, 'db4')
        gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
        beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
        alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
        theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
        delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
        gamma_data1['2ndgamma'].append(gamma_RMS2)
        beta_data1['2ndbeta'].append(beta_RMS2)
        alpha_data1['2ndalpha'].append(alpha_RMS2)
        theta_data1['2ndtheta'].append(theta_RMS2)
        delta_data1['2nddelta'].append(delta_RMS2)

        cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
        cA32, d32 = pywt.dwt(cA3, 'db4')
        cA33, d33 = pywt.dwt(cA32, 'db4')
        a34, d34 = pywt.dwt(cA33, 'db4')
        gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
        beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
        alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
        theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
        delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
        gamma_data1['3rdgamma'].append(gamma_RMS3)
        beta_data1['3rdbeta'].append(beta_RMS3)
        alpha_data1['3rdalpha'].append(alpha_RMS3)
        theta_data1['3rdtheta'].append(theta_RMS3)
        delta_data1['3rddelta'].append(delta_RMS3)

        cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
        cA42, d42 = pywt.dwt(cA4, 'db4')
        cA43, d43 = pywt.dwt(cA42, 'db4')
        a44, d44 = pywt.dwt(cA43, 'db4')
        gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
        beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
        alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
        theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
        delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
        gamma_data1['4thgamma'].append(gamma_RMS4)
        beta_data1['4thbeta'].append(beta_RMS4)
        alpha_data1['4thalpha'].append(alpha_RMS4)
        theta_data1['4ththeta'].append(theta_RMS4)
        delta_data1['4thdelta'].append(delta_RMS4)

        cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
        cA52, d52 = pywt.dwt(cA5, 'db4')
        cA53, d53 = pywt.dwt(cA52, 'db4')
        a54, d54 = pywt.dwt(cA53, 'db4')
        gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
        beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
        alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
        theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
        delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
        gamma_data1['5thgamma'].append(gamma_RMS5)
        beta_data1['5thbeta'].append(beta_RMS5)
        alpha_data1['5thalpha'].append(alpha_RMS5)
        theta_data1['5ththeta'].append(theta_RMS5)
        delta_data1['5thdelta'].append(delta_RMS5)

        cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
        cA62, d62 = pywt.dwt(cA6, 'db4')
        cA63, d63 = pywt.dwt(cA62, 'db4')
        a64, d64 = pywt.dwt(cA63, 'db4')
        gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
        beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
        alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
        theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
        delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
        gamma_data1['6thgamma'].append(gamma_RMS6)
        beta_data1['6thbeta'].append(beta_RMS6)
        alpha_data1['6thalpha'].append(alpha_RMS6)
        theta_data1['6ththeta'].append(theta_RMS6)
        delta_data1['6thdelta'].append(delta_RMS6)


        cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
        cA72, d72 = pywt.dwt(cA7, 'db4')
        cA73, d73 = pywt.dwt(cA72, 'db4')
        a74, d74 = pywt.dwt(cA73, 'db4')
        gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
        beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
        alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
        theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
        delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
        gamma_data1['7thgamma'].append(gamma_RMS7)
        beta_data1['7thbeta'].append(beta_RMS7)
        alpha_data1['7thalpha'].append(alpha_RMS7)
        theta_data1['7ththeta'].append(theta_RMS7)
        delta_data1['7thdelta'].append(delta_RMS7)

        cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
        cA82, d82 = pywt.dwt(cA8, 'db4')
        cA83, d83 = pywt.dwt(cA82, 'db4')
        a84, d84 = pywt.dwt(cA83, 'db4')
        gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
        beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
        alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
        theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
        delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
        gamma_data1['8thgamma'].append(gamma_RMS8)
        beta_data1['8thbeta'].append(beta_RMS8)
        alpha_data1['8thalpha'].append(alpha_RMS8)
        theta_data1['8ththeta'].append(theta_RMS8)
        delta_data1['8thdelta'].append(delta_RMS8)

        cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
        cA92, d92 = pywt.dwt(cA9, 'db4')
        cA93, d93 = pywt.dwt(cA92, 'db4')
        a94, d94 = pywt.dwt(cA93, 'db4')
        gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
        beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
        alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
        theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
        delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
        gamma_data1['9thgamma'].append(gamma_RMS9)
        beta_data1['9thbeta'].append(beta_RMS9)
        alpha_data1['9thalpha'].append(alpha_RMS9)
        theta_data1['9ththeta'].append(theta_RMS9)
        delta_data1['9thdelta'].append(delta_RMS9)

        cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
        cA102, d102 = pywt.dwt(cA10, 'db4')
        cA103, d103 = pywt.dwt(cA102, 'db4')
        a104, d104 = pywt.dwt(cA103, 'db4')
        gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
        beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
        alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
        theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
        delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
        gamma_data1['10thgamma'].append(gamma_RMS10)
        beta_data1['10thbeta'].append(beta_RMS10)
        alpha_data1['10thalpha'].append(alpha_RMS10)
        theta_data1['10ththeta'].append(theta_RMS10)
        delta_data1['10thdelta'].append(delta_RMS10)

        cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
        cA112, d112 = pywt.dwt(cA11, 'db4')
        cA113, d113 = pywt.dwt(cA112, 'db4')
        a114, d114 = pywt.dwt(cA113, 'db4')
        gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
        beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
        alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
        theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
        delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
        gamma_data1['11thgamma'].append(gamma_RMS11)
        beta_data1['11thbeta'].append(beta_RMS11)
        alpha_data1['11thalpha'].append(alpha_RMS11)
        theta_data1['11ththeta'].append(theta_RMS11)
        delta_data1['11thdelta'].append(delta_RMS11)

        cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
        cA122, d122 = pywt.dwt(cA12, 'db4')
        cA123, d123 = pywt.dwt(cA122, 'db4')
        a124, d124 = pywt.dwt(cA123, 'db4')
        gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
        beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
        alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
        theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
        delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
        gamma_data1['12thgamma'].append(gamma_RMS12)
        beta_data1['12thbeta'].append(beta_RMS12)
        alpha_data1['12thalpha'].append(alpha_RMS12)
        theta_data1['12ththeta'].append(theta_RMS12)
        delta_data1['12thdelta'].append(delta_RMS12)

        cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
        cA132, d132 = pywt.dwt(cA13, 'db4')
        cA133, d133 = pywt.dwt(cA132, 'db4')
        a134, d134 = pywt.dwt(cA133, 'db4')
        gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
        beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
        alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
        theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
        delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
        gamma_data1['13thgamma'].append(gamma_RMS13)
        beta_data1['13thbeta'].append(beta_RMS13)
        alpha_data1['13thalpha'].append(alpha_RMS13)
        theta_data1['13ththeta'].append(theta_RMS13)
        delta_data1['13thdelta'].append(delta_RMS13)

        cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
        cA142, d142 = pywt.dwt(cA14, 'db4')
        cA143, d143 = pywt.dwt(cA142, 'db4')
        a144, d144 = pywt.dwt(cA143, 'db4')
        gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
        beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
        alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
        theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
        delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
        gamma_data1['14thgamma'].append(gamma_RMS14)
        beta_data1['14thbeta'].append(beta_RMS14)
        alpha_data1['14thalpha'].append(alpha_RMS14)
        theta_data1['14ththeta'].append(theta_RMS14)
        delta_data1['14thdelta'].append(delta_RMS14)
        
gamma_data1=pd.DataFrame.from_dict(gamma_data1)
theta_data1=pd.DataFrame.from_dict(theta_data1)
alpha_data1=pd.DataFrame.from_dict(alpha_data1)
delta_data1=pd.DataFrame.from_dict(delta_data1)
merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
merged= pd.DataFrame.from_dict(merged)
beta_data1=pd.DataFrame.from_dict(beta_data1)


pca_gamma = PCA(n_components=0.9)
principalComponents_gamma = pca_gamma.fit_transform(gamma_data1.drop(['username','label'],axis=1))
gamma_data11 = pd.DataFrame(data = principalComponents_gamma)
gamma_data11['label']=gamma_data1['label']
gamma_data11['username']=gamma_data1['username']
gamma_data1=gamma_data11

pca_beta = PCA(n_components=0.9)
principalComponents_beta = pca_beta.fit_transform(beta_data1.drop(['username','label'],axis=1))
beta_data11 = pd.DataFrame(data = principalComponents_beta)
beta_data11['label']=beta_data1['label']
beta_data11['username']=beta_data1['username']
beta_data1=beta_data11


pca_alpha = PCA(n_components=0.9)
principalComponents_alpha = pca_alpha.fit_transform(alpha_data1.drop(['username','label'],axis=1))
alpha_data11 = pd.DataFrame(data = principalComponents_alpha)
alpha_data11['label']=alpha_data1['label']
alpha_data11['username']=alpha_data1['username']
alpha_data1=alpha_data11

pca_theta = PCA(n_components=0.9)
principalComponents_theta = pca_theta.fit_transform(theta_data1.drop(['username','label'],axis=1))
theta_data11 = pd.DataFrame(data = principalComponents_theta)
theta_data11['label']=theta_data1['label']
theta_data11['username']=theta_data1['username']
theta_data1=theta_data11

pca_delta = PCA(n_components=0.9)
principalComponents_delta = pca_delta.fit_transform(delta_data1.drop(['username','label'],axis=1))
delta_data11 = pd.DataFrame(data = principalComponents_delta)
delta_data11['label']=delta_data1['label']
delta_data11['username']=delta_data1['username']
delta_data1=delta_data11

pca_merged = PCA(n_components=0.9)
principalComponents_merged = pca_merged.fit_transform(merged.drop(['username','label'],axis=1))
merged1 = pd.DataFrame(data = principalComponents_merged)
merged1['label']=merged['label']
merged1['username']=merged['username']
merged=merged1

# %%
results_mk={"result_theta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (theta_data1.loc[theta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = theta_data1.loc[theta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_theta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean =0.0
for i in results_mk['result_theta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_theta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
    
print(mean/len(results_mk['result_theta']),maxx,j,k)
# Out:
# 0.4596660908081523 0.5704545454545455 {'Disike': {'precision': 0.52, 'recall': 0.6842105263157895, 'f1-score': 0.5909090909090909, 'support': 19}, 'Like': {'precision': 0.6470588235294118, 'recall': 0.4782608695652174, 'f1-score': 0.55, 'support': 23}, 'accuracy': 0.5714285714285714, 'macro avg': {'precision': 0.5835294117647059, 'recall': 0.5812356979405034, 'f1-score': 0.5704545454545455, 'support': 42}, 'weighted avg': {'precision': 0.5895798319327732, 'recall': 0.5714285714285714, 'f1-score': 0.5685064935064935, 'support': 42}} 18

# %%
results_mk={"result_gamma":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (gamma_data1.loc[gamma_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = gamma_data1.loc[gamma_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_gamma'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean =0.0
for i in results_mk['result_gamma'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_gamma'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
    
print(mean/len(results_mk['result_gamma']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.4588772791252518 0.57629179331307 {'Disike': {'precision': 0.5769230769230769, 'recall': 0.7142857142857143, 'f1-score': 0.6382978723404256, 'support': 21}, 'Like': {'precision': 0.6, 'recall': 0.45, 'f1-score': 0.5142857142857143, 'support': 20}, 'accuracy': 0.5853658536585366, 'macro avg': {'precision': 0.5884615384615384, 'recall': 0.5821428571428572, 'f1-score': 0.57629179331307, 'support': 41}, 'weighted avg': {'precision': 0.5881801125703564, 'recall': 0.5853658536585366, 'f1-score': 0.577804136703981, 'support': 41}} 1

# %%
results_mk={"result_beta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (beta_data1.loc[beta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = beta_data1.loc[beta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_beta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_beta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_beta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean += i['macro avg']['f1-score']
print(mean/len(results_mk['result_beta']),maxx,j,k)
# Out:
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\users\ghazal\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.4667116716045481 0.5851851851851853 {'Disike': {'precision': 0.3888888888888889, 'recall': 0.5833333333333334, 'f1-score': 0.4666666666666666, 'support': 12}, 'Like': {'precision': 0.7916666666666666, 'recall': 0.6333333333333333, 'f1-score': 0.7037037037037038, 'support': 30}, 'accuracy': 0.6190476190476191, 'macro avg': {'precision': 0.5902777777777778, 'recall': 0.6083333333333334, 'f1-score': 0.5851851851851853, 'support': 42}, 'weighted avg': {'precision': 0.6765873015873016, 'recall': 0.6190476190476191, 'f1-score': 0.6359788359788361, 'support': 42}} 19

# %%
results_mk={"result_alpha":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (alpha_data1.loc[alpha_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = alpha_data1.loc[alpha_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_alpha'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean = 0.0
for i in results_mk['result_alpha'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_alpha'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean+=i['macro avg']['f1-score']
print(mean/len(results_mk['result_alpha']),maxx,j,k)
# Out:
# 0.4921989638506682 0.764367816091954 {'Disike': {'precision': 1.0, 'recall': 0.7575757575757576, 'f1-score': 0.8620689655172413, 'support': 33}, 'Like': {'precision': 0.5, 'recall': 1.0, 'f1-score': 0.6666666666666666, 'support': 8}, 'accuracy': 0.8048780487804879, 'macro avg': {'precision': 0.75, 'recall': 0.8787878787878788, 'f1-score': 0.764367816091954, 'support': 41}, 'weighted avg': {'precision': 0.9024390243902439, 'recall': 0.8048780487804879, 'f1-score': 0.8239416876927389, 'support': 41}} 14

# %%
results_mk={"result_delta":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (delta_data1.loc[delta_data1['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = delta_data1.loc[delta_data1['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_delta'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_delta'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_delta'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean +=i['macro avg']['f1-score'] 
print(mean/len(results_mk['result_delta']),maxx,j,k)
# Out:
# 0.4726018690684732 0.6190476190476191 {'Disike': {'precision': 0.48148148148148145, 'recall': 0.8666666666666667, 'f1-score': 0.6190476190476191, 'support': 15}, 'Like': {'precision': 0.8666666666666667, 'recall': 0.48148148148148145, 'f1-score': 0.6190476190476191, 'support': 27}, 'accuracy': 0.6190476190476191, 'macro avg': {'precision': 0.674074074074074, 'recall': 0.674074074074074, 'f1-score': 0.6190476190476191, 'support': 42}, 'weighted avg': {'precision': 0.7291005291005291, 'recall': 0.6190476190476191, 'f1-score': 0.6190476190476191, 'support': 42}} 6

# %%
results_mk={"result_merged":[]}
for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :
    test = (merged.loc[merged['username'] == name])
    labels_test = test.label.tolist()
    test = test.drop(['username','label'],axis=1)
    train = merged.loc[merged['username'] != name]
    labels_train = train.label.tolist()
    train = train.drop(['username','label'],axis=1)
    dtree4 = RandomForestClassifier(n_estimators=100)
    dtree4.fit(train,labels_train)
    predictions = dtree4.predict(test)
    results_mk['result_merged'].append(classification_report(labels_test,predictions,output_dict=True))
maxx = 0.0
k=0
mean=0.0
for i in results_mk['result_merged'] :
    j =  i['macro avg']['f1-score']>maxx  and i  or j
    k = i['macro avg']['f1-score']>maxx and results_mk['result_merged'].index(i)  or k
    maxx = i['macro avg']['f1-score']>maxx and i['macro avg']['f1-score']  or maxx
    mean += i['macro avg']['f1-score']
print(mean/len(results_mk['result_merged']),maxx,j,k)
# Out:
# 0.45379660056704674 0.5906432748538011 {'Disike': {'precision': 0.7, 'recall': 0.7777777777777778, 'f1-score': 0.7368421052631577, 'support': 27}, 'Like': {'precision': 0.5, 'recall': 0.4, 'f1-score': 0.4444444444444445, 'support': 15}, 'accuracy': 0.6428571428571429, 'macro avg': {'precision': 0.6, 'recall': 0.5888888888888889, 'f1-score': 0.5906432748538011, 'support': 42}, 'weighted avg': {'precision': 0.6285714285714286, 'recall': 0.6428571428571429, 'f1-score': 0.6324143692564744, 'support': 42}} 3

# %%
        results = {
            'result_gamma':[],
            'result_beta':[],
            'result_theta':[],
            'result_alpha':[],
            'result_delta':[],
            'result_merged':[],
        }
        labels=[]
        gamma_data1={
            "1stgamma":[],
            "2ndgamma":[],
            "3rdgamma":[],
            "4thgamma":[],
            "5thgamma":[],
            "6thgamma":[],
            "7thgamma":[],
            "8thgamma":[],
            "9thgamma":[],
            "10thgamma":[],
            "11thgamma":[],
            "12thgamma":[],
            "13thgamma":[],
            "14thgamma":[]}
        beta_data1={
            "1stbeta":[],
            "2ndbeta":[],
            "3rdbeta":[],
            "4thbeta":[],
            "5thbeta":[],
            "6thbeta":[],
            "7thbeta":[],
            "8thbeta":[],
            "9thbeta":[],
            "10thbeta":[],
            "11thbeta":[],
            "12thbeta":[],
            "13thbeta":[],
            "14thbeta":[]}
        alpha_data1={
            "1stalpha":[],
            "2ndalpha":[],
            "3rdalpha":[],
            "4thalpha":[],
            "5thalpha":[],
            "6thalpha":[],
            "7thalpha":[],
            "8thalpha":[],
            "9thalpha":[],
            "10thalpha":[],
            "11thalpha":[],
            "12thalpha":[],
            "13thalpha":[],
            "14thalpha":[]}
        theta_data1={
            "1sttheta":[],
            "2ndtheta":[],
            "3rdtheta":[],
            "4ththeta":[],
            "5ththeta":[],
            "6ththeta":[],
            "7ththeta":[],
            "8ththeta":[],
            "9ththeta":[],
            "10ththeta":[],
            "11ththeta":[],
            "12ththeta":[],
            "13ththeta":[],
            "14ththeta":[]}
        delta_data1={
            "1stdelta":[],
            "2nddelta":[],
            "3rddelta":[],
            "4thdelta":[],
            "5thdelta":[],
            "6thdelta":[],
            "7thdelta":[],
            "8thdelta":[],
            "9thdelta":[],
            "10thdelta":[],
            "11thdelta":[],
            "12thdelta":[],
            "13thdelta":[],
            "14thdelta":[]}


        for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :

            for i in range(42):
                try:
                    user_data = pd.read_csv("25-users/"+name+str(i+1)+".txt", sep=" ", header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
                    user_label = pd.read_csv("labels/"+name+str(i+1)+".lab",header=None,names=["label"])
                except:
                    continue
                labels.append(user_label.values.tolist()[0][0])

                user_data.apply(lambda row : carf(row), axis = 1)

                first_electrode = user_data['1st']
                second_electrode = user_data['2nd']
                third_electrode = user_data['3rd']
                fourth_electrode = user_data['4th']
                fifth_electrode = user_data['5th']
                sixth_electrode = user_data['6th']
                seventh_electrode = user_data['7th']
                eighth_electrode = user_data['8th']
                nineth_electrode = user_data['9th']
                tenth_electrode = user_data['10th']
                eleventh_electrode = user_data['11th']
                twelveth_electrode = user_data['12th']
                thirteenth_electrode = user_data['13th']
                fouteenth_electrode = user_data['14th']

                s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
                s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
                s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
                s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
                s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
                s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
                s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
                s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
                s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
                s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
                s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
                s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
                s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
                s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


                cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
                cA12, d12 = pywt.dwt(cA1, 'db4')
                cA13, d13 = pywt.dwt(cA12, 'db4')
                a14, d14 = pywt.dwt(cA13, 'db4')
                gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
                beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
                alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
                theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
                delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
                gamma_data1['1stgamma'].append(gamma_RMS1)
                beta_data1['1stbeta'].append(beta_RMS1)
                alpha_data1['1stalpha'].append(alpha_RMS1)
                theta_data1['1sttheta'].append(theta_RMS1)
                delta_data1['1stdelta'].append(delta_RMS1)

                cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
                cA22, d22 = pywt.dwt(cA2, 'db4')
                cA23, d23 = pywt.dwt(cA22, 'db4')
                a24, d24 = pywt.dwt(cA23, 'db4')
                gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
                beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
                alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
                theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
                delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
                gamma_data1['2ndgamma'].append(gamma_RMS2)
                beta_data1['2ndbeta'].append(beta_RMS2)
                alpha_data1['2ndalpha'].append(alpha_RMS2)
                theta_data1['2ndtheta'].append(theta_RMS2)
                delta_data1['2nddelta'].append(delta_RMS2)

                cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
                cA32, d32 = pywt.dwt(cA3, 'db4')
                cA33, d33 = pywt.dwt(cA32, 'db4')
                a34, d34 = pywt.dwt(cA33, 'db4')
                gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
                beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
                alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
                theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
                delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
                gamma_data1['3rdgamma'].append(gamma_RMS3)
                beta_data1['3rdbeta'].append(beta_RMS3)
                alpha_data1['3rdalpha'].append(alpha_RMS3)
                theta_data1['3rdtheta'].append(theta_RMS3)
                delta_data1['3rddelta'].append(delta_RMS3)

                cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
                cA42, d42 = pywt.dwt(cA4, 'db4')
                cA43, d43 = pywt.dwt(cA42, 'db4')
                a44, d44 = pywt.dwt(cA43, 'db4')
                gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
                beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
                alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
                theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
                delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
                gamma_data1['4thgamma'].append(gamma_RMS4)
                beta_data1['4thbeta'].append(beta_RMS4)
                alpha_data1['4thalpha'].append(alpha_RMS4)
                theta_data1['4ththeta'].append(theta_RMS4)
                delta_data1['4thdelta'].append(delta_RMS4)

                cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
                cA52, d52 = pywt.dwt(cA5, 'db4')
                cA53, d53 = pywt.dwt(cA52, 'db4')
                a54, d54 = pywt.dwt(cA53, 'db4')
                gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
                beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
                alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
                theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
                delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
                gamma_data1['5thgamma'].append(gamma_RMS5)
                beta_data1['5thbeta'].append(beta_RMS5)
                alpha_data1['5thalpha'].append(alpha_RMS5)
                theta_data1['5ththeta'].append(theta_RMS5)
                delta_data1['5thdelta'].append(delta_RMS5)

                cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
                cA62, d62 = pywt.dwt(cA6, 'db4')
                cA63, d63 = pywt.dwt(cA62, 'db4')
                a64, d64 = pywt.dwt(cA63, 'db4')
                gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
                beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
                alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
                theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
                delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
                gamma_data1['6thgamma'].append(gamma_RMS6)
                beta_data1['6thbeta'].append(beta_RMS6)
                alpha_data1['6thalpha'].append(alpha_RMS6)
                theta_data1['6ththeta'].append(theta_RMS6)
                delta_data1['6thdelta'].append(delta_RMS6)


                cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
                cA72, d72 = pywt.dwt(cA7, 'db4')
                cA73, d73 = pywt.dwt(cA72, 'db4')
                a74, d74 = pywt.dwt(cA73, 'db4')
                gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
                beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
                alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
                theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
                delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
                gamma_data1['7thgamma'].append(gamma_RMS7)
                beta_data1['7thbeta'].append(beta_RMS7)
                alpha_data1['7thalpha'].append(alpha_RMS7)
                theta_data1['7ththeta'].append(theta_RMS7)
                delta_data1['7thdelta'].append(delta_RMS7)

                cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
                cA82, d82 = pywt.dwt(cA8, 'db4')
                cA83, d83 = pywt.dwt(cA82, 'db4')
                a84, d84 = pywt.dwt(cA83, 'db4')
                gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
                beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
                alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
                theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
                delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
                gamma_data1['8thgamma'].append(gamma_RMS8)
                beta_data1['8thbeta'].append(beta_RMS8)
                alpha_data1['8thalpha'].append(alpha_RMS8)
                theta_data1['8ththeta'].append(theta_RMS8)
                delta_data1['8thdelta'].append(delta_RMS8)

                cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
                cA92, d92 = pywt.dwt(cA9, 'db4')
                cA93, d93 = pywt.dwt(cA92, 'db4')
                a94, d94 = pywt.dwt(cA93, 'db4')
                gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
                beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
                alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
                theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
                delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
                gamma_data1['9thgamma'].append(gamma_RMS9)
                beta_data1['9thbeta'].append(beta_RMS9)
                alpha_data1['9thalpha'].append(alpha_RMS9)
                theta_data1['9ththeta'].append(theta_RMS9)
                delta_data1['9thdelta'].append(delta_RMS9)

                cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
                cA102, d102 = pywt.dwt(cA10, 'db4')
                cA103, d103 = pywt.dwt(cA102, 'db4')
                a104, d104 = pywt.dwt(cA103, 'db4')
                gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
                beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
                alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
                theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
                delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
                gamma_data1['10thgamma'].append(gamma_RMS10)
                beta_data1['10thbeta'].append(beta_RMS10)
                alpha_data1['10thalpha'].append(alpha_RMS10)
                theta_data1['10ththeta'].append(theta_RMS10)
                delta_data1['10thdelta'].append(delta_RMS10)

                cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
                cA112, d112 = pywt.dwt(cA11, 'db4')
                cA113, d113 = pywt.dwt(cA112, 'db4')
                a114, d114 = pywt.dwt(cA113, 'db4')
                gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
                beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
                alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
                theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
                delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
                gamma_data1['11thgamma'].append(gamma_RMS11)
                beta_data1['11thbeta'].append(beta_RMS11)
                alpha_data1['11thalpha'].append(alpha_RMS11)
                theta_data1['11ththeta'].append(theta_RMS11)
                delta_data1['11thdelta'].append(delta_RMS11)

                cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
                cA122, d122 = pywt.dwt(cA12, 'db4')
                cA123, d123 = pywt.dwt(cA122, 'db4')
                a124, d124 = pywt.dwt(cA123, 'db4')
                gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
                beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
                alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
                theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
                delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
                gamma_data1['12thgamma'].append(gamma_RMS12)
                beta_data1['12thbeta'].append(beta_RMS12)
                alpha_data1['12thalpha'].append(alpha_RMS12)
                theta_data1['12ththeta'].append(theta_RMS12)
                delta_data1['12thdelta'].append(delta_RMS12)

                cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
                cA132, d132 = pywt.dwt(cA13, 'db4')
                cA133, d133 = pywt.dwt(cA132, 'db4')
                a134, d134 = pywt.dwt(cA133, 'db4')
                gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
                beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
                alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
                theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
                delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
                gamma_data1['13thgamma'].append(gamma_RMS13)
                beta_data1['13thbeta'].append(beta_RMS13)
                alpha_data1['13thalpha'].append(alpha_RMS13)
                theta_data1['13ththeta'].append(theta_RMS13)
                delta_data1['13thdelta'].append(delta_RMS13)

                cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
                cA142, d142 = pywt.dwt(cA14, 'db4')
                cA143, d143 = pywt.dwt(cA142, 'db4')
                a144, d144 = pywt.dwt(cA143, 'db4')
                gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
                beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
                alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
                theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
                delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
                gamma_data1['14thgamma'].append(gamma_RMS14)
                beta_data1['14thbeta'].append(beta_RMS14)
                alpha_data1['14thalpha'].append(alpha_RMS14)
                theta_data1['14ththeta'].append(theta_RMS14)
                delta_data1['14thdelta'].append(delta_RMS14)

                merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
                merged= pd.DataFrame.from_dict(merged)
                gamma_data1=pd.DataFrame.from_dict(gamma_data1)
                beta_data1=pd.DataFrame.from_dict(beta_data1)
                alpha_data1=pd.DataFrame.from_dict(alpha_data1)
                theta_data1=pd.DataFrame.from_dict(theta_data1)
                delta_data1=pd.DataFrame.from_dict(delta_data1)



                data_train_gamma=gamma_data1[:1003]
                data_test_gamma=gamma_data1[1003:]
                label_train_gamma=labels[:1003]
                label_test_gamma = labels[1003:]


                data_train_beta=beta_data1[:1003]
                data_test_beta=beta_data1[1003:]
                label_train_beta=labels[:1003]
                label_test_beta = labels[1003:]

                data_train_alpha=alpha_data1[:1003]
                data_test_alpha=alpha_data1[1003:]
                label_train_alpha=labels[:1003]
                label_test_alpha = labels[1003:]

                data_train_theta=theta_data1[:1003]
                data_test_theta=theta_data1[1003:]
                label_train_theta=labels[:1003]
                label_test_theta = labels[1003:]

                data_train_delta=delta_data1[:1003]
                data_test_delta=delta_data1[1003:]
                label_train_delta=labels[:1003]
                label_test_delta = labels[1003:]

                data_train_merged=merged[:1003]
                data_test_merged=merged[1003:]
                label_train_merged=labels[:1003]
                label_merged = labels[1003:]






                standard_gamma = StandardScaler().fit_transform(gamma_data1) 
                normalised_gamma = pd.DataFrame(standard_gamma)
                pca_gamma = PCA(n_components=0.9)
                principalComponents_gamma = pca_gamma.fit_transform(standard_gamma)
                gamma_data1 = pd.DataFrame(data = principalComponents_gamma)

                standard_beta = StandardScaler().fit_transform(beta_data1) 
                normalised_beta = pd.DataFrame(standard_beta)
                pca_beta = PCA(n_components=0.9)
                principalComponents_beta = pca_beta.fit_transform(standard_beta)
                beta_data1 = pd.DataFrame(data = principalComponents_beta)

                standard_alpha = StandardScaler().fit_transform(alpha_data1) 
                normalised_alpha = pd.DataFrame(standard_alpha)
                pca_alpha = PCA(n_components=0.9)
                principalComponents_alpha = pca_alpha.fit_transform(standard_alpha)
                alpha_data1 = pd.DataFrame(data = principalComponents_alpha)

                standard_theta = StandardScaler().fit_transform(theta_data1) 
                normalised_theta = pd.DataFrame(standard_theta)
                pca_theta = PCA(n_components=0.9)
                principalComponents_theta = pca_theta.fit_transform(standard_theta)
                theta_data1 = pd.DataFrame(data = principalComponents_theta)


                standard_delta = StandardScaler().fit_transform(delta_data1) 
                normalised_delta = pd.DataFrame(standard_delta)
                pca_delta = PCA(n_components=0.9)
                principalComponents_delta = pca_delta.fit_transform(standard_delta)
                delta_data1 = pd.DataFrame(data = principalComponents_delta)

                standard_merged = StandardScaler().fit_transform(merged) 
                normalised_merged = pd.DataFrame(standard_merged)
                pca_merged = PCA(n_components=0.9)
                principalComponents_merged = pca_merged.fit_transform(standard_merged)
                merged = pd.DataFrame(data = principalComponents_merged)

                dtree1 = RandomForestClassifier(n_estimators=20000)
                dtree1.fit(data_train_gamma,label_train_gamma)
                predictions_gamma = dtree1.predict(data_test_gamma)
                results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

                dtree2 = RandomForestClassifier(n_estimators=20000)
                dtree2.fit(data_train_beta,label_train_beta)
                predictions_beta = dtree2.predict(data_test_beta)
                results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

                dtree3 = RandomForestClassifier(n_estimators=20000)
                dtree3.fit(data_train_alpha,label_train_alpha)
                predictions_alpha = dtree3.predict(data_test_alpha)
                results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

                dtree4 = RandomForestClassifier(n_estimators=20000)
                dtree4.fit(data_train_theta,label_train_theta)
                predictions_theta = dtree4.predict(data_test_theta)
                results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

                dtree5 = RandomForestClassifier(n_estimators=20000)
                dtree5.fit(data_train_delta,label_train_delta)
                predictions_delta = dtree5.predict(data_test_delta)
                results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

                dtree6 = RandomForestClassifier(n_estimators=20000)
                dtree6.fit(data_train_merged,label_train_merged)
                predictions_mereged = dtree6.predict(data_test_merged)
                results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))

# %%
mean_gama=0.0
mean_beta=0.0
mean_alpha=0.0
mean_theta=0.0
mean_delta=0.0
mean_merged=0.0

max_gama=0.0
max_beta=0.0
max_alpha=0.0
max_theta=0.0
max_delta=0.0
max_merged=0.0

k_gama=0.0
k_beta=0.0
k_alpha=0.0
k_theta=0.0
k_delta=0.0
k_merged=0.0

for i in results['result_gamma'] :
    mean_gama+=i['macro avg']['f1-score']
    k_gama = i['macro avg']['f1-score']>max_gama and results['result_gamma'].index(i)  or k_gama
    max_gama = i['macro avg']['f1-score']>max_gama and i['macro avg']['f1-score']  or max_gama
for i in results['result_beta'] :
    mean_beta+=i['macro avg']['f1-score']
    k_beta = i['macro avg']['f1-score']>max_beta and results['result_beta'].index(i)  or k_beta
    max_beta = i['macro avg']['f1-score']>max_beta and i['macro avg']['f1-score']  or max_beta
for i in results['result_alpha'] :
    mean_alpha+=i['macro avg']['f1-score']
    k_alpha = i['macro avg']['f1-score']>max_alpha and results['result_alpha'].index(i)  or k_alpha
    max_alpha = i['macro avg']['f1-score']>max_alpha and i['macro avg']['f1-score']  or max_alpha
for i in results['result_theta'] :
    mean_theta+=i['macro avg']['f1-score']
    k_theta = i['macro avg']['f1-score']>max_theta and results['result_theta'].index(i)  or k_theta
    max_theta = i['macro avg']['f1-score']>max_theta and i['macro avg']['f1-score']  or max_theta
for i in results['result_delta'] :
    mean_delta+=i['macro avg']['f1-score']
    k_delta = i['macro avg']['f1-score']>max_delta and results['result_delta'].index(i)  or k_delta
    max_delta = i['macro avg']['f1-score']>max_delta and i['macro avg']['f1-score']  or max_delta
for i in results['result_merged'] :
    mean_merged+=i['macro avg']['f1-score']
    k_merged = i['macro avg']['f1-score']>max_delta and results['result_merged'].index(i)  or k_merged
    max_merged = i['macro avg']['f1-score']>max_merged and i['macro avg']['f1-score']  or max_merged
print('mean gamma=',mean_gama/len(results['result_gamma']),'mean beta=',mean_beta/len(results['result_beta']),'mean alpha =',mean_alpha/len(results['result_alpha']),'mean theta =',mean_theta/len(results['result_theta']),'mean delta=',mean_delta/len(results['result_delta']),'mean combined =',mean_merged/len(results['result_merged']))
print(max_gama,k_gama,max_beta,k_beta,max_alpha,k_alpha,max_theta,k_theta,max_delta,k_delta,max_merged,k_merged)

# %%
        results = {
            'result_gamma':[],
            'result_beta':[],
            'result_theta':[],
            'result_alpha':[],
            'result_delta':[],
            'result_merged':[],
        }
        labels=[]
        gamma_data1={
            "1stgamma":[],
            "2ndgamma":[],
            "3rdgamma":[],
            "4thgamma":[],
            "5thgamma":[],
            "6thgamma":[],
            "7thgamma":[],
            "8thgamma":[],
            "9thgamma":[],
            "10thgamma":[],
            "11thgamma":[],
            "12thgamma":[],
            "13thgamma":[],
            "14thgamma":[]}
        beta_data1={
            "1stbeta":[],
            "2ndbeta":[],
            "3rdbeta":[],
            "4thbeta":[],
            "5thbeta":[],
            "6thbeta":[],
            "7thbeta":[],
            "8thbeta":[],
            "9thbeta":[],
            "10thbeta":[],
            "11thbeta":[],
            "12thbeta":[],
            "13thbeta":[],
            "14thbeta":[]}
        alpha_data1={
            "1stalpha":[],
            "2ndalpha":[],
            "3rdalpha":[],
            "4thalpha":[],
            "5thalpha":[],
            "6thalpha":[],
            "7thalpha":[],
            "8thalpha":[],
            "9thalpha":[],
            "10thalpha":[],
            "11thalpha":[],
            "12thalpha":[],
            "13thalpha":[],
            "14thalpha":[]}
        theta_data1={
            "1sttheta":[],
            "2ndtheta":[],
            "3rdtheta":[],
            "4ththeta":[],
            "5ththeta":[],
            "6ththeta":[],
            "7ththeta":[],
            "8ththeta":[],
            "9ththeta":[],
            "10ththeta":[],
            "11ththeta":[],
            "12ththeta":[],
            "13ththeta":[],
            "14ththeta":[]}
        delta_data1={
            "1stdelta":[],
            "2nddelta":[],
            "3rddelta":[],
            "4thdelta":[],
            "5thdelta":[],
            "6thdelta":[],
            "7thdelta":[],
            "8thdelta":[],
            "9thdelta":[],
            "10thdelta":[],
            "11thdelta":[],
            "12thdelta":[],
            "13thdelta":[],
            "14thdelta":[]}


        for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :

            for i in range(42):
                try:
                    user_data = pd.read_csv("25-users/"+name+str(i+1)+".txt", sep=" ", header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
                    user_label = pd.read_csv("labels/"+name+str(i+1)+".lab",header=None,names=["label"])
                except:
                    continue
                labels.append(user_label.values.tolist()[0][0])

                user_data.apply(lambda row : carf(row), axis = 1)

                first_electrode = user_data['1st']
                second_electrode = user_data['2nd']
                third_electrode = user_data['3rd']
                fourth_electrode = user_data['4th']
                fifth_electrode = user_data['5th']
                sixth_electrode = user_data['6th']
                seventh_electrode = user_data['7th']
                eighth_electrode = user_data['8th']
                nineth_electrode = user_data['9th']
                tenth_electrode = user_data['10th']
                eleventh_electrode = user_data['11th']
                twelveth_electrode = user_data['12th']
                thirteenth_electrode = user_data['13th']
                fouteenth_electrode = user_data['14th']

                s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
                s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
                s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
                s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
                s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
                s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
                s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
                s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
                s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
                s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
                s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
                s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
                s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
                s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


                cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
                cA12, d12 = pywt.dwt(cA1, 'db4')
                cA13, d13 = pywt.dwt(cA12, 'db4')
                a14, d14 = pywt.dwt(cA13, 'db4')
                gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
                beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
                alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
                theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
                delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
                gamma_data1['1stgamma'].append(gamma_RMS1)
                beta_data1['1stbeta'].append(beta_RMS1)
                alpha_data1['1stalpha'].append(alpha_RMS1)
                theta_data1['1sttheta'].append(theta_RMS1)
                delta_data1['1stdelta'].append(delta_RMS1)

                cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
                cA22, d22 = pywt.dwt(cA2, 'db4')
                cA23, d23 = pywt.dwt(cA22, 'db4')
                a24, d24 = pywt.dwt(cA23, 'db4')
                gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
                beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
                alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
                theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
                delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
                gamma_data1['2ndgamma'].append(gamma_RMS2)
                beta_data1['2ndbeta'].append(beta_RMS2)
                alpha_data1['2ndalpha'].append(alpha_RMS2)
                theta_data1['2ndtheta'].append(theta_RMS2)
                delta_data1['2nddelta'].append(delta_RMS2)

                cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
                cA32, d32 = pywt.dwt(cA3, 'db4')
                cA33, d33 = pywt.dwt(cA32, 'db4')
                a34, d34 = pywt.dwt(cA33, 'db4')
                gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
                beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
                alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
                theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
                delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
                gamma_data1['3rdgamma'].append(gamma_RMS3)
                beta_data1['3rdbeta'].append(beta_RMS3)
                alpha_data1['3rdalpha'].append(alpha_RMS3)
                theta_data1['3rdtheta'].append(theta_RMS3)
                delta_data1['3rddelta'].append(delta_RMS3)

                cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
                cA42, d42 = pywt.dwt(cA4, 'db4')
                cA43, d43 = pywt.dwt(cA42, 'db4')
                a44, d44 = pywt.dwt(cA43, 'db4')
                gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
                beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
                alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
                theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
                delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
                gamma_data1['4thgamma'].append(gamma_RMS4)
                beta_data1['4thbeta'].append(beta_RMS4)
                alpha_data1['4thalpha'].append(alpha_RMS4)
                theta_data1['4ththeta'].append(theta_RMS4)
                delta_data1['4thdelta'].append(delta_RMS4)

                cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
                cA52, d52 = pywt.dwt(cA5, 'db4')
                cA53, d53 = pywt.dwt(cA52, 'db4')
                a54, d54 = pywt.dwt(cA53, 'db4')
                gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
                beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
                alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
                theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
                delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
                gamma_data1['5thgamma'].append(gamma_RMS5)
                beta_data1['5thbeta'].append(beta_RMS5)
                alpha_data1['5thalpha'].append(alpha_RMS5)
                theta_data1['5ththeta'].append(theta_RMS5)
                delta_data1['5thdelta'].append(delta_RMS5)

                cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
                cA62, d62 = pywt.dwt(cA6, 'db4')
                cA63, d63 = pywt.dwt(cA62, 'db4')
                a64, d64 = pywt.dwt(cA63, 'db4')
                gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
                beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
                alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
                theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
                delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
                gamma_data1['6thgamma'].append(gamma_RMS6)
                beta_data1['6thbeta'].append(beta_RMS6)
                alpha_data1['6thalpha'].append(alpha_RMS6)
                theta_data1['6ththeta'].append(theta_RMS6)
                delta_data1['6thdelta'].append(delta_RMS6)


                cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
                cA72, d72 = pywt.dwt(cA7, 'db4')
                cA73, d73 = pywt.dwt(cA72, 'db4')
                a74, d74 = pywt.dwt(cA73, 'db4')
                gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
                beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
                alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
                theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
                delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
                gamma_data1['7thgamma'].append(gamma_RMS7)
                beta_data1['7thbeta'].append(beta_RMS7)
                alpha_data1['7thalpha'].append(alpha_RMS7)
                theta_data1['7ththeta'].append(theta_RMS7)
                delta_data1['7thdelta'].append(delta_RMS7)

                cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
                cA82, d82 = pywt.dwt(cA8, 'db4')
                cA83, d83 = pywt.dwt(cA82, 'db4')
                a84, d84 = pywt.dwt(cA83, 'db4')
                gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
                beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
                alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
                theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
                delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
                gamma_data1['8thgamma'].append(gamma_RMS8)
                beta_data1['8thbeta'].append(beta_RMS8)
                alpha_data1['8thalpha'].append(alpha_RMS8)
                theta_data1['8ththeta'].append(theta_RMS8)
                delta_data1['8thdelta'].append(delta_RMS8)

                cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
                cA92, d92 = pywt.dwt(cA9, 'db4')
                cA93, d93 = pywt.dwt(cA92, 'db4')
                a94, d94 = pywt.dwt(cA93, 'db4')
                gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
                beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
                alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
                theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
                delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
                gamma_data1['9thgamma'].append(gamma_RMS9)
                beta_data1['9thbeta'].append(beta_RMS9)
                alpha_data1['9thalpha'].append(alpha_RMS9)
                theta_data1['9ththeta'].append(theta_RMS9)
                delta_data1['9thdelta'].append(delta_RMS9)

                cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
                cA102, d102 = pywt.dwt(cA10, 'db4')
                cA103, d103 = pywt.dwt(cA102, 'db4')
                a104, d104 = pywt.dwt(cA103, 'db4')
                gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
                beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
                alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
                theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
                delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
                gamma_data1['10thgamma'].append(gamma_RMS10)
                beta_data1['10thbeta'].append(beta_RMS10)
                alpha_data1['10thalpha'].append(alpha_RMS10)
                theta_data1['10ththeta'].append(theta_RMS10)
                delta_data1['10thdelta'].append(delta_RMS10)

                cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
                cA112, d112 = pywt.dwt(cA11, 'db4')
                cA113, d113 = pywt.dwt(cA112, 'db4')
                a114, d114 = pywt.dwt(cA113, 'db4')
                gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
                beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
                alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
                theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
                delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
                gamma_data1['11thgamma'].append(gamma_RMS11)
                beta_data1['11thbeta'].append(beta_RMS11)
                alpha_data1['11thalpha'].append(alpha_RMS11)
                theta_data1['11ththeta'].append(theta_RMS11)
                delta_data1['11thdelta'].append(delta_RMS11)

                cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
                cA122, d122 = pywt.dwt(cA12, 'db4')
                cA123, d123 = pywt.dwt(cA122, 'db4')
                a124, d124 = pywt.dwt(cA123, 'db4')
                gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
                beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
                alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
                theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
                delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
                gamma_data1['12thgamma'].append(gamma_RMS12)
                beta_data1['12thbeta'].append(beta_RMS12)
                alpha_data1['12thalpha'].append(alpha_RMS12)
                theta_data1['12ththeta'].append(theta_RMS12)
                delta_data1['12thdelta'].append(delta_RMS12)

                cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
                cA132, d132 = pywt.dwt(cA13, 'db4')
                cA133, d133 = pywt.dwt(cA132, 'db4')
                a134, d134 = pywt.dwt(cA133, 'db4')
                gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
                beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
                alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
                theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
                delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
                gamma_data1['13thgamma'].append(gamma_RMS13)
                beta_data1['13thbeta'].append(beta_RMS13)
                alpha_data1['13thalpha'].append(alpha_RMS13)
                theta_data1['13ththeta'].append(theta_RMS13)
                delta_data1['13thdelta'].append(delta_RMS13)

                cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
                cA142, d142 = pywt.dwt(cA14, 'db4')
                cA143, d143 = pywt.dwt(cA142, 'db4')
                a144, d144 = pywt.dwt(cA143, 'db4')
                gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
                beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
                alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
                theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
                delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
                gamma_data1['14thgamma'].append(gamma_RMS14)
                beta_data1['14thbeta'].append(beta_RMS14)
                alpha_data1['14thalpha'].append(alpha_RMS14)
                theta_data1['14ththeta'].append(theta_RMS14)
                delta_data1['14thdelta'].append(delta_RMS14)

            merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
            merged= pd.DataFrame.from_dict(merged)
            gamma_data1=pd.DataFrame.from_dict(gamma_data1)
            beta_data1=pd.DataFrame.from_dict(beta_data1)
            alpha_data1=pd.DataFrame.from_dict(alpha_data1)
            theta_data1=pd.DataFrame.from_dict(theta_data1)
            delta_data1=pd.DataFrame.from_dict(delta_data1)



            data_train_gamma=gamma_data1[:1003]
            data_test_gamma=gamma_data1[1003:]
            label_train_gamma=labels[:1003]
            label_test_gamma = labels[1003:]


            data_train_beta=beta_data1[:1003]
            data_test_beta=beta_data1[1003:]
            label_train_beta=labels[:1003]
            label_test_beta = labels[1003:]

            data_train_alpha=alpha_data1[:1003]
            data_test_alpha=alpha_data1[1003:]
            label_train_alpha=labels[:1003]
            label_test_alpha = labels[1003:]

            data_train_theta=theta_data1[:1003]
            data_test_theta=theta_data1[1003:]
            label_train_theta=labels[:1003]
            label_test_theta = labels[1003:]

            data_train_delta=delta_data1[:1003]
            data_test_delta=delta_data1[1003:]
            label_train_delta=labels[:1003]
            label_test_delta = labels[1003:]

            data_train_merged=merged[:1003]
            data_test_merged=merged[1003:]
            label_train_merged=labels[:1003]
            label_merged = labels[1003:]




            pca_gamma = PCA(n_components=0.9)
            principalComponents_gamma = pca_gamma.fit_transform(gamma_data1)


            pca_beta = PCA(n_components=0.9)
            principalComponents_beta = pca_beta.fit_transform(beta_data1)


            pca_alpha = PCA(n_components=0.9)
            principalComponents_alpha = pca_alpha.fit_transform(alpha_data1)


            pca_theta = PCA(n_components=0.9)
            principalComponents_theta = pca_theta.fit_transform(theta_data1)



            pca_delta = PCA(n_components=0.9)
            principalComponents_delta = pca_delta.fit_transform(delta_data1)


            pca_merged = PCA(n_components=0.9)
            principalComponents_merged = pca_merged.fit_transform(merged)

            dtree1 = RandomForestClassifier(n_estimators=20000)
            dtree1.fit(data_train_gamma,label_train_gamma)
            predictions_gamma = dtree1.predict(data_test_gamma)
            results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

            dtree2 = RandomForestClassifier(n_estimators=20000)
            dtree2.fit(data_train_beta,label_train_beta)
            predictions_beta = dtree2.predict(data_test_beta)
            results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

            dtree3 = RandomForestClassifier(n_estimators=20000)
            dtree3.fit(data_train_alpha,label_train_alpha)
            predictions_alpha = dtree3.predict(data_test_alpha)
            results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

            dtree4 = RandomForestClassifier(n_estimators=20000)
            dtree4.fit(data_train_theta,label_train_theta)
            predictions_theta = dtree4.predict(data_test_theta)
            results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

            dtree5 = RandomForestClassifier(n_estimators=20000)
            dtree5.fit(data_train_delta,label_train_delta)
            predictions_delta = dtree5.predict(data_test_delta)
            results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

            dtree6 = RandomForestClassifier(n_estimators=20000)
            dtree6.fit(data_train_merged,label_train_merged)
            predictions_mereged = dtree6.predict(data_test_merged)
            results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))

# %%
mean_gama=0.0
mean_beta=0.0
mean_alpha=0.0
mean_theta=0.0
mean_delta=0.0
mean_merged=0.0

max_gama=0.0
max_beta=0.0
max_alpha=0.0
max_theta=0.0
max_delta=0.0
max_merged=0.0

k_gama=0.0
k_beta=0.0
k_alpha=0.0
k_theta=0.0
k_delta=0.0
k_merged=0.0

for i in results['result_gamma'] :
    mean_gama+=i['macro avg']['f1-score']
    k_gama = i['macro avg']['f1-score']>max_gama and results['result_gamma'].index(i)  or k_gama
    max_gama = i['macro avg']['f1-score']>max_gama and i['macro avg']['f1-score']  or max_gama
for i in results['result_beta'] :
    mean_beta+=i['macro avg']['f1-score']
    k_beta = i['macro avg']['f1-score']>max_beta and results['result_beta'].index(i)  or k_beta
    max_beta = i['macro avg']['f1-score']>max_beta and i['macro avg']['f1-score']  or max_beta
for i in results['result_alpha'] :
    mean_alpha+=i['macro avg']['f1-score']
    k_alpha = i['macro avg']['f1-score']>max_alpha and results['result_alpha'].index(i)  or k_alpha
    max_alpha = i['macro avg']['f1-score']>max_alpha and i['macro avg']['f1-score']  or max_alpha
for i in results['result_theta'] :
    mean_theta+=i['macro avg']['f1-score']
    k_theta = i['macro avg']['f1-score']>max_theta and results['result_theta'].index(i)  or k_theta
    max_theta = i['macro avg']['f1-score']>max_theta and i['macro avg']['f1-score']  or max_theta
for i in results['result_delta'] :
    mean_delta+=i['macro avg']['f1-score']
    k_delta = i['macro avg']['f1-score']>max_delta and results['result_delta'].index(i)  or k_delta
    max_delta = i['macro avg']['f1-score']>max_delta and i['macro avg']['f1-score']  or max_delta
for i in results['result_merged'] :
    mean_merged+=i['macro avg']['f1-score']
    k_merged = i['macro avg']['f1-score']>max_delta and results['result_merged'].index(i)  or k_merged
    max_merged = i['macro avg']['f1-score']>max_merged and i['macro avg']['f1-score']  or max_merged
print('mean gamma=',mean_gama/len(results['result_gamma']),'mean beta=',mean_beta/len(results['result_beta']),'mean alpha =',mean_alpha/len(results['result_alpha']),'mean theta =',mean_theta/len(results['result_theta']),'mean delta=',mean_delta/len(results['result_delta']),'mean combined =',mean_merged/len(results['result_merged']))
print(max_gama,k_gama,max_beta,k_beta,max_alpha,k_alpha,max_theta,k_theta,max_delta,k_delta,max_merged,k_merged)

# %% [markdown]
# # car in bandwidth

# %%
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
for i in range(25):
        labels=[]
        gamma_data1={
            "1stgamma":[],
            "2ndgamma":[],
            "3rdgamma":[],
            "4thgamma":[],
            "5thgamma":[],
            "6thgamma":[],
            "7thgamma":[],
            "8thgamma":[],
            "9thgamma":[],
            "10thgamma":[],
            "11thgamma":[],
            "12thgamma":[],
            "13thgamma":[],
            "14thgamma":[]}
        beta_data1={
            "1stbeta":[],
            "2ndbeta":[],
            "3rdbeta":[],
            "4thbeta":[],
            "5thbeta":[],
            "6thbeta":[],
            "7thbeta":[],
            "8thbeta":[],
            "9thbeta":[],
            "10thbeta":[],
            "11thbeta":[],
            "12thbeta":[],
            "13thbeta":[],
            "14thbeta":[]}
        alpha_data1={
            "1stalpha":[],
            "2ndalpha":[],
            "3rdalpha":[],
            "4thalpha":[],
            "5thalpha":[],
            "6thalpha":[],
            "7thalpha":[],
            "8thalpha":[],
            "9thalpha":[],
            "10thalpha":[],
            "11thalpha":[],
            "12thalpha":[],
            "13thalpha":[],
            "14thalpha":[]}
        theta_data1={
            "1sttheta":[],
            "2ndtheta":[],
            "3rdtheta":[],
            "4ththeta":[],
            "5ththeta":[],
            "6ththeta":[],
            "7ththeta":[],
            "8ththeta":[],
            "9ththeta":[],
            "10ththeta":[],
            "11ththeta":[],
            "12ththeta":[],
            "13ththeta":[],
            "14ththeta":[]}
        delta_data1={
            "1stdelta":[],
            "2nddelta":[],
            "3rddelta":[],
            "4thdelta":[],
            "5thdelta":[],
            "6thdelta":[],
            "7thdelta":[],
            "8thdelta":[],
            "9thdelta":[],
            "10thdelta":[],
            "11thdelta":[],
            "12thdelta":[],
            "13thdelta":[],
            "14thdelta":[]}


        for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :

            for i in range(42):
                try:
                    user_data = pd.read_csv("25-users/"+name+str(i+1)+".txt", sep=" ", header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
                    user_label = pd.read_csv("labels/"+name+str(i+1)+".lab",header=None,names=["label"])
                except:
                    continue
                labels.append(user_label.values.tolist()[0][0])


                first_electrode = user_data['1st']
                second_electrode = user_data['2nd']
                third_electrode = user_data['3rd']
                fourth_electrode = user_data['4th']
                fifth_electrode = user_data['5th']
                sixth_electrode = user_data['6th']
                seventh_electrode = user_data['7th']
                eighth_electrode = user_data['8th']
                nineth_electrode = user_data['9th']
                tenth_electrode = user_data['10th']
                eleventh_electrode = user_data['11th']
                twelveth_electrode = user_data['12th']
                thirteenth_electrode = user_data['13th']
                fouteenth_electrode = user_data['14th']

                s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
                s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
                s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
                s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
                s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
                s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
                s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
                s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
                s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
                s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
                s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
                s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
                s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
                s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


                cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
                cA12, d12 = pywt.dwt(cA1, 'db4')
                cA13, d13 = pywt.dwt(cA12, 'db4')
                a14, d14 = pywt.dwt(cA13, 'db4')
                gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
                beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
                alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
                theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
                delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
                gamma_data1['1stgamma'].append(gamma_RMS1)
                beta_data1['1stbeta'].append(beta_RMS1)
                alpha_data1['1stalpha'].append(alpha_RMS1)
                theta_data1['1sttheta'].append(theta_RMS1)
                delta_data1['1stdelta'].append(delta_RMS1)

                cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
                cA22, d22 = pywt.dwt(cA2, 'db4')
                cA23, d23 = pywt.dwt(cA22, 'db4')
                a24, d24 = pywt.dwt(cA23, 'db4')
                gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
                beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
                alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
                theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
                delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
                gamma_data1['2ndgamma'].append(gamma_RMS2)
                beta_data1['2ndbeta'].append(beta_RMS2)
                alpha_data1['2ndalpha'].append(alpha_RMS2)
                theta_data1['2ndtheta'].append(theta_RMS2)
                delta_data1['2nddelta'].append(delta_RMS2)

                cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
                cA32, d32 = pywt.dwt(cA3, 'db4')
                cA33, d33 = pywt.dwt(cA32, 'db4')
                a34, d34 = pywt.dwt(cA33, 'db4')
                gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
                beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
                alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
                theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
                delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
                gamma_data1['3rdgamma'].append(gamma_RMS3)
                beta_data1['3rdbeta'].append(beta_RMS3)
                alpha_data1['3rdalpha'].append(alpha_RMS3)
                theta_data1['3rdtheta'].append(theta_RMS3)
                delta_data1['3rddelta'].append(delta_RMS3)

                cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
                cA42, d42 = pywt.dwt(cA4, 'db4')
                cA43, d43 = pywt.dwt(cA42, 'db4')
                a44, d44 = pywt.dwt(cA43, 'db4')
                gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
                beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
                alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
                theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
                delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
                gamma_data1['4thgamma'].append(gamma_RMS4)
                beta_data1['4thbeta'].append(beta_RMS4)
                alpha_data1['4thalpha'].append(alpha_RMS4)
                theta_data1['4ththeta'].append(theta_RMS4)
                delta_data1['4thdelta'].append(delta_RMS4)

                cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
                cA52, d52 = pywt.dwt(cA5, 'db4')
                cA53, d53 = pywt.dwt(cA52, 'db4')
                a54, d54 = pywt.dwt(cA53, 'db4')
                gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
                beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
                alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
                theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
                delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
                gamma_data1['5thgamma'].append(gamma_RMS5)
                beta_data1['5thbeta'].append(beta_RMS5)
                alpha_data1['5thalpha'].append(alpha_RMS5)
                theta_data1['5ththeta'].append(theta_RMS5)
                delta_data1['5thdelta'].append(delta_RMS5)

                cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
                cA62, d62 = pywt.dwt(cA6, 'db4')
                cA63, d63 = pywt.dwt(cA62, 'db4')
                a64, d64 = pywt.dwt(cA63, 'db4')
                gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
                beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
                alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
                theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
                delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
                gamma_data1['6thgamma'].append(gamma_RMS6)
                beta_data1['6thbeta'].append(beta_RMS6)
                alpha_data1['6thalpha'].append(alpha_RMS6)
                theta_data1['6ththeta'].append(theta_RMS6)
                delta_data1['6thdelta'].append(delta_RMS6)


                cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
                cA72, d72 = pywt.dwt(cA7, 'db4')
                cA73, d73 = pywt.dwt(cA72, 'db4')
                a74, d74 = pywt.dwt(cA73, 'db4')
                gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
                beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
                alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
                theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
                delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
                gamma_data1['7thgamma'].append(gamma_RMS7)
                beta_data1['7thbeta'].append(beta_RMS7)
                alpha_data1['7thalpha'].append(alpha_RMS7)
                theta_data1['7ththeta'].append(theta_RMS7)
                delta_data1['7thdelta'].append(delta_RMS7)

                cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
                cA82, d82 = pywt.dwt(cA8, 'db4')
                cA83, d83 = pywt.dwt(cA82, 'db4')
                a84, d84 = pywt.dwt(cA83, 'db4')
                gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
                beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
                alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
                theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
                delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
                gamma_data1['8thgamma'].append(gamma_RMS8)
                beta_data1['8thbeta'].append(beta_RMS8)
                alpha_data1['8thalpha'].append(alpha_RMS8)
                theta_data1['8ththeta'].append(theta_RMS8)
                delta_data1['8thdelta'].append(delta_RMS8)

                cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
                cA92, d92 = pywt.dwt(cA9, 'db4')
                cA93, d93 = pywt.dwt(cA92, 'db4')
                a94, d94 = pywt.dwt(cA93, 'db4')
                gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
                beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
                alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
                theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
                delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
                gamma_data1['9thgamma'].append(gamma_RMS9)
                beta_data1['9thbeta'].append(beta_RMS9)
                alpha_data1['9thalpha'].append(alpha_RMS9)
                theta_data1['9ththeta'].append(theta_RMS9)
                delta_data1['9thdelta'].append(delta_RMS9)

                cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
                cA102, d102 = pywt.dwt(cA10, 'db4')
                cA103, d103 = pywt.dwt(cA102, 'db4')
                a104, d104 = pywt.dwt(cA103, 'db4')
                gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
                beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
                alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
                theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
                delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
                gamma_data1['10thgamma'].append(gamma_RMS10)
                beta_data1['10thbeta'].append(beta_RMS10)
                alpha_data1['10thalpha'].append(alpha_RMS10)
                theta_data1['10ththeta'].append(theta_RMS10)
                delta_data1['10thdelta'].append(delta_RMS10)

                cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
                cA112, d112 = pywt.dwt(cA11, 'db4')
                cA113, d113 = pywt.dwt(cA112, 'db4')
                a114, d114 = pywt.dwt(cA113, 'db4')
                gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
                beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
                alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
                theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
                delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
                gamma_data1['11thgamma'].append(gamma_RMS11)
                beta_data1['11thbeta'].append(beta_RMS11)
                alpha_data1['11thalpha'].append(alpha_RMS11)
                theta_data1['11ththeta'].append(theta_RMS11)
                delta_data1['11thdelta'].append(delta_RMS11)

                cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
                cA122, d122 = pywt.dwt(cA12, 'db4')
                cA123, d123 = pywt.dwt(cA122, 'db4')
                a124, d124 = pywt.dwt(cA123, 'db4')
                gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
                beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
                alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
                theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
                delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
                gamma_data1['12thgamma'].append(gamma_RMS12)
                beta_data1['12thbeta'].append(beta_RMS12)
                alpha_data1['12thalpha'].append(alpha_RMS12)
                theta_data1['12ththeta'].append(theta_RMS12)
                delta_data1['12thdelta'].append(delta_RMS12)

                cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
                cA132, d132 = pywt.dwt(cA13, 'db4')
                cA133, d133 = pywt.dwt(cA132, 'db4')
                a134, d134 = pywt.dwt(cA133, 'db4')
                gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
                beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
                alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
                theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
                delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
                gamma_data1['13thgamma'].append(gamma_RMS13)
                beta_data1['13thbeta'].append(beta_RMS13)
                alpha_data1['13thalpha'].append(alpha_RMS13)
                theta_data1['13ththeta'].append(theta_RMS13)
                delta_data1['13thdelta'].append(delta_RMS13)

                cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
                cA142, d142 = pywt.dwt(cA14, 'db4')
                cA143, d143 = pywt.dwt(cA142, 'db4')
                a144, d144 = pywt.dwt(cA143, 'db4')
                gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
                beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
                alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
                theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
                delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
                gamma_data1['14thgamma'].append(gamma_RMS14)
                beta_data1['14thbeta'].append(beta_RMS14)
                alpha_data1['14thalpha'].append(alpha_RMS14)
                theta_data1['14ththeta'].append(theta_RMS14)
                delta_data1['14thdelta'].append(delta_RMS14)

            merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
            merged= pd.DataFrame.from_dict(merged)
            gamma_data1=pd.DataFrame.from_dict(gamma_data1)
            beta_data1=pd.DataFrame.from_dict(beta_data1)
            alpha_data1=pd.DataFrame.from_dict(alpha_data1)
            theta_data1=pd.DataFrame.from_dict(theta_data1)
            delta_data1=pd.DataFrame.from_dict(delta_data1)
            gamma_data1.apply(lambda row : carf(row), axis = 1)
            beta_data1.apply(lambda row : carf(row), axis = 1)
            alpha_data1.apply(lambda row : carf(row), axis = 1)
            theta_data1.apply(lambda row : carf(row), axis = 1)
            delta_data1.apply(lambda row : carf(row), axis = 1)
            merged.apply(lambda row : carf(row), axis = 1)
            data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.1,stratify=labels)
            data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.1,stratify=labels)
            data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.1,stratify=labels)
            data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.1,stratify=labels)
            data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.1,stratify=labels)
            data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.1,stratify=labels)


            dtree1 = RandomForestClassifier(n_estimators=20000)
            dtree1.fit(data_train_gamma,label_train_gamma)
            predictions_gamma = dtree1.predict(data_test_gamma)
            results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

            dtree2 = RandomForestClassifier(n_estimators=20000)
            dtree2.fit(data_train_beta,label_train_beta)
            predictions_beta = dtree2.predict(data_test_beta)
            results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

            dtree3 = RandomForestClassifier(n_estimators=20000)
            dtree3.fit(data_train_alpha,label_train_alpha)
            predictions_alpha = dtree3.predict(data_test_alpha)
            results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

            dtree4 = RandomForestClassifier(n_estimators=20000)
            dtree4.fit(data_train_theta,label_train_theta)
            predictions_theta = dtree4.predict(data_test_theta)
            results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

            dtree5 = RandomForestClassifier(n_estimators=20000)
            dtree5.fit(data_train_delta,label_train_delta)
            predictions_delta = dtree5.predict(data_test_delta)
            results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

            dtree6 = RandomForestClassifier(n_estimators=20000)
            dtree6.fit(data_train_merged,label_train_merged)
            predictions_mereged = dtree6.predict(data_test_merged)
            results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))

# %%
mean_gama=0.0
mean_beta=0.0
mean_alpha=0.0
mean_theta=0.0
mean_delta=0.0
mean_merged=0.0

for i in results['result_gamma'] :
    mean_gama+=i['macro avg']['f1-score']
for i in results['result_beta'] :
    mean_beta+=i['macro avg']['f1-score']
for i in results['result_alpha'] :
    mean_alpha+=i['macro avg']['f1-score']
for i in results['result_theta'] :
    mean_theta+=i['macro avg']['f1-score']
for i in results['result_delta'] :
    mean_delta+=i['macro avg']['f1-score']
for i in results['result_merged'] :
    mean_merged+=i['macro avg']['f1-score']
print('mean gamma=',mean_gama/25,'mean beta=',mean_beta/25,'mean alpha =',mean_alpha/25,'mean theta =',mean_theta/25,'mean delta=',mean_delta/25,'mean combined =',mean_merged/25)

# %%
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
for i in range(25):
        labels=[]
        gamma_data1={
            "1stgamma":[],
            "2ndgamma":[],
            "3rdgamma":[],
            "4thgamma":[],
            "5thgamma":[],
            "6thgamma":[],
            "7thgamma":[],
            "8thgamma":[],
            "9thgamma":[],
            "10thgamma":[],
            "11thgamma":[],
            "12thgamma":[],
            "13thgamma":[],
            "14thgamma":[]}
        beta_data1={
            "1stbeta":[],
            "2ndbeta":[],
            "3rdbeta":[],
            "4thbeta":[],
            "5thbeta":[],
            "6thbeta":[],
            "7thbeta":[],
            "8thbeta":[],
            "9thbeta":[],
            "10thbeta":[],
            "11thbeta":[],
            "12thbeta":[],
            "13thbeta":[],
            "14thbeta":[]}
        alpha_data1={
            "1stalpha":[],
            "2ndalpha":[],
            "3rdalpha":[],
            "4thalpha":[],
            "5thalpha":[],
            "6thalpha":[],
            "7thalpha":[],
            "8thalpha":[],
            "9thalpha":[],
            "10thalpha":[],
            "11thalpha":[],
            "12thalpha":[],
            "13thalpha":[],
            "14thalpha":[]}
        theta_data1={
            "1sttheta":[],
            "2ndtheta":[],
            "3rdtheta":[],
            "4ththeta":[],
            "5ththeta":[],
            "6ththeta":[],
            "7ththeta":[],
            "8ththeta":[],
            "9ththeta":[],
            "10ththeta":[],
            "11ththeta":[],
            "12ththeta":[],
            "13ththeta":[],
            "14ththeta":[]}
        delta_data1={
            "1stdelta":[],
            "2nddelta":[],
            "3rddelta":[],
            "4thdelta":[],
            "5thdelta":[],
            "6thdelta":[],
            "7thdelta":[],
            "8thdelta":[],
            "9thdelta":[],
            "10thdelta":[],
            "11thdelta":[],
            "12thdelta":[],
            "13thdelta":[],
            "14thdelta":[]}


        for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :

            for i in range(42):
                try:
                    user_data = pd.read_csv("25-users/"+name+str(i+1)+".txt", sep=" ", header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
                    user_label = pd.read_csv("labels/"+name+str(i+1)+".lab",header=None,names=["label"])
                except:
                    continue
                labels.append(user_label.values.tolist()[0][0])

                

                first_electrode = user_data['1st']
                second_electrode = user_data['2nd']
                third_electrode = user_data['3rd']
                fourth_electrode = user_data['4th']
                fifth_electrode = user_data['5th']
                sixth_electrode = user_data['6th']
                seventh_electrode = user_data['7th']
                eighth_electrode = user_data['8th']
                nineth_electrode = user_data['9th']
                tenth_electrode = user_data['10th']
                eleventh_electrode = user_data['11th']
                twelveth_electrode = user_data['12th']
                thirteenth_electrode = user_data['13th']
                fouteenth_electrode = user_data['14th']

                s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
                s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
                s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
                s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
                s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
                s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
                s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
                s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
                s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
                s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
                s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
                s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
                s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
                s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


                cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
                cA12, d12 = pywt.dwt(cA1, 'db4')
                cA13, d13 = pywt.dwt(cA12, 'db4')
                a14, d14 = pywt.dwt(cA13, 'db4')
                gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
                beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
                alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
                theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
                delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
                gamma_data1['1stgamma'].append(gamma_RMS1)
                beta_data1['1stbeta'].append(beta_RMS1)
                alpha_data1['1stalpha'].append(alpha_RMS1)
                theta_data1['1sttheta'].append(theta_RMS1)
                delta_data1['1stdelta'].append(delta_RMS1)

                cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
                cA22, d22 = pywt.dwt(cA2, 'db4')
                cA23, d23 = pywt.dwt(cA22, 'db4')
                a24, d24 = pywt.dwt(cA23, 'db4')
                gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
                beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
                alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
                theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
                delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
                gamma_data1['2ndgamma'].append(gamma_RMS2)
                beta_data1['2ndbeta'].append(beta_RMS2)
                alpha_data1['2ndalpha'].append(alpha_RMS2)
                theta_data1['2ndtheta'].append(theta_RMS2)
                delta_data1['2nddelta'].append(delta_RMS2)

                cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
                cA32, d32 = pywt.dwt(cA3, 'db4')
                cA33, d33 = pywt.dwt(cA32, 'db4')
                a34, d34 = pywt.dwt(cA33, 'db4')
                gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
                beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
                alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
                theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
                delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
                gamma_data1['3rdgamma'].append(gamma_RMS3)
                beta_data1['3rdbeta'].append(beta_RMS3)
                alpha_data1['3rdalpha'].append(alpha_RMS3)
                theta_data1['3rdtheta'].append(theta_RMS3)
                delta_data1['3rddelta'].append(delta_RMS3)

                cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
                cA42, d42 = pywt.dwt(cA4, 'db4')
                cA43, d43 = pywt.dwt(cA42, 'db4')
                a44, d44 = pywt.dwt(cA43, 'db4')
                gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
                beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
                alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
                theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
                delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
                gamma_data1['4thgamma'].append(gamma_RMS4)
                beta_data1['4thbeta'].append(beta_RMS4)
                alpha_data1['4thalpha'].append(alpha_RMS4)
                theta_data1['4ththeta'].append(theta_RMS4)
                delta_data1['4thdelta'].append(delta_RMS4)

                cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
                cA52, d52 = pywt.dwt(cA5, 'db4')
                cA53, d53 = pywt.dwt(cA52, 'db4')
                a54, d54 = pywt.dwt(cA53, 'db4')
                gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
                beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
                alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
                theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
                delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
                gamma_data1['5thgamma'].append(gamma_RMS5)
                beta_data1['5thbeta'].append(beta_RMS5)
                alpha_data1['5thalpha'].append(alpha_RMS5)
                theta_data1['5ththeta'].append(theta_RMS5)
                delta_data1['5thdelta'].append(delta_RMS5)

                cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
                cA62, d62 = pywt.dwt(cA6, 'db4')
                cA63, d63 = pywt.dwt(cA62, 'db4')
                a64, d64 = pywt.dwt(cA63, 'db4')
                gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
                beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
                alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
                theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
                delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
                gamma_data1['6thgamma'].append(gamma_RMS6)
                beta_data1['6thbeta'].append(beta_RMS6)
                alpha_data1['6thalpha'].append(alpha_RMS6)
                theta_data1['6ththeta'].append(theta_RMS6)
                delta_data1['6thdelta'].append(delta_RMS6)


                cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
                cA72, d72 = pywt.dwt(cA7, 'db4')
                cA73, d73 = pywt.dwt(cA72, 'db4')
                a74, d74 = pywt.dwt(cA73, 'db4')
                gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
                beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
                alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
                theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
                delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
                gamma_data1['7thgamma'].append(gamma_RMS7)
                beta_data1['7thbeta'].append(beta_RMS7)
                alpha_data1['7thalpha'].append(alpha_RMS7)
                theta_data1['7ththeta'].append(theta_RMS7)
                delta_data1['7thdelta'].append(delta_RMS7)

                cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
                cA82, d82 = pywt.dwt(cA8, 'db4')
                cA83, d83 = pywt.dwt(cA82, 'db4')
                a84, d84 = pywt.dwt(cA83, 'db4')
                gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
                beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
                alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
                theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
                delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
                gamma_data1['8thgamma'].append(gamma_RMS8)
                beta_data1['8thbeta'].append(beta_RMS8)
                alpha_data1['8thalpha'].append(alpha_RMS8)
                theta_data1['8ththeta'].append(theta_RMS8)
                delta_data1['8thdelta'].append(delta_RMS8)

                cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
                cA92, d92 = pywt.dwt(cA9, 'db4')
                cA93, d93 = pywt.dwt(cA92, 'db4')
                a94, d94 = pywt.dwt(cA93, 'db4')
                gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
                beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
                alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
                theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
                delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
                gamma_data1['9thgamma'].append(gamma_RMS9)
                beta_data1['9thbeta'].append(beta_RMS9)
                alpha_data1['9thalpha'].append(alpha_RMS9)
                theta_data1['9ththeta'].append(theta_RMS9)
                delta_data1['9thdelta'].append(delta_RMS9)

                cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
                cA102, d102 = pywt.dwt(cA10, 'db4')
                cA103, d103 = pywt.dwt(cA102, 'db4')
                a104, d104 = pywt.dwt(cA103, 'db4')
                gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
                beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
                alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
                theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
                delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
                gamma_data1['10thgamma'].append(gamma_RMS10)
                beta_data1['10thbeta'].append(beta_RMS10)
                alpha_data1['10thalpha'].append(alpha_RMS10)
                theta_data1['10ththeta'].append(theta_RMS10)
                delta_data1['10thdelta'].append(delta_RMS10)

                cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
                cA112, d112 = pywt.dwt(cA11, 'db4')
                cA113, d113 = pywt.dwt(cA112, 'db4')
                a114, d114 = pywt.dwt(cA113, 'db4')
                gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
                beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
                alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
                theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
                delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
                gamma_data1['11thgamma'].append(gamma_RMS11)
                beta_data1['11thbeta'].append(beta_RMS11)
                alpha_data1['11thalpha'].append(alpha_RMS11)
                theta_data1['11ththeta'].append(theta_RMS11)
                delta_data1['11thdelta'].append(delta_RMS11)

                cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
                cA122, d122 = pywt.dwt(cA12, 'db4')
                cA123, d123 = pywt.dwt(cA122, 'db4')
                a124, d124 = pywt.dwt(cA123, 'db4')
                gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
                beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
                alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
                theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
                delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
                gamma_data1['12thgamma'].append(gamma_RMS12)
                beta_data1['12thbeta'].append(beta_RMS12)
                alpha_data1['12thalpha'].append(alpha_RMS12)
                theta_data1['12ththeta'].append(theta_RMS12)
                delta_data1['12thdelta'].append(delta_RMS12)

                cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
                cA132, d132 = pywt.dwt(cA13, 'db4')
                cA133, d133 = pywt.dwt(cA132, 'db4')
                a134, d134 = pywt.dwt(cA133, 'db4')
                gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
                beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
                alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
                theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
                delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
                gamma_data1['13thgamma'].append(gamma_RMS13)
                beta_data1['13thbeta'].append(beta_RMS13)
                alpha_data1['13thalpha'].append(alpha_RMS13)
                theta_data1['13ththeta'].append(theta_RMS13)
                delta_data1['13thdelta'].append(delta_RMS13)

                cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
                cA142, d142 = pywt.dwt(cA14, 'db4')
                cA143, d143 = pywt.dwt(cA142, 'db4')
                a144, d144 = pywt.dwt(cA143, 'db4')
                gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
                beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
                alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
                theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
                delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
                gamma_data1['14thgamma'].append(gamma_RMS14)
                beta_data1['14thbeta'].append(beta_RMS14)
                alpha_data1['14thalpha'].append(alpha_RMS14)
                theta_data1['14ththeta'].append(theta_RMS14)
                delta_data1['14thdelta'].append(delta_RMS14)

            merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
            merged= pd.DataFrame.from_dict(merged)
            gamma_data1=pd.DataFrame.from_dict(gamma_data1)
            beta_data1=pd.DataFrame.from_dict(beta_data1)
            alpha_data1=pd.DataFrame.from_dict(alpha_data1)
            theta_data1=pd.DataFrame.from_dict(theta_data1)
            delta_data1=pd.DataFrame.from_dict(delta_data1)

            gamma_data1.apply(lambda row : carf(row), axis = 1)
            beta_data1.apply(lambda row : carf(row), axis = 1)
            alpha_data1.apply(lambda row : carf(row), axis = 1)
            theta_data1.apply(lambda row : carf(row), axis = 1)
            delta_data1.apply(lambda row : carf(row), axis = 1)
            merged.apply(lambda row : carf(row), axis = 1)

            standard_gamma = StandardScaler().fit_transform(gamma_data1) 
            normalised_gamma = pd.DataFrame(standard_gamma)
            pca_gamma = PCA(n_components=0.9)
            principalComponents_gamma = pca_gamma.fit_transform(standard_gamma)
            gamma_data1 = pd.DataFrame(data = principalComponents_gamma)
            data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.1,stratify=labels)

            standard_beta = StandardScaler().fit_transform(beta_data1) 
            normalised_beta = pd.DataFrame(standard_beta)
            pca_beta = PCA(n_components=0.9)
            principalComponents_beta = pca_beta.fit_transform(standard_beta)
            beta_data1 = pd.DataFrame(data = principalComponents_beta)
            data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.1,stratify=labels)

            standard_alpha = StandardScaler().fit_transform(alpha_data1) 
            normalised_alpha = pd.DataFrame(standard_alpha)
            pca_alpha = PCA(n_components=0.9)
            principalComponents_alpha = pca_alpha.fit_transform(standard_alpha)
            alpha_data1 = pd.DataFrame(data = principalComponents_alpha)
            data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.1,stratify=labels)

            standard_theta = StandardScaler().fit_transform(theta_data1) 
            normalised_theta = pd.DataFrame(standard_theta)
            pca_theta = PCA(n_components=0.9)
            principalComponents_theta = pca_theta.fit_transform(standard_theta)
            theta_data1 = pd.DataFrame(data = principalComponents_theta)
            data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.1,stratify=labels)


            standard_delta = StandardScaler().fit_transform(delta_data1) 
            normalised_delta = pd.DataFrame(standard_delta)
            pca_delta = PCA(n_components=0.9)
            principalComponents_delta = pca_delta.fit_transform(standard_delta)
            delta_data1 = pd.DataFrame(data = principalComponents_delta)
            data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.1,stratify=labels)

            standard_merged = StandardScaler().fit_transform(merged) 
            normalised_merged = pd.DataFrame(standard_merged)
            pca_merged = PCA(n_components=0.9)
            principalComponents_merged = pca_merged.fit_transform(standard_merged)
            merged = pd.DataFrame(data = principalComponents_merged)
            data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.1,stratify=labels)

            dtree1 = RandomForestClassifier(n_estimators=20000)
            dtree1.fit(data_train_gamma,label_train_gamma)
            predictions_gamma = dtree1.predict(data_test_gamma)
            results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

            dtree2 = RandomForestClassifier(n_estimators=20000)
            dtree2.fit(data_train_beta,label_train_beta)
            predictions_beta = dtree2.predict(data_test_beta)
            results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

            dtree3 = RandomForestClassifier(n_estimators=20000)
            dtree3.fit(data_train_alpha,label_train_alpha)
            predictions_alpha = dtree3.predict(data_test_alpha)
            results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

            dtree4 = RandomForestClassifier(n_estimators=20000)
            dtree4.fit(data_train_theta,label_train_theta)
            predictions_theta = dtree4.predict(data_test_theta)
            results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

            dtree5 = RandomForestClassifier(n_estimators=20000)
            dtree5.fit(data_train_delta,label_train_delta)
            predictions_delta = dtree5.predict(data_test_delta)
            results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

            dtree6 = RandomForestClassifier(n_estimators=20000)
            dtree6.fit(data_train_merged,label_train_merged)
            predictions_mereged = dtree6.predict(data_test_merged)
            results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))

# %%
mean_gama=0.0
mean_beta=0.0
mean_alpha=0.0
mean_theta=0.0
mean_delta=0.0
mean_merged=0.0

for i in results['result_gamma'] :
    mean_gama+=i['macro avg']['f1-score']
for i in results['result_beta'] :
    mean_beta+=i['macro avg']['f1-score']
for i in results['result_alpha'] :
    mean_alpha+=i['macro avg']['f1-score']
for i in results['result_theta'] :
    mean_theta+=i['macro avg']['f1-score']
for i in results['result_delta'] :
    mean_delta+=i['macro avg']['f1-score']
for i in results['result_merged'] :
    mean_merged+=i['macro avg']['f1-score']
print('mean gamma=',mean_gama/25,'mean beta=',mean_beta/25,'mean alpha =',mean_alpha/25,'mean theta =',mean_theta/25,'mean delta=',mean_delta/25,'mean combined =',mean_merged/25)

# %%
results = {
    'result_gamma':[],
    'result_beta':[],
    'result_theta':[],
    'result_alpha':[],
    'result_delta':[],
    'result_merged':[],
}
for i in range(25):
        labels=[]
        gamma_data1={
            "1stgamma":[],
            "2ndgamma":[],
            "3rdgamma":[],
            "4thgamma":[],
            "5thgamma":[],
            "6thgamma":[],
            "7thgamma":[],
            "8thgamma":[],
            "9thgamma":[],
            "10thgamma":[],
            "11thgamma":[],
            "12thgamma":[],
            "13thgamma":[],
            "14thgamma":[]}
        beta_data1={
            "1stbeta":[],
            "2ndbeta":[],
            "3rdbeta":[],
            "4thbeta":[],
            "5thbeta":[],
            "6thbeta":[],
            "7thbeta":[],
            "8thbeta":[],
            "9thbeta":[],
            "10thbeta":[],
            "11thbeta":[],
            "12thbeta":[],
            "13thbeta":[],
            "14thbeta":[]}
        alpha_data1={
            "1stalpha":[],
            "2ndalpha":[],
            "3rdalpha":[],
            "4thalpha":[],
            "5thalpha":[],
            "6thalpha":[],
            "7thalpha":[],
            "8thalpha":[],
            "9thalpha":[],
            "10thalpha":[],
            "11thalpha":[],
            "12thalpha":[],
            "13thalpha":[],
            "14thalpha":[]}
        theta_data1={
            "1sttheta":[],
            "2ndtheta":[],
            "3rdtheta":[],
            "4ththeta":[],
            "5ththeta":[],
            "6ththeta":[],
            "7ththeta":[],
            "8ththeta":[],
            "9ththeta":[],
            "10ththeta":[],
            "11ththeta":[],
            "12ththeta":[],
            "13ththeta":[],
            "14ththeta":[]}
        delta_data1={
            "1stdelta":[],
            "2nddelta":[],
            "3rddelta":[],
            "4thdelta":[],
            "5thdelta":[],
            "6thdelta":[],
            "7thdelta":[],
            "8thdelta":[],
            "9thdelta":[],
            "10thdelta":[],
            "11thdelta":[],
            "12thdelta":[],
            "13thdelta":[],
            "14thdelta":[]}


        for name in ['Abhishek_','Ankur_sir_','Gautam_','Gautam_123_','Girvar_yadav_','Kishore_babu_','mahendra_','Mohit_','pawan_sahu_','pradeep_','Rajesh_el_','rajkumar_','Ravi_baba_','Ravi_ph_','Rockysingh_','Rupak_','Sachin_','Sandeep_','Soumendu_','Suraj_sir_','taufiq_','Veerpal_','Vijay_','Vipin_1_','Viraj_1_'] :

            for i in range(42):
                try:
                    user_data = pd.read_csv("25-users/"+name+str(i+1)+".txt", sep=" ", header=None,names=["1st", "2nd", "3rd", "4th","5th","6th","7th","8th","9th","10th","11th","12th","13th","14th"])
                    user_label = pd.read_csv("labels/"+name+str(i+1)+".lab",header=None,names=["label"])
                except:
                    continue
                labels.append(user_label.values.tolist()[0][0])

               

                first_electrode = user_data['1st']
                second_electrode = user_data['2nd']
                third_electrode = user_data['3rd']
                fourth_electrode = user_data['4th']
                fifth_electrode = user_data['5th']
                sixth_electrode = user_data['6th']
                seventh_electrode = user_data['7th']
                eighth_electrode = user_data['8th']
                nineth_electrode = user_data['9th']
                tenth_electrode = user_data['10th']
                eleventh_electrode = user_data['11th']
                twelveth_electrode = user_data['12th']
                thirteenth_electrode = user_data['13th']
                fouteenth_electrode = user_data['14th']

                s_golay_filtered_signal1 =scipy.signal.savgol_filter(first_electrode,5,2)
                s_golay_filtered_signal2 =scipy.signal.savgol_filter(second_electrode,5,2)
                s_golay_filtered_signal3 =scipy.signal.savgol_filter(third_electrode,5,2)
                s_golay_filtered_signal4 =scipy.signal.savgol_filter(fourth_electrode,5,2)
                s_golay_filtered_signal5 =scipy.signal.savgol_filter(fifth_electrode,5,2)
                s_golay_filtered_signal6 =scipy.signal.savgol_filter(sixth_electrode,5,2)
                s_golay_filtered_signal7 =scipy.signal.savgol_filter(seventh_electrode,5,2)
                s_golay_filtered_signal8 =scipy.signal.savgol_filter(eighth_electrode,5,2)
                s_golay_filtered_signal9 =scipy.signal.savgol_filter(nineth_electrode,5,2)
                s_golay_filtered_signal10 =scipy.signal.savgol_filter(tenth_electrode,5,2)
                s_golay_filtered_signal11 =scipy.signal.savgol_filter(eleventh_electrode,5,2)
                s_golay_filtered_signal12 =scipy.signal.savgol_filter(twelveth_electrode,5,2)
                s_golay_filtered_signal13 =scipy.signal.savgol_filter(thirteenth_electrode,5,2)
                s_golay_filtered_signal14 =scipy.signal.savgol_filter(fouteenth_electrode,5,2)


                cA1, d11 = pywt.dwt(s_golay_filtered_signal1, 'db4')
                cA12, d12 = pywt.dwt(cA1, 'db4')
                cA13, d13 = pywt.dwt(cA12, 'db4')
                a14, d14 = pywt.dwt(cA13, 'db4')
                gamma_RMS1 = np.sqrt(sum([d11[i]**2 for i in range(d11.size)])/d11.size)
                beta_RMS1 = np.sqrt(sum([d12[i]**2 for i in range(d12.size)])/d12.size)
                alpha_RMS1 = np.sqrt(sum([d13[i]**2 for i in range(d13.size)])/d13.size)
                theta_RMS1 = np.sqrt(sum([d14[i]**2 for i in range(d14.size)])/d14.size)
                delta_RMS1 = np.sqrt(sum([a14[i]**2 for i in range(a14.size)])/a14.size)
                gamma_data1['1stgamma'].append(gamma_RMS1)
                beta_data1['1stbeta'].append(beta_RMS1)
                alpha_data1['1stalpha'].append(alpha_RMS1)
                theta_data1['1sttheta'].append(theta_RMS1)
                delta_data1['1stdelta'].append(delta_RMS1)

                cA2, d21 = pywt.dwt(s_golay_filtered_signal2, 'db4')
                cA22, d22 = pywt.dwt(cA2, 'db4')
                cA23, d23 = pywt.dwt(cA22, 'db4')
                a24, d24 = pywt.dwt(cA23, 'db4')
                gamma_RMS2 = np.sqrt(sum([d21[i]**2 for i in range(d21.size)])/d21.size)
                beta_RMS2 = np.sqrt(sum([d22[i]**2 for i in range(d22.size)])/d22.size)
                alpha_RMS2 = np.sqrt(sum([d23[i]**2 for i in range(d23.size)])/d23.size)
                theta_RMS2 = np.sqrt(sum([d24[i]**2 for i in range(d24.size)])/d24.size)
                delta_RMS2 = np.sqrt(sum([a24[i]**2 for i in range(a24.size)])/a24.size)
                gamma_data1['2ndgamma'].append(gamma_RMS2)
                beta_data1['2ndbeta'].append(beta_RMS2)
                alpha_data1['2ndalpha'].append(alpha_RMS2)
                theta_data1['2ndtheta'].append(theta_RMS2)
                delta_data1['2nddelta'].append(delta_RMS2)

                cA3, d31 = pywt.dwt(s_golay_filtered_signal3, 'db4')
                cA32, d32 = pywt.dwt(cA3, 'db4')
                cA33, d33 = pywt.dwt(cA32, 'db4')
                a34, d34 = pywt.dwt(cA33, 'db4')
                gamma_RMS3 = np.sqrt(sum([d31[i]**2 for i in range(d31.size)])/d31.size)
                beta_RMS3 = np.sqrt(sum([d32[i]**2 for i in range(d32.size)])/d32.size)
                alpha_RMS3 = np.sqrt(sum([d33[i]**2 for i in range(d33.size)])/d33.size)
                theta_RMS3 = np.sqrt(sum([d34[i]**2 for i in range(d34.size)])/d34.size)
                delta_RMS3 = np.sqrt(sum([a34[i]**2 for i in range(a34.size)])/a34.size)
                gamma_data1['3rdgamma'].append(gamma_RMS3)
                beta_data1['3rdbeta'].append(beta_RMS3)
                alpha_data1['3rdalpha'].append(alpha_RMS3)
                theta_data1['3rdtheta'].append(theta_RMS3)
                delta_data1['3rddelta'].append(delta_RMS3)

                cA4, d41 = pywt.dwt(s_golay_filtered_signal4, 'db4')
                cA42, d42 = pywt.dwt(cA4, 'db4')
                cA43, d43 = pywt.dwt(cA42, 'db4')
                a44, d44 = pywt.dwt(cA43, 'db4')
                gamma_RMS4 = np.sqrt(sum([d41[i]**2 for i in range(d41.size)])/d41.size)
                beta_RMS4 = np.sqrt(sum([d42[i]**2 for i in range(d42.size)])/d42.size)
                alpha_RMS4 = np.sqrt(sum([d43[i]**2 for i in range(d43.size)])/d43.size)
                theta_RMS4 = np.sqrt(sum([d44[i]**2 for i in range(d44.size)])/d44.size)
                delta_RMS4 = np.sqrt(sum([a44[i]**2 for i in range(a44.size)])/a44.size)
                gamma_data1['4thgamma'].append(gamma_RMS4)
                beta_data1['4thbeta'].append(beta_RMS4)
                alpha_data1['4thalpha'].append(alpha_RMS4)
                theta_data1['4ththeta'].append(theta_RMS4)
                delta_data1['4thdelta'].append(delta_RMS4)

                cA5, d51 = pywt.dwt(s_golay_filtered_signal5, 'db4')
                cA52, d52 = pywt.dwt(cA5, 'db4')
                cA53, d53 = pywt.dwt(cA52, 'db4')
                a54, d54 = pywt.dwt(cA53, 'db4')
                gamma_RMS5 = np.sqrt(sum([d51[i]**2 for i in range(d51.size)])/d51.size)
                beta_RMS5 = np.sqrt(sum([d52[i]**2 for i in range(d52.size)])/d52.size)
                alpha_RMS5 = np.sqrt(sum([d53[i]**2 for i in range(d53.size)])/d53.size)
                theta_RMS5 = np.sqrt(sum([d54[i]**2 for i in range(d54.size)])/d54.size)
                delta_RMS5 = np.sqrt(sum([a54[i]**2 for i in range(a54.size)])/a54.size)
                gamma_data1['5thgamma'].append(gamma_RMS5)
                beta_data1['5thbeta'].append(beta_RMS5)
                alpha_data1['5thalpha'].append(alpha_RMS5)
                theta_data1['5ththeta'].append(theta_RMS5)
                delta_data1['5thdelta'].append(delta_RMS5)

                cA6, d61 = pywt.dwt(s_golay_filtered_signal6, 'db4')
                cA62, d62 = pywt.dwt(cA6, 'db4')
                cA63, d63 = pywt.dwt(cA62, 'db4')
                a64, d64 = pywt.dwt(cA63, 'db4')
                gamma_RMS6 = np.sqrt(sum([d61[i]**2 for i in range(d61.size)])/d61.size)
                beta_RMS6 = np.sqrt(sum([d62[i]**2 for i in range(d62.size)])/d62.size)
                alpha_RMS6 = np.sqrt(sum([d63[i]**2 for i in range(d63.size)])/d63.size)
                theta_RMS6 = np.sqrt(sum([d64[i]**2 for i in range(d64.size)])/d64.size)
                delta_RMS6 = np.sqrt(sum([a64[i]**2 for i in range(a64.size)])/a64.size)
                gamma_data1['6thgamma'].append(gamma_RMS6)
                beta_data1['6thbeta'].append(beta_RMS6)
                alpha_data1['6thalpha'].append(alpha_RMS6)
                theta_data1['6ththeta'].append(theta_RMS6)
                delta_data1['6thdelta'].append(delta_RMS6)


                cA7, d71 = pywt.dwt(s_golay_filtered_signal7, 'db4')
                cA72, d72 = pywt.dwt(cA7, 'db4')
                cA73, d73 = pywt.dwt(cA72, 'db4')
                a74, d74 = pywt.dwt(cA73, 'db4')
                gamma_RMS7 = np.sqrt(sum([d71[i]**2 for i in range(d71.size)])/d71.size)
                beta_RMS7 = np.sqrt(sum([d72[i]**2 for i in range(d72.size)])/d72.size)
                alpha_RMS7 = np.sqrt(sum([d73[i]**2 for i in range(d73.size)])/d73.size)
                theta_RMS7 = np.sqrt(sum([d74[i]**2 for i in range(d74.size)])/d74.size)
                delta_RMS7 = np.sqrt(sum([a74[i]**2 for i in range(a74.size)])/a74.size)
                gamma_data1['7thgamma'].append(gamma_RMS7)
                beta_data1['7thbeta'].append(beta_RMS7)
                alpha_data1['7thalpha'].append(alpha_RMS7)
                theta_data1['7ththeta'].append(theta_RMS7)
                delta_data1['7thdelta'].append(delta_RMS7)

                cA8, d81 = pywt.dwt(s_golay_filtered_signal8, 'db4')
                cA82, d82 = pywt.dwt(cA8, 'db4')
                cA83, d83 = pywt.dwt(cA82, 'db4')
                a84, d84 = pywt.dwt(cA83, 'db4')
                gamma_RMS8 = np.sqrt(sum([d81[i]**2 for i in range(d81.size)])/d81.size)
                beta_RMS8 = np.sqrt(sum([d82[i]**2 for i in range(d82.size)])/d82.size)
                alpha_RMS8 = np.sqrt(sum([d83[i]**2 for i in range(d83.size)])/d83.size)
                theta_RMS8 = np.sqrt(sum([d84[i]**2 for i in range(d84.size)])/d84.size)
                delta_RMS8 = np.sqrt(sum([a84[i]**2 for i in range(a84.size)])/a84.size)
                gamma_data1['8thgamma'].append(gamma_RMS8)
                beta_data1['8thbeta'].append(beta_RMS8)
                alpha_data1['8thalpha'].append(alpha_RMS8)
                theta_data1['8ththeta'].append(theta_RMS8)
                delta_data1['8thdelta'].append(delta_RMS8)

                cA9, d91 = pywt.dwt(s_golay_filtered_signal9, 'db4')
                cA92, d92 = pywt.dwt(cA9, 'db4')
                cA93, d93 = pywt.dwt(cA92, 'db4')
                a94, d94 = pywt.dwt(cA93, 'db4')
                gamma_RMS9 = np.sqrt(sum([d91[i]**2 for i in range(d91.size)])/d91.size)
                beta_RMS9 = np.sqrt(sum([d92[i]**2 for i in range(d92.size)])/d92.size)
                alpha_RMS9 = np.sqrt(sum([d93[i]**2 for i in range(d93.size)])/d93.size)
                theta_RMS9 = np.sqrt(sum([d94[i]**2 for i in range(d94.size)])/d94.size)
                delta_RMS9 = np.sqrt(sum([a94[i]**2 for i in range(a94.size)])/a94.size)
                gamma_data1['9thgamma'].append(gamma_RMS9)
                beta_data1['9thbeta'].append(beta_RMS9)
                alpha_data1['9thalpha'].append(alpha_RMS9)
                theta_data1['9ththeta'].append(theta_RMS9)
                delta_data1['9thdelta'].append(delta_RMS9)

                cA10, d101 = pywt.dwt(s_golay_filtered_signal10, 'db4')
                cA102, d102 = pywt.dwt(cA10, 'db4')
                cA103, d103 = pywt.dwt(cA102, 'db4')
                a104, d104 = pywt.dwt(cA103, 'db4')
                gamma_RMS10 = np.sqrt(sum([d101[i]**2 for i in range(d101.size)])/d101.size)
                beta_RMS10 = np.sqrt(sum([d102[i]**2 for i in range(d102.size)])/d102.size)
                alpha_RMS10 = np.sqrt(sum([d103[i]**2 for i in range(d103.size)])/d103.size)
                theta_RMS10 = np.sqrt(sum([d104[i]**2 for i in range(d104.size)])/d104.size)
                delta_RMS10 = np.sqrt(sum([a104[i]**2 for i in range(a104.size)])/a104.size)
                gamma_data1['10thgamma'].append(gamma_RMS10)
                beta_data1['10thbeta'].append(beta_RMS10)
                alpha_data1['10thalpha'].append(alpha_RMS10)
                theta_data1['10ththeta'].append(theta_RMS10)
                delta_data1['10thdelta'].append(delta_RMS10)

                cA11, d111 = pywt.dwt(s_golay_filtered_signal11, 'db4')
                cA112, d112 = pywt.dwt(cA11, 'db4')
                cA113, d113 = pywt.dwt(cA112, 'db4')
                a114, d114 = pywt.dwt(cA113, 'db4')
                gamma_RMS11 = np.sqrt(sum([d111[i]**2 for i in range(d111.size)])/d111.size)
                beta_RMS11 = np.sqrt(sum([d112[i]**2 for i in range(d112.size)])/d112.size)
                alpha_RMS11 = np.sqrt(sum([d113[i]**2 for i in range(d113.size)])/d113.size)
                theta_RMS11 = np.sqrt(sum([d114[i]**2 for i in range(d114.size)])/d114.size)
                delta_RMS11 = np.sqrt(sum([a114[i]**2 for i in range(a114.size)])/a114.size)
                gamma_data1['11thgamma'].append(gamma_RMS11)
                beta_data1['11thbeta'].append(beta_RMS11)
                alpha_data1['11thalpha'].append(alpha_RMS11)
                theta_data1['11ththeta'].append(theta_RMS11)
                delta_data1['11thdelta'].append(delta_RMS11)

                cA12, d121 = pywt.dwt(s_golay_filtered_signal12, 'db4')
                cA122, d122 = pywt.dwt(cA12, 'db4')
                cA123, d123 = pywt.dwt(cA122, 'db4')
                a124, d124 = pywt.dwt(cA123, 'db4')
                gamma_RMS12 = np.sqrt(sum([d121[i]**2 for i in range(d121.size)])/d11.size)
                beta_RMS12 = np.sqrt(sum([d122[i]**2 for i in range(d122.size)])/d12.size)
                alpha_RMS12 = np.sqrt(sum([d123[i]**2 for i in range(d123.size)])/d13.size)
                theta_RMS12 = np.sqrt(sum([d124[i]**2 for i in range(d124.size)])/d14.size)
                delta_RMS12 = np.sqrt(sum([a124[i]**2 for i in range(a124.size)])/a14.size)
                gamma_data1['12thgamma'].append(gamma_RMS12)
                beta_data1['12thbeta'].append(beta_RMS12)
                alpha_data1['12thalpha'].append(alpha_RMS12)
                theta_data1['12ththeta'].append(theta_RMS12)
                delta_data1['12thdelta'].append(delta_RMS12)

                cA13, d131 = pywt.dwt(s_golay_filtered_signal13, 'db4')
                cA132, d132 = pywt.dwt(cA13, 'db4')
                cA133, d133 = pywt.dwt(cA132, 'db4')
                a134, d134 = pywt.dwt(cA133, 'db4')
                gamma_RMS13 = np.sqrt(sum([d131[i]**2 for i in range(d131.size)])/d11.size)
                beta_RMS13 = np.sqrt(sum([d132[i]**2 for i in range(d132.size)])/d12.size)
                alpha_RMS13 = np.sqrt(sum([d133[i]**2 for i in range(d133.size)])/d13.size)
                theta_RMS13 = np.sqrt(sum([d134[i]**2 for i in range(d134.size)])/d14.size)
                delta_RMS13 = np.sqrt(sum([a134[i]**2 for i in range(a134.size)])/a14.size)
                gamma_data1['13thgamma'].append(gamma_RMS13)
                beta_data1['13thbeta'].append(beta_RMS13)
                alpha_data1['13thalpha'].append(alpha_RMS13)
                theta_data1['13ththeta'].append(theta_RMS13)
                delta_data1['13thdelta'].append(delta_RMS13)

                cA14, d141 = pywt.dwt(s_golay_filtered_signal14, 'db4')
                cA142, d142 = pywt.dwt(cA14, 'db4')
                cA143, d143 = pywt.dwt(cA142, 'db4')
                a144, d144 = pywt.dwt(cA143, 'db4')
                gamma_RMS14 = np.sqrt(sum([d141[i]**2 for i in range(d141.size)])/d141.size)
                beta_RMS14 = np.sqrt(sum([d142[i]**2 for i in range(d142.size)])/d142.size)
                alpha_RMS14 = np.sqrt(sum([d143[i]**2 for i in range(d143.size)])/d143.size)
                theta_RMS14 = np.sqrt(sum([d144[i]**2 for i in range(d144.size)])/d144.size)
                delta_RMS14 = np.sqrt(sum([a144[i]**2 for i in range(a144.size)])/a144.size)
                gamma_data1['14thgamma'].append(gamma_RMS14)
                beta_data1['14thbeta'].append(beta_RMS14)
                alpha_data1['14thalpha'].append(alpha_RMS14)
                theta_data1['14ththeta'].append(theta_RMS14)
                delta_data1['14thdelta'].append(delta_RMS14)

            merged = {**gamma_data1, **beta_data1,**alpha_data1,**theta_data1,**delta_data1}
            merged= pd.DataFrame.from_dict(merged)
            gamma_data1=pd.DataFrame.from_dict(gamma_data1)
            beta_data1=pd.DataFrame.from_dict(beta_data1)
            alpha_data1=pd.DataFrame.from_dict(alpha_data1)
            theta_data1=pd.DataFrame.from_dict(theta_data1)
            delta_data1=pd.DataFrame.from_dict(delta_data1)
            gamma_data1.apply(lambda row : carf(row), axis = 1)
            beta_data1.apply(lambda row : carf(row), axis = 1)
            alpha_data1.apply(lambda row : carf(row), axis = 1)
            theta_data1.apply(lambda row : carf(row), axis = 1)
            delta_data1.apply(lambda row : carf(row), axis = 1)
            merged.apply(lambda row : carf(row), axis = 1)

            pca_gamma = PCA(n_components=0.9)
            principalComponents_gamma = pca_gamma.fit_transform(gamma_data1)
            gamma_data1 = pd.DataFrame(data = principalComponents_gamma)
            data_train_gamma, data_test_gamma, label_train_gamma, label_test_gamma = train_test_split(gamma_data1, labels, test_size=0.1,stratify=labels)


            pca_beta = PCA(n_components=0.9)
            principalComponents_beta = pca_beta.fit_transform(beta_data1)
            beta_data1 = pd.DataFrame(data = principalComponents_beta)
            data_train_beta, data_test_beta, label_train_beta, label_test_beta = train_test_split(beta_data1, labels, test_size=0.1,stratify=labels)


            pca_alpha = PCA(n_components=0.9)
            principalComponents_alpha = pca_alpha.fit_transform(alpha_data1)
            alpha_data1 = pd.DataFrame(data = principalComponents_alpha)
            data_train_alpha, data_test_alpha, label_train_alpha, label_test_alpha = train_test_split(alpha_data1, labels, test_size=0.1,stratify=labels)


            pca_theta = PCA(n_components=0.9)
            principalComponents_theta = pca_theta.fit_transform(theta_data1)
            theta_data1 = pd.DataFrame(data = principalComponents_theta)
            data_train_theta, data_test_theta, label_train_theta, label_test_theta = train_test_split(theta_data1, labels, test_size=0.1,stratify=labels)



            pca_delta = PCA(n_components=0.9)
            principalComponents_delta = pca_delta.fit_transform(delta_data1)
            delta_data1 = pd.DataFrame(data = principalComponents_delta)
            data_train_delta, data_test_delta, label_train_delta, label_test_delta = train_test_split(delta_data1, labels, test_size=0.1,stratify=labels)


            pca_merged = PCA(n_components=0.9)
            principalComponents_merged = pca_merged.fit_transform(merged)
            merged = pd.DataFrame(data = principalComponents_merged)
            data_train_merged, data_test_merged, label_train_merged, label_merged = train_test_split(merged, labels, test_size=0.1,stratify=labels)

            dtree1 = RandomForestClassifier(n_estimators=20000)
            dtree1.fit(data_train_gamma,label_train_gamma)
            predictions_gamma = dtree1.predict(data_test_gamma)
            results['result_gamma'].append(classification_report(label_test_gamma,predictions_gamma,output_dict=True))

            dtree2 = RandomForestClassifier(n_estimators=20000)
            dtree2.fit(data_train_beta,label_train_beta)
            predictions_beta = dtree2.predict(data_test_beta)
            results['result_beta'].append(classification_report(label_test_beta,predictions_beta,output_dict=True))

            dtree3 = RandomForestClassifier(n_estimators=20000)
            dtree3.fit(data_train_alpha,label_train_alpha)
            predictions_alpha = dtree3.predict(data_test_alpha)
            results['result_alpha'].append(classification_report(label_test_alpha,predictions_alpha,output_dict=True))

            dtree4 = RandomForestClassifier(n_estimators=20000)
            dtree4.fit(data_train_theta,label_train_theta)
            predictions_theta = dtree4.predict(data_test_theta)
            results['result_theta'].append(classification_report(label_test_theta,predictions_theta,output_dict=True))

            dtree5 = RandomForestClassifier(n_estimators=20000)
            dtree5.fit(data_train_delta,label_train_delta)
            predictions_delta = dtree5.predict(data_test_delta)
            results['result_delta'].append(classification_report(label_test_delta,predictions_delta,output_dict=True))

            dtree6 = RandomForestClassifier(n_estimators=20000)
            dtree6.fit(data_train_merged,label_train_merged)
            predictions_mereged = dtree6.predict(data_test_merged)
            results['result_merged'].append(classification_report(label_merged,predictions_mereged,output_dict=True))

# %%
mean_gama=0.0
mean_beta=0.0
mean_alpha=0.0
mean_theta=0.0
mean_delta=0.0
mean_merged=0.0

for i in results['result_gamma'] :
    mean_gama+=i['macro avg']['f1-score']
for i in results['result_beta'] :
    mean_beta+=i['macro avg']['f1-score']
for i in results['result_alpha'] :
    mean_alpha+=i['macro avg']['f1-score']
for i in results['result_theta'] :
    mean_theta+=i['macro avg']['f1-score']
for i in results['result_delta'] :
    mean_delta+=i['macro avg']['f1-score']
for i in results['result_merged'] :
    mean_merged+=i['macro avg']['f1-score']
print('mean gamma=',mean_gama/25,'mean beta=',mean_beta/25,'mean alpha =',mean_alpha/25,'mean theta =',mean_theta/25,'mean delta=',mean_delta/25,'mean combined =',mean_merged/25)
